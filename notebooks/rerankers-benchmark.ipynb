# %% [markdown]
# ### Benchmark de rerankers / tailles de fragment (chunk size)
# **Problème:**<br>
# Les retrievers ont du mal à sélectionner les documents pertinents pour des questions complexes, non formulées avec suffisament de détails, et dont le contexte nécessaire pour produire une réponse s'étale sur plusieurs pages<br>
#
# **Cas d'étude:**<br>
# Basé sur le PP Mahakam project, AAP dépot sur site<br>
# La question n°5 <i>"Context, environment, project rationale and challenges"</i> recouvre des enjeux institutionnels, socio-économiques, de biodiversité ... qui sont impossibles à déduire de façon automatique de la question de départ telle que présentée ci dessus<br>
#
# **Objectifs:**<br>
# La question ci-dessus trouve ses réponses sur les pages 9 à 18<br>
# Nous allons tenter d'élargir la plage de sélection des documents à 30, puis les analyser avec différentes approches de reranking afin de voir quelle proportion de bonnes pages nous pouvons atteindre sur la première moitiée de la liste (10 à 15 premiers documents)
#
# **Méthode:**
# 1. Créer différentes bases de documents avec des tailles de fragments allant de 500 à 6000 caractères
# 2. Créer des retrievers basés sur de la recherche sémantique (mmr), par fréquence de mots (tfidf) et par lexique
# 3. Extraire les fragments les plus pertinents avec les méthodes natives des retrievers
# 4. Evaluer ces documents avec 4 types de retrievers par rapport à la question de l'AAP:
#     * Le score calculé indique dans quelle mesure le document permet de répondre à cette question

# %% [markdown]
# ### Librairies

# %%
# ! pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain pypdf

# %% [markdown]
# Variables d'nvironement

# %%
import dotenv

dotenv.load_dotenv("/home/chougar/Documents/GitHub/Formation_datascientest/DL-NLP/.env")
# Out:
# True

# %%
# libraries and models setup
import os
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma, FAISS
from langchain.retrievers import SelfQueryRetriever
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_ollama.llms import OllamaLLM
from time import time as timing

# %%
# model_qa_name="qwen2.5:3b"
# model_qa_name="mistral:latest"
# model_qa_name="deepseek-r1:8b"
#model_qa_name="hf.co/bartowski/Falcon3-7B-Instruct-GGUF:Q4_0"
# model_qa_alias="falcon3-7b-mamba"
# llm_qa = OllamaLLM(model=model_qa_name, temperature=0.2)

model_qa_name="gpt-4o-mini"
model_qa_alias=model_qa_name
llm_qa = ChatOpenAI(model_name=model_qa_name, temperature=0.2)



# Embeddings model definition
# model_emb_name='text-embedding-ada-002'
model_emb_name="text-embedding-3-small"
embedding_model = OpenAIEmbeddings(model=model_emb_name)

# %% [markdown]
# #### Step 1: charger le PP

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document

# Load the PDF
pdf_file_path = './data/PROJECT DOCUMENT MAHAKAM 2023-2025_balise.pdf'
loader = PyPDFLoader(pdf_file_path)
pages = loader.load()

# nettoyage
bruits=["Planète Urgence | FOREST Programme"]
for doc in pages:
    for bruit in bruits:
        if bruit in doc.page_content:
            doc.page_content=doc.page_content.replace(bruit, "")
# del empty docs
pages = [doc for doc in pages if len(doc.page_content)>0]

# Combine all pages into a single text blob while tracking page numbers
full_text = ""
page_mapping = []  # Maps each character in `full_text` to its page number
for page in pages:
    page_content = page.page_content
    full_text += page_content + " "  # Add a space between pages
    page_mapping.extend([page.metadata['page']] * len(page_content))  # Map characters to page number
    page_mapping.extend([None] * 1)  # Add a space between pages (optional)

# %%
def split_raw_text(chunk_size, full_text=full_text):
    # Use RecursiveCharacterTextSplitter to split the text
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,  # Desired chunk size
        chunk_overlap=chunk_size*0.2,  # Overlap between chunks
        length_function=len,  # Function to measure chunk size
    )

    # Split the text into chunks
    text_chunks = text_splitter.split_text(full_text)

    # Create new Document objects for each chunk with precise page numbers
    chunked_documents = []
    start_idx = 0
    for chunk in text_chunks:
        end_idx = start_idx + len(chunk)
        
        # Get the page numbers for this chunk
        chunk_pages = set(page_mapping[int(start_idx):int(end_idx)])  # Use set to get unique page numbers
        chunk_pages.discard(None)  # Remove None values (spaces between pages)
        
        # Create a new Document object with the chunk and metadata
        new_doc = Document(
            page_content=chunk,
            metadata={
                "source": pdf_file_path,
                "pages": sorted(chunk_pages),  # List of pages contributing to this chunk
            },
        )
        chunked_documents.append(new_doc)
        
        # Update the start index for the next chunk
        start_idx = end_idx - text_splitter._chunk_overlap  # Account for overlap
    
    return chunked_documents

# %% [markdown]
# #### Step 2: Retrait documents pertinents (phase RETRIEVAL)
# Tester plusieurs longueurs de chunks pour voir si la taille améliorer le retrait
# 1. Creation de n DB selon différentes tailles de chunk

# %%
chunk_sizes=[500, 1000, 1500, 2000, 3000, 4000, 5000, 6000]

# %%
databases=[]
for chunk_size in chunk_sizes:
    
    split_docs = split_raw_text(chunk_size)
    db=FAISS.from_documents(split_docs, embedding_model,)
    databases.append({"chunk_size": chunk_size, "split_docs": split_docs, "db": db})

# %%
for db in databases:
    print(f"chuck {db['chunk_size']}")
    print(len(db['split_docs']))
# Out:
# chuck 500
# 253
# chuck 1000
# 123
# chuck 1500
# 82
# chuck 2000
# 62
# chuck 3000
# 41
# chuck 4000
# 31
# chuck 5000
# 25
# chuck 6000
# 21

# %% [markdown]
# Query rewriter

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

"v1"
# system = """You are a question re-writer that converts an input question to a better version that is optimized \n
#      for vectorstore retrieval. Re-write the input in an interrogative, clear and concise way."""

"v2"
# system="""
#     You are a **question rewriter** that refines input questions to optimize them for **vector store retrieval**.  

#     ### **Instructions:**  
#     - Convert the input into a **clear, concise, and well-structured interrogative sentence**.  
#     - Ensure the reworded question **preserves the original intent** while improving retrieval effectiveness.  
#     - Remove ambiguity and redundant phrasing to enhance search relevance.  

#     Here is the initial question: \n\n {question} \n Formulate an improved question.

#     ### **Optimized Output:**  
#     Provide only the rewritten question, without any additional text.  

# """

"v3"
system="""
    You are a question rewriter tasked with improving input questions to optimize them for vector store retrieval. 
    Your mission is to refine, rephrase, and enhance the provided questions to ensure they are:
    * Clear and easy to understand.
    * Focused.
    * Optimized for effective retrieval by removing ambiguities.
    * Written in an interrogative form while preserving the original intent.

    #### Input Fields to Rework:
    Example 1:
    * Project Description: Reword questions that focus on the project’s overall scope and objectives.
    Example 2:
    * Country and City: Refine questions to specifically inquire about the project’s location.
    Example 3:
    * Target Beneficiaries: Enhance questions to clarify the population or group that benefits from the project.    
    * Number of People Concerned: Rework questions to quantify how many people the project impacts.
    Example 4:
    * Context, Environment, Project Rationale, Challenges, include these topics to enhance the final output:
            * Environmental Context
            * Biodiversity
            * Climate Change impacts
            * Socio-Economic Context
            * Economic, Demographic, Community impacts
            * Institutional context
            * Health context
        Rephrase questions that ask for background information, challenges, and the reasoning behind the project.

    Example 5:
    * Project Start Date / End Date: Rework questions regarding the project’s timeline.
    Example 6:
    * Financial Information:
        * Project Budget: Reword questions about the overall project budget.
        * Total Project Cost: Rephrase inquiries about the total cost of the project.
        * Donation Request Amount: Refine questions asking about the amount of funding requested.
        * Provisional Project Budget: Rework questions about the detailed provisional budget for the project.
        * Current Year Budget: Enhance questions related to the budget specific to the current year.


    #### Response Format:
    For each input question, rephrase it in a clear, and interrogative form, optimized for vector store retrieval. Return only the reworked question.
"""

"v4"
# system = """
#     You are a question rewriter tasked with improving input questions to optimize them for vector store retrieval. 
#     Your mission is to refine, rephrase, and enhance the provided questions to ensure they are:
#     * Clear and easy to understand.
#     * Focused.
#     * Optimized for effective retrieval by removing ambiguities.
#     * Written in an interrogative form while preserving the original intent.
#     * **Expanded with relevant details when applicable** (e.g., including specific topics related to the question).  

#     #### Input Fields to Rework:
#     Example 1:
#     * Project Description: Reword questions that focus on the project’s overall scope and objectives.
#     Example 2:
#     * Country and City: Refine questions to specifically inquire about the project’s location.
#     Example 3:
#     * Target Beneficiaries: Enhance questions to clarify the population or group that benefits from the project.    
#     * Number of People Concerned: Rework questions to quantify how many people the project impacts.
#     Example 4:
#     * Context, Environment, Project Rationale, Challenges: When reformulating questions related to this category, **explicitly incorporate** relevant aspects, such as:
#         - Environmental Context
#         - Biodiversity
#         - Climate Change Impacts
#         - Socio-Economic Context
#         - Economic, Demographic, and Community Impacts
#         - Institutional Context
#         - Health Context  

#     *Ensure that reformulated questions include these aspects where relevant.*

#     Example 5:
#     * Project Start Date / End Date: Rework questions regarding the project’s timeline.
#     Example 6:
#     * Financial Information:
#         * Project Budget: Reword questions about the overall project budget.
#         * Total Project Cost: Rephrase inquiries about the total cost of the project.
#         * Donation Request Amount: Refine questions asking about the amount of funding requested.
#         * Provisional Project Budget: Rework questions about the detailed provisional budget for the project.
#         * Current Year Budget: Enhance questions related to the budget specific to the current year.

#     #### Response Format:
#     For each input question, rephrase it in a **clear, interrogative form** optimized for vector store retrieval.  
#     *If the question relates to a category with specific example topics, explicitly integrate those topics into the reworded question.*  
#     Return **only the reworked question**.
# """

re_write_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        (
            "human",
            "Here is the initial question: \n\n {question} \n Formulate an improved question.",
        ),
    ]
)
llm_rewriter = ChatOpenAI(model_name="gpt-4o-mini", temperature=0.2)
question_rewriter = re_write_prompt | llm_rewriter | StrOutputParser()
# question="""Context, environment, project rationale and challenges"""
question="Country and City"
# question="Number of people concerned"
# question="Description of the project"
print(f"Initial question:\n{question}")
question_rewriter.invoke({"question": question})
# Out:
# Initial question:
# Country and City
# 'What is the specific country and city where the project is located?'
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f5ac6153-245a-49de-bfdf-4e94b477c352,id=a4480f25-6b87-4cd8-8c61-7e0e73cef61b; trace=f5ac6153-245a-49de-bfdf-4e94b477c352,id=4e8e0632-9b57-476b-a7d2-bea1ebca1dee; trace=f5ac6153-245a-49de-bfdf-4e94b477c352,id=f5ac6153-245a-49de-bfdf-4e94b477c352
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=c6b3b29e-9fb7-40cf-aa9f-11066427b014,id=c6b3b29e-9fb7-40cf-aa9f-11066427b014; trace=c6b3b29e-9fb7-40cf-aa9f-11066427b014,id=2e16a7c9-5066-4a40-89be-2de7f615575a; trace=c6b3b29e-9fb7-40cf-aa9f-11066427b014,id=60b5dfd0-1d44-43ed-ba68-a54a08dffc55
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=c6b3b29e-9fb7-40cf-aa9f-11066427b014,id=b045ad6b-fa88-425e-b6ec-f3497d45609b; trace=c6b3b29e-9fb7-40cf-aa9f-11066427b014,id=c6b3b29e-9fb7-40cf-aa9f-11066427b014; trace=c6b3b29e-9fb7-40cf-aa9f-11066427b014,id=60b5dfd0-1d44-43ed-ba68-a54a08dffc55
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=aec1380d-779a-4f37-b348-13d7cd029571,id=aec1380d-779a-4f37-b348-13d7cd029571; trace=aec1380d-779a-4f37-b348-13d7cd029571,id=340bff74-24ab-4fb3-8a4d-fb051dd4f7f9; trace=aec1380d-779a-4f37-b348-13d7cd029571,id=f9874551-183a-40cf-b207-e5bf4282729a
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=aec1380d-779a-4f37-b348-13d7cd029571,id=3ecae727-dde4-4fe3-ae02-6c9364c4dc94; trace=aec1380d-779a-4f37-b348-13d7cd029571,id=aec1380d-779a-4f37-b348-13d7cd029571; trace=aec1380d-779a-4f37-b348-13d7cd029571,id=f9874551-183a-40cf-b207-e5bf4282729a
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=b93b2faa-cb15-402c-8ba3-c1ee93e45735,id=b93b2faa-cb15-402c-8ba3-c1ee93e45735; trace=b93b2faa-cb15-402c-8ba3-c1ee93e45735,id=df023f54-0fac-4b38-b1c9-910e0f7cc024; trace=b93b2faa-cb15-402c-8ba3-c1ee93e45735,id=c341567d-2a6f-46cb-ac26-844cb872adbc
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=b93b2faa-cb15-402c-8ba3-c1ee93e45735,id=bd182d6f-ca0a-4ca3-96e3-384ec6c8df50; trace=b93b2faa-cb15-402c-8ba3-c1ee93e45735,id=c341567d-2a6f-46cb-ac26-844cb872adbc; trace=b93b2faa-cb15-402c-8ba3-c1ee93e45735,id=b93b2faa-cb15-402c-8ba3-c1ee93e45735
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1,id=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1; trace=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1,id=8c4782bb-a3d4-4951-a486-451e1b3ab240; trace=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1,id=ac971622-e733-4bbb-94be-31542b8b8a9b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1,id=30beac53-9838-415a-aa22-355a164eee4f; trace=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1,id=ac971622-e733-4bbb-94be-31542b8b8a9b; trace=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1,id=3037c0d1-d1ba-4e59-997e-4c05ddef3cf1
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=fdf81de2-fe71-4123-8021-4099d6a9c2e5,id=fdf81de2-fe71-4123-8021-4099d6a9c2e5; trace=fdf81de2-fe71-4123-8021-4099d6a9c2e5,id=3368695c-7741-40e3-81d8-2451c1638029; trace=fdf81de2-fe71-4123-8021-4099d6a9c2e5,id=58238aa9-c954-45df-acd2-0428ebcfa1dd
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=fdf81de2-fe71-4123-8021-4099d6a9c2e5,id=3a66227c-3a6c-45ca-9351-1d5b270b422f; trace=fdf81de2-fe71-4123-8021-4099d6a9c2e5,id=58238aa9-c954-45df-acd2-0428ebcfa1dd; trace=fdf81de2-fe71-4123-8021-4099d6a9c2e5,id=fdf81de2-fe71-4123-8021-4099d6a9c2e5
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=df4014a1-8e4b-4ccd-9fed-1e796bf58875,id=df4014a1-8e4b-4ccd-9fed-1e796bf58875; trace=df4014a1-8e4b-4ccd-9fed-1e796bf58875,id=e0b8de88-dbd8-479a-824a-1aaa20fe8347; trace=df4014a1-8e4b-4ccd-9fed-1e796bf58875,id=7cd2a36d-0215-4f6d-92b5-1c42e7bbea70
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=df4014a1-8e4b-4ccd-9fed-1e796bf58875,id=96f7a4f3-e19d-40e0-b986-6d369c8a6de5; trace=df4014a1-8e4b-4ccd-9fed-1e796bf58875,id=df4014a1-8e4b-4ccd-9fed-1e796bf58875; trace=df4014a1-8e4b-4ccd-9fed-1e796bf58875,id=7cd2a36d-0215-4f6d-92b5-1c42e7bbea70
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=35a8930a-229f-45e9-956a-5ff2bca415ad,id=35a8930a-229f-45e9-956a-5ff2bca415ad; trace=35a8930a-229f-45e9-956a-5ff2bca415ad,id=3b9bf860-c301-48e4-81c6-5a6d443f4459; trace=35a8930a-229f-45e9-956a-5ff2bca415ad,id=d9eb9d53-2d74-4cbe-b913-1a0700a674d8
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=35a8930a-229f-45e9-956a-5ff2bca415ad,id=7b89581d-f480-423d-815a-fbc2b404b174; trace=35a8930a-229f-45e9-956a-5ff2bca415ad,id=35a8930a-229f-45e9-956a-5ff2bca415ad; trace=35a8930a-229f-45e9-956a-5ff2bca415ad,id=d9eb9d53-2d74-4cbe-b913-1a0700a674d8
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f,id=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f; trace=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f,id=b33153c1-869b-45f5-8a2e-c56c44e190ed; trace=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f,id=a78f6de5-6a5a-492a-a728-15c4ea039f86
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f,id=886fb9b5-9e90-488b-bff3-c55b0b1b94d7; trace=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f,id=a78f6de5-6a5a-492a-a728-15c4ea039f86; trace=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f,id=eb103be5-81b4-4ce6-bdeb-cc4f3f24930f
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=4d1e4509-fa32-4528-b707-b325809e314e,id=4d1e4509-fa32-4528-b707-b325809e314e; trace=4d1e4509-fa32-4528-b707-b325809e314e,id=f58901bf-4832-4935-8116-9f8ff0ba7e3e; trace=4d1e4509-fa32-4528-b707-b325809e314e,id=aa44c0ea-833e-4a22-8e78-64f7d3806f42
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=4d1e4509-fa32-4528-b707-b325809e314e,id=be373259-d9ee-4fc2-b092-fc80a2301b6e; trace=4d1e4509-fa32-4528-b707-b325809e314e,id=aa44c0ea-833e-4a22-8e78-64f7d3806f42; trace=4d1e4509-fa32-4528-b707-b325809e314e,id=4d1e4509-fa32-4528-b707-b325809e314e
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f0a1a0e7-24ea-4045-ae30-f9bb323f1861,id=f0a1a0e7-24ea-4045-ae30-f9bb323f1861; trace=f0a1a0e7-24ea-4045-ae30-f9bb323f1861,id=07fc5fcd-dfce-42d1-89f4-87e1ce0e465e; trace=f0a1a0e7-24ea-4045-ae30-f9bb323f1861,id=e7800f6c-cb3a-4af2-828f-2442220a8c7f
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f0a1a0e7-24ea-4045-ae30-f9bb323f1861,id=d36954cd-61df-4c46-877c-a1bcc773adcf; trace=f0a1a0e7-24ea-4045-ae30-f9bb323f1861,id=e7800f6c-cb3a-4af2-828f-2442220a8c7f; trace=f0a1a0e7-24ea-4045-ae30-f9bb323f1861,id=f0a1a0e7-24ea-4045-ae30-f9bb323f1861
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=cb79dcb3-1dda-4f3b-9235-5559b3f17507,id=cb79dcb3-1dda-4f3b-9235-5559b3f17507; trace=cb79dcb3-1dda-4f3b-9235-5559b3f17507,id=0819460a-2a07-4b1b-9e30-4af9428fb9a7; trace=cb79dcb3-1dda-4f3b-9235-5559b3f17507,id=98f311a1-defe-4342-902c-7f733be8798c
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=cb79dcb3-1dda-4f3b-9235-5559b3f17507,id=2d1d1155-c842-4c22-bcf4-c4d3d4df4eff; trace=cb79dcb3-1dda-4f3b-9235-5559b3f17507,id=cb79dcb3-1dda-4f3b-9235-5559b3f17507; trace=cb79dcb3-1dda-4f3b-9235-5559b3f17507,id=98f311a1-defe-4342-902c-7f733be8798c
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=5e927599-a3da-4d61-95e2-c885b9e05f62,id=5e927599-a3da-4d61-95e2-c885b9e05f62; trace=5e927599-a3da-4d61-95e2-c885b9e05f62,id=42f0dbba-c993-4327-a89a-d91af17c7ec8; trace=5e927599-a3da-4d61-95e2-c885b9e05f62,id=9594348c-b707-4c94-8850-f1719fc59b10
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=5e927599-a3da-4d61-95e2-c885b9e05f62,id=afc4ddd2-9f2d-47e3-8761-d7be45129843; trace=5e927599-a3da-4d61-95e2-c885b9e05f62,id=9594348c-b707-4c94-8850-f1719fc59b10; trace=5e927599-a3da-4d61-95e2-c885b9e05f62,id=5e927599-a3da-4d61-95e2-c885b9e05f62
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1,id=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1; trace=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1,id=4cb7385f-18a5-4dab-b41f-49fc419aaef0; trace=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1,id=f641d937-dad5-4d02-8e77-131f4e481e39
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1,id=dd1beee7-989e-44b9-ad19-5307f5e224ff; trace=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1,id=f641d937-dad5-4d02-8e77-131f4e481e39; trace=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1,id=fd4f5ca9-4f16-4f3d-9e3d-6f48d29fb8f1
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd,id=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd; trace=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd,id=2d98f6f5-de70-4fb3-b327-8569eb6341ab; trace=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd,id=e09344cc-7df9-4e89-b5e9-736b16edcfbb
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd,id=7357f5dc-92cb-4904-8774-1900205e3430; trace=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd,id=e09344cc-7df9-4e89-b5e9-736b16edcfbb; trace=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd,id=cdbd534d-a0b2-46f8-ad8e-a0ddf224f3dd
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=0b64d552-a180-487c-ac1b-3bf8633bc9c9,id=0b64d552-a180-487c-ac1b-3bf8633bc9c9; trace=0b64d552-a180-487c-ac1b-3bf8633bc9c9,id=cdaf29d7-c062-4989-babd-c41906bfe473; trace=0b64d552-a180-487c-ac1b-3bf8633bc9c9,id=58bd79bd-3e63-4333-8890-4bb463e3ab0a
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=0b64d552-a180-487c-ac1b-3bf8633bc9c9,id=41145519-59c8-44a5-aa31-cd8f57d6e561; trace=0b64d552-a180-487c-ac1b-3bf8633bc9c9,id=58bd79bd-3e63-4333-8890-4bb463e3ab0a; trace=0b64d552-a180-487c-ac1b-3bf8633bc9c9,id=0b64d552-a180-487c-ac1b-3bf8633bc9c9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=6c54945c-dcbf-40e2-9644-d817d243ac8d,id=6c54945c-dcbf-40e2-9644-d817d243ac8d; trace=6c54945c-dcbf-40e2-9644-d817d243ac8d,id=1605e5a9-36cc-494a-a05e-64a20685cb12; trace=6c54945c-dcbf-40e2-9644-d817d243ac8d,id=b9b73e1d-db2d-4545-90ff-269236dcfc5b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=6c54945c-dcbf-40e2-9644-d817d243ac8d,id=59b6450d-0a10-4f04-88a0-ef1e683efd52; trace=6c54945c-dcbf-40e2-9644-d817d243ac8d,id=6c54945c-dcbf-40e2-9644-d817d243ac8d; trace=6c54945c-dcbf-40e2-9644-d817d243ac8d,id=b9b73e1d-db2d-4545-90ff-269236dcfc5b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=e40d34f8-235b-4ad7-ad4a-74d55e47eb53,id=e40d34f8-235b-4ad7-ad4a-74d55e47eb53; trace=e40d34f8-235b-4ad7-ad4a-74d55e47eb53,id=d03be356-07af-4edc-860a-4f00e71d4397; trace=e40d34f8-235b-4ad7-ad4a-74d55e47eb53,id=0f0577a8-aca0-474a-a55c-afd221407ce2
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=e40d34f8-235b-4ad7-ad4a-74d55e47eb53,id=37594ff7-9c9b-4eac-b7bc-9941081c5148; trace=e40d34f8-235b-4ad7-ad4a-74d55e47eb53,id=0f0577a8-aca0-474a-a55c-afd221407ce2; trace=e40d34f8-235b-4ad7-ad4a-74d55e47eb53,id=e40d34f8-235b-4ad7-ad4a-74d55e47eb53
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f26aeac9-d38c-4caf-bf5a-12b5373c6003,id=f26aeac9-d38c-4caf-bf5a-12b5373c6003; trace=f26aeac9-d38c-4caf-bf5a-12b5373c6003,id=73ab843b-e3f6-42b5-9d2a-ab7c9d391743; trace=f26aeac9-d38c-4caf-bf5a-12b5373c6003,id=61d58697-2755-47d5-a590-c937f23661af
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f26aeac9-d38c-4caf-bf5a-12b5373c6003,id=8cd1930b-0925-4c6d-b9fc-866d76becfad; trace=f26aeac9-d38c-4caf-bf5a-12b5373c6003,id=61d58697-2755-47d5-a590-c937f23661af; trace=f26aeac9-d38c-4caf-bf5a-12b5373c6003,id=f26aeac9-d38c-4caf-bf5a-12b5373c6003
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=51fceee4-2b44-4437-b688-3bcfe1213c76,id=51fceee4-2b44-4437-b688-3bcfe1213c76; trace=51fceee4-2b44-4437-b688-3bcfe1213c76,id=4dd51191-fe55-4ca3-b360-6d93f279f47a; trace=51fceee4-2b44-4437-b688-3bcfe1213c76,id=f8768f62-5170-4627-a1f9-e7ed18c5b7a4
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=51fceee4-2b44-4437-b688-3bcfe1213c76,id=155700c7-03aa-4daa-a2ab-1008a745eb42; trace=51fceee4-2b44-4437-b688-3bcfe1213c76,id=f8768f62-5170-4627-a1f9-e7ed18c5b7a4; trace=51fceee4-2b44-4437-b688-3bcfe1213c76,id=51fceee4-2b44-4437-b688-3bcfe1213c76
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=161619aa-9e5a-4060-95db-1ef7a7cc3e71,id=161619aa-9e5a-4060-95db-1ef7a7cc3e71; trace=161619aa-9e5a-4060-95db-1ef7a7cc3e71,id=87b41ab0-dc14-4ab9-ab0a-7151d42482a6; trace=161619aa-9e5a-4060-95db-1ef7a7cc3e71,id=dcad65ae-6166-45e7-a9f0-f9f94f742c1b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=161619aa-9e5a-4060-95db-1ef7a7cc3e71,id=39639e43-c2f2-4441-97cf-c8fdf3e83826; trace=161619aa-9e5a-4060-95db-1ef7a7cc3e71,id=dcad65ae-6166-45e7-a9f0-f9f94f742c1b; trace=161619aa-9e5a-4060-95db-1ef7a7cc3e71,id=161619aa-9e5a-4060-95db-1ef7a7cc3e71
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=9115c69a-86fb-470f-8ca8-9bfe583259e0,id=9115c69a-86fb-470f-8ca8-9bfe583259e0; trace=9115c69a-86fb-470f-8ca8-9bfe583259e0,id=f4be4f43-6354-4f81-aefd-0be28f9764f2; trace=9115c69a-86fb-470f-8ca8-9bfe583259e0,id=fa78854b-5ea5-408a-8a35-26bf4f700da7
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=9115c69a-86fb-470f-8ca8-9bfe583259e0,id=97e2234f-1e18-4616-8ebc-c0e795a5ad95; trace=9115c69a-86fb-470f-8ca8-9bfe583259e0,id=fa78854b-5ea5-408a-8a35-26bf4f700da7; trace=9115c69a-86fb-470f-8ca8-9bfe583259e0,id=9115c69a-86fb-470f-8ca8-9bfe583259e0
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf,id=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf; trace=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf,id=e92e5e3f-4701-44bd-8a74-f64ee8a5bdd8; trace=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf,id=671702b3-2976-4108-9bca-3ecf55ac16df
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf,id=8dca4fec-b91d-4e20-a2f9-9969330af542; trace=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf,id=671702b3-2976-4108-9bca-3ecf55ac16df; trace=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf,id=30c7551e-0b3b-4896-ba98-fb02fd1bd6cf
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=9f9ecb78-9a6e-4a58-a57b-b750fa8826a9,id=9f9ecb78-9a6e-4a58-a57b-b750fa8826a9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f6c687d8-e714-4558-af23-9fa238356076,id=f6c687d8-e714-4558-af23-9fa238356076; trace=671005ff-99ea-4363-9c14-ffa8b6f99c3c,id=671005ff-99ea-4363-9c14-ffa8b6f99c3c; trace=671005ff-99ea-4363-9c14-ffa8b6f99c3c,id=2ba1cecd-1962-47a1-9471-9e8fb9db5451; trace=671005ff-99ea-4363-9c14-ffa8b6f99c3c,id=1f7a62e8-3c3e-44bd-91db-4375e53da05c; trace=9f9ecb78-9a6e-4a58-a57b-b750fa8826a9,id=9f9ecb78-9a6e-4a58-a57b-b750fa8826a9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=671005ff-99ea-4363-9c14-ffa8b6f99c3c,id=9f9bd15e-640e-4de4-9e47-1191f5dc5e84; trace=671005ff-99ea-4363-9c14-ffa8b6f99c3c,id=1f7a62e8-3c3e-44bd-91db-4375e53da05c; trace=671005ff-99ea-4363-9c14-ffa8b6f99c3c,id=671005ff-99ea-4363-9c14-ffa8b6f99c3c
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=4adfea27-46d4-4ef3-874e-ad12ca4c352f,id=4adfea27-46d4-4ef3-874e-ad12ca4c352f; trace=4adfea27-46d4-4ef3-874e-ad12ca4c352f,id=889d2dda-4a3d-4ebe-a794-369a03cd2342; trace=4adfea27-46d4-4ef3-874e-ad12ca4c352f,id=f274e3f3-2f81-464e-917c-f09337edf4bd
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=4adfea27-46d4-4ef3-874e-ad12ca4c352f,id=1407924e-d298-4c75-8c0f-c2da8cf48f51; trace=4adfea27-46d4-4ef3-874e-ad12ca4c352f,id=f274e3f3-2f81-464e-917c-f09337edf4bd; trace=4adfea27-46d4-4ef3-874e-ad12ca4c352f,id=4adfea27-46d4-4ef3-874e-ad12ca4c352f
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f9d26f29-1744-4261-9596-58019867531e,id=f9d26f29-1744-4261-9596-58019867531e; trace=f9d26f29-1744-4261-9596-58019867531e,id=7735755a-7dba-435b-a77c-6242b5d27099; trace=f9d26f29-1744-4261-9596-58019867531e,id=bcd6bcd2-db93-480f-829b-e11a7bfe8d13
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f9d26f29-1744-4261-9596-58019867531e,id=1d89403e-4ced-4080-b0ec-8cafd74bd412; trace=f9d26f29-1744-4261-9596-58019867531e,id=f9d26f29-1744-4261-9596-58019867531e; trace=f9d26f29-1744-4261-9596-58019867531e,id=bcd6bcd2-db93-480f-829b-e11a7bfe8d13
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=417542df-5475-4ff5-a0b5-e9bba77d881d,id=417542df-5475-4ff5-a0b5-e9bba77d881d; trace=417542df-5475-4ff5-a0b5-e9bba77d881d,id=971a36e0-3bce-4513-9c60-d2c5ac7fa349; trace=417542df-5475-4ff5-a0b5-e9bba77d881d,id=4d2f82cb-245b-4fea-a2ae-0daa8495f8ce
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=417542df-5475-4ff5-a0b5-e9bba77d881d,id=a78c88a5-53fd-4485-bb96-5452ba472355; trace=417542df-5475-4ff5-a0b5-e9bba77d881d,id=4d2f82cb-245b-4fea-a2ae-0daa8495f8ce; trace=417542df-5475-4ff5-a0b5-e9bba77d881d,id=417542df-5475-4ff5-a0b5-e9bba77d881d
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=d3ff5570-710b-481d-9da2-d856ac60c32f,id=d3ff5570-710b-481d-9da2-d856ac60c32f; trace=d3ff5570-710b-481d-9da2-d856ac60c32f,id=c7dc4ab8-323a-49a4-9fc1-664b8cdf92f4; trace=d3ff5570-710b-481d-9da2-d856ac60c32f,id=65e952c5-cef8-4e52-8afc-da158d8b163b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=d3ff5570-710b-481d-9da2-d856ac60c32f,id=ede16d2a-7e57-4e44-9277-97d936e61b18; trace=d3ff5570-710b-481d-9da2-d856ac60c32f,id=65e952c5-cef8-4e52-8afc-da158d8b163b; trace=d3ff5570-710b-481d-9da2-d856ac60c32f,id=d3ff5570-710b-481d-9da2-d856ac60c32f
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f1d0fbc0-18cd-49a5-ac49-64fe644255a4,id=f1d0fbc0-18cd-49a5-ac49-64fe644255a4; trace=f1d0fbc0-18cd-49a5-ac49-64fe644255a4,id=ebf1c033-3c9c-410a-bd77-baca422eac8d; trace=f1d0fbc0-18cd-49a5-ac49-64fe644255a4,id=afaec192-c4cb-4851-8db5-4f7b9a06b58e
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f1d0fbc0-18cd-49a5-ac49-64fe644255a4,id=a7819cf7-7d18-480b-8f00-48a7f383388e; trace=f1d0fbc0-18cd-49a5-ac49-64fe644255a4,id=afaec192-c4cb-4851-8db5-4f7b9a06b58e; trace=f1d0fbc0-18cd-49a5-ac49-64fe644255a4,id=f1d0fbc0-18cd-49a5-ac49-64fe644255a4
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=781489b0-e53b-4a52-aa9f-865d77c71cd4,id=781489b0-e53b-4a52-aa9f-865d77c71cd4; trace=781489b0-e53b-4a52-aa9f-865d77c71cd4,id=c08cfae4-fa21-4ac4-8722-d627737d26c0; trace=781489b0-e53b-4a52-aa9f-865d77c71cd4,id=17bc2af2-e42c-47c6-880c-6bed8dd030dd
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=781489b0-e53b-4a52-aa9f-865d77c71cd4,id=0dc662c6-341b-4192-a2b9-ba0e64602b86; trace=781489b0-e53b-4a52-aa9f-865d77c71cd4,id=781489b0-e53b-4a52-aa9f-865d77c71cd4; trace=781489b0-e53b-4a52-aa9f-865d77c71cd4,id=17bc2af2-e42c-47c6-880c-6bed8dd030dd
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=29205698-9859-41d8-85b5-f891e4e7caa7,id=29205698-9859-41d8-85b5-f891e4e7caa7; trace=29205698-9859-41d8-85b5-f891e4e7caa7,id=b50e2f18-f911-4b99-80d3-23ea8c24c08a; trace=29205698-9859-41d8-85b5-f891e4e7caa7,id=ca1a4705-22a9-4f2f-8efe-1cc9981813d1
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=29205698-9859-41d8-85b5-f891e4e7caa7,id=7e507187-0bc0-473b-be0d-f022544f3792; trace=29205698-9859-41d8-85b5-f891e4e7caa7,id=29205698-9859-41d8-85b5-f891e4e7caa7; trace=29205698-9859-41d8-85b5-f891e4e7caa7,id=ca1a4705-22a9-4f2f-8efe-1cc9981813d1
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314,id=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314; trace=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314,id=2c5f1a8d-9285-40dc-8717-9187b0e20d37; trace=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314,id=823228f3-2eff-4646-b4b3-39a77badc198
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314,id=022b6a83-c685-4df6-8942-a4378024f000; trace=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314,id=823228f3-2eff-4646-b4b3-39a77badc198; trace=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314,id=a639ebcd-64ec-4b2d-97cf-cc5ca7e42314
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=6c2e699b-9764-40ca-8294-e1a6441f8e68,id=6c2e699b-9764-40ca-8294-e1a6441f8e68; trace=6c2e699b-9764-40ca-8294-e1a6441f8e68,id=a29d1fe7-1df1-4ac6-bd9e-caf04304cee5; trace=6c2e699b-9764-40ca-8294-e1a6441f8e68,id=83a83d66-b679-4598-bdcd-09e1f8043af9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=6c2e699b-9764-40ca-8294-e1a6441f8e68,id=a2c54508-897c-440e-8a58-ebe1bef8b28a; trace=6c2e699b-9764-40ca-8294-e1a6441f8e68,id=6c2e699b-9764-40ca-8294-e1a6441f8e68; trace=6c2e699b-9764-40ca-8294-e1a6441f8e68,id=83a83d66-b679-4598-bdcd-09e1f8043af9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=d7205f58-63a4-4fc3-8ae9-4585a75851ce,id=d7205f58-63a4-4fc3-8ae9-4585a75851ce; trace=d7205f58-63a4-4fc3-8ae9-4585a75851ce,id=c4c045f7-3204-4d8f-beb9-2c102cc5f23a; trace=d7205f58-63a4-4fc3-8ae9-4585a75851ce,id=335b157f-6387-4b24-ac5c-d857763bc07d
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=d7205f58-63a4-4fc3-8ae9-4585a75851ce,id=c5e1851a-faaa-417d-90de-679b6c86846f; trace=d7205f58-63a4-4fc3-8ae9-4585a75851ce,id=335b157f-6387-4b24-ac5c-d857763bc07d; trace=d7205f58-63a4-4fc3-8ae9-4585a75851ce,id=d7205f58-63a4-4fc3-8ae9-4585a75851ce
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=7e7fd274-bcc4-4873-a700-5882c71d4710,id=7e7fd274-bcc4-4873-a700-5882c71d4710; trace=7e7fd274-bcc4-4873-a700-5882c71d4710,id=1e45430c-99b7-4af2-a873-8ed4a6f236cb; trace=7e7fd274-bcc4-4873-a700-5882c71d4710,id=8a94059c-fd52-413e-8601-e8afb9f65f85
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=7e7fd274-bcc4-4873-a700-5882c71d4710,id=4f3feae0-aec7-4c4b-8b55-26c81105b0d4; trace=7e7fd274-bcc4-4873-a700-5882c71d4710,id=8a94059c-fd52-413e-8601-e8afb9f65f85; trace=7e7fd274-bcc4-4873-a700-5882c71d4710,id=7e7fd274-bcc4-4873-a700-5882c71d4710
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=735571fa-050b-4a0a-8a3d-5fede45e5ca7,id=735571fa-050b-4a0a-8a3d-5fede45e5ca7; trace=735571fa-050b-4a0a-8a3d-5fede45e5ca7,id=0734b25a-8ca4-4215-a5d0-7bfa8c646d67; trace=735571fa-050b-4a0a-8a3d-5fede45e5ca7,id=d6a67857-7582-4e85-87d8-2e35f0c13eff
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=735571fa-050b-4a0a-8a3d-5fede45e5ca7,id=a59e06d6-937f-4d08-8ddd-ac5a1630135f; trace=735571fa-050b-4a0a-8a3d-5fede45e5ca7,id=735571fa-050b-4a0a-8a3d-5fede45e5ca7; trace=735571fa-050b-4a0a-8a3d-5fede45e5ca7,id=d6a67857-7582-4e85-87d8-2e35f0c13eff
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=3653186b-74ba-464d-b6d2-164dfa722eb9,id=3653186b-74ba-464d-b6d2-164dfa722eb9; trace=3653186b-74ba-464d-b6d2-164dfa722eb9,id=2205140f-8605-4526-9f25-be543013bb15; trace=3653186b-74ba-464d-b6d2-164dfa722eb9,id=0529f885-feab-499f-9a12-3b232f124b78
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=3653186b-74ba-464d-b6d2-164dfa722eb9,id=70c746ec-6872-4862-99d4-78fa820b7ac6; trace=3653186b-74ba-464d-b6d2-164dfa722eb9,id=0529f885-feab-499f-9a12-3b232f124b78; trace=3653186b-74ba-464d-b6d2-164dfa722eb9,id=3653186b-74ba-464d-b6d2-164dfa722eb9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=323b5fa0-f390-4aec-9499-7ba34f12a5e0,id=323b5fa0-f390-4aec-9499-7ba34f12a5e0; trace=323b5fa0-f390-4aec-9499-7ba34f12a5e0,id=f5621f84-4f41-4b2d-b4ba-04f7f42300ce; trace=323b5fa0-f390-4aec-9499-7ba34f12a5e0,id=036bfc3f-a760-4725-a6be-c4498aa8beb8
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=323b5fa0-f390-4aec-9499-7ba34f12a5e0,id=7d52160e-530d-4f84-86d3-a7588e617436; trace=323b5fa0-f390-4aec-9499-7ba34f12a5e0,id=036bfc3f-a760-4725-a6be-c4498aa8beb8; trace=323b5fa0-f390-4aec-9499-7ba34f12a5e0,id=323b5fa0-f390-4aec-9499-7ba34f12a5e0
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f,id=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f; trace=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f,id=262f89ce-ad0c-4670-82cc-7cd69d0274ca; trace=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f,id=dab03379-65e5-4bf1-a9b0-44349a88204a
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f,id=f0773e90-c860-44fc-9b3f-c703b4d45d98; trace=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f,id=dab03379-65e5-4bf1-a9b0-44349a88204a; trace=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f,id=8dbcd1ed-b250-44dc-960c-b45f8dac3b6f
# ...
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=cf68ab10-9db3-48d8-9a8a-f6fef29a785d,id=cf68ab10-9db3-48d8-9a8a-f6fef29a785d; trace=cf68ab10-9db3-48d8-9a8a-f6fef29a785d,id=07282d7e-a70c-4235-a3a9-a50e4c301440; trace=cf68ab10-9db3-48d8-9a8a-f6fef29a785d,id=50af33fb-b859-487f-b35b-a527e39da448
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=cf68ab10-9db3-48d8-9a8a-f6fef29a785d,id=16722681-8a8c-42aa-804d-984fd3384843; trace=cf68ab10-9db3-48d8-9a8a-f6fef29a785d,id=50af33fb-b859-487f-b35b-a527e39da448; trace=cf68ab10-9db3-48d8-9a8a-f6fef29a785d,id=cf68ab10-9db3-48d8-9a8a-f6fef29a785d
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=2bbc6060-30d6-4fb2-b202-2cbf721796da,id=2bbc6060-30d6-4fb2-b202-2cbf721796da; trace=2bbc6060-30d6-4fb2-b202-2cbf721796da,id=557fc4e3-01b6-499b-8aac-81c7942ffa55; trace=2bbc6060-30d6-4fb2-b202-2cbf721796da,id=17f907fc-16e9-4272-83e7-eebdb72221d2
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=2bbc6060-30d6-4fb2-b202-2cbf721796da,id=ddb0bfef-144f-475e-a384-170995506703; trace=2bbc6060-30d6-4fb2-b202-2cbf721796da,id=17f907fc-16e9-4272-83e7-eebdb72221d2; trace=2bbc6060-30d6-4fb2-b202-2cbf721796da,id=2bbc6060-30d6-4fb2-b202-2cbf721796da
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=9f1faca2-16ec-4844-b9cb-c52bd48e2025,id=9f1faca2-16ec-4844-b9cb-c52bd48e2025; trace=9f1faca2-16ec-4844-b9cb-c52bd48e2025,id=149eb2c7-d58f-4959-b61d-591f80730696; trace=9f1faca2-16ec-4844-b9cb-c52bd48e2025,id=57985c0b-afdc-4ba3-9dd8-b54ffbc172a1
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=9f1faca2-16ec-4844-b9cb-c52bd48e2025,id=d6b32820-759c-43b7-9218-52ce12c4cf86; trace=9f1faca2-16ec-4844-b9cb-c52bd48e2025,id=57985c0b-afdc-4ba3-9dd8-b54ffbc172a1; trace=9f1faca2-16ec-4844-b9cb-c52bd48e2025,id=9f1faca2-16ec-4844-b9cb-c52bd48e2025
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=6057ade5-f128-4294-8743-ae6236842479,id=6057ade5-f128-4294-8743-ae6236842479; trace=6057ade5-f128-4294-8743-ae6236842479,id=bedc7e2c-e77d-49aa-8697-19553fe84173; trace=6057ade5-f128-4294-8743-ae6236842479,id=bc1d6247-1f17-44a7-95e6-7c002a1aca56
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=6057ade5-f128-4294-8743-ae6236842479,id=fd53ac25-a46b-47fb-90f9-d6b4d98e718b; trace=6057ade5-f128-4294-8743-ae6236842479,id=bc1d6247-1f17-44a7-95e6-7c002a1aca56; trace=6057ade5-f128-4294-8743-ae6236842479,id=6057ade5-f128-4294-8743-ae6236842479
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=121361d4-6465-433e-aaf3-94181d19a6f2,id=121361d4-6465-433e-aaf3-94181d19a6f2; trace=121361d4-6465-433e-aaf3-94181d19a6f2,id=93d07d91-c0fb-481a-b8c1-3f04a2490a10; trace=121361d4-6465-433e-aaf3-94181d19a6f2,id=e5e5e00d-08f4-4ec4-9016-b84db6e9999f
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=121361d4-6465-433e-aaf3-94181d19a6f2,id=837e08de-a02a-43df-a17e-d776409be08e; trace=121361d4-6465-433e-aaf3-94181d19a6f2,id=e5e5e00d-08f4-4ec4-9016-b84db6e9999f; trace=121361d4-6465-433e-aaf3-94181d19a6f2,id=121361d4-6465-433e-aaf3-94181d19a6f2
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=23ef69c9-8785-4848-9868-b507c203579f,id=23ef69c9-8785-4848-9868-b507c203579f; trace=23ef69c9-8785-4848-9868-b507c203579f,id=6ffead14-58bf-47cd-8f62-d80d17ee643f; trace=23ef69c9-8785-4848-9868-b507c203579f,id=9b540e6b-28a7-40fc-8afd-8f708465a07b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=23ef69c9-8785-4848-9868-b507c203579f,id=49c4e4a4-7eab-416c-96d2-c07af9f13cc6; trace=23ef69c9-8785-4848-9868-b507c203579f,id=23ef69c9-8785-4848-9868-b507c203579f; trace=23ef69c9-8785-4848-9868-b507c203579f,id=9b540e6b-28a7-40fc-8afd-8f708465a07b
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=77df62e6-b95d-4f5c-af4e-f72e547edd31,id=77df62e6-b95d-4f5c-af4e-f72e547edd31; trace=77df62e6-b95d-4f5c-af4e-f72e547edd31,id=d3c418b5-fc0a-4072-a10b-1b6b2f738b29; trace=77df62e6-b95d-4f5c-af4e-f72e547edd31,id=732441ca-8e9c-4871-84c5-19f3932cddcd
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=77df62e6-b95d-4f5c-af4e-f72e547edd31,id=5738fb1a-d068-435a-90da-ff61e3ac3a18; trace=77df62e6-b95d-4f5c-af4e-f72e547edd31,id=732441ca-8e9c-4871-84c5-19f3932cddcd; trace=77df62e6-b95d-4f5c-af4e-f72e547edd31,id=77df62e6-b95d-4f5c-af4e-f72e547edd31
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=50d62263-646a-4b34-928e-e14a1ddd5b23,id=50d62263-646a-4b34-928e-e14a1ddd5b23; trace=50d62263-646a-4b34-928e-e14a1ddd5b23,id=8fe13367-35a3-4393-bcce-66ba5cdaa82b; trace=50d62263-646a-4b34-928e-e14a1ddd5b23,id=6d2b4a62-dbca-43d6-a7f4-39318fc7d03e
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=50d62263-646a-4b34-928e-e14a1ddd5b23,id=69cb0252-237a-411c-9c11-3c2237bc4179; trace=50d62263-646a-4b34-928e-e14a1ddd5b23,id=6d2b4a62-dbca-43d6-a7f4-39318fc7d03e; trace=50d62263-646a-4b34-928e-e14a1ddd5b23,id=50d62263-646a-4b34-928e-e14a1ddd5b23
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=8a48519f-870e-4497-9d65-01aea504562d,id=8a48519f-870e-4497-9d65-01aea504562d; trace=8a48519f-870e-4497-9d65-01aea504562d,id=844f3a2c-9c46-4b40-9515-0d17249523b4; trace=8a48519f-870e-4497-9d65-01aea504562d,id=cf14f8ca-c867-4b16-8fde-d78284e69576
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=8a48519f-870e-4497-9d65-01aea504562d,id=2f4e9f73-f904-4050-95b3-a391f345bd57; trace=8a48519f-870e-4497-9d65-01aea504562d,id=cf14f8ca-c867-4b16-8fde-d78284e69576; trace=8a48519f-870e-4497-9d65-01aea504562d,id=8a48519f-870e-4497-9d65-01aea504562d
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=11952cf6-d9d7-4d7a-bf9b-1a3794144420,id=11952cf6-d9d7-4d7a-bf9b-1a3794144420; trace=11952cf6-d9d7-4d7a-bf9b-1a3794144420,id=c164c6a6-b7b6-43a3-b34f-b49241ba48ff; trace=11952cf6-d9d7-4d7a-bf9b-1a3794144420,id=95eb3b30-76c3-4e53-ab7c-e8bd4bce2e7c
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=11952cf6-d9d7-4d7a-bf9b-1a3794144420,id=5f06f622-7372-4df4-9ce9-f0bc48f1af94; trace=11952cf6-d9d7-4d7a-bf9b-1a3794144420,id=95eb3b30-76c3-4e53-ab7c-e8bd4bce2e7c; trace=11952cf6-d9d7-4d7a-bf9b-1a3794144420,id=11952cf6-d9d7-4d7a-bf9b-1a3794144420
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=68d7bb78-d9fc-4d24-99d7-568882e86b91,id=68d7bb78-d9fc-4d24-99d7-568882e86b91; trace=68d7bb78-d9fc-4d24-99d7-568882e86b91,id=d0cbe2f5-842f-4d49-9bdd-f0329f3d26ad; trace=68d7bb78-d9fc-4d24-99d7-568882e86b91,id=4ad68b0e-2e69-4292-963a-b3d62e36e3b9
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=68d7bb78-d9fc-4d24-99d7-568882e86b91,id=eabf87c3-f915-4ec4-beef-6083427200f1; trace=68d7bb78-d9fc-4d24-99d7-568882e86b91,id=4ad68b0e-2e69-4292-963a-b3d62e36e3b9; trace=68d7bb78-d9fc-4d24-99d7-568882e86b91,id=68d7bb78-d9fc-4d24-99d7-568882e86b91
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=589f828a-6a2a-4a4b-aed5-bac9c469523f,id=589f828a-6a2a-4a4b-aed5-bac9c469523f; trace=589f828a-6a2a-4a4b-aed5-bac9c469523f,id=abfdaa32-55ee-46f4-b99d-f0e329194224; trace=589f828a-6a2a-4a4b-aed5-bac9c469523f,id=d82219bb-afa7-4ff4-b807-62ad5eac0ee0
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=589f828a-6a2a-4a4b-aed5-bac9c469523f,id=6f0c485e-01ca-49fa-92bd-d13c45d2ea61; trace=589f828a-6a2a-4a4b-aed5-bac9c469523f,id=d82219bb-afa7-4ff4-b807-62ad5eac0ee0; trace=589f828a-6a2a-4a4b-aed5-bac9c469523f,id=589f828a-6a2a-4a4b-aed5-bac9c469523f
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f12756d9-16b5-407a-ba59-b2ecf4bcdce2,id=f12756d9-16b5-407a-ba59-b2ecf4bcdce2; trace=f12756d9-16b5-407a-ba59-b2ecf4bcdce2,id=d5ccb56c-4602-4de8-97bf-4df060081dcd; trace=f12756d9-16b5-407a-ba59-b2ecf4bcdce2,id=7d3fa252-6d48-4104-aa6c-9a86251ed365
# Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Too many requests: tenant exceeded usage limits: Monthly unique traces usage limit exceeded"}\n')trace=f12756d9-16b5-407a-ba59-b2ecf4bcdce2,id=88d55700-5e3e-45f5-8f76-1e0e861052f0; trace=f12756d9-16b5-407a-ba59-b2ecf4bcdce2,id=7d3fa252-6d48-4104-aa6c-9a86251ed365; trace=f12756d9-16b5-407a-ba59-b2ecf4bcdce2,id=f12756d9-16b5-407a-ba59-b2ecf4bcdce2

# %% [markdown]
# #### Step 3: Creation des rerankers

# %%
from sentence_transformers import CrossEncoder
from transformers import pipeline
import torch
from sentence_transformers import SentenceTransformer


reranker1 = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2", device=0)
# Load the reranker model in bfloat16 precision
reranker2 = pipeline(
    "text-classification", 
    model="BAAI/bge-reranker-v2-m3", 
    device=-1,  # Use GPU
    # torch_dtype=torch.flo  # Load in bfloat16 precision
)



reranker3 = SentenceTransformer("Alibaba-NLP/gte-multilingual-reranker-base", trust_remote_code=True, device='cuda')
# Out:
# /home/chougar/miniconda3/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2025-03-11 20:16:43.701984: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741720603.727856   50656 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741720603.735819   50656 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Device set to use cpu
# No sentence-transformers model found with name Alibaba-NLP/gte-multilingual-reranker-base. Creating a new one with mean pooling.
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.5.1+cu121 with CUDA 1201 (you have 2.6.0+cu124)
#     Python  3.11.10 (you have 3.11.8)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details

# %%
reranker4 = pipeline(
    "text-classification", 
    model="BAAI/bge-reranker-v2-gemma", 
    device=0,  
    torch_dtype=torch.bfloat16
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some weights of GemmaForSequenceClassification were not initialized from the model checkpoint at BAAI/bge-reranker-v2-gemma and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0

# %%
### Retrieval Grader
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

from pydantic import BaseModel, Field


# Data model
class GradeDocuments(BaseModel):
    """Score for relevance check on retrieved documents."""

    score: int = Field(
        description="Documents are relevant to the question, score from 1 (not relevant) to 10 (perfectly relevant)"
    )


# LLM with function call
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
structured_llm_grader = llm.with_structured_output(GradeDocuments)

# Prompt
system = """You are a grader assessing relevance of a retrieved document to a user question. \n
    It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    If the document contains keyword(s) or semantic meaning related to the user question, grade it as relevant. \n
    Give a score from 1 (not relevant) to 10 (perfectly relevant) to indicate whether the document is relevant to the question."""
grade_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved document: \n\n {document} \n\n User question: {question}"),
    ]
)

reranker5 = grade_prompt | structured_llm_grader
question = "What is the specific country and city where the project is being implemented?"
doc_txt = """
The location of the project is in Paser District (Adang Bay village) and Kutai
            Kartanegara district (Delta Mahakam) East Kalimantan Province. The location
            of project is nearby the new capital of Indonesia which is in the Penajam
            Paser Utara (around 130-160 km)
"""
eval=reranker5.invoke({"question": question, "document": doc_txt}).score
print(eval)
# Out:
# 8

# %% [markdown]
# Tester les rerankers sur un exemple simple

# %%
query = "What is the capital of France?"
documents = [
    "Paris is the capital of France.",
    "Berlin is the capital of Germany.",
    "London is the capital of the United Kingdom."
]

rerankers=[
    {"type": "crossencoder", "name": "ms-marco-MiniLM", "instance": reranker1},
    {"type": "pipeline", "name": "bge-reranker-v2-m3", "instance": reranker2},
    {"type": "sentence_transformer", "name": "gte-multilingual-reranker-base", "instance": reranker3},
    {"type": "pipeline", "name": "bge-reranker-v2-gemma", "instance": reranker4},
    {"type": "llm", "name": "gpt4o-mini", "instance": reranker5},
]




# Rerank documents based on the query
def rank_documents(documents, query, rerankers=rerankers, print_time=False):
    from langchain.schema import Document
    from time import time as timing

    ranking_results=[]
    doc_num=1
    for doc in documents:
        if type(doc)==Document:
            content=doc.page_content
        elif type(doc)==str:
            content=doc

        for reranker in rerankers:
            t=timing()
            if reranker["type"]=="crossencoder":
                score=reranker["instance"].predict((query, content))
            elif reranker["type"]=="pipeline":
                score=reranker["instance"]([query, content])[1]["score"]
            elif reranker["type"]=="sentence_transformer":
                embeddings=reranker["instance"].encode([query, content])
                score= reranker["instance"].similarity(embeddings[0], embeddings[1]).flatten().tolist()[0]
            elif reranker["type"]=="llm":
                score= reranker["instance"].invoke({"question": query, "document": doc}).score

            ranking_results.append({
                "doc_#": doc_num, "doc": doc, "score": score, "reranker_type": reranker["type"], 
                "reranker_name": reranker["name"],
            })

            if print_time:
                print(f"""time {reranker["name"]}: {timing()-t}""")
        doc_num+=1
                
    return ranking_results

# %%
import pandas as pd
ranking_results=rank_documents(documents, query, print_time=True)
pd.DataFrame(ranking_results)
# Out:
# time ms-marco-MiniLM: 0.026719331741333008
# time bge-reranker-v2-m3: 0.28534626960754395
# time gte-multilingual-reranker-base: 0.026337146759033203
# time bge-reranker-v2-gemma: 0.23152661323547363
# time gpt4o-mini: 0.5652215480804443
# time ms-marco-MiniLM: 0.017348527908325195
# time bge-reranker-v2-m3: 0.30226826667785645
# time gte-multilingual-reranker-base: 0.024649858474731445
# time bge-reranker-v2-gemma: 0.21747374534606934
# time gpt4o-mini: 0.5332901477813721
# time ms-marco-MiniLM: 0.015106916427612305
# time bge-reranker-v2-m3: 0.27315521240234375
# time gte-multilingual-reranker-base: 0.02592635154724121
# time bge-reranker-v2-gemma: 0.21768593788146973
# time gpt4o-mini: 0.6181278228759766
#     doc_#                                           doc      score  \
# 0       1               Paris is the capital of France.   8.500708
# 1       1               Paris is the capital of France.   0.918915
# 2       1               Paris is the capital of France.   0.932206
# 3       1               Paris is the capital of France.   0.985271
# 4       1               Paris is the capital of France.  10.000000
# 5       2             Berlin is the capital of Germany.  -2.541009
# 6       2             Berlin is the capital of Germany.   0.726833
# 7       2             Berlin is the capital of Germany.   0.867957
# 8       2             Berlin is the capital of Germany.   0.985496
# 9       2             Berlin is the capital of Germany.   1.000000
# 10      3  London is the capital of the United Kingdom.  -2.174299
# 11      3  London is the capital of the United Kingdom.   0.930457
# 12      3  London is the capital of the United Kingdom.   0.859547
# 13      3  London is the capital of the United Kingdom.   0.983597
# 14      3  London is the capital of the United Kingdom.   1.000000
#
#            reranker_type                   reranker_name
# 0           crossencoder                 ms-marco-MiniLM
# 1               pipeline              bge-reranker-v2-m3
# 2   sentence_transformer  gte-multilingual-reranker-base
# 3               pipeline           bge-reranker-v2-gemma
# 4                    llm                      gpt4o-mini
# 5           crossencoder                 ms-marco-MiniLM
# 6               pipeline              bge-reranker-v2-m3
# 7   sentence_transformer  gte-multilingual-reranker-base
# 8               pipeline           bge-reranker-v2-gemma
# 9                    llm                      gpt4o-mini
# 10          crossencoder                 ms-marco-MiniLM
# 11              pipeline              bge-reranker-v2-m3
# 12  sentence_transformer  gte-multilingual-reranker-base
# 13              pipeline           bge-reranker-v2-gemma
# 14                   llm                      gpt4o-mini

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


import string

def remove_punctuation(text):
    text_no_punctuation = text.translate(str.maketrans('', '', string.punctuation))
    words = text_no_punctuation.split()
    return words

def keyword_association_retriever(query, top_k=10, documents=split_docs, print_keywords=False):
    query_keywords = llm_extract_keyworks.invoke({"question":query})
    # print(query_keywords)
    query_keywords = remove_punctuation(query_keywords)  # Liste des mots-clés dans la requête
    if print_keywords:
        print(query_keywords)
    results = []


    for doc in documents:
        doc_text = doc.page_content.lower()
        # Compter les cooccurrences des mots-clés dans le document
        keyword_matches = sum(1 for word in query_keywords if word.lower() in doc_text)
        # Pondérer le score par la densité des mots-clés
        try:
            score = keyword_matches / len(doc_text.split())
        except Exception as e:
            print(e)
            score=0

        results.append((doc, score))

    # Trier les résultats par score
    ranked_results = sorted(results, key=lambda x: x[1], reverse=True)
    return [doc for doc, _ in ranked_results[:top_k]]

system_prompt_exact="""Extract the most relevant keywords from the following text to facilitate searching for important documents containing these terms. 
    Only provide the extracted keywords, without additional text or explanations.
"""

system_prompt_synonyms="""Extract the most relevant keywords from the following text to facilitate searching for important documents.  

- For each extracted keyword, also include its closest synonyms.  
- Return all keywords and synonyms in a **single flat list**, without categorization, explanations, or additional text.  
- Ensure the extracted terms are meaningful and relevant to the text's context.  

### **Output Format:**  
A **comma-separated** flat list of keywords and their closest synonyms.  
"""

prompt_extract_keyworks = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt_exact),
        ("human", "{question}"),
    ]
)
llm_extract_keyworks = prompt_extract_keyworks | llm_qa | StrOutputParser()
# resp=llm_extract_keyworks.invoke(question)
# remove_punctuation(resp)

# %%
# Bench des retrievers
from langchain.retrievers import BM25Retriever, TFIDFRetriever
import pandas as pd
import numpy as np


question = "Context, environment, project rationale and challenges"
enhanced_query= question_rewriter.invoke({"question": question})
print(f"Enhanced query: {enhanced_query}")

# récu des pages du pdf associées aux fragments de docs
def get_pages(d):
    return d.metadata["pages"]


# détecter si la page retournée par le retriever est dans la bonne plage de pages pour la question posée


target_pages=np.arange(8, 19)
def in_target(pages):
    nb_pages_in_target=0
    for p in pages:
        if p in target_pages:
            nb_pages_in_target+=1
    return nb_pages_in_target
    
# stockages des stats de bonne couverture des pages cibles
stats_is_target=[]
global_ranking_results=[]

for i in range(0, len(databases)):
    # get params
    faiss_db=databases[i]["db"]
    split_docs=databases[i]["split_docs"]
    chunk_size=databases[i]["chunk_size"]

    print(f"""Chunk size: {chunk_size}\n""")
    print(f"Nb docs: {len(split_docs)}\n\n")

    # build retievers
    search_type="mmr"
    retriever_faiss = faiss_db.as_retriever(
        search_kwargs={
            "k": 15, 
            "fetch_k": 40
        },
        search_type= search_type
    )

    sparse_retriever_tfidf = TFIDFRetriever.from_documents(
        documents=split_docs,
        k=15,
        tfidf_params={"min_df":1,
                "max_df":2,
                "ngram_range":(1, 2)}
        )



    # get docs
    result_dense = retriever_faiss.invoke(enhanced_query)
    result_dense = [doc.metadata.update({"type": "dense"}) or doc for doc in result_dense]

    result_sparse = sparse_retriever_tfidf.invoke(enhanced_query)
    result_sparse = [doc.metadata.update({"type": "sparse"}) or doc for doc in result_sparse]

    result_lexical= keyword_association_retriever(query=enhanced_query, top_k=10, documents=split_docs, print_keywords=False)
    result_lexical = [doc.metadata.update({"type": "lexical"}) or doc for doc in result_lexical]


    # Fusionner docs
    combined_results = result_dense+result_sparse+result_lexical

    # Supprimer les doublons
    unique_results = {doc.page_content: doc for doc in combined_results}.values()

    print(f"Combined docs: {len(combined_results)}")
    print(f"Unique docs: {len(unique_results)}")

    # ranking des docs
    print("Ranking docs")
    ranking_results=rank_documents(unique_results, enhanced_query)

    # ajout chunk_size & pages source
    ranking_results=[e.update({
        "chunk_size":chunk_size, "pages":e["doc"].metadata["pages"], "nb_pages": len(e["doc"].metadata["pages"])
    }) or e for e in ranking_results]

    global_ranking_results=global_ranking_results+ranking_results

    
 

    print(f"\n------------\n")
# Out:
# Enhanced query: What is the context, environment, rationale, and the challenges associated with the project?
# Chunk size: 500
#
# Nb docs: 253
#
#
# Combined docs: 40
# Unique docs: 35
# Ranking docs
#
# ------------
#
# Chunk size: 1000
#
# Nb docs: 123
#
#
# Combined docs: 40
# Unique docs: 32
# Ranking docs
#
# ------------
#
# Chunk size: 1500
#
# Nb docs: 82
#
#
# Combined docs: 40
# Unique docs: 31
# Ranking docs
#
# ------------
#
# Chunk size: 2000
#
# Nb docs: 62
#
#
# Combined docs: 40
# Unique docs: 29
# Ranking docs
#
# ------------
#
# Chunk size: 3000
#
# Nb docs: 41
#
#
# Combined docs: 40
# Unique docs: 28
# Ranking docs
#
# ------------
#
# Chunk size: 4000
#
# Nb docs: 31
#
#
# Combined docs: 40
# Unique docs: 23
# Ranking docs
#
# ------------
#
# Chunk size: 5000
#
# Nb docs: 25
#
#
# Combined docs: 40
# Unique docs: 23
# Ranking docs
#
# ------------
#
# Chunk size: 6000
#
# Nb docs: 21
#
#
# Combined docs: 40
# Unique docs: 20
# Ranking docs
#
# ------------

# %%
df_global_ranking_results= pd.DataFrame(global_ranking_results)
df_global_ranking_results['pages_in_target']=df_global_ranking_results["pages"].apply(in_target)
df_global_ranking_results['%_pages_in_target']=df_global_ranking_results["pages_in_target"]/df_global_ranking_results["nb_pages"]
df_global_ranking_results[(df_global_ranking_results["chunk_size"]==500)&(df_global_ranking_results["reranker_name"]=="gpt4o-mini")].head()
# Out:
#     doc_#                                                doc  score  \
# 4       1  page_content='environmental \ncontext\n1) The ...    6.0
# 9       2  page_content='but a new variant emerged, namel...    6.0
# 14      3  page_content=' Identification and mapping of ...    4.0
# 19      4  page_content='FPIC (Free, Prior, and Informed ...    3.0
# 24      5  page_content='understanding the gender issue, ...    7.0
#
#    reranker_type reranker_name  chunk_size     pages  nb_pages  \
# 4            llm    gpt4o-mini         500  [40, 41]         2
# 9            llm    gpt4o-mini         500  [15, 16]         2
# 14           llm    gpt4o-mini         500  [47, 48]         2
# 19           llm    gpt4o-mini         500      [29]         1
# 24           llm    gpt4o-mini         500  [35, 36]         2
#
#     pages_in_target  %_pages_in_target
# 4                 0                0.0
# 9                 2                1.0
# 14                0                0.0
# 19                0                0.0
# 24                0                0.0

# %%
# analyse du ranking
stats_is_target=[]


for reranker in df_global_ranking_results["reranker_name"].unique():
    for chunk_size in df_global_ranking_results["chunk_size"].unique():
        # filtre sur reranker
        _df_ranking_results= df_global_ranking_results[
            (df_global_ranking_results["reranker_name"]==reranker)&
            (df_global_ranking_results["chunk_size"]==chunk_size)].sort_values("score", ascending=False).reset_index(drop=True)

        # stats first half    
        df_first_half=_df_ranking_results.loc[: int(len(_df_ranking_results)/2)]
        nb_positiv_pages_first_half= df_first_half["pages_in_target"].sum()
        rate_positiv_pages_first_half= df_first_half["pages_in_target"].sum()/df_first_half["nb_pages"].sum()

        # stats last half
        df_last_half=_df_ranking_results.loc[int(len(_df_ranking_results)/2)+1:]
        nb_positiv_pages_last_half= df_last_half["pages_in_target"].sum()
        rate_positiv_pages_last_half= df_last_half["pages_in_target"].sum()/df_last_half["nb_pages"].sum()

        stats_is_target.append({
            "chunk_size": chunk_size, "reranker": reranker, 
            "#_pages": _df_ranking_results["nb_pages"].sum(),
            "%_pages_in_target": _df_ranking_results["pages_in_target"].sum()/_df_ranking_results["nb_pages"].sum(),            
            "nb_positive_pages_first_half": nb_positiv_pages_first_half,
            "%_positive_pages_first_half": rate_positiv_pages_first_half,
            "nb_positive_pages_last_half": nb_positiv_pages_last_half,
            "%_positive_pages_last_half": rate_positiv_pages_last_half    
        })

# %%
df_stats_is_target= pd.DataFrame(stats_is_target)
df_stats_is_target.head()
# Out:
#    chunk_size         reranker  #_pages  %_pages_in_target  \
# 0         500  ms-marco-MiniLM       54           0.370370
# 1        1000  ms-marco-MiniLM       48           0.333333
# 2        1500  ms-marco-MiniLM       61           0.344262
# 3        2000  ms-marco-MiniLM       59           0.271186
# 4        3000  ms-marco-MiniLM       73           0.246575
#
#    nb_positive_pages_first_half  %_positive_pages_first_half  \
# 0                             9                     0.321429
# 1                             8                     0.320000
# 2                            12                     0.387097
# 3                            13                     0.406250
# 4                            13                     0.333333
#
#    nb_positive_pages_last_half  %_positive_pages_last_half
# 0                           11                    0.423077
# 1                            8                    0.347826
# 2                            9                    0.300000
# 3                            3                    0.111111
# 4                            5                    0.147059

# %%
df_stats_is_target.to_csv("./retrievers-benchmark-stats_is_target.csv", index=False)
df_global_ranking_results.to_csv("./retrievers-benchmark-global_ranking_results.csv", index=False)

# df_stats_is_target= pd.read_csv("./retrievers-benchmark-stats_is_target.csv",)
# df_global_ranking_results=pd.read_csv("./retrievers-benchmark-global_ranking_results.csv",)

# %% [markdown]
# #### Visualisation des résultats
# Nous cherchons à vérifier comment évolue la pertinence des fragments de documents sélectionnés (cad leur appartenance à la plage des pages 8-18), selon le type de reranker utilisé, et la taille des fragments, mesurée en nombre de caractères
#
# Dans le tableau ci dessous, nous pouvons voir que sur le top 10 des documents les mieux évalués par `gpt4o-mini`, 60% tombent effectivement dans la bonne plage de pages (pages_in_target)

# %%
best_docs=df_global_ranking_results[
    (df_global_ranking_results["reranker_name"]=="gpt4o-mini")&
    (df_global_ranking_results["chunk_size"]==1500)
].sort_values("score", ascending=False).head(10)
display(best_docs)
best_docs["%_pages_in_target"].sum()
# Out:
#      doc_#                                                doc  score  \
# 474     28  page_content='and demographic problems and cha...    9.0
# 384     10  page_content='depends and confirms challenges ...    8.0
# 374      8  page_content='continue  but  still  pay  atten...    8.0
# 409     15  page_content='(BKSDA) \n \nYML still has a lac...    8.0
# 404     14  page_content='Table of contents\n1. IMPLEMENTI...    8.0
# 464     26  page_content='especially that of Java Island. ...    8.0
# 469     27  page_content='environment, and others item (ac...    8.0
# 444     22  page_content='land is available for opening po...    8.0
# 354      4  page_content='conservation value in Balikpapan...    8.0
# 349      3  page_content='hazards and natural disasters in...    8.0
#
#     reranker_type reranker_name  chunk_size         pages  nb_pages  \
# 474           llm    gpt4o-mini        1500          [13]         1
# 384           llm    gpt4o-mini        1500  [15, 16, 17]         3
# 374           llm    gpt4o-mini        1500      [16, 17]         2
# 409           llm    gpt4o-mini        1500      [42, 43]         2
# 404           llm    gpt4o-mini        1500     [3, 4, 5]         3
# 464           llm    gpt4o-mini        1500      [13, 14]         2
# 469           llm    gpt4o-mini        1500      [21, 22]         2
# 444           llm    gpt4o-mini        1500      [15, 16]         2
# 354           llm    gpt4o-mini        1500        [8, 9]         2
# 349           llm    gpt4o-mini        1500     [3, 4, 5]         3
#
#      pages_in_target  %_pages_in_target
# 474                1                1.0
# 384                3                1.0
# 374                2                1.0
# 409                0                0.0
# 404                0                0.0
# 464                2                1.0
# 469                0                0.0
# 444                2                1.0
# 354                2                1.0
# 349                0                0.0
# 6.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cols=[
    {"col": "%_pages_in_target", "label": "% de bonnes pages détectées par reranker / total des fragments du retriever"},
    {"col": "%_positive_pages_first_half", "label": "% de bonnes pages dans la 1ere moitiée de la liste"}
]

for col in cols:
    sns.set(style="whitegrid")

    plt.figure(figsize=(10, 6))
    sns.barplot(
        x="chunk_size",
        y=col["col"],
        hue="reranker",
        data=df_stats_is_target,
        palette="tab10", 
    )

    # labels and title
    plt.xlabel("Chunk Size")
    plt.ylabel(col["col"])
    plt.title(col["label"])

    plt.legend(title="Reranker", bbox_to_anchor=(1.05, 1), loc="upper left")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Conclusions:
# * Le taux de sélection des bonnes pages (9 à 18), sur la totalité des documents sélectionnés par les retrievers, ne dépasse pas 40%
# * Le taux de sélection des bonnes pages (9 à 18), sur les 15 premiers documents, ne dépasse pas 60%
# * Le taux de bonne sélection est le plus haut pour la taille de fragment 1500 caractères
# * Le seul reranker qui présente des performances consistantes est `bge-reranker-v2-gemma` (basé sur un fine tuning du llm gemma 3b)
# * Hors LLM (gemma et gpt), `BGE reranker v2 mini` est le meilleur compromis jusqu'à 1500 cacactères (modèle spécialisé, très léger)
# * Ce travail ayant été motivé par l'article longRAG n'a pas confirmé ses résultats, affirmant que des documents avec un long contexte, combinés avec des rerankers efficaces, permet d'extraire les fragments les plus pertinents
