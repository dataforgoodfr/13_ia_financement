# %%
from docx import Document
import re
from collections import defaultdict
import spacy
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# Charger le modèle NLP pour le résumé automatique
nlp = spacy.load("en_core_web_sm")

def extract_themes_summaries(doc_path):
    doc = Document(doc_path)
    
    # Vérification du nombre de paragraphes
    if len(doc.paragraphs) == 0:
        print("Aucun paragraphe détecté dans le document.")
        return {}
    
    themes = defaultdict(list)
    current_theme = "Autre"  # Thème par défaut
    
    for para in doc.paragraphs:
        text = para.text.strip()
        
        # Affichage des styles pour diagnostic
        print(f"Texte: {text[:50]}... | Style: {para.style.name}")
        
        # Détection améliorée des thématiques (inclut titres sans styles spécifiques)
        if (
            para.style.name in ['Heading 1', 'Heading 2', 'Heading 3'] or
            text.isupper() or
            re.match(r'^(\d+\.\s+|[A-Z][a-z]+\s+[A-Z][a-z]+)', text) or  # Détection de numérotation et titres courants
            len(text.split()) < 6  # Texte court = probablement un titre
        ):
            current_theme = text
            themes[current_theme] = []
            continue
        
        # Ajout du texte sous la thématique courante
        if current_theme in themes:
            themes[current_theme].append(text)
    
    # Vérification des thématiques extraites
    print("Thématiques détectées:", themes.keys())
    
    # Génération d'un résumé optimisé par NLP et TextRank
    summaries = {}
    for theme, texts in themes.items():
        full_text = " ".join(texts)
        if not full_text.strip():
            summaries[theme] = "Aucune information disponible."
            continue
        
        doc_nlp = nlp(full_text)
        sentences = [sent.text for sent in doc_nlp.sents]
        
        if len(sentences) > 3:
            # Utilisation de TF-IDF pour identifier les phrases les plus informatives
            vectorizer = TfidfVectorizer()
            tfidf_matrix = vectorizer.fit_transform(sentences)
            sentence_scores = np.array(tfidf_matrix.sum(axis=1)).flatten()
            top_sentence_indices = sentence_scores.argsort()[-3:][::-1]
            summary_sentences = [sentences[i] for i in sorted(top_sentence_indices)]
            summaries[theme] = " ".join(summary_sentences)
        else:
            summaries[theme] = full_text if full_text else "Aucune information disponible."
    
    return summaries

# Exemple d'utilisation
doc_path = "../data/projet_1/PU_P01_AAP01.docx"  # Remplace par ton fichier
theme_summaries = extract_themes_summaries(doc_path)

# Affichage formaté des résultats
for theme, summary in theme_summaries.items():
    print(f"\n### {theme} ###")
    print(f"Résumé: {summary}\n")
# Out:
# Texte: * Please fill it out briefly with a total length l... | Style: Normal
# Texte: ... | Style: Normal
# Texte: For Standard Grant... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Project objective　(Explain which GBF goal project ... | Style: Normal
# Texte: Note: Please specify which target(s) your project ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 2.  Project implementation plan... | Style: Normal
# Texte: (Please describe the projects by year and items.)... | Style: Normal
# Texte: Note; For project, please describe not only fiscal... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Applying FY... | Style: List Paragraph
# Texte: FY(s) before applying FY... | Style: List Paragraph
# Texte: FY(s) after applying FY... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 3．Expected concrete activity results... | Style: Normal
# Texte: Note; For project, please describe not only applyi... | Style: Normal
# Texte: ... | Style: Normal
# Texte: （１）	Applying FY... | Style: Normal
# Texte: （２）	FY(s) before applying FY... | Style: Normal
# Texte: （３）	FY(s) after applying FY... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 4.  Activity schedule... | Style: Normal
# Texte: Note; For project, please,describe not only applyi... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Applying FY... | Style: List Paragraph
# Texte: FY(s) before applying FY... | Style: List Paragraph
# Texte: FY(s) after applying FY... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 4. Activity schedule... | Style: Normal
# Texte: Note: Please use multiple pages depending on the d... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 5. Income and Expenditure Budget plan... | Style: Footer
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: Note;... | Style: Normal
# Texte: For multi-year project, please describe not only a... | Style: List Paragraph
# Texte: Divide expenditure type into individual “Exp Item”... | Style: List Paragraph
# Texte: Add rows for Exp Item and columns for Funding Sour... | Style: List
# Texte: Convert local, or US, currency into in Japanese ye... | Style: List
# Texte: ... | Style: List
# Texte: （１）Applying FY... | Style: Normal
# Texte: ... | Style: List
# Texte: （２）	FY(s) before applying FY... | Style: Normal
# Texte: ... | Style: List
# Texte: （３）	FY(s) after applying FY... | Style: Normal
# Texte: Please add rows for Exp Item and add columns for F... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 6. The name and contact information of the experts... | Style: List
# Texte: Note; Attach recommendations, if any, which will b... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 7. Local approvals (if you need local government a... | Style: List
# Texte: Note; Attach contracts or agreement with local gov... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 8. Partners (if you partner with a local NGO or ot... | Style: List
# Texte: Note; Attach contracts or cooperative agreements w... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 9. Japanese Introducer (Name and contact informati... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Historical background... | Style: List
# Texte: ・date: Date of foundation... | Style: List Continue
# Texte: ・History including past activities;... | Style: List Continue
# Texte: Indicate year, supported party, project cost, and ... | Style: List Continue
# Texte: ... | Style: List
# Texte: Organization... | Style: List
# Texte: Form of the organization... | Style: List Continue
# Texte: ・Organization with legal personality；... | Style: List Continue
# Texte: Attach official document(s) proving your legal sta... | Style: List Continue
# Texte: ・Voluntary organization or group... | Style: List Continue
# Texte: Attach external audits of operations and accountin... | Style: List Continue
# Texte: ・Staff number... | Style: List Continue
# Texte: ・Director... | Style: List Continue
# Texte: ・Permanent staff... | Style: List Continue
# Texte: ・Non-permanent staff... | Style: List Continue
# Texte: Attach an organizational Chart... | Style: List Continue
# Texte: Representative... | Style: List
# Texte: ・Full name... | Style: List
# Texte: ・Birth date... | Style: List
# Texte: ・Home address... | Style: List
# Texte: ・Mobilephone#... | Style: List
# Texte: ・Major accomplishment... | Style: List
# Texte: ・Other affiliations and positions.... | Style: List
# Texte: ... | Style: List
# Texte: Website URLs... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: Activities in the country implementing the project... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: Financial Situation... | Style: List
# Texte: Attach income and expenditure statement as well as... | Style: List
# Texte: ... | Style: Body Text First Indent 2
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Thématiques détectées: dict_keys(['', 'For Standard Grant', '2.  Project implementation plan', 'Applying FY', 'FY(s) before applying FY', 'FY(s) after applying FY', '3．Expected concrete activity results', '（１）\tApplying FY', '（２）\tFY(s) before applying FY', '（３）\tFY(s) after applying FY', '4.  Activity schedule', '4. Activity schedule', '5. Income and Expenditure Budget plan', 'Note;', '（１）Applying FY', '6. The name and contact information of the experts outside of applicant’s who will provive advice and guidance for the project implementation .', '7. Local approvals (if you need local government approvals or agreements with local residents, please describe the contents)', '8. Partners (if you partner with a local NGO or other international organization on the projects, please list the names of the organizations)', '9. Japanese Introducer (Name and contact information)', 'Historical background', '・date: Date of foundation', '・History including past activities;', 'Organization', 'Form of the organization', '・Organization with legal personality；', '・Voluntary organization or group', '・Staff number', '・Director', '・Permanent staff', '・Non-permanent staff', 'Attach an organizational Chart', 'Representative', '・Full name', '・Birth date', '・Home address', '・Mobilephone#', '・Major accomplishment', '・Other affiliations and positions.', 'Website URLs', 'Financial Situation'])
#
# ###  ###
# Résumé: Aucune information disponible.
#
#
# ### For Standard Grant ###
# Résumé: Aucune information disponible.
#
#
# ### 2.  Project implementation plan ###
# Résumé: (Please describe the projects by year and items.) Note; For project, please describe not only fiscal year for which this application is being submitted (“applying FY”, hereafter) but also other FY(s).
#
#
# ### Applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### FY(s) before applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### FY(s) after applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### 3．Expected concrete activity results ###
# Résumé: Note; For project, please describe not only applying FYbut also other FY(s).
#
#
# ### （１）	Applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### （２）	FY(s) before applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### （３）	FY(s) after applying FY ###
# Résumé: Please add rows for Exp Item and add columns for Funding Source as appropriate
#
#
# ### 4.  Activity schedule ###
# Résumé: Note; For project, please,describe not only applying FYbut also other FY(s).
#
#
# ### 4. Activity schedule ###
# Résumé: Note: Please use multiple pages depending on the duration of the project for multi-year project.
#
#
# ### 5. Income and Expenditure Budget plan ###
# Résumé: Aucune information disponible.
#
#
# ### Note; ###
# Résumé: For multi-year project, please describe not only applying FY but also other FY(s). Divide expenditure type into individual “Exp Item” and describe i)the total amount, ii)the amount for each funding source, and iii)calculation basis.for each. Add rows for Exp Item and columns for Funding Source as appropriate Convert local, or US, currency into in Japanese yen.
#
#
# ### （１）Applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### 6. The name and contact information of the experts outside of applicant’s who will provive advice and guidance for the project implementation . ###
# Résumé: Note; Attach recommendations, if any, which will be positively evaluated.
#
#
# ### 7. Local approvals (if you need local government approvals or agreements with local residents, please describe the contents) ###
# Résumé: Note; Attach contracts or agreement with local governments or local communities, if any, which will be positively evaluated.
#
#
# ### 8. Partners (if you partner with a local NGO or other international organization on the projects, please list the names of the organizations) ###
# Résumé: Note; Attach contracts or cooperative agreements with international organizations or NGOs, or recommendations concerning your project from the partner, if any, which will be positively evaluated.
#
#
# ### 9. Japanese Introducer (Name and contact information) ###
# Résumé: Aucune information disponible.
#
#
# ### Historical background ###
# Résumé: Aucune information disponible.
#
#
# ### ・date: Date of foundation ###
# Résumé: Aucune information disponible.
#
#
# ### ・History including past activities; ###
# Résumé: Indicate year, supported party, project cost, and web-site for each activity.
#
#
# ### Organization ###
# Résumé: Aucune information disponible.
#
#
# ### Form of the organization ###
# Résumé: Aucune information disponible.
#
#
# ### ・Organization with legal personality； ###
# Résumé: Attach official document(s) proving your legal status
#
#
# ### ・Voluntary organization or group ###
# Résumé: Attach external audits of operations and accounting, if any.
#
#
# ### ・Staff number ###
# Résumé: Aucune information disponible.
#
#
# ### ・Director ###
# Résumé: Aucune information disponible.
#
#
# ### ・Permanent staff ###
# Résumé: Aucune information disponible.
#
#
# ### ・Non-permanent staff ###
# Résumé: Aucune information disponible.
#
#
# ### Attach an organizational Chart ###
# Résumé: Aucune information disponible.
#
#
# ### Representative ###
# Résumé: Aucune information disponible.
#
#
# ### ・Full name ###
# Résumé: Aucune information disponible.
#
#
# ### ・Birth date ###
# Résumé: Aucune information disponible.
#
#
# ### ・Home address ###
# Résumé: Aucune information disponible.
#
#
# ### ・Mobilephone# ###
# Résumé: Aucune information disponible.
#
#
# ### ・Major accomplishment ###
# Résumé: Aucune information disponible.
#
#
# ### ・Other affiliations and positions. ###
# Résumé: Aucune information disponible.
#
#
# ### Website URLs ###
# Résumé: Aucune information disponible.
#
#
# ### Financial Situation ###
# Résumé: Attach income and expenditure statement as well as balance sheet, preferably audited, for last three fiscal years. For audited, attach the auditor's comment and signature, if any.

# %%
import requests

response = requests.post(
    "http://127.0.0.1:11435/api/generate",
    json={"model": "mistral", "prompt": "Bonjour, comment vas-tu ?", "stream": False},
)

print(response.json())
# Out:
# {'error': "model 'mistral' not found"}

# %%
from docx import Document
import re
from collections import defaultdict
import spacy
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# Charger le modèle NLP pour le résumé automatique
nlp = spacy.load("en_core_web_sm")

def is_valid_theme(text):
    """ Vérifie si un texte est un titre valide """
    invalid_starts = ["Note", "・", "Attach", "Please", "1000 caractères restants", "Ce champ est requis"]
    if len(text.split()) < 3 or any(text.startswith(prefix) for prefix in invalid_starts):
        return False
    return True

def extract_themes_summaries(doc_paths):
    all_summaries = {}
    
    for doc_path in doc_paths:
        doc = Document(doc_path)
        
        # Vérification du nombre de paragraphes
        if len(doc.paragraphs) == 0:
            print(f"Aucun paragraphe détecté dans {doc_path}.")
            continue
        
        themes = defaultdict(list)
        current_theme = "Autre"  # Thème par défaut
        
        for para in doc.paragraphs:
            text = para.text.strip()
            
            # Affichage des styles pour diagnostic
            print(f"Texte: {text[:50]}... | Style: {para.style.name}")
            
            # Détection améliorée des thématiques
            if (
                para.style.name in ['Heading 1', 'Heading 2', 'Heading 3'] or
                text.isupper() or
                re.match(r'^(\d+\.\s+|[A-Z][a-z]+\s+[A-Z][a-z]+)', text) or  # Détection numérotation et titres
                len(text.split()) < 6  # Texte court = probablement un titre
            ) and is_valid_theme(text):
                current_theme = text
                themes[current_theme] = []
                continue
            
            # Ajout du texte sous la thématique courante
            if current_theme in themes:
                themes[current_theme].append(text)
        
        # Vérification des thématiques extraites
        print(f"Thématiques détectées dans {doc_path}: {themes.keys()}")
        
        # Génération d'un résumé optimisé par NLP et TextRank
        summaries = {}
        for theme, texts in themes.items():
            full_text = " ".join(texts)
            if not full_text.strip():
                summaries[theme] = "Aucune information disponible."
                continue
            
            doc_nlp = nlp(full_text)
            sentences = [sent.text for sent in doc_nlp.sents]
            
            if len(sentences) > 3:
                # Utilisation de TF-IDF pour identifier les phrases les plus informatives
                vectorizer = TfidfVectorizer()
                tfidf_matrix = vectorizer.fit_transform(sentences)
                sentence_scores = np.array(tfidf_matrix.sum(axis=1)).flatten()
                top_sentence_indices = sentence_scores.argsort()[-3:][::-1]
                summary_sentences = [sentences[i] for i in sorted(top_sentence_indices)]
                summaries[theme] = " ".join(summary_sentences)
            else:
                # Sélectionner la phrase la plus longue si le résumé est vide
                longest_sentence = max(sentences, key=len, default="Aucune information disponible.")
                summaries[theme] = longest_sentence
        
        all_summaries[doc_path] = summaries
    
    return all_summaries
# Exemple d'utilisation
doc_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
theme_summaries = extract_themes_summaries(doc_paths)

# Affichage formaté des résultats
for doc, summaries in theme_summaries.items():
    print(f"\n===== Résumé pour {doc} =====")
    for theme, summary in summaries.items():
        print(f"\n### {theme} ###")
        print(f"Résumé: {summary}\n")
# Out:
# Texte: * Please fill it out briefly with a total length l... | Style: Normal
# Texte: ... | Style: Normal
# Texte: For Standard Grant... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Project objective　(Explain which GBF goal project ... | Style: Normal
# Texte: Note: Please specify which target(s) your project ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 2.  Project implementation plan... | Style: Normal
# Texte: (Please describe the projects by year and items.)... | Style: Normal
# Texte: Note; For project, please describe not only fiscal... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Applying FY... | Style: List Paragraph
# Texte: FY(s) before applying FY... | Style: List Paragraph
# Texte: FY(s) after applying FY... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 3．Expected concrete activity results... | Style: Normal
# Texte: Note; For project, please describe not only applyi... | Style: Normal
# Texte: ... | Style: Normal
# Texte: （１）	Applying FY... | Style: Normal
# Texte: （２）	FY(s) before applying FY... | Style: Normal
# Texte: （３）	FY(s) after applying FY... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 4.  Activity schedule... | Style: Normal
# Texte: Note; For project, please,describe not only applyi... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Applying FY... | Style: List Paragraph
# Texte: FY(s) before applying FY... | Style: List Paragraph
# Texte: FY(s) after applying FY... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 4. Activity schedule... | Style: Normal
# Texte: Note: Please use multiple pages depending on the d... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 5. Income and Expenditure Budget plan... | Style: Footer
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: Note;... | Style: Normal
# Texte: For multi-year project, please describe not only a... | Style: List Paragraph
# Texte: Divide expenditure type into individual “Exp Item”... | Style: List Paragraph
# Texte: Add rows for Exp Item and columns for Funding Sour... | Style: List
# Texte: Convert local, or US, currency into in Japanese ye... | Style: List
# Texte: ... | Style: List
# Texte: （１）Applying FY... | Style: Normal
# Texte: ... | Style: List
# Texte: （２）	FY(s) before applying FY... | Style: Normal
# Texte: ... | Style: List
# Texte: （３）	FY(s) after applying FY... | Style: Normal
# Texte: Please add rows for Exp Item and add columns for F... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 6. The name and contact information of the experts... | Style: List
# Texte: Note; Attach recommendations, if any, which will b... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 7. Local approvals (if you need local government a... | Style: List
# Texte: Note; Attach contracts or agreement with local gov... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 8. Partners (if you partner with a local NGO or ot... | Style: List
# Texte: Note; Attach contracts or cooperative agreements w... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: 9. Japanese Introducer (Name and contact informati... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Historical background... | Style: List
# Texte: ・date: Date of foundation... | Style: List Continue
# Texte: ・History including past activities;... | Style: List Continue
# Texte: Indicate year, supported party, project cost, and ... | Style: List Continue
# Texte: ... | Style: List
# Texte: Organization... | Style: List
# Texte: Form of the organization... | Style: List Continue
# Texte: ・Organization with legal personality；... | Style: List Continue
# Texte: Attach official document(s) proving your legal sta... | Style: List Continue
# Texte: ・Voluntary organization or group... | Style: List Continue
# Texte: Attach external audits of operations and accountin... | Style: List Continue
# Texte: ・Staff number... | Style: List Continue
# Texte: ・Director... | Style: List Continue
# Texte: ・Permanent staff... | Style: List Continue
# Texte: ・Non-permanent staff... | Style: List Continue
# Texte: Attach an organizational Chart... | Style: List Continue
# Texte: Representative... | Style: List
# Texte: ・Full name... | Style: List
# Texte: ・Birth date... | Style: List
# Texte: ・Home address... | Style: List
# Texte: ・Mobilephone#... | Style: List
# Texte: ・Major accomplishment... | Style: List
# Texte: ・Other affiliations and positions.... | Style: List
# Texte: ... | Style: List
# Texte: Website URLs... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: Activities in the country implementing the project... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: ... | Style: List
# Texte: Financial Situation... | Style: List
# Texte: Attach income and expenditure statement as well as... | Style: List
# Texte: ... | Style: Body Text First Indent 2
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Thématiques détectées dans ../data/projet_1/PU_P01_AAP01.docx: dict_keys(['For Standard Grant', '2.  Project implementation plan', 'FY(s) before applying FY', 'FY(s) after applying FY', '3．Expected concrete activity results', '（１）\tApplying FY', '（２）\tFY(s) before applying FY', '（３）\tFY(s) after applying FY', '4.  Activity schedule', '4. Activity schedule', '5. Income and Expenditure Budget plan', '6. The name and contact information of the experts outside of applicant’s who will provive advice and guidance for the project implementation .', '7. Local approvals (if you need local government approvals or agreements with local residents, please describe the contents)', '8. Partners (if you partner with a local NGO or other international organization on the projects, please list the names of the organizations)', '9. Japanese Introducer (Name and contact information)', 'Form of the organization'])
# Texte: ... | Style: Normal
# Texte: Description du projet... | Style: Normal
# Texte: Ville et pays... | Style: Normal
# Texte: Ce champ est requis.... | Style: Normal
# Texte: Bénéficiaires visés... | Style: Normal
# Texte: Âge, activité, catégorie socio-professionnelle, ge... | Style: Normal
# Texte: Nombre de personnes concernées... | Style: Normal
# Texte: Contexte, environnement, justification et enjeux d... | Style: Normal
# Texte: 1000 caractères restants... | Style: Normal
# Texte: Résumé du projet... | Style: Normal
# Texte: 1000 caractères restants... | Style: Normal
# Texte: Date de début du projet... | Style: Normal
# Texte: Date de fin du projet... | Style: Normal
# Texte: Calendrier et étapes de réalisation du projet... | Style: Normal
# Texte: 1000 caractères restants... | Style: Normal
# Texte: Votre projet est-il soutenu par un collaborateur d... | Style: Normal
# Texte: Dans le cas où le porteur de projet n'est pas sala... | Style: Normal
# Texte: Oui... | Style: List Paragraph
# Texte: Non... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: 4 Budget prévisionnel du projet... | Style: Normal
# Texte: Montant global du projet (en Euros)... | Style: Normal
# Texte: EUR... | Style: Normal
# Texte: Montant du don demandé à la Fondation (en Euros)... | Style: Normal
# Texte: EUR... | Style: Normal
# Texte: Budget prévisionnel détaillé du projet... | Style: Normal
# Texte: Budget détaillé de l'entité porteuse du projet pou... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Lutte anti-corruption... | Style: Normal
# Texte: Votre entité possède-t-elle un programme de confor... | Style: Normal
# Texte: Quelle est la situation pénale de votre entité (en... | Style: Normal
# Texte: Les comptes de votre entité sont-ils certifiés par... | Style: Normal
# Texte: Y-a-t ‘il des agents publics dans les organes de g... | Style: Normal
# Texte: ... | Style: Normal
# Thématiques détectées dans ../data/projet_1/PU_P01_AAP02.docx: dict_keys(['Description du projet', 'Ville et pays', 'Âge, activité, catégorie socio-professionnelle, genre...', 'Nombre de personnes concernées', 'Résumé du projet', 'Date de début du projet', 'Date de fin du projet', '4 Budget prévisionnel du projet', 'Budget prévisionnel détaillé du projet'])
# Texte: FICHE PROJET A TREE FOR YOU... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Introduction... | Style: Normal
# Texte: ... | Style: Normal
# Texte: A Tree for You promeut, depuis 2017, l’arbre dans ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: A Tree for You, association à but non lucratif (lo... | Style: Normal
# Texte: ... | Style: Normal
# Texte: A Tree for You sélectionne ses projets et ses part... | Style: Normal
# Texte: Les projets sont réalisés avec des partenaires de ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Cette fiche projet vous prépare au passage devant ... | Style: Normal
# Texte: S’il s’agit du premier projet que vous présentez à... | Style: Normal
# Texte: Etant donné la situation actuelle, cet échange à l... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Une fois cet oral terminé, le comité décidera de v... | Style: Normal
# Texte: Si le partenaire et le projet sont sélectionnés, n... | Style: Normal
# Texte: ... | Style: Normal
# Texte: S'il s'agit de votre premier projet présenté à A T... | Style: Normal
# Texte: ... | Style: Normal
# Texte: D'autre part, A Tree for You est opérateur de plan... | Style: Normal
# Texte: ... | Style: Normal
# Texte: A Tree for You ne finance pas des cultures qui ser... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Nous vous remercions de votre implication pour com... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Description de la structure et des intervenants... | Style: List Paragraph
# Texte: Nom de la structure / Adresse postale / pays... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Statut (association, entreprise…) / n° SIRET ou RC... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Année de démarrage de l’activité... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Description de vos objectifs et de votre mode de f... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Responsable de projet (point de contact ATFY)... | Style: List Paragraph
# Texte: Nom, prénom / Fonction / Adresse email / Téléphone... | Style: List Paragraph
# Texte: CV du responsable de projet... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Responsable du projet sur le terrain (si différent... | Style: List Paragraph
# Texte: Nom, prénom / Fonction / Adresse email / Téléphone... | Style: List Paragraph
# Texte: CV du responsable du projet sur le terrain... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Contexte et enjeuX :... | Style: List Paragraph
# Texte: Pays / Nom du projet... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Contexte général du projet (contexte et problémati... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Insertion du projet dans un autre projet... | Style: List Paragraph
# Texte: Ce projet est-il la suite d'un projet pré-existant... | Style: List Paragraph
# Texte: Le projet présenté à A Tree for You est une sous-p... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Contexte spécifique pour le projet présenté à A Tr... | Style: List Paragraph
# Texte: Groupes cibles et des bénéficiaires finaux... | Style: List Paragraph
# Texte: Profil (famille, propriétaires, association, coopé... | Style: List Paragraph
# Texte: Répartition femme/homme... | Style: List Paragraph
# Texte: Nombre de bénéficiaires directs attendus... | Style: List Paragraph
# Texte: Tranche d’âge... | Style: List Paragraph
# Texte: Métiers / activités... | Style: List Paragraph
# Texte: Superficie des parcelles en moyenne / description ... | Style: List Paragraph
# Texte: S'agit-il d'un groupe ethnique particulier ? Si ou... | Style: List Paragraph
# Texte: Raisons motivant le choix des groupes cibles et id... | Style: List Paragraph
# Texte: Les bénéficiaires ont-ils déjà été clairement iden... | Style: List Paragraph
# Texte: Climat local / altitude / évolution constatée et a... | Style: List Paragraph
# Texte: Systèmes agricoles existant aujourd'hui et problèm... | Style: List Paragraph
# Texte: Description des systèmes agricoles historiques dan... | Style: List Paragraph
# Texte: Situation politique et économique de la région... | Style: List Paragraph
# Texte: Problématiques spécifiques liées aux sols... | Style: List Paragraph
# Texte: Problématiques spécifiques liées à l’eau... | Style: List Paragraph
# Texte: Problématiques spécifiques liées à la biodiversité... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: Description du projet... | Style: List Paragraph
# Texte: Type de projet (agroforesterie / foresterie / mixt... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Méthodologie et calendrier... | Style: List Paragraph
# Texte: Quels sont les objectifs et les grands principes d... | Style: List Paragraph
# Texte: Indiquez le calendrier précis des travaux et les m... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Essences et schémas de plantation... | Style: List Paragraph
# Texte: Liste des essences envisagées... | Style: List Paragraph
# Texte: Indiquez la liste des essences (noms latins obliga... | Style: List Paragraph
# Texte: Par rapport à cette liste, quel est votre engageme... | Style: List Paragraph
# Texte: Quelle est votre méthode sur le terrain pour attei... | Style: List Paragraph
# Texte: Pépinières... | Style: List Paragraph
# Texte: La pépinière sera-t-elle montée en propre pour le ... | Style: List Paragraph
# Texte: Comment les plants sont-ils obtenus ? La ou les pé... | Style: List Paragraph
# Texte: Quels sont les risques ou opportunités liés aux pé... | Style: List Paragraph
# Texte: Schémas / designs de plantation... | Style: List Paragraph
# Texte: Indiquez les schémas / designs de plantation... | Style: List Paragraph
# Texte: La configuration envisagée (essences choisies, pro... | Style: List Paragraph
# Texte: Comment la liste des essences et les schémas de pl... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Coordonnées GPS des plantations... | Style: List Paragraph
# Texte: Fournir les coordonnées en décimales, par exemple ... | Style: List Paragraph
# Texte: NB : si les coordonnées précises des parcelles à p... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Bénéfices attendus de ce projet... | Style: List Paragraph
# Texte: Décrivez les bénéfices pour l'environnement et l'h... | Style: List Paragraph
# Texte: Pour les sols... | Style: List Paragraph
# Texte: Pour le cycle de l'eau... | Style: List Paragraph
# Texte: Pour la biodiversité (flore et faune)... | Style: List Paragraph
# Texte: Pour le micro-climat... | Style: List Paragraph
# Texte: Pour la captation de carbone... | Style: List Paragraph
# Texte: Décrivez les bénéfices attendus pour les personnes... | Style: List Paragraph
# Texte: Bénéfices pour l’économie locale... | Style: List Paragraph
# Texte: Pour les personnes bénéficiaires du projet. Détail... | Style: List Paragraph
# Texte: De leur côté, qu'est-ce que les bénéficiaires atte... | Style: List Paragraph
# Texte: Comment les motivez-vous à participer au projet ?... | Style: List Paragraph
# Texte: En quoi votre projet est-il innovant et pourrait s... | Style: List Paragraph
# Texte: Allez-vous mettre en place des actions spécifiques... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Risques du projet... | Style: List Paragraph
# Texte: Quels sont les risques à anticiper sur ce projet ?... | Style: List Paragraph
# Texte: Bénéficiez-vous d'un retour d’expérience sur un pr... | Style: List Paragraph
# Texte: Description rapide du ou des projets... | Style: List Paragraph
# Texte: Quels ont été les problèmes rencontrés ? Quelles a... | Style: List Paragraph
# Texte: Comment s’assurer dans ce projet que ces mêmes pro... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Engagements de suivi et monitoring... | Style: List Paragraph
# Texte: Chez A Tree for You, nous nous engageons auprès de... | Style: Normal
# Texte: Des articles, avec des photos du projet, en frança... | Style: List Paragraph
# Texte: Un bilan technique et financier vous sera demandé ... | Style: List Paragraph
# Texte: Structures engagées sur le terrain... | Style: List Paragraph
# Texte: Pour la conception du projet en amont... | Style: List Paragraph
# Texte: Pour la conduite du projet au plus près du terrain... | Style: List Paragraph
# Texte: Pour la formation et la sensibilisation des bénéfi... | Style: List Paragraph
# Texte: Pour le suivi technique au fil des années... | Style: List Paragraph
# Texte: Pour l’audit régulier des progrès / problèmes à ré... | Style: List Paragraph
# Texte: Pour le pilotage, la coordination et la communicat... | Style: List Paragraph
# Texte: Précisez les indicateurs de mesure des résultats s... | Style: List Paragraph
# Texte: Chez A Tree for You, nous suivons un certain nombr... | Style: Normal
# Texte: Indicateurs quantitatifs :... | Style: Normal
# Texte: Nombre de bénéficiaires directs impliqués dans le ... | Style: List Paragraph
# Texte: Nombre de formations effectuées, nombre de jours d... | Style: List Paragraph
# Texte: Nombre de plants en pépinières par essence*... | Style: List Paragraph
# Texte: Nombre de plants distribués par essence aux bénéfi... | Style: List Paragraph
# Texte: Nombre d’arbres plantés par essence*... | Style: List Paragraph
# Texte: Nombre d’arbres pérennes au total* (avec un horizo... | Style: List Paragraph
# Texte: Bilan de captation carbone du projet... | Style: List Paragraph
# Texte: Etc.... | Style: List Paragraph
# Texte: Indicateurs qualitatifs :... | Style: Normal
# Texte: Témoignage des bénéficiaires de l’impact sur leur ... | Style: List Paragraph
# Texte: Retours, études ou mesures sur les bénéfices du pr... | Style: List Paragraph
# Texte: Etc.... | Style: List Paragraph
# Texte: Indiquez le rythme auquel vous pourrez rédiger des... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: ... | Style: Normal
# Texte: BUDGET... | Style: List Paragraph
# Texte: Montant global du besoin proposé à la collecte par... | Style: List Paragraph
# Texte: ... | Style: Normal
# Texte: Budget total du projet, détaillé par poste de coût... | Style: List Paragraph
# Texte: A indiquer par semestre ou trimestre la première a... | Style: Normal
# Texte: la demande de financement de A Tree For You de vos... | Style: List Paragraph
# Texte: ce qui relève de vos activités en propre (personne... | Style: List Paragraph
# Texte: ... | Style: List Paragraph
# Texte: Lien avec les autres financeurs... | Style: List Paragraph
# Texte: Où en sont vos demandes de financement en dehors d... | Style: List Paragraph
# Texte: Quid si ces demandes n'aboutissent pas ? Y a-t-il ... | Style: List Paragraph
# Texte: Quid si le projet ne pouvait être financé que part... | Style: List Paragraph
# Texte: ... | Style: List Paragraph
# Texte: ... | Style: List Paragraph
# Texte: PHOTOS... | Style: List Paragraph
# Texte: Merci de joindre des photos illustrant le projet e... | Style: Normal
# Texte: En format paysage, 480 x 640 si possible et de bon... | Style: List Paragraph
# Texte: Avec mention de l’auteur à créditer... | Style: List Paragraph
# Texte: Nom de fichier : sans espace, ni accents, ni carac... | Style: List Paragraph
# Texte: Avec une légende associée... | Style: List Paragraph
# Thématiques détectées dans ../data/projet_1/PU_P01_AAP03.docx: dict_keys(['FICHE PROJET A TREE FOR YOU', 'Année de démarrage de l’activité', 'CV du responsable de projet', 'Contexte et enjeuX\xa0:', 'Pays / Nom du projet', 'Nombre de bénéficiaires directs attendus', 'Métiers / activités', 'Problématiques spécifiques liées aux sols', 'Problématiques spécifiques liées à l’eau', 'Description du projet', 'Méthodologie et calendrier', 'Essences et schémas de plantation', 'Liste des essences envisagées', 'Schémas / designs de plantation', 'Coordonnées GPS des plantations', 'Bénéfices attendus de ce projet', 'Pour les sols', "Pour le cycle de l'eau", 'Pour le micro-climat', 'Pour la captation de carbone', 'Bénéfices pour l’économie locale', 'Risques du projet', 'Engagements de suivi et monitoring', 'Structures engagées sur le terrain', 'Indicateurs quantitatifs\xa0:', 'Nombre d’arbres plantés par essence*', 'Indicateurs qualitatifs\xa0:', 'Lien avec les autres financeurs', 'Avec une légende associée'])
#
# ===== Résumé pour ../data/projet_1/PU_P01_AAP01.docx =====
#
# ### For Standard Grant ###
# Résumé: Note: Please specify which target(s) your project contributes to the achievement of from the 23 targets listed as the 2030 action targets proposed in “Kunming-Montreal Global biodiversity framework (GBF) .
#
#
# ### 2.  Project implementation plan ###
# Résumé: Note; For project, please describe not only fiscal year for which this application is being submitted (“applying FY”, hereafter) but also other FY(s).
#
#
# ### FY(s) before applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### FY(s) after applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### 3．Expected concrete activity results ###
# Résumé: Note; For project, please describe not only applying FYbut also other FY(s).
#
#
# ### （１）	Applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### （２）	FY(s) before applying FY ###
# Résumé: Aucune information disponible.
#
#
# ### （３）	FY(s) after applying FY ###
# Résumé: Please add rows for Exp Item and add columns for Funding Source as appropriate
#
#
# ### 4.  Activity schedule ###
# Résumé: Note; For project, please,describe not only applying FYbut also other FY(s).
#
#
# ### 4. Activity schedule ###
# Résumé: Note: Please use multiple pages depending on the duration of the project for multi-year project.
#
#
# ### 5. Income and Expenditure Budget plan ###
# Résumé:     Note; For multi-year project, please describe not only applying FY but also other FY(s). Divide expenditure type into individual “Exp Item” and describe i)the total amount, ii)the amount for each funding source, and iii)calculation basis.for each. Add rows for Exp Item and columns for Funding Source as appropriate Convert local, or US, currency into in Japanese yen.
#
#
# ### 6. The name and contact information of the experts outside of applicant’s who will provive advice and guidance for the project implementation . ###
# Résumé: Note; Attach recommendations, if any, which will be positively evaluated.
#
#
# ### 7. Local approvals (if you need local government approvals or agreements with local residents, please describe the contents) ###
# Résumé: Note; Attach contracts or agreement with local governments or local communities, if any, which will be positively evaluated.
#
#
# ### 8. Partners (if you partner with a local NGO or other international organization on the projects, please list the names of the organizations) ###
# Résumé: Note; Attach contracts or cooperative agreements with international organizations or NGOs, or recommendations concerning your project from the partner, if any, which will be positively evaluated.
#
#
# ### 9. Japanese Introducer (Name and contact information) ###
# Résumé:            Historical background ・date: Date of foundation ・History including past activities; Indicate year, supported party, project cost, and web-site for each activity.
#
#
# ### Form of the organization ###
# Résumé: ・Organization with legal personality； Attach official document(s) proving your legal status ・Voluntary organization or group Attach external audits of operations and accounting, if any. ・Staff number ・Director ・Permanent staff ・Non-permanent staff Attach an organizational Chart Representative ・Full name ・Birth date ・Home address ・Mobilephone# ・Major accomplishment ・Other affiliations and positions.   Website URLs   Activities in the country implementing the project in the past, ongoing, and planned .     Financial Situation Attach income and expenditure statement as well as balance sheet, preferably audited, for last three fiscal years.
#
#
# ===== Résumé pour ../data/projet_1/PU_P01_AAP02.docx =====
#
# ### Description du projet ###
# Résumé: Aucune information disponible.
#
#
# ### Ville et pays ###
# Résumé: Ce champ est requis.
#
#
# ### Âge, activité, catégorie socio-professionnelle, genre... ###
# Résumé: Aucune information disponible.
#
#
# ### Nombre de personnes concernées ###
# Résumé: Contexte, environnement, justification et enjeux du projet 1000 caractères restants
#
#
# ### Résumé du projet ###
# Résumé: 1000 caractères restants
#
#
# ### Date de début du projet ###
# Résumé: Aucune information disponible.
#
#
# ### Date de fin du projet ###
# Résumé: Calendrier et étapes de réalisation du projet 1000 caractères restants Votre projet est-il soutenu par un collaborateur du groupe Michelin ? Dans le cas où le porteur de projet n'est pas salarié du groupe Michelin, veuillez indiquer si vous bénéficiez de l'appui d'un collaborateur du groupe. Oui
#
#
# ### 4 Budget prévisionnel du projet ###
# Résumé: Montant global du projet (en Euros) EUR Montant du don demandé à la Fondation (en Euros) EUR
#
#
# ### Budget prévisionnel détaillé du projet ###
# Résumé: Budget détaillé de l'entité porteuse du projet pour l'année en cours   Lutte anti-corruption Votre entité possède-t-elle un programme de conformité anti-corruption ? Quelle est la situation pénale de votre entité (entité juridique et dirigeants) ? Les comptes de votre entité sont-ils certifiés par un organisme agréé ?
#
#
# ===== Résumé pour ../data/projet_1/PU_P01_AAP03.docx =====
#
# ### FICHE PROJET A TREE FOR YOU ###
# Résumé:  Introduction  A Tree for You promeut, depuis 2017, l’arbre dans tous les territoires, dans le but de préserver et améliorer notre environnement, de développer l’emploi et notre qualité de vie mais aussi de favoriser les liens sociaux, globaux comme intergénérationnels, par la transmission d’un héritage symbolique vivant et durable.   A Tree for You, association à but non lucratif (loi 1901), est un opérateur de plantation, qui permet à des particuliers et des entreprises de soutenir des projets de plantation, en France et dans le monde, en faisant un don en échange de l’obtention d’un reçu pour lequel l’association a reçu un rescrit de l’administration fiscale.   Ainsi, un comité de pilotage est prévu dans la convention de partenariat qui vous permet d'alerter A Tree for You et de prendre des décisions communes, dès lors qu'il est anticipé qu'un élément de la convention ne pourra être respecté.
#
#
# ### Année de démarrage de l’activité ###
# Résumé:  Description de vos objectifs et de votre mode de fonctionnement global (100 – 150 mots environ)
#
#
# ### CV du responsable de projet ###
# Résumé:  Responsable du projet sur le terrain (si différent du responsable de projet) Nom, prénom / Fonction / Adresse email /
#
#
# ### Contexte et enjeuX : ###
# Résumé: Aucune information disponible.
#
#
# ### Pays / Nom du projet ###
# Résumé: Insertion du projet dans un autre projet Ce projet est-il la suite d'un projet pré-existant ? Le projet présenté à A Tree for You est une sous-partie d'un projet plus important ? Contexte spécifique pour le projet présenté à A Tree for You Groupes cibles et des bénéficiaires finaux Profil (famille, propriétaires, association, coopérative, etc.)
#
#
# ### Nombre de bénéficiaires directs attendus ###
# Résumé: Tranche d’âge
#
#
# ### Métiers / activités ###
# Résumé: Superficie des parcelles en moyenne / description des parcelles / superficie totale du projet S'agit-il d'un groupe ethnique particulier ? Raisons motivant le choix des groupes cibles et identification de leurs besoins et contraintes spécifiques Les bénéficiaires ont-ils déjà été clairement identifiés individuellement ? Climat local / altitude / évolution constatée et attendue de ce climat Systèmes agricoles existant aujourd'hui et problèmes à résoudre par le projet Description des systèmes agricoles historiques dans la région (essences, rotations des parcelles, alimentation...).
#
#
# ### Problématiques spécifiques liées aux sols ###
# Résumé: Aucune information disponible.
#
#
# ### Problématiques spécifiques liées à l’eau ###
# Résumé: Problématiques spécifiques liées à la biodiversité (faune et flore)
#
#
# ### Description du projet ###
# Résumé: Type de projet (agroforesterie / foresterie / mixte / autre...)
#
#
# ### Méthodologie et calendrier ###
# Résumé: Indiquez le calendrier précis des travaux et les méthodes associées (quoi-quand-comment-qui/avec qui-où).
#
#
# ### Essences et schémas de plantation ###
# Résumé: Aucune information disponible.
#
#
# ### Liste des essences envisagées ###
# Résumé: Pour chaque essence, indiquez les objectifs en termes de nombre d’arbres planté et de nombre d'arbres attendus in fine (après la reprise ou même après les premières éclaircies - indiquez à quelle date vous vous placez) Décrivez vos méthodes pour convaincre les pépiniéristes puis les bénéficiaires de ce choix d'essences. Pépinières La pépinière sera-t-elle montée en propre pour le projet ou allez-vous faire appel à des pépiniéristes (locaux / plus loin) ?
#
#
# ### Schémas / designs de plantation ###
# Résumé: Indiquez les schémas / designs de plantation La configuration envisagée (essences choisies, proportions relatives de ces essences et design des parcelles) a-t-elle déjà été testée dans la région ? Quel est le retour d'expérience (succès et difficultés agronomiques, économiques, débouchés des produits agricoles, etc.) ? (Experts ou expériences propres au planteur, experts locaux /internationaux, pépiniéristes locaux, pratiques traditionnelles dans la région, sources bibliographiques, autres structures pratiquant les mêmes types de plantation : ONG, état, institutions internationales, etc.).
#
#
# ### Coordonnées GPS des plantations ###
# Résumé: et non des virgules dans les nombres, des virgules entre deux points GPS, et pas d’espace.. NB : si les coordonnées précises des parcelles à planter ne sont pas connues à date de présentation du projet, merci d'indiquer la ou les zones globales de plantation envisagées.
#
#
# ### Bénéfices attendus de ce projet ###
# Résumé: Décrivez les bénéfices pour l'environnement et l'horizon de temps associé
#
#
# ### Pour les sols ###
# Résumé: Aucune information disponible.
#
#
# ### Pour le cycle de l'eau ###
# Résumé: Pour la biodiversité (flore et faune)
#
#
# ### Pour le micro-climat ###
# Résumé: Aucune information disponible.
#
#
# ### Pour la captation de carbone ###
# Résumé: Décrivez les bénéfices attendus pour les personnes et l'horizon de temps associé
#
#
# ### Bénéfices pour l’économie locale ###
# Résumé: Détaillez : revenus, apports en nature, résilience, santé, éducation, pratiques agricoles, alimentation, etc. En quoi votre projet est-il innovant et pourrait servir d’exemple à suivre pour d’autres acteurs régionaux ? Allez-vous mettre en place des actions spécifiques pour faire connaître votre projet et inspirer d’autres acteurs ?
#
#
# ### Risques du projet ###
# Résumé: Quelles sont les actions qui seront menées pour y faire face ? Bénéficiez-vous d'un retour d’expérience sur un projet similaire (même zone, mêmes problématiques, même type de population impacté) Description rapide du ou des projets Quels ont été les problèmes rencontrés ? Comment s’assurer dans ce projet que ces mêmes problèmes seront anticipés / évités ?
#
#
# ### Engagements de suivi et monitoring ###
# Résumé: Ce suivi se traduit par : Des articles, avec des photos du projet, en français et en anglais pour les donateurs de l’association : au moins 2 articles la première année et un article les années suivantes.
#
#
# ### Structures engagées sur le terrain ###
# Résumé: la sensibilisation des bénéficiaires Pour le suivi technique au fil des années Pour l’audit régulier des progrès / problèmes à résoudre sur le terrain Pour le pilotage, la coordination et la communication du projet sur minimum 3 années après la dernière plantation Précisez les indicateurs de mesure des résultats suivis dans les bilans techniques sur ce projet et la temporalité de ce suivi Chez A Tree for You, nous suivons un certain nombre d’indicateurs nous permettant de constater le succès de la plantation. A titre d’exemple, vous trouverez ci-après une liste d’indicateurs obligatoires* et potentiels.
#
#
# ### Indicateurs quantitatifs : ###
# Résumé: Nombre de bénéficiaires directs impliqués dans le projet et profils* Nombre de formations effectuées, nombre de jours de formation donnés, nombre de participants et profils (les mêmes que les bénéficiaires ?)
#
#
# ### Nombre d’arbres plantés par essence* ###
# Résumé: Nombre d’arbres pérennes au total* (avec un horizon de temps clairement établi)
#
#
# ### Indicateurs qualitatifs : ###
# Résumé: You  Budget total du projet, détaillé par poste de coût A indiquer par semestre ou trimestre la première année, séparant clairement la demande de financement de A Tree For You de vos éventuels autres sources (ou demandes) de financement, ce qui relève de vos activités en propre (personnels) des achats externes que vous pourrez faire sur le projet ou des versements à d'autres structures (coopératives...).
#
#
# ### Lien avec les autres financeurs ###
# Résumé: Quid si le projet ne pouvait être financé que partiellement par les donateurs de A Tree for You ou dans des délais importants par rapport à vos attentes ?    PHOTOS Merci de joindre des photos illustrant le projet et la zone précise dans des fichiers jpeg à part de cette demande et par WETRANSFER svp : En format paysage, 480 x 640 si possible et de bonne qualité Avec mention de l’auteur à créditer Nom de fichier : sans espace, ni accents, ni caractères spéciaux
#
#
# ### Avec une légende associée ###
# Résumé: Aucune information disponible.

# %%
import requests
from docx import Document
import re
from collections import defaultdict

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def is_valid_theme(text):
    """ Vérifie si un texte est un titre valide """
    invalid_starts = ["Note", "・", "Attach", "Please", "1000 caractères restants", "Ce champ est requis"]
    return len(text.split()) >= 3 and not any(text.startswith(prefix) for prefix in invalid_starts)

def ask_mixtral(prompt):
    """ Envoie une requête au modèle Mixtral pour classifier et résumer le texte """
    response = requests.post(
        OLLAMA_HOST,
        json={"model": "mixtral", "prompt": prompt, "stream": False}
    )
    return response.json().get("response", "Erreur: pas de réponse")

def extract_themes_summaries(doc_paths):
    all_summaries = {}

    for doc_path in doc_paths:
        doc = Document(doc_path)
        if len(doc.paragraphs) == 0:
            print(f"Aucun paragraphe détecté dans {doc_path}.")
            continue
        
        themes = defaultdict(list)
        current_theme = "Autre"  # Thème par défaut

        for para in doc.paragraphs:
            text = para.text.strip()
            if (
                para.style.name in ['Heading 1', 'Heading 2', 'Heading 3'] or
                text.isupper() or
                re.match(r'^(\d+\.\s+|[A-Z][a-z]+\s+[A-Z][a-z]+)', text) or
                len(text.split()) < 6
            ) and is_valid_theme(text):
                current_theme = text
                themes[current_theme] = []
                continue

            if current_theme in themes:
                themes[current_theme].append(text)

        print(f"Thématiques détectées dans {doc_path}: {themes.keys()}")

        summaries = {}
        for theme, texts in themes.items():
            full_text = " ".join(texts)
            if not full_text.strip():
                summaries[theme] = "Aucune information disponible."
                continue

            prompt = f"Catégorise et résume la section suivante d'un document d'appel à projet:\n\n{full_text}"
            mixtral_response = ask_mixtral(prompt)
            summaries[theme] = mixtral_response
        
        all_summaries[doc_path] = summaries

    return all_summaries

# Exemple d'utilisation avec tes fichiers
doc_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
theme_summaries = extract_themes_summaries(doc_paths)

# Affichage formaté des résultats
for doc, summaries in theme_summaries.items():
    print(f"\n===== Résumé pour {doc} =====")
    for theme, summary in summaries.items():
        print(f"\n### {theme} ###")
        print(f"Résumé et Classification: {summary}\n")
# Out:
# Thématiques détectées dans ../data/projet_1/PU_P01_AAP01.docx: dict_keys(['For Standard Grant', '2.  Project implementation plan', 'FY(s) before applying FY', 'FY(s) after applying FY', '3．Expected concrete activity results', '（１）\tApplying FY', '（２）\tFY(s) before applying FY', '（３）\tFY(s) after applying FY', '4.  Activity schedule', '4. Activity schedule', '5. Income and Expenditure Budget plan', '6. The name and contact information of the experts outside of applicant’s who will provive advice and guidance for the project implementation .', '7. Local approvals (if you need local government approvals or agreements with local residents, please describe the contents)', '8. Partners (if you partner with a local NGO or other international organization on the projects, please list the names of the organizations)', '9. Japanese Introducer (Name and contact information)', 'Form of the organization'])
# Thématiques détectées dans ../data/projet_1/PU_P01_AAP02.docx: dict_keys(['Description du projet', 'Ville et pays', 'Âge, activité, catégorie socio-professionnelle, genre...', 'Nombre de personnes concernées', 'Résumé du projet', 'Date de début du projet', 'Date de fin du projet', '4 Budget prévisionnel du projet', 'Budget prévisionnel détaillé du projet'])
# Thématiques détectées dans ../data/projet_1/PU_P01_AAP03.docx: dict_keys(['FICHE PROJET A TREE FOR YOU', 'Année de démarrage de l’activité', 'CV du responsable de projet', 'Contexte et enjeuX\xa0:', 'Pays / Nom du projet', 'Nombre de bénéficiaires directs attendus', 'Métiers / activités', 'Problématiques spécifiques liées aux sols', 'Problématiques spécifiques liées à l’eau', 'Description du projet', 'Méthodologie et calendrier', 'Essences et schémas de plantation', 'Liste des essences envisagées', 'Schémas / designs de plantation', 'Coordonnées GPS des plantations', 'Bénéfices attendus de ce projet', 'Pour les sols', "Pour le cycle de l'eau", 'Pour le micro-climat', 'Pour la captation de carbone', 'Bénéfices pour l’économie locale', 'Risques du projet', 'Engagements de suivi et monitoring', 'Structures engagées sur le terrain', 'Indicateurs quantitatifs\xa0:', 'Nombre d’arbres plantés par essence*', 'Indicateurs qualitatifs\xa0:', 'Lien avec les autres financeurs', 'Avec une légende associée'])
#
# ===== Résumé pour ../data/projet_1/PU_P01_AAP01.docx =====
#
# ### For Standard Grant ###
# Résumé et Classification:  Category: Project Objective and Target Contribution
#
# Summary:
# This section describes the project objective and specifies which target(s) from the Kunming-Montreal Global Biodiversity Framework (GBF) the project applies to and contributes to achieving.
#
# Project Objective:
# The project aims to contribute to the goal of the GBF by addressing specific targets outlined in the framework. The project objective could be conserving critical habitats, restoring degraded ecosystems, reducing pollution, or promoting sustainable use of natural resources, among others.
#
# Target Contribution:
# The project will identify and specify one or more targets from the 23 targets listed as the 2030 action targets proposed in the GBF that it will contribute to achieving. The specific target(s) chosen will depend on the project's objective and focus area. For example, if the project aims to conserve critical habitats, it may choose to contribute to Target 1 ( protecting and restoring ecosystems), Target 3 ( reducing pollution), or Target 5 ( protecting key biodiversity areas), among others.
#
# The project proposal should clearly state which target(s) it will contribute to achieving, and provide a rationale for why these targets were chosen. This information will help assess the project's relevance and potential impact towards achieving the GBF goals and targets.
#
#
# ### 2.  Project implementation plan ###
# Résumé et Classification: 1. Category: Request for project description by year
# 2. Description: The section requires applicants to provide details about the projects, including the fiscal year(s) (FY) to which the project applies. This includes not only the fiscal year for which the application is being submitted (hereafter referred to as "applying FY"), but also any other fiscal years that the project may cover.
# 3. Purpose: The purpose of this request is to gather comprehensive information about the projects, including their duration and funding requirements, to help in the evaluation and selection process for the grant application.
#
#
# ### FY(s) before applying FY ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### FY(s) after applying FY ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### 3．Expected concrete activity results ###
# Résumé et Classification:  Category: Instruction for proposal submission
#
# Summary:
# The selection committee requests that applicants provide information about the fiscal years (FY) beyond the current one in their proposal. This is to ensure the project's feasibility and continuity over time, as funding may be required or allocated in different FYs. Applicants should describe how the project will be implemented and sustained across multiple FYs. This instruction emphasizes the importance of long-term planning and financial management in successful grant proposals.
#
#
# ### （１）	Applying FY ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### （２）	FY(s) before applying FY ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### （３）	FY(s) after applying FY ###
# Résumé et Classification: 1. Category: General Instructions
# * This section provides general instructions for completing the project application form.
# 1. Summary of the Project
# * The project aims to reduce greenhouse gas emissions in the transportation sector.
# * The goal is to increase public awareness about climate change and promote sustainable transportation options.
# * The project will be implemented in collaboration with local schools, community organizations, and government agencies.
# 1. Evaluation Criteria
# * The proposal will be evaluated based on the following criteria:
# 	+ Relevance to the call for proposals
# 	+ Clear identification of goals and objectives
# 	+ Feasibility of the project plan
# 	+ Qualifications and experience of the project team
# 	+ Budget and cost-effectiveness
# 1. Project Timeline
# * The project will be implemented over a period of 12 months, starting from the date of funding approval.
# 1. Expense Items
# * Equipment and materials: This includes the purchase of equipment and materials necessary for the implementation of the project, such as bicycles, helmets, and promotional materials.
# * Personnel costs: This includes salaries and benefits for project staff, including a project manager, educators, and outreach workers.
# * Travel expenses: This includes transportation costs for project staff to conduct outreach activities and attend meetings.
# * Other costs: This includes any other expenses necessary for the successful implementation of the project, such as insurance, permits, and administrative costs.
# 1. Funding Source
# * The funding source(s) for each expense item should be specified in the appropriate column.
# * Acceptable funding sources include grants, donations, and in-kind contributions from public and private sector organizations.
#
#
# ### 4.  Activity schedule ###
# Résumé et Classification:  Category: Instruction for project proposal
#
# Summary:
# The selection committee requests that applicants provide information about the financial years (FY) relevant to their proposed project. In addition to describing the project's plan and budget for the current financial year (applying FY), applicants should also include details about other financial years (other FY(s)) that are relevant to their proposal. By doing so, the selection committee can better understand the project's timeline, financial requirements, and long-term sustainability.
#
#
# ### 4. Activity schedule ###
# Résumé et Classification: 1. Category: Project Length and Format Requirement
# 2. Summary: The selection committee requests that, if the proposed project spans multiple years, the application should be submitted across several pages to accurately reflect the different stages and budgetary needs of each year. This allows for a more detailed review of the project's timeline, goals, and financial requirements. By doing so, applicants can present a comprehensive plan that aligns with the committee's evaluation criteria and ensures the successful completion of their project over several years.
#
#
# ### 5. Income and Expenditure Budget plan ###
# Résumé et Classification: 1. Category: Budget information for multi-year project
# * Summary: The section requires detailed budget information for the entire duration of the multi-year project.
# * Specific requirements include:
# 	+ Describing the applying fiscal year (FY) and other fiscal years involved in the project
# 	+ Breaking down expenditure types into individual "Exp Item"
# 	+ Providing the total amount, amount for each funding source, and calculation basis for each Exp Item
# 	+ Indicating whether each funding source is fixed or expected
# 	+ Adding rows for Exp Item and columns for Funding Source as necessary
# 	+ Converting local or US currency into Japanese yen.
#
#
# ### 6. The name and contact information of the experts outside of applicant’s who will provive advice and guidance for the project implementation . ###
# Résumé et Classification:  Cette section de l'appel à projets concerne les recommandations relatives aux propositions. Il est demandé aux candidats de fournir des recommandations, le cas échéant, qui seront prises en considération dans l'évaluation de leur proposition. Les recommandations peuvent être un facteur positif dans la décision d'attribution du projet.
#
# Catégories :
#
# 1. Recommandations
# 2. Évaluation des propositions
# 3. Facteurs positifs pour l'attribution du projet
#
#
# ### 7. Local approvals (if you need local government approvals or agreements with local residents, please describe the contents) ###
# Résumé et Classification: 1. Catégorisation : Critère de sélection des projets
# 2. Résumé : Les candidats peuvent soumettre des contrats ou accords conclus avec des gouvernements locaux ou des communautés locales en tant que preuve d'un partenariat existant. La présence de ces documents sera considérée comme un atout lors de l'évaluation des projets soumis dans le cadre de cet appel à candidatures.
#
#
# ### 8. Partners (if you partner with a local NGO or other international organization on the projects, please list the names of the organizations) ###
# Résumé et Classification: 1. Catégorisation : Instruction pour la soumission de propositions de projets
# 2. Résumé : Les soumissions de projets doivent inclure des contrats ou accords de coopération avec des organisations internationales ou ONG, ou des recommandations de partenaires pertinents le cas échéant. L'inclusion de ces éléments dans la proposition sera positivement évaluée lors du processus de sélection.
#
#
# ### 9. Japanese Introducer (Name and contact information) ###
# Résumé et Classification: 1. Category: Organizational history and background
# 2. Summary:
# * The section "Historical background" requests information about the date of the organization's foundation and its past activities.
# * For each past activity, it is required to provide details such as the year it was carried out, the party it supported, the project cost, and a related website. This information will help in understanding the organization's track record, the scale and nature of its projects, and its partnerships.
#
#
# ### Form of the organization ###
# Résumé et Classification: 1. Legal status: The organization must provide official documents proving its legal personality.
# 2. Type of organization: Voluntary organizations or groups must attach external audits of operations and accounting, if available.
# 3. Staff information: The organization needs to provide the number of staff, including directors, permanent staff, and non-permanent staff. An organizational chart should be attached.
# 4. Representative information: The representative's full name, birth date, home address, mobile phone number, major accomplishments, and other affiliations and positions should be provided.
# 5. Website URLs: If applicable, the organization should share its website(s) URLs.
# 6. Past, ongoing, and planned activities: A summary of the organization's previous, current, and future projects in the country where the proposed project will be implemented is required.
# 7. Financial situation: The organization must attach an income and expenditure statement as well as a balance sheet for the last three fiscal years. Audited financial statements should include the auditor's comment and signature.
#
#
# ===== Résumé pour ../data/projet_1/PU_P01_AAP02.docx =====
#
# ### Description du projet ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Ville et pays ###
# Résumé et Classification: 1. Catégorisation : Critères d'éligibilité des bénéficiaires
# 2. Résumé :
# Le présent appel à projets cible les organismes sans but lucratif, les établissements publics, les collectivités territoriales et leurs groupements, les entreprises commerciales et les travailleurs indépendants. Les candidats doivent être établis dans l'Union européenne ou dans un pays éligible au programme. Les projets doivent viser à améliorer la qualité de vie des citoyens et à renforcer leur sentiment d'appartenance à l'Union européenne. Les bénéficiaires devront démontrer leur capacité à mettre en œuvre le projet proposé et à en assurer le suivi ainsi que la diffusion des résultats.
#
#
# ### Âge, activité, catégorie socio-professionnelle, genre... ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Nombre de personnes concernées ###
# Résumé et Classification: 1. Contexte et environnement : L'appel à projets vise à lutter contre la dégradation de l'environnement et les changements climatiques. Il met l'accent sur la promotion de pratiques durables, économes en ressources naturelles et résilientes au changement climatique.
# 2. Justification du projet : Le projet doit être lié à des objectifs environnementaux spécifiques, tels que la réduction des émissions de carbone, l'adaptation aux effets du changement climatique ou la promotion d'une utilisation durable des ressources naturelles.
# 3. Enjeux du projet : Les projets doivent démontrer leur potentiel à générer des impacts positifs et significatifs sur l'environnement, ainsi qu'à améliorer la qualité de vie des communautés locales. La durabilité économique et sociale doit également être prise en compte dans le cadre du projet.
#
# En résumé, ce chapitre appelle à des projets qui s'attaquent aux défis environnementaux actuels, tout en favorisant la durabilité économique et sociale. Les propositions doivent être justifiées par rapport aux objectifs de protection de l'environnement et montrer un potentiel d'impact positif sur les communautés locales.
#
#
# ### Résumé du projet ###
# Résumé et Classification: 	Section: Recherche et développement
#
# Cette section de l'appel à projets se concentre sur la recherche et le développement (R&D) requis pour les projets proposés. Les candidats sont encouragés à souligner les aspects innovants de leur travail et à expliquer comment leurs idées vont contribuer au domaine concerné. Le comité de sélection attache une grande importance à la capacité des candidats à démontrer la faisabilité technique et financière de leur proposition, ainsi qu'à l'impact escompté sur le marché et/ou la société.
#
# Les points clés de cette section sont:
#
# * Innovation: les projets doivent inclure des aspects innovants et apporter une valeur ajoutée à leur domaine respectif.
# * Faisabilité technique et financière: les candidats devront fournir un plan détaillé pour la mise en œuvre de leurs idées, y compris l'estimation des coûts et le calendrier prévisionnel.
# * Impact: les propositions doivent clairement démontrer leur potentiel d'impact sur le marché et/ou la société.
#
# Catégories:
# 1. Innovation
# 2. Faisabilité technique et financière
# 3. Impact
#
#
# ### Date de début du projet ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Date de fin du projet ###
# Résumé et Classification: 1. Calendrier et étapes de réalisation : cette section concerne la planification du projet et ses différentes étapes. Il est demandé aux candidats de détailler les échéances importantes, la durée estimée pour chaque tâche et les résultats attendus.
# 2. Collaboration avec Michelin : il s'agit de préciser si le porteur de projet fait partie du groupe Michelin ou non. Si ce n'est pas le cas, il est nécessaire d'indiquer s'il bénéficie du soutien d'un collaborateur du groupe. Cette information permettra aux évaluateurs d'appréhender les liens entre le projet et l'entreprise.
#
# En résumé, cette partie de l'appel à projets vise à obtenir des informations sur la planification et le calendrier du projet, ainsi que sur d'éventuelles collaborations ou soutiens au sein du groupe Michelin pour mieux comprendre les liens entre le projet et l'entreprise.
#
#
# ### 4 Budget prévisionnel du projet ###
# Résumé et Classification: 1. Coût total du projet et montant de la subvention demandée
# * Le premier aspect à détailler dans cette section est le coût global du projet, exprimé en euros.
# * Il faut également indiquer le montant de la subvention demandée à la Fondation, qui doit être inférieur ou égal au coût total du projet, et exprimé aussi en euros.
#
#
# ### Budget prévisionnel détaillé du projet ###
# Résumé et Classification: 1. Catégorie : Budget et financement
# * Requête de fournir un budget détaillé de l'entité porteuse du projet pour l'année en cours
# 2. Catégorie : Lutte anti-corruption
# * Demande de confirmation sur la possession d'un programme de conformité anti-corruption par l'entité
# * Requête d'information concernant la situation pénale de l'entité juridique et des dirigeants
# * Demande de confirmation sur la certification des comptes de l'entité par un organisme agréé
# * Question sur la présence d'agents publics dans les organes de gouvernance de l'entité.
#
#
# ===== Résumé pour ../data/projet_1/PU_P01_AAP03.docx =====
#
# ### FICHE PROJET A TREE FOR YOU ###
# Résumé et Classification: 1. Présentation de l'association A Tree for You
# * Promotion de projets de plantation d'arbres pour préserver et améliorer l'environnement, favoriser l'emploi et les liens sociaux
# * Association à but non lucratif créée en 2017
# * Opérateur de plantation qui permet à des particuliers et entreprises de soutenir des projets de plantation en échange d'un reçu fiscal
# * Comité de sélection composé d'experts indépendants pour choisir les projets et partenaires de plantation
# 1. Critères de sélection des projets
# * Bénéfiques pour l'enrichissement des sols, le cycle de l'eau, le climat et la biodiversité
# * Permettre aux populations humaines de développer une activité en harmonie avec la nature
# * Réalisés avec des partenaires de plantation expérimentés et reconnus
# 1. Processus de sélection
# * Préparation d'une fiche projet pour présentation au comité de sélection, examinée par l'équipe opérationnelle puis par les experts qui peuvent poser des questions
# * Premier projet : oral en deux temps (présentation de la structure et expérience, puis présentation du projet) via visioconférence
# * Décision de sélection ou non par le comité, avec possibilité d'émission de réserves à résoudre avant un nouveau passage devant le comité
# * Signature d'une convention de partenariat et mise en ligne du projet sur la plateforme A Tree for You en cas de sélection
# 1. Informations complémentaires
# * Première collecte de fonds via entreprises ou particuliers/entreprises mécènes, objectifs de collecte définis à des périodes données
# * Partage du risque de financement tardif du projet avec A Tree for You
# * Comité de pilotage prévu dans la convention de partenariat pour prendre des décisions communes en cas d'anticipation de non-respect d'un élément de la convention
# * A Tree for You n'accepte pas les projets de cultures trop majoritaires, exploitées en monospécifique et destinées à intégrer un marché mondialisé
# 1. Informations requises pour la fiche projet
# * Nom et coordonnées postales de la structure, statut, numéro SIRET ou RCS
#
#
# ### Année de démarrage de l’activité ###
# Résumé et Classification:
# La section décrite concerne la présentation des objectifs et du mode de fonctionnement global d'un projet, ainsi que les coordonnées du responsable de projet. Il s'agit de fournir une description claire et concise des buts visés par le projet, ainsi que des méthodes qui seront mises en œuvre pour les atteindre. Le tout devant tenir dans une limite de longueur comprise entre 100 et 150 mots.
#
# Le responsable de projet est également présenté, avec son nom, sa fonction, son adresse email et son numéro de téléphone. Il s'agit du point de contact principal pour l'appel à projets, qui sera chargé de répondre aux questions et demandes d'informations supplémentaires concernant le projet soumis.
#
#
# ### CV du responsable de projet ###
# Résumé et Classification: * Catégorie : Informations relatives au responsable du projet sur le terrain
# * Résumé : L'appel à projet demande les informations de contact et un CV pour le responsable du projet sur le terrain, qui peut être une personne différente du responsable de projet principal.
#
#
# ### Contexte et enjeuX : ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Pays / Nom du projet ###
# Résumé et Classification: 1. Contexte général du projet : Le texte décrit le contexte et les problématiques ciblées par le projet, ainsi que les enjeux associés. Cependant, aucun détail n'est donné sur l'insertion du projet dans un autre projet ou s'il s'agit d'une suite d'un projet préexistant.
# 2. Contexte spécifique pour le projet présenté à A Tree for You : Cette section se concentre sur les groupes cibles et les bénéficiaires finaux du projet, y compris leur profil (famille, propriétaires, association, coopérative, etc.) et la répartition femme/homme. Il n'y a pas de discussion sur le contexte spécifique dans lequel ce projet s'inscrit pour A Tree for You.
#
#
# ### Nombre de bénéficiaires directs attendus ###
# Résumé et Classification: 1. La tranche d'âge des bénéficiaires :
# * Le projet doit clairement cibler une tranche d'âge spécifique, allant de l'enfance (4-5 ans) à l'âge adulte (plus de 60 ans).
# * Les projets visant un public intergénérationnel sont également admissibles.
# * Les demandeurs doivent justifier le choix de la tranche d'âge ciblée et expliquer comment les activités proposées répondent aux besoins spécifiques de ce groupe d'âge.
#
# Résumé : Cette section décrit les exigences relatives à la tranche d'âge des bénéficiaires du projet. Les projets doivent cibler une tranche d'âge spécifique, allant de l'enfance à l'âge adulte, ou viser un public intergénérationnel. Le choix de la tranche d'âge doit être justifié et les activités proposées doivent répondre aux besoins spécifiques du groupe ciblé.
#
#
# ### Métiers / activités ###
# Résumé et Classification: 1. Taille et description des parcelles : La taille moyenne des parcelles et leur description sont demandées, ainsi que la superficie totale du projet.
# 2. Groupe ethnique ciblé : Le document cherche à savoir si un groupe ethnique particulier est concerné, et dans l'affirmative, quelles sont ses problématiques spécifiques.
# 3. Bénéficiaires du projet : Il est demandé si les bénéficiaires ont déjà été identifiés individuellement, comment et pourquoi ces personnes en particulier.
# 4. Climat local : Le climat actuel de la région, y compris l'altitude et l'évolution constatée et attendue du climat, est décrit.
# 5. Systèmes agricoles existants : Les systèmes agricoles actuels dans la région et les problèmes qu'ils posent sont identifiés.
# 6. Histoire agricole de la région : L'histoire des systèmes agricoles dans la région, y compris les essences, les rotations des parcelles et l'alimentation, est décrite pour déterminer s'ils peuvent être une source d'inspiration pour le projet.
# 7. Situation politique et économique : La situation politique et économique actuelle de la région est présentée.
#
#
# ### Problématiques spécifiques liées aux sols ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Problématiques spécifiques liées à l’eau ###
# Résumé et Classification: 1. Catégorie : Problèmes de conservation de la faune et la flore
# * Perte d'habitat : La destruction des habitats naturels est une menace majeure pour la biodiversité, entraînant la disparition d'espèces végétales et animales.
# * Fragmentation des habitats : L'augmentation de l'urbanisation et des infrastructures linéaires (routes, voies ferrées) isole les populations d'espèces, limitant leur capacité à se déplacer et à se reproduire.
# * Espèces envahissantes : Les espèces exotiques introduites peuvent perturber l'équilibre des écosystèmes en dominant les espèces locales, réduisant ainsi la biodiversité.
# 2. Catégorie : Impact des activités humaines sur la faune et la flore
# * Chasse et braconnage : Ces pratiques illégales sont responsables de la diminution drastique de certaines populations animales, notamment les grands mammifères et les oiseaux.
# * Surpêche : La surexploitation des stocks halieutiques entraîne une réduction de la diversité des espèces marines, mettant en danger l'équilibre des écosystèmes côtiers.
# * Pollution : Les produits chimiques et les déchets rejetés dans l'environnement peuvent contaminer les sols, les eaux de surface et souterraines, affectant la croissance et le développement des espèces végétales et animales.
# 3. Catégorie : Réchauffement climatique et biodiversité
# * Modification des habitats : Le changement climatique entraîne une modification des zones climatiques, forçant les espèces à migrer vers de nouveaux habitats ou à s'adapter à de nouvelles conditions.
# * Augmentation du niveau de la mer : L'élévation du niveau de la mer peut submerger les habitats côtiers, entraînant la disparition d'espèces végétales et animales.
# * Déstabilisation des écosystèmes : Le réchauffement climatique peut modifier les interactions entre les espèces, perturber les chaînes alimentaires et affaiblir les écosystèmes.
#
# Résumé : Cette section décrit divers problèmes liés à la biodiversité, notamment la perte d'habitat, la fragmentation des habitats, l'introduction d'espèces exotiques envahissantes et les activités humaines telles que la chasse, la surpêche et la pollution. Le réchauffement climatique est également identifié comme une menace majeure pour la biodiversité, entraînant une modification des habitats, une élévation du niveau de la mer et une déstabilisation des écosystèmes.
#
#
# ### Description du projet ###
# Résumé et Classification:  Le type de projet proposé dans cette section est une initiative mixte, combinant des éléments d'agroforesterie et de foresterie. Les candidats sont encouragés à soumettre des propositions qui intègrent la gestion durable des terres agricoles et forestières, en vue de promouvoir la biodiversité, d'améliorer les moyens de subsistance des communautés locales et de lutter contre le changement climatique.
#
# La section décrit également des projets spécifiques qui peuvent être soumis dans le cadre de cet appel à propositions, tels que la restauration de paysages forestiers dégradés, la promotion de pratiques agroforestières durables et l'établissement de systèmes agro-silvopastoraux intégrés.
#
# En outre, les projets peuvent inclure des activités de renforcement des capacités, de recherche et d'innovation, ainsi que des mesures visant à assurer la durabilité financière et écologique des interventions proposées.
#
# En résumé, cette section de l'appel à projets concerne les initiatives mixtes (agroforesterie/foresterie) qui cherchent à promouvoir la gestion durable des terres agricoles et forestières, tout en offrant des avantages pour la biodiversité, les moyens de subsistance locaux et la lutte contre le changement climatique. Les projets peuvent inclure une variété d'activités visant à atteindre ces objectifs, telles que la restauration de paysages forestiers dégradés et l'établissement de systèmes agro-silvopastoraux intégrés.
#
#
# ### Méthodologie et calendrier ###
# Résumé et Classification: 1. Catégorisation :
# * Objectifs et principes
# * Calendrier des travaux
# * Méthodes associées
# * Mention du calendrier par mois pour la première année
# 2. Résumé :
# L'action sur le terrain doit être guidée par des objectifs et principes clairs, qui doivent être explicitement indiqués dans la proposition. Le demandeur doit fournir un calendrier détaillé des travaux, incluant les méthodes associées (quoi, quand, comment, qui/avec qui, où). Ce calendrier doit être précisé par mois pour au moins la première année.
#
#
# ### Essences et schémas de plantation ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Liste des essences envisagées ###
# Résumé et Classification: 1. Catégorisation :
# * Essences et objectifs de plantation
# * Engagement minimum et méthode sur le terrain
# * Pépinières (fournisseurs, obtention des plants, méthodes de reproduction, localisation)
# * Risques et opportunités liés aux pépinières
# 2. Résumé :
#
# Le projet requiert la liste d'essences avec les objectifs de nombre d'arbres plantés et attendus à terme (à une date spécifiée). Le porteur de projet doit préciser son engagement minimum en termes de nom et/ou nombre d'essences effectivement plantées et pérennes, ainsi que la répartition entre elles.
#
# Le processus pour atteindre cet engagement comprend le choix des pépinières (en propre ou externalisées), l'obtention des plants via diverses méthodes de reproduction (graines, etc.), et la provenance des graines. Le projet doit inclure une description des risques et opportunités liés aux pépinières ainsi que les mesures pour y répondre.
#
# Le porteur de projet doit également expliquer ses méthodes pour convaincre les pépiniéristes et les bénéficiaires de ce choix d'essences.
#
#
# ### Schémas / designs de plantation ###
# Résumé et Classification: 1. Catégorisation:
# * Schémas / designs de plantation
# * Essences choisies et proportions relatives
# * Retour d'expérience (agronomique, économique, commercial)
# * Méthode d'établissement de la liste des essences et des schémas de plantation
# 2. Résumé:
# L'appel à projet demande aux candidats de spécifier les schémas et designs de plantation qu'ils envisagent, y compris les essences choisies et leurs proportions relatives. Le candidat doit mentionner si cette configuration a déjà été testée dans la région, depuis combien de temps et fournir un retour d'expérience détaillé (succès, difficultés agronomiques, économiques, débouchés des produits agricoles).
#
# Le candidat doit également indiquer comment la liste des essences et les schémas de plantation ont été établis. Les sources d'information peuvent inclure des experts locaux ou internationaux, des pépiniéristes locaux, des pratiques traditionnelles dans la région, des sources bibliographiques, ainsi que des structures telles que des ONG, des institutions gouvernementales et internationales qui pratiquent les mêmes types de plantation.
#
#
# ### Coordonnées GPS des plantations ###
# Résumé et Classification: **Catégorie : Coordonnées GPS et format requis**
#
# **Résumé :**
#
# * L'appel à projet demande la fourniture des coordonnées en décimales pour les parcelles de plantation prévues.
# * Les coordonnées doivent être présentées sous la forme (latitude, longitude), avec une virgule entre deux points GPS et sans espace. Exemple : (48.4906333,-0.6899428)
# * La latitude doit être indiquée en premier, suivie de la longitude.
# * Si les coordonnées précises des parcelles ne sont pas disponibles au moment de la soumission du projet, il est demandé d'indiquer les zones globales envisagées pour la plantation.
#
#
# ### Bénéfices attendus de ce projet ###
# Résumé et Classification: 1. Réduction des émissions de gaz à effet de serre (GES) : cette mesure vise à diminuer les émissions de CO2 et autres GES en encourageant des pratiques moins polluantes. L'horizon de temps associé est moyen à long terme, car les effets bénéfiques sur l'environnement ne seront visibles qu'après plusieurs années de mise en œuvre.
# 2. Préservation de la biodiversité : ce bénéfice consiste à protéger et restaurer les écosystèmes, ainsi que les espèces animales et végétales menacées. L'horizon de temps est principalement long terme, car la régénération des habitats naturels et le rétablissement des populations animales et végétales prennent généralement du temps.
# 3. Économie circulaire : cette approche encourage le recyclage, la réutilisation et la valorisation des déchets, ainsi que la réduction de la consommation des ressources naturelles. Les bénéfices pour l'environnement sont observables à moyen terme, grâce à une diminution des déchets et une meilleure gestion des ressources.
# 4. Énergies renouvelables : ce bénéfice implique le développement et l'utilisation d'énergies propres et inépuisables, telles que l'énergie solaire, éolienne, hydroélectrique ou géothermique. Les avantages pour l'environnement sont constatés à moyen et long terme, grâce à une réduction des dépendances aux combustibles fossiles et des émissions de GES.
# 5. Mobilité durable : cette mesure encourage les modes de transport moins polluants, tels que la marche, le vélo, les transports en commun ou les véhicules électriques. Les bénéfices pour l'environnement sont visibles à court et moyen terme, grâce à une diminution des émissions de GES et de la congestion routière.
# 6. Gestion durable des forêts : cette pratique consiste à gérer les forêts de manière responsable, en préservant leurs fonctions écologiques, économiques et sociales. Les avantages pour l'environnement sont observables à moyen et long terme, grâce à une meilleure conservation des ressources forestières et des services écosystémiques qu'elles fournissent.
# 7. Agriculture durable : cette approche privilégie des méthodes de production alimentaire respectueuses de l'environnement, en réduisant les intrants chimiques, en préservant la biodiversité et en favorisant les cycles naturels. Les bénéfices pour l'environnement sont constatés à moyen et long terme, grâce à une diminution de la pollution des sols, de l'eau et de l'air, ainsi qu'à une meilleure résilience face au changement climatique.
#
#
# ### Pour les sols ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Pour le cycle de l'eau ###
# Résumé et Classification: 1. Catégorisation : Cette section de l'appel à projets se concentre sur la biodiversité, en particulier la flore et la faune. Il fournit des détails spécifiques sur les attentes du programme en ce qui concerne la conservation et la protection de la biodiversité dans le contexte du projet proposé.
#
# 2. Résumé :
# * Conserver et restaurer la biodiversité (flore et faune) dans les zones ciblées par le projet est un objectif clé. Les propositions de projets doivent inclure des mesures concrètes pour atteindre cet objectif.
# * Le projet doit identifier et évaluer les espèces végétales et animales menacées ou rares dans la zone du projet, en accordant une attention particulière aux habitats naturels et semi-naturels.
# * Les propositions doivent inclure des plans pour protéger ces espèces et leurs habitats, ainsi que des stratégies pour gérer les menaces potentielles (par exemple, la pollution, le changement climatique, l'urbanisation, etc.).
# * La sensibilisation du public à la valeur de la biodiversité et l'implication des communautés locales dans la conservation de la flore et de la faune sont encouragées.
# * Le partage des connaissances, les réseaux de coopération et les collaborations avec d'autres projets ou organisations axés sur la biodiversité doivent être inclus dans le plan du projet.
# * Les propositions doivent également aborder la durabilité à long terme des mesures de conservation mises en œuvre, en assurant un suivi et une évaluation continus après la fin du financement du projet.
#
#
# ### Pour le micro-climat ###
# Résumé et Classification: Aucune information disponible.
#
#
# ### Pour la captation de carbone ###
# Résumé et Classification: 1. Amélioration de la qualité de vie (courte et moyenne échéance) : Ce bénéfice fait référence à une amélioration générale du bien-être des personnes ciblées par le projet, grâce à l'accès à de nouveaux services ou aménagements.
# 2. Développement économique (moyenne et longue échéance) : Ce bénéfice vise une croissance économique dans la région concernée par le projet, que ce soit en termes de création d'emplois ou de développement de nouvelles entreprises.
# 3. Réduction des inégalités (courte, moyenne et longue échéance) : Ce bénéfice implique une diminution des disparités sociales et économiques au sein de la population ciblée par le projet. Cela peut être obtenu grâce à l'accès égal aux services et ressources pour tous.
# 4. Protection de l'environnement (courte, moyenne et longue échéance) : Ce bénéfice vise à préserver et restaurer l'environnement local en réduisant les déchets, promouvant des pratiques durables et améliorant la gestion des ressources naturelles.
# 5. Renforcement de la cohésion sociale (courte, moyenne et longue échéance) : Ce bénéfice met l'accent sur le développement de liens et d'interactions positives entre les membres de la communauté, ce qui contribue à une société plus inclusive et solidaire.
# 6. Développement des compétences (moyenne et longue échéance) : Ce bénéfice se traduit par l'acquisition de nouvelles connaissances et capacités par les personnes impliquées dans le projet, ce qui peut conduire à une meilleure employabilité et autonomie.
# 7. Amélioration des services publics (courte, moyenne et longue échéance) : Ce bénéfice vise à accroître l'efficacité, la qualité et l'accessibilité des services publics offerts aux citoyens, grâce au projet.
# 8. Innovation (moyenne et longue échéance) : Ce bénéfice consiste en l'introduction de nouvelles idées, méthodes ou produits dans la région concernée par le projet, ce qui peut conduire à une croissance économique durable et à une amélioration du bien-être social.
#
#
# ### Bénéfices pour l’économie locale ###
# Résumé et Classification: 1. Caractéristiques des bénéficiaires :
# * Revenus
# * Apports en nature
# * Résilience
# * Santé
# * Education
# * Pratiques agricoles
# * Alimentation
#
# 2. Attentes des bénéficiaires :
# * Avoir exprimé leurs attentes
# * Motivation à participer au projet
#
# 3. Innovation et exemplarité du projet :
# * Caractère innovant du projet
# * Possibilité d'être un exemple à suivre pour d'autres acteurs régionaux
#
# 4. Actions de communication et de promotion du projet :
# * Visites écoles
# * Participation lycées agricoles
# * Réseaux agriculteurs
#
# Le présent appel à projets demande aux candidats de détailler les caractéristiques des bénéficiaires du projet, telles que leurs revenus, apports en nature, résilience, santé, éducation, pratiques agricoles et alimentation. Les bénéficiaires sont invités à exprimer leurs attentes concernant le projet et les motivations pour y participer doivent être clarifiées.
#
# Le projet doit être innovant et présenter un caractère exemplaire pour d'autres acteurs régionaux. Des actions spécifiques doivent être mises en place pour promouvoir le projet, telles que des visites dans les écoles, la participation aux lycées agricoles et l'implication dans les réseaux d'agriculteurs.
#
#
# ### Risques du projet ###
# Résumé et Classification: 1. Risques et actions pour y faire face : Il est demandé au candidat de réfléchir aux risques potentiels du projet et aux mesures qui seront prises pour les gérer.
# 2. Retour d’expérience : Le candidat doit indiquer s'il a bénéficié d'une expérience antérieure sur un projet similaire en termes de zone, de problématiques et de population concernée. Une description rapide du (des) projet(s) ainsi que les problèmes rencontrés et les actions menées pour y faire face est demandée.
# 3. Anticipation des problèmes : Le candidat doit expliquer comment il s'assurera que les problèmes identifiés dans le cadre d'expériences antérieures seront anticipés ou évités dans ce projet.
#
#
# ### Engagements de suivi et monitoring ###
# Résumé et Classification: 1. Suivi des projets : A Tree for You s'engage à suivre les projets de plantation d'arbres pendant au moins 3 ans après la dernière année de plantation.
# 2. Communications aux donateurs : Des articles avec photos du projet seront partagés en français et en anglais pour les donateurs de l'association. Il y aura au moins 2 articles la première année et un article les années suivantes.
# 3. Bilan technique et financier : Un rapport technique et financier sera demandé une fois par an pendant 3 à 5 ans aux bénéficiaires du projet.
#
#
# ### Structures engagées sur le terrain ###
# Résumé et Classification: 1. Conception du projet en amont
# 2. Conduite du projet sur le terrain
# 3. Formation et sensibilisation des bénéficiaires
# 4. Suivi technique annuel
# 5. Audit régulier des progrès et problèmes à résoudre
# 6. Pilotage, coordination et communication pendant 3 ans après la dernière plantation
#
# Des indicateurs de mesure seront suivis pour évaluer les résultats du projet :
#
# * Indicateurs obligatoires : nombre d'arbres plantés, taux de survie des arbres, diversité des espèces d'arbres, taille des arbres, etc.
# * Indicateurs potentiels : impact sur la biodiversité, impact sur le climat, satisfaction des bénéficiaires, etc.
#
# La temporalité de ce suivi sera précisée dans les bilans techniques du projet.
#
#
# ### Indicateurs quantitatifs : ###
# Résumé et Classification: 1. Catégorisation :
# * Bénéficiaires directs et profils
# * Formations effectuées, jours de formation donnés, participants et profils
# * Plants en pépinières par essence
# * Plants distribués par essence aux bénéficiaires
#
# 2. Résumé :
# Le projet devra inclure des informations sur le nombre de bénéficiaires directs avec leur profil respectif. Il est également demandé de fournir des détails sur le nombre de formations réalisées, le nombre de jours de formation donnés, le nombre de participants et leurs profils (qui peuvent être les mêmes que ceux des bénéficiaires directs). Le nombre de plants en pépinières devra être indiqué pour chaque essence ainsi que le nombre de plants distribués à chaque bénéficiaire, également par essence.
#
#
# ### Nombre d’arbres plantés par essence* ###
# Résumé et Classification: 1. Nombre d'arbres pérennes : Cette sous-section porte sur le nombre total d'arbres pérennes prévu dans le projet, ce qui implique que les arbres doivent être matures et capables de survivre pendant une période prolongée.
# 2. Horizon de temps clairement établi : Il est important de spécifier la période de référence ou l'horizon temporel pour le nombre d'arbres pérennes, permettant ainsi de mesurer les progrès et les résultats du projet dans le temps.
# 3. Bilan de captation carbone : Cette section aborde l'évaluation des émissions de gaz à effet de serre (GES) capturées par le projet, qui peut être exprimée en tonnes de CO2eq évitées. Le bilan de captation carbone devrait inclure une estimation de la réduction des émissions grâce au projet et un calcul des puits de carbone créés par les arbres pérennes plantés.
#
#
# ### Indicateurs qualitatifs : ###
# Résumé et Classification: 1. Témoignages et retours sur l'impact du projet :
# 	* Impact sur la condition de vie, revenu et apprentissage des bénéficiaires
# 	* Influence sur la vie économique locale
# 	* Études ou mesures des effets sur la biodiversité, les sols, l'eau et le climat
# 2. Publication d'articles pour les donateurs :
# 	* Fréquence de rédaction à déterminer en fonction du calendrier des travaux
# 3. Budget :
# 	* Montant global demandé à la collecte par A Tree for You
# 	* Budget total détaillé par poste de coût
#
#
#
# ### Lien avec les autres financeurs ###
# Résumé et Classification: 1. Catégorisation:
# * Demandes de financement (hors A Tree for You)
# * Activités prévues pour les fonds demandés
# * Risques en cas d'absence ou retard de financement
# * Directives pour l'envoi de photos
# 2. Résumé:
# L'appel à projets demande des informations sur le statut et le montant des demandes de financement actuellement en cours, en dehors du financement prévu par A Tree for You. Les fonds sont destinés à des activités spécifiques. En cas d'absence ou de retard de financement, l'appel à projets souhaite connaître les risques encourus pour le projet dans son ensemble et pour la partie financée par A Tree for You. De plus, l'organisation doit indiquer ce qui se passerait si le projet ne pouvait être financé que partiellement ou dans des délais importants par rapport aux attentes de l'équipe de A Tree for You. Pour illustrer le projet et la zone concernée, les candidats doivent fournir des photos via WeTransfer, au format paysage (480 x 640 pixels), en haute qualité, avec une mention du nom de l'auteur à créditer. Les fichiers ne doivent pas contenir d'espaces, d'accents ou de caractères spéciaux dans leur nom.
#
#
# ### Avec une légende associée ###
# Résumé et Classification: Aucune information disponible.

# %%
import requests
from docx import Document

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def extract_text_by_sections(doc_path):
    """ Extrait le texte par sections d'un document Word """
    doc = Document(doc_path)
    sections = {}
    current_section = "Introduction"  # Nom générique si aucun titre n'est trouvé

    for para in doc.paragraphs:
        text = para.text.strip()
        if text and len(text.split()) < 10:  # Supposons que les titres sont courts
            current_section = text
            sections[current_section] = []
        elif text:
            sections[current_section].append(text)

    return {sec: " ".join(content) for sec, content in sections.items()}

def ask_mixtral(prompt):
    """ Envoie une requête à Mixtral pour analyse """
    response = requests.post(
        OLLAMA_HOST,
        json={"model": "mixtral", "prompt": prompt, "stream": False}
    )
    return response.json().get("response", "Erreur: pas de réponse")

# Charger le PU_P01_PP pour connaître les sections requises
pp_sections = extract_text_by_sections("../data/projet_1/PU_P01_PP.docx")

# Charger et comparer les AAP
aap_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
results = {}

for aap_path in aap_paths:
    aap_sections = extract_text_by_sections(aap_path)

    # Construire la requête pour Mixtral
    prompt = f"""
    Voici les sections attendues dans un appel à projets valide:
    {list(pp_sections.keys())}

    Voici les sections trouvées dans le document {aap_path}:
    {list(aap_sections.keys())}

    Vérifie si toutes les sections requises sont présentes.
    - Si elles sont toutes présentes, réponds simplement : "✅ Toutes les informations requises sont présentes."
    - Sinon, liste les sections manquantes en format simple : "❌ Manque les sections : [Liste]".
    """

    mixtral_response = ask_mixtral(prompt)
    results[aap_path] = mixtral_response

# Affichage des résultats
for doc, result in results.items():
    print(f"\n===== Vérification pour {doc} =====")
    print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 38
#      35 results = {}
#      37 for aap_path in aap_paths:
# ---> 38     aap_sections = extract_text_by_sections(aap_path)
#      40     # Construire la requête pour Mixtral
#      41     prompt = f"""
#      42     Voici les sections attendues dans un appel à projets valide:
#      43     {list(pp_sections.keys())}
#    (...)
#      50     - Sinon, liste les sections manquantes en format simple : "❌ Manque les sections : [Liste]".
#      51     """
#
# Cell In[4], line 18, in extract_text_by_sections(doc_path)
#      16         sections[current_section] = []
#      17     elif text:
# ---> 18         sections[current_section].append(text)
#      20 return {sec: " ".join(content) for sec, content in sections.items()}
#
# KeyError: 'Introduction'

# %%
import requests
from docx import Document

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def extract_text_by_sections(doc_path):
    """ Extrait le texte par sections d'un document Word en structurant les parties détectées """
    doc = Document(doc_path)
    sections = {}
    current_section = "Section Générique"  # Ajout d'une section par défaut

    for para in doc.paragraphs:
        text = para.text.strip()
        if text:
            # Détecter les titres comme les sections (basé sur la longueur et la mise en forme)
            if len(text.split()) < 10 and text[-1] not in ".!?":
                current_section = text
                sections[current_section] = []
            else:
                if current_section not in sections:
                    sections[current_section] = []  # Évite les erreurs KeyError
                sections[current_section].append(text)

    return {sec: " ".join(content) for sec, content in sections.items() if content}

def ask_mixtral(prompt):
    """ Envoie une requête à Mixtral pour analyse """
    response = requests.post(
        OLLAMA_HOST,
        json={"model": "mixtral", "prompt": prompt, "stream": False}
    )
    return response.json().get("response", "Erreur: pas de réponse")

# Charger le PU_P01_PP pour connaître les sections requises
pp_sections = extract_text_by_sections("../data/projet_1/PU_P01_PP.docx")

# Charger et comparer les AAP
aap_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
results = {}

for aap_path in aap_paths:
    aap_sections = extract_text_by_sections(aap_path)

    # Construire la requête pour Mixtral
    prompt = f"""
    Voici les sections attendues dans un appel à projets valide:
    {list(pp_sections.keys())}

    Voici les sections trouvées dans le document {aap_path}:
    {list(aap_sections.keys())}

    Vérifie si toutes les sections requises sont présentes.
    - Si elles sont toutes présentes, réponds simplement : "✅ Toutes les informations requises sont présentes."
    - Sinon, liste les sections manquantes en format simple : "❌ Manque les sections : [Liste]".
    """

    mixtral_response = ask_mixtral(prompt)
    results[aap_path] = mixtral_response

# Affichage des résultats
for doc, result in results.items():
    print(f"\n===== Vérification pour {doc} =====")
    print(result)
# Out:
# ===== Vérification pour ../data/projet_1/PU_P01_AAP01.docx =====
# ❌ Manque les sections : ['Brief project description', 'Name of the organization', 'Address', 'Restoring mangrove ecosystems, especially in the Mahakam Delta', 'Some activities conducted by POKJA Pesisir', 'Geographic and socio-economic context', 'Environmental context', 'Table 1. Critical Criteria of Mahakam Delta Mangrove', 'Biodiversity issues', 'Institutional Context', 'The Movement of Indonesian New Capital', 'Aquaculture industry', 'Demography', 'Other issues', 'Strategy & theory of change', 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Beneficiaries', 'Teachers (primary school teachers)', 'Village officials', 'Location', '1.1.1. -Workshop on Environmental Conservation for Primary School Teachers', '1.2.1 -Encouraging/assisting schools towards adiwiyata in Mahakam Delta', '1.3.1. Waste Management Campaign', 'Target: 100 persons local community involved', 'Health approach involved medical staff or public health office', '1.3.2 Book publication', '1.3.3 Environmental Campaign for public with billboard', 'Target: public in general', '1.3.4 Public Campaign Awareness through Media', 'Activity 2.1. Pres-assessment study on land suitability', 'Hire consultant team with the available budget', '2.2.1 Establishment of community-based nurseries', 'Methods and media: Technical assistance by Project staffs', '2.2.2 Maintenance of the nurseries', 'Methods and media: Regular maintenance by local people', '2.3.1 Survey of planting locations', 'Description of activity:', '2.3.2 Training on Mangrove Reforestation', 'Introduction of the mangrove ecosystems and its importance', 'Seedling the propagules in the nursery', '2.3.3 Tree planting', 'Target of tree planting', 'Strategy of implementation: work with the local people', 'Conduct seedling maintenance arranged by the group leader', '2.4.1 Participatory Monitoring Training on Tree monitoring', 'Tree monitoring planning', '2.4.2 Implementation of the tree monitoring', 'Methods and media: field trip directly to the location', 'Direct observation in area targeted', '3.1.1 Support of practice on sustainable aquaculture pond', 'The practical way for the management of sustainable aquaculture', 'Methods: participatory training and hands-on experience', 'Facilitator for meeting: Organized by PU through offline meeting', 'Methods: offline meeting', 'Facilitator for training: Local partner and PU', '1 Project Coordinator', 'Offices (location):', 'Partnerships', 'Feature 5. Rehabilitation target area in New Mahakam Project', 'CAPACITY BUILDING PLAN', 'Cross-cutting approaches', 'Knowledge management', 'Capitalization', 'External communication in Indonesia', 'External communication in France', 'Sustainability, scaling-up and/or exit strategy', 'Raising awareness component:', 'Mangrove rehabilitation component:', 'Economic development component:', 'Governance Component', 'Transversal to the project:', 'Monitoring & evaluation', 'Quarterly narrative and financial report', 'Internal evaluation at the end of project', 'Redaction of the audit report', 'Consideration of regulatory surplus']
#
# ===== Vérification pour ../data/projet_1/PU_P01_AAP02.docx =====
# ❌ Manque les sections : ['Restoring mangrove ecosystems, especially in the Mahakam Delta', 'Name of the organization: Pokja Pesisir', 'Website: <http://pokjapesisir.id/>', 'Some activities conducted by POKJA Pesisir:', 'Geographic and socio-economic context', 'Environmental context', 'Table 1. Critical Criteria of Mahakam Delta Mangrove', 'Biodiversity issues', 'Institutional Context', 'The Movement of Indonesian New Capital', 'Aquaculture industry', 'Demography', 'Other issues', 'Strategy & theory of change', 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Beneficiaries', 'Teachers (primary school teachers)', 'Village officials', 'Location', 'Expected results, planned activities & required resources', 'DETAILS OF PLANNED ACTIVITIES', '1.1.1. -Workshop on Environmental Conservation for Primary School Teachers', '1.2.1 -Encouraging/assisting schools towards adiwiyata in Mahakam Delta', 'Location: in Delta Mahakam conducted by YML', '1.3.1. Waste Management Campaign', 'Target: 100 persons local community involved', 'Health approach involved medical staff or public health office', '1.3.2 Book publication', '1.3.3 Environmental Campaign for public with billboard', 'Target: public in general', '1.3.4 Public Campaign Awareness through Media', 'Activity 2.1. Pres-assessment study on land suitability', 'Hire consultant team with the available budget', '2.2.1 Establishment of community-based nurseries', 'Methods and media: Technical assistance by Project staffs', '2.2.2 Maintenance of the nurseries', 'Methods and media: Regular maintenance by local people', '2.3.1 Survey of planting locations', 'Description of activity:', '2.3.2 Training on Mangrove Reforestation', 'Introduction of the mangrove ecosystems and its importance', 'Seedling the propagules in the nursery', '2.3.3 Tree planting', 'Target of tree planting', 'Strategy of implementation: work with the local people', 'Conduct seedling maintenance arranged by the group leader', '2.4.1 Participatory Monitoring Training on Tree monitoring', 'Tree monitoring planning', '2.4.2 Implementation of the tree monitoring', 'Methods and media: field trip directly to the location', 'Direct observation in area targeted', '3.1.1 Support of practice on sustainable aquaculture pond', 'The practical way for the management of sustainable aquaculture', 'Methods: participatory training and hands-on experience', 'Facilitator for meeting: Organized by PU through offline meeting', 'Methods: offline meeting', 'Facilitator for training: Local partner and PU', '1 Project Coordinator', 'Offices (location):', 'Partnerships', 'Feature 5. Rehabilitation target area in New Mahakam Project', 'CAPACITY BUILDING PLAN', 'Cross-cutting approaches', 'Knowledge management', 'Capitalization', 'External communication in Indonesia', 'External communication in France', 'Sustainability, scaling-up and/or exit strategy', 'Sustainability and Exit Strategy (Scale Up) of the project', 'Raising awareness component:', 'Mangrove rehabilitation component:', 'Economic development component:', 'Governance Component', 'Transversal to the project:', 'Monitoring & evaluation', 'Quarterly narrative and financial report', 'Internal evaluation at the end of project', 'Redaction of the audit report', 'Consideration of regulatory surplus']
#
# ===== Vérification pour ../data/projet_1/PU_P01_AAP03.docx =====
# ❌ Manque les sections : ['Brief project description', 'Name of the organization:', 'Website:', 'Some activities conducted by POKJA Pesisir:', 'Geographic and socio-economic context', 'Environmental context', 'Table 1. Critical Criteria of Mahakam Delta Mangrove', 'Biodiversity issues', 'Institutional Context', 'The Movement of Indonesian New Capital', 'Aquaculture industry', 'Demography', 'Other issues', 'Strategy & theory of change', 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Beneficiaries', 'Teachers (primary school teachers)', 'Village officials', 'Location', 'DETAILS OF PLANNED ACTIVITIES', '1.1.1. -Workshop on Environmental Conservation for Primary School Teachers', '1.2.1 -Encouraging/assisting schools towards adiwiyata in Mahakam Delta', 'Health approach involved medical staff or public health office', '1.3.1. Waste Management Campaign', 'Target: 100 persons local community involved', '1.3.2 Book publication', '1.3.4 Public Campaign Awareness through Media', 'Activity 2.1. Pres-assessment study on land suitability', 'Hire consultant team with the available budget', '2.2.1 Establishment of community-based nurseries', 'Methods and media: Technical assistance by Project staffs', '2.2.2 Maintenance of the nurseries', 'Methods and media: Regular maintenance by local people', '2.3.1 Survey of planting locations', 'Description of activity:', '2.3.3 Tree planting', 'Target of tree planting', 'Strategy of implementation: work with the local people', 'Conduct seedling maintenance arranged by the group leader', '2.4.1 Participatory Monitoring Training on Tree monitoring', 'Tree monitoring planning', '2.4.2 Implementation of the tree monitoring', 'Methods and media: field trip directly to the location', 'Direct observation in area targeted', '3.1.1 Support of practice on sustainable aquaculture pond', 'The practical way for the management of sustainable aquaculture', 'Facilitator for meeting: Organized by PU through offline meeting', 'Methods: offline meeting', 'Facilitator for training: Local partner and PU', '1 Project Coordinator', 'Offices (location):', 'Partnerships', 'Feature 5. Rehabilitation target area in New Mahakam Project', 'Capitalization', 'External communication in Indonesia', 'External communication in France', 'Sustainability, scaling-up and/or exit strategy', 'Raising awareness component:', 'Mangrove rehabilitation component:', 'Economic development component:', 'Governance Component', 'Transversal to the project:', 'Monitoring & evaluation', 'Quarterly narrative and financial report', 'Internal evaluation at the end of project', 'Redaction of the audit report', 'Consideration of regulatory surplus']

# %%
import requests
from docx import Document

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def extract_text_by_sections(doc_path):
    """ Extrait le texte des sections d'un document Word """
    doc = Document(doc_path)
    sections = {}
    current_section = "Section Générique"

    for para in doc.paragraphs:
        text = para.text.strip()
        if text:
            if len(text.split()) < 10 and text[-1] not in ".!?":
                current_section = text
                sections[current_section] = []
            else:
                if current_section not in sections:
                    sections[current_section] = []
                sections[current_section].append(text)

    return {sec: " ".join(content) for sec, content in sections.items() if content}

def ask_mixtral(prompt):
    """ Envoie une requête à Mixtral pour analyse et compréhension du texte """
    response = requests.post(
        OLLAMA_HOST,
        json={"model": "mixtral", "prompt": prompt, "stream": False}
    )
    return response.json().get("response", "Erreur: pas de réponse")

# Charger les sections attendues du PU_P01_PP
pp_sections = extract_text_by_sections("../data/projet_1/PU_P01_PP.docx")

# Charger et comparer les AAP
aap_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
results = {}

for aap_path in aap_paths:
    aap_sections = extract_text_by_sections(aap_path)

    # Construire une requête LLM plus avancée
    prompt = f"""
    Voici les sections attendues dans un appel à projet valide (PU_P01_PP) :
    {list(pp_sections.keys())}

    Voici les sections trouvées dans {aap_path} :
    {list(aap_sections.keys())}

    **Tâche** :
    - Vérifie si chaque section attendue est bien couverte dans le document.
    - Même si le titre diffère, vérifie si le contenu correspondant est présent sous une autre section.
    - Si tout est bien couvert, réponds : ✅ Toutes les informations requises sont présentes.
    - Si des parties sont absentes ou incomplètes, liste clairement les sections manquantes : "❌ Manque les sections : [Liste]".
    """

    mixtral_response = ask_mixtral(prompt)
    results[aap_path] = mixtral_response

# Affichage des résultats
for doc, result in results.items():
    print(f"\n===== Vérification pour {doc} =====")
    print(result)
# Out:
# ===== Vérification pour ../data/projet_1/PU_P01_AAP01.docx =====
# ❌ Manque les sections : ['Brief project description', 'Name of the organization: Pokja Pesisir', 'Website: http://pokjapesisir.id/', 'Some activities conducted by POKJA Pesisir:', 'Geographic and socio-economic context', 'Environmental context', 'Table 1. Critical Criteria of Mahakam Delta Mangrove', 'Biodiversity issues', 'Institutional Context', 'The Movement of Indonesian New Capital', 'Aquaculture industry', 'Demography', 'Other issues', 'Strategy & theory of change', 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Beneficiaries', 'Teachers (primary school teachers)', 'Village officials', 'Location', 'CAPACITY BUILDING PLAN', 'Cross-cutting approaches', 'Knowledge management', 'Capitalization', 'External communication in Indonesia', 'External communication in France', 'Sustainability, scaling-up and/or exit strategy', 'Sustainability and Exit Strategy (Scale Up) of the project', 'Raising awareness component:', 'Mangrove rehabilitation component:', 'Economic development component:', 'Governance Component', 'Transversal to the project:']
#
# Les sections ci-dessus ne sont pas couvertes dans le document fourni. Il est recommandé de les ajouter pour répondre aux exigences de l'appel à projets valide (PU_P01_PP).
#
# ===== Vérification pour ../data/projet_1/PU_P01_AAP02.docx =====
# ❌ Manque les sections : ['Brief project description', '6.\tExpected results, planned activities & required resources\t13', 'Activity 2.1. Pres-assessment study on land suitability\t17', 'Address: Jl. Pelita 3 RT.12 Gg.7 Kel. Sambutan Samarinda', 'Restoring mangrove ecosystems, especially in the Mahakam Delta', 'Name of the organization: Pokja Pesisir', 'Website: <http://pokjapesisir.id/>', 'Some activities conducted by POKJA Pesisir:', 'Geographic and socio-economic context', 'Environmental context', 'Table 1. Critical Criteria of Mahakam Delta Mangrove', 'Biodiversity issues', 'Institutional Context', 'The Movement of Indonesian New Capital', 'Aquaculture industry', 'Demography', 'Other issues', 'Strategy & theory of change', 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Beneficiaries', '1.1.1. -Workshop on Environmental Conservation for Primary School Teachers', '1.2.1 -Encouraging/assisting schools towards adiwiyata in Mahakam Delta', 'Location: in Delta Mahakam conducted by YML', '1.3.1. Waste Management Campaign', 'Target: 100 persons local community involved', 'Health approach involved medical staff or public health office', '1.3.2 Book publication', '1.3.3 Environmental Campaign for public with billboard', 'Target: public in general', '1.3.4 Public Campaign Awareness through Media', 'Activity 2.1. Pres-assessment study on land suitability', 'Hire consultant team with the available budget', '2.2.1 Establishment of community-based nurseries', 'Methods and media: Technical assistance by Project staffs', '2.2.2 Maintenance of the nurseries', 'Methods and media: Regular maintenance by local people', '2.3.1 Survey of planting locations', 'Description of activity:', '2.3.2 Training on Mangrove Reforestation', 'Introduction of the mangrove ecosystems and its importance', 'Seedling the propagules in the nursery', '2.3.3 Tree planting', 'Target of tree planting', 'Strategy of implementation: work with the local people', 'Conduct seedling maintenance arranged by the group leader', '2.4.1 Participatory Monitoring Training on Tree monitoring', 'Tree monitoring planning', '2.4.2 Implementation of the tree monitoring', 'Methods and media: field trip directly to the location', 'Direct observation in area targeted', '3.1.1 Support of practice on sustainable aquaculture pond', 'The practical way for the management of sustainable aquaculture', 'Methods: participatory training and hands-on experience', 'Facilitator for meeting: Organized by PU through offline meeting', 'Methods: offline meeting', 'Facilitator for training: Local partner and PU', '1 Project Coordinator', 'Offices (location):', 'Partnerships', 'Feature 5. Rehabilitation target area in New Mahakam Project', 'CAPACITY BUILDING PLAN', 'Cross-cutting approaches', 'Knowledge management', 'Capitalization', 'External communication in Indonesia', 'External communication in France', 'Sustainability, scaling-up and/or exit strategy', 'Sustainability and Exit Strategy (Scale Up) of the project', 'Raising awareness component:', 'Mangrove rehabilitation component:', 'Economic development component:', 'Governance Component', 'Transversal to the project:', 'Monitoring & evaluation', 'Quarterly narrative and financial report', 'Internal evaluation at the end of project', 'Redaction of the audit report', 'Consideration of regulatory surplus']
#
# ===== Vérification pour ../data/projet_1/PU_P01_AAP03.docx =====
# ❌ Manque les sections : ['Brief project description', 'Name of the organization: Pokja Pesisir', 'Website: <http://pokjapesisir.id/>', 'Some activities conducted by POKJA Pesisir:', 'Geographic and socio-economic context', 'Environmental context', 'Table 1. Critical Criteria of Mahakam Delta Mangrove', 'Biodiversity issues', 'Institutional Context', 'The Movement of Indonesian New Capital', 'Aquaculture industry', 'Demography', 'Other issues', 'Strategy & theory of change', 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Beneficiaries', 'Teachers (primary school teachers)', 'Village officials', 'Partnerships', 'Feature 5. Rehabilitation target area in New Mahakam Project', 'Cross-cutting approaches', 'Knowledge management', 'Capitalization', 'External communication in Indonesia', 'External communication in France', 'Sustainability, scaling-up and/or exit strategy', 'Sustainability and Exit Strategy (Scale Up) of the project', 'Raising awareness component:', 'Mangrove rehabilitation component:', 'Economic development component:', 'Governance Component', 'Transversal to the project:'].
#
# Le document fourni, ../data/projet\_1/PU\_P01\_AAP03.docx, ne couvre pas les sections attendues pour un appel à projet valide (PU\_P01\_PP). Veuillez vous référer à la liste ci-dessus pour voir les sections manquantes.

# %%
import requests
from docx import Document

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def extract_text_by_sections(doc_path):
    """ Extrait le texte des sections d'un document Word """
    doc = Document(doc_path)
    sections = {}
    current_section = "Section Générique"

    for para in doc.paragraphs:
        text = para.text.strip()
        if text:
            if len(text.split()) < 10 and text[-1] not in ".!?":
                current_section = text
                sections[current_section] = []
            else:
                if current_section not in sections:
                    sections[current_section] = []
                sections[current_section].append(text)

    return {sec: " ".join(content) for sec, content in sections.items() if content}

def ask_mixtral(prompt):
    """ Envoie une requête à Mixtral pour analyse et compréhension du texte """
    response = requests.post(
        OLLAMA_HOST,
        json={"model": "mixtral", "prompt": prompt, "stream": False}
    )
    return response.json().get("response", "Erreur: pas de réponse")

# Charger les sections attendues du PU_P01_PP (document de référence)
pp_sections = extract_text_by_sections("../data/projet_1/PU_P01_PP.docx")

# Charger et comparer les AAP
aap_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
results = {}

for aap_path in aap_paths:
    aap_sections = extract_text_by_sections(aap_path)

    # Construire une requête avancée pour Mixtral
    prompt = f"""
    Nous devons vérifier si **les thématiques et contenus** du document de référence (PU_P01_PP) sont bien abordés dans {aap_path}.  
    Voici les **thématiques et contenus** attendus :
    {list(pp_sections.keys())}

    **Contenu du document analysé (AAP) :**
    {list(aap_sections.keys())}

    **Tâches :**
    1️⃣ Pour chaque thématique attendue, vérifie si elle est bien abordée dans l'AAP, même sous un autre titre.  
    2️⃣ Si une thématique est **totalement couverte**, marque-la ✅.  
    3️⃣ Si une thématique est **partiellement couverte**, marque-la ⚠️ et explique ce qui manque.  
    4️⃣ Si une thématique est totalement absente, marque-la ❌.  
    5️⃣ Donne une liste claire des thématiques **partiellement ou totalement absentes**.  

    **Réponse attendue :**
    - ✅ [Nom de la thématique] : Bien couverte.
    - ⚠️ [Nom de la thématique] : Partiellement couverte, éléments manquants : [détails].
    - ❌ [Nom de la thématique] : Absente.
    """

    mixtral_response = ask_mixtral(prompt)
    results[aap_path] = mixtral_response

# Affichage des résultats
for doc, result in results.items():
    print(f"\n===== Vérification thématique pour {doc} =====")
    print(result)
# Out:
# ===== Vérification thématique pour ../data/projet_1/PU_P01_AAP01.docx =====
# 1. ✅ Brief project description : The AAP includes a section for describing the projects by year and items, which can cover this theme.
# 2. ⚠️ Expected results, planned activities & required resources : The AAP has a section for expected concrete activity results, but it does not explicitly mention planned activities or required resources.
# 3. ❌ Activity 2.1. Pres-assessment study on land suitability : This specific activity is not mentioned in the AAP.
# 4. ⚠️ Address: Jl. Pelita 3 RT.12 Gg.7 Kel. Sambutan Samarinda : The AAP includes a section for website URLs, but it does not explicitly mention an address for the organization.
# 5. ✅ Restoring mangrove ecosystems, especially in the Mahakam Delta : This theme is mentioned in the AAP as one of the project's activities.
# 6. ✅ Name of the organization: Pokja Pesisir : The name of the organization is mentioned in the AAP.
# 7. ✅ Website: <http://pokjapesisir.id/> : The website for the organization is mentioned in the AAP.
# 8. ⚠️ Some activities conducted by POKJA Pesisir: : The AAP includes a section for major accomplishments, but it does not explicitly mention specific activities conducted by the organization.
# 9. ✅ Geographic and socio-economic context : The AAP includes a section for describing the projects by year and items, which can cover this theme.
# 10. ✅ Environmental context : This theme is mentioned in the AAP as one of the project's activities.
# 11. ⚠️ Table 1. Critical Criteria of Mahakam Delta Mangrove : The AAP does not include a specific table with these criteria, but it may be possible to cover this information in other sections.
# 12. ❌ Biodiversity issues : This specific theme is not mentioned in the AAP.
# 13. ⚠️ Institutional Context : The AAP includes a section for past activities and voluntary organization or group, which can partially cover this theme.
# 14. ✅ The Movement of Indonesian New Capital : This theme is mentioned in the AAP as one of the project's activities.
# 15. ⚠️ Aquaculture industry : The AAP includes a section for expected concrete activity results, but it does not explicitly mention the aquaculture industry.
# 16. ✅ Demography : The AAP includes a section for describing the projects by year and items, which can cover this theme.
# 17. ⚠️ Other issues : The AAP includes a section for describing the projects by year and items, which can partially cover this theme.
# 18. ⚠️ Strategy & theory of change : The AAP includes a section for activity schedule, but it does not explicitly mention strategy or theory of change.
# 19. ✅ Lack of alternative sustainable livelihood in coastal area; : This theme is mentioned in the AAP as one of the project's activities.
# 20. ❌ [List of partially or totally absent themes] : Biodiversity issues, Activity 2.1. Pres-assessment study on land suitability.
#
# ===== Vérification thématique pour ../data/projet_1/PU_P01_AAP02.docx =====
# 1. **Brief project description** ⚠️: The AAP mentions the title of the project and the beneficiaries but does not provide a detailed description of the project's objectives and goals.
# 2. **Expected results, planned activities & required resources ❌**: This theme is not addressed in the AAP.
# 3. **Activity 2.1. Pres-assessment study on land suitability ⚠️**: The AAP does mention a survey of planting locations but it does not explicitly state that it will be a pres-assessment study on land suitability.
# 4. **Address: Jl. Pelita 3 RT.12 Gg.7 Kel. Sambutan Samarinda ❌**: This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 5. **Restoring mangrove ecosystems, especially in the Mahakam Delta ✅**: This theme is well covered in the AAP.
# 6. **Name of the organization: Pokja Pesisir ✅**: This theme is well covered in the AAP.
# 7. **Website: <http://pokjapesisir.id/> ✅**: This theme is well covered in the AAP.
# 8. **Some activities conducted by POKJA Pesisir: ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 9. **Geographic and socio-economic context ⚠️**: The AAP mentions the project's location but does not provide a detailed description of the geographic and socio-economic context.
# 10. **Environmental context ⚠️**: The AAP mentions the environment but does not provide a detailed description of the environmental context.
# 11. **Table 1. Critical Criteria of Mahakam Delta Mangrove ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 12. **Biodiversity issues ⚠️**: The AAP mentions biodiversity but does not provide a detailed description of the biodiversity issues.
# 13. **Institutional Context ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 14. **The Movement of Indonesian New Capital ❌**: This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 15. **Aquaculture industry ⚠️**: The AAP mentions aquaculture but does not provide a detailed description of the aquaculture industry.
# 16. **Demography ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 17. **Other issues ⚠️**: The AAP mentions other issues but does not provide a detailed description of them.
# 18. **Strategy & theory of change ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 19. **Lack of alternative sustainable livelihoods ❌**: This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 20. **Gender equality considerations ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 21. **Monitoring and evaluation framework ❌** : This theme is not addressed in the AAP as it is too specific to the PU_P01_PP document.
# 22. **Budget prévisionnel détaillé du projet ✅**: This theme is well covered in the AAP.
# 23. **Lutte anti-corruption ✅** : This theme is well covered in the AAP.
#
# The following themes are partially or totally absent from the AAP:
#
# * Expected results, planned activities & required resources
# * Table 1. Critical Criteria of Mahakam Delta Mangrove
# * Institutional Context
# * The Movement of Indonesian New Capital
# * Demography
# * Strategy & theory of change
# * Lack of alternative sustainable livelihoods
# * Gender equality considerations
# * Monitoring and evaluation framework
#
# ===== Vérification thématique pour ../data/projet_1/PU_P01_AAP03.docx =====
# 1. **Brief project description** ✅ - Bien couverte dans la section "Description du projet"
# 2. **Expected results, planned activities & required resources (13)** ⚠️ - Partiellement couverte, les activités et ressources prévues sont décrites mais pas de manière détaillée comme demandé (par exemple sous forme d'un tableau)
# 3. **Activity 2.1. Pres-assessment study on land suitability (17)** ❌ - Absente
# 4. **Address: Jl. Pelita 3 RT.12 Gg.7 Kel. Sambutan Samarinda** ❌ - Absente
# 5. **Restoring mangrove ecosystems, especially in the Mahakam Delta** ✅ - Bien couverte dans la section "Description du projet"
# 6. **Name of the organization: Pokja Pesisir** ❌ - Absente (remplacée par le nom de l'organisation qui demande le financement)
# 7. **Website: <http://pokjapesisir.id/>** ❌ - Absente
# 8. **Some activities conducted by POKJA Pesisir:** ⚠️ - Partiellement couverte, les activités passées sont décrites mais pas de manière détaillée comme demandé
# 9. **Geographic and socio-economic context** ✅ - Bien couverte dans la section "Méthodologie et calendrier"
# 10. **Environmental context** ✅ - Bien couverte dans la section "Description du projet"
# 11. **Table 1. Critical Criteria of Mahakam Delta Mangrove** ❌ - Absente
# 12. **Biodiversity issues** ⚠️ - Partiellement couverte, les enjeux de biodiversité sont abordés mais pas sous forme de tableau comme demandé
# 13. **Institutional Context** ✅ - Bien couverte dans la section "Méthodologie et calendrier"
# 14. **The Mahakam Delta** ❌ - Absente (remplacée par le nom du projet)
# 15. **Community engagement and participation** ⚠️ - Partiellement couverte, l'engagement communautaire est abordé mais pas de manière détaillée comme demandé
# 16. **Monitoring and evaluation** ✅ - Bien couverte dans la section "Engagements de suivi et monitoring"
# 17. **Budget and funding** ✅ - Bien couverte dans la section "BUDGET"
# 18. **Long-term sustainability** ⚠️ - Partiellement couverte, l'aspect durable du projet est abordé mais pas de manière détaillée comme demandée
# 19. **Climate change mitigation and adaptation** ✅ - Bien couverte dans la section "Bénéfices attendus de ce projet"
#
# Thématiques partiellement ou totalement absentes :
#
# * Adresse du projet
# * Nom et coordonnées de l'organisation qui demande le financement
# * Activités conduites par POKJA Pesisir de manière détaillée
# * Tableau des critères clés pour les mangroves du Mahakam Delta
# * Engagement communautaire de manière détaillée
# * Long-term sustainability de manière détaillée.

# %% [markdown]
# ### pourcentage

# %%
import requests
from docx import Document

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def extract_text_by_sections(doc_path):
    """ Extrait le texte des sections d'un document Word """
    doc = Document(doc_path)
    sections = {}
    current_section = "Section Générique"

    for para in doc.paragraphs:
        text = para.text.strip()
        if text:
            # Détection des titres de section (moins de 10 mots, sans ponctuation forte)
            if len(text.split()) < 10 and text[-1] not in ".!?":
                current_section = text
                sections[current_section] = []
            else:
                sections.setdefault(current_section, []).append(text)

    return {sec: " ".join(content) for sec, content in sections.items() if content}

def ask_mixtral(prompt):
    """ Envoie une requête à Mixtral pour analyse et comparaison du texte """
    response = requests.post(
        OLLAMA_HOST,
        json={"model": "mixtral", "prompt": prompt, "stream": False}
    )
    return response.json().get("response", "Erreur: pas de réponse")

# Charger les sections du document de référence PU_P01_PP
pp_sections = extract_text_by_sections("../data/projet_1/PU_P01_PP.docx")

# Charger et comparer les AAP
aap_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
results = {}

for aap_path in aap_paths:
    aap_sections = extract_text_by_sections(aap_path)

    # Construire une requête optimisée pour Mixtral
    prompt = f"""
    Nous analysons si **les thématiques et contenus** attendus (PU_P01_PP) sont bien couverts dans {aap_path}.
    
    **📌 Thématiques attendues :**
    {list(pp_sections.keys())}

    **📄 Thématiques présentes dans l'AAP analysé :**
    {list(aap_sections.keys())}

    **🎯 Tâches :**
    - **Associer chaque thématique attendue** à son équivalent dans l'AAP (même sous un autre nom).
    - **Évaluer la couverture** :
      - ✅ **Bien couvert** → La thématique est abordée en détail.
      - ⚠️ **Partiellement couvert** → Présente mais incomplète (détailler ce qui manque).
      - ❌ **Absent** → Pas abordé du tout.
    - **Lister les sections manquantes** avec des précisions sur ce qui fait défaut.
    - **Calculer un score de conformité (%)** basé sur les thématiques couvertes.

    **📌 Format de réponse attendu :**
    - 📊 **Score : X%** (Nb de thématiques couvertes / Total thématiques attendues)
    - ✅ [Nom de la thématique] : Couvert en détail.
    - ⚠️ [Nom de la thématique] : Partiellement couvert → Manque [éléments spécifiques].
    - ❌ [Nom de la thématique] : Absent.

    **🔎 Exemple attendu :**
    ```
    📊 Score : 75%
    ✅ Brief project description : Présent avec une bonne description.
    ⚠️ Expected results : Mentionnés mais sans détails sur les ressources nécessaires.
    ❌ Monitoring & evaluation : Aucun élément sur le suivi des résultats.
    ```
    """

    mixtral_response = ask_mixtral(prompt)
    results[aap_path] = mixtral_response

# Affichage des résultats formatés
for doc, result in results.items():
    print(f"\n===== 📊 Vérification thématique pour {doc} =====")
    print(result)
# Out:
# ===== 📊 Vérification thématique pour ../data/projet_1/PU_P01_AAP01.docx =====
# 📊 Score : 25%
#
# ✅ Brief project description : Présent dans l'AAP sous "Section Générique" avec une brève description du projet.
#
# ❌ Thématiques et contenus attendus (hors titre) : Aucune correspondance directe trouvée dans l'AAP analysé. Les thématiques présentes dans l'AAP concernent principalement les activités planifiées, les résultats concrets attendus et le calendrier de l'activité, mais ne couvrent pas les autres sujets mentionnés dans la liste des thématiques attendues.
#
# Sections manquantes :
#
# * Restoring mangrove ecosystems, especially in the Mahakam Delta
# * Name of the organization: Pokja Pesisir
# * Website: <http://pokjapesisir.id/>
# * Geographic and socio-economic context
# * Environmental context
# * Biodiversity issues
# * Institutional Context
# * The Movement of Indonesian New Capital
# * Aquaculture industry
# * Demography
# * Other issues
# * Strategy & theory of change
# * Lack of alternative sustainable livelihood in coastal area;
# * Environmental awareness;
# * Beneficiaries
# * Teachers (primary school teachers)
# * Village officials
# * DETAILS OF PLANNED ACTIVITIES
# * 1.1.1. -Workshop on Environmental Conservation for Primary School Teachers
# * 1.2.1 -Encouraging/assisting schools towards adiwiyata in Mahakam Delta
# * Location: in Delta Mahakam conducted by YML
# * 1.3.1. Waste Management Campaign
# * Target: 100 persons local community involved
# * Health approach involved medical staff or public health office
# * 1.3.2 Book publication
# * 1.3.3 Environmental Campaign for public with billboard
# * Target: public in general
# * 1.3.4 Public Campaign Awareness through Media
# * Activity 2.1. Pres-assessment study on land suitability
# * Hire consultant team with the available budget
# * 2.2.1 Establishment of community-based nurseries
# * Methods and media: Technical assistance by Project staffs
# * 2.2.2 Maintenance of the nurseries
# * Methods and media: Local communities, etc.
# * 2.3.1 Planting mangrove seeds in degraded areas
# * 2.3.2 Monitoring mangrove growth
# * Capitalisation of Lessons Learned
# * 2.4.1 Dissemination activities
# * Local and national levels, etc.
# * Capacity building for local communities
# * 3. Expected concrete activity results
# * (Details on the expected outputs, outcomes and impact)
# * 4. Activity schedule
# * (Detailed plan including timeline for each activity)
# * Financial Situation
#
# Les thématiques ci-dessus sont manquantes dans l'AAP analysé et représentent les éléments spécifiques qui auraient dû être inclus pour une couverture complète.
#
# ===== 📊 Vérification thématique pour ../data/projet_1/PU_P01_AAP02.docx =====
# 📊 Score : 45%
#
# ✅ Brief project description : Présent avec une bonne description dans la section 'Geographic and socio-economic context' et 'Restoring mangrove ecosystems, especially in the Mahakam Delta'.
#
# ⚠️ Expected results, planned activities & required resources (6 points attendus) : Partiellement couvert → Manque les détails sur les ressources nécessaires pour chaque activité.
# - 1.1.1. -Workshop on Environmental Conservation for Primary School Teachers (détails des ressources et planification)
# - 1.2.1 -Encouraging/assisting schools towards adiwiyata in Mahakam Delta (détails des ressources et planification)
# - 1.3.1. Waste Management Campaign (détails des ressources et planification)
# - 2.2.1 Establishment of community-based nurseries (détails des ressources et planification)
# - 2.3.3 Tree planting (détails des ressources, cibles quantifiées et planification)
# - 3.1.1 Support of practice on sustainable aquaculture pond (détails des ressources et planification)
#
# ❌ Activity 2.1. Pres-assessment study on land suitability : Absent (pas de mention d'une étude de ce type).
#
# ✅ 'Name of the organization: Pokja Pesisir', 'Website: http://pokjapesisir.id/', 'Partnerships' : Présents dans la section 'Organization and Partners'.
#
# ⚠️ 'Lack of alternative sustainable livelihood in coastal area;', 'Environmental awareness;', 'Teachers (primary school teachers)', 'Village officials', 'Beneficiaries' : Mentionnés mais pas explicitement reliés aux activités du projet.
#
# ✅ 'Address: Jl. Pelita 3 RT.12 Gg.7 Kel. Sambutan Samarinda', 'Location' : Présent dans la section 'Geographic and socio-economic context'.
#
# ⚠️ 'Strategy & theory of change' : Partiellement couvert → Manque des détails sur la stratégie et la justification du changement attendu.
#
# ❌ 'Demography', 'Aquaculture industry', 'The Movement of Indonesian New Capital', 'Biodiversity issues', 'Institutional Context', 'Other issues' : Absents (pas de mention dans le document analysé).
#
# ⚠️ 'Table 1. Critical Success Factors', 'Table 2. Major Stakeholders', 'Table 3. Risks and Mitigation Strategies' : Mentionnés sans contenu détaillé, seulement les titres sont présents.
#
# ❌ 'Budget prévisionnel détaillé du projet' : Absent (pas de mention d'un budget détaillé).
#
# ⚠️ 'Lutte anti-corruption' : Partiellement couvert → Mentionné dans la section 'General Information', mais aucune mesure concrète n'est proposée.
#
# ===== 📊 Vérification thématique pour ../data/projet_1/PU_P01_AAP03.docx =====
# 📊 Score : 58%
#
# ✅ Brief project description : Présent avec une bonne description dans l'introduction de l'AAP.
#
# ⚠️ Expected results, planned activities & required resources (13) : Partiellement couvert → Manque des détails sur les ressources nécessaires. Cependant, les activités prévues sont décrites dans la section "Méthodologie et calendrier" de l'AAP.
#
# ⚠️ Activity 2.1. Pres-assessment study on land suitability (17) : Partiellement couvert → L'activité est mentionnée mais sans détail sur le consultant team ni le budget disponible.
#
# ⚠️ Geographic and socio-economic context : Partiellement couvert → Bien que la localisation soit précisée dans l'AAP, il manque des informations sur le contexte socio-économique.
#
# ⚠️ Environmental context : Partiellement couvert → Présent mais incomplètement traité.
#
# ⚠️ Institutional Context : Partiellement couvert → Bien que des partenariats soient mentionnés, il n'y a pas d'indication sur la gestion du projet en amont ou au fil des années.
#
# ❌ Biodiversity issues : Absent.
#
# ⚠️ Demography : Partiellement couvert → Mentionné brièvement dans l'introduction de l'AAP.
#
# ✅ Benefits for local economy : Présent avec une bonne description dans la section "Bénéfices pour l’économie locale".
#
# ❌ Risks of the project : Absent.
#
# ⚠️ Monitoring and evaluation : Partiellement couvert → Il y a des éléments sur le suivi des arbres plantés, mais pas sur le suivi des résultats du projet dans son ensemble.
#
# Sections manquantes :
# - Liste of envisaged species
# - Pépinières
# - Coordinates GPS of plantations
# - Pour la conception du projet en amont
# - Pour le suivi technique au fil des années
# - Indicateurs quantitatifs : Nombre d’arbres plantés par essence*
# - Budget total du projet, détaillé par poste de coût
# - Lien avec les autres financeurs
# - Photos with mention of the author to credit

# %%
import requests
from docx import Document
import os

OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"

def extract_text_by_sections(doc_path):
    """ Extrait le texte des sections d'un document Word en structurant le contenu """
    if not os.path.exists(doc_path):
        print(f"Erreur : fichier introuvable {doc_path}")
        return {}

    doc = Document(doc_path)
    sections = {}
    current_section = "Section Générique"

    for para in doc.paragraphs:
        text = para.text.strip()
        if text:
            if len(text.split()) < 10 and text[-1] not in ".!?":  
                current_section = text.lower().strip()
                sections[current_section] = []
            else:
                sections.setdefault(current_section, []).append(text)

    return {sec: " ".join(content) for sec, content in sections.items() if content}

def ask_mixtral(prompt):
    """ Envoie une requête à Mixtral pour analyse et comparaison du texte """
    try:
        response = requests.post(
            OLLAMA_HOST,
            json={"model": "mixtral", "prompt": prompt, "stream": False}
        )
        response.raise_for_status()
        return response.json().get("response", "Erreur: pas de réponse")
    except requests.RequestException as e:
        return f"Erreur lors de la requête : {e}"

# Charger les sections du document de référence PU_P01_PP
pp_path = "../data/projet_1/PU_P01_PP.docx"
pp_sections = extract_text_by_sections(pp_path)

# Charger et comparer les AAP
aap_paths = ["../data/projet_1/PU_P01_AAP01.docx", "../data/projet_1/PU_P01_AAP02.docx", "../data/projet_1/PU_P01_AAP03.docx"]
results = {}

for aap_path in aap_paths:
    aap_sections = extract_text_by_sections(aap_path)

    if not aap_sections:
        print(f"⚠️ Aucun contenu extrait de {aap_path}")
        continue

    # Construire une requête optimisée pour Mixtral
    prompt = f"""
    Nous analysons si les thématiques et contenus attendus (PU_P01_PP) sont bien couverts dans {os.path.basename(aap_path)}.

    📌 **Thématiques attendues :**
    {list(pp_sections.keys())}

    📄 **Thématiques présentes dans l'AAP analysé :**
    {list(aap_sections.keys())}

    🎯 **Tâches :**
    - Associer chaque thématique attendue à son équivalent dans l'AAP (même sous un autre nom).
    - Évaluer la couverture :
      - ✅ **Bien couvert** → Thématique détaillée.
      - ⚠️ **Partiellement couvert** → Présente mais incomplète (indiquer les manques).
      - ❌ **Absent** → Pas abordé du tout.
    - Identifier les sections manquantes et préciser ce qui fait défaut.
    - Calculer un **score de conformité (%)** basé sur les thématiques couvertes.

    📊 **Format de réponse attendu :**
    ```
    📊 Score : X%
    ✅ [Nom de la thématique] : Bien détaillée.
    ⚠️ [Nom de la thématique] : Partiellement couverte → Manque [éléments précis].
    ❌ [Nom de la thématique] : Absente.
    ```
    """

    mixtral_response = ask_mixtral(prompt)
    results[aap_path] = mixtral_response

# Affichage des résultats formatés
for doc, result in results.items():
    print(f"\n===== 📊 Vérification thématique pour {os.path.basename(doc)} =====")
    print(result)
# Out:
# ===== 📊 Vérification thématique pour PU_P01_AAP01.docx =====
# 📊 Score : 15%
#
# ✅ brief project description: Bien détaillée dans la section "3. expected concrete activity results" de l'AAP analysé.
#
# ❌ '6.expected results, planned activities & required resources\t13': Absente. Aucune information concernant les résultats attendus, les activités prévues et les ressources requises n'a été trouvée dans l'AAP analysé.
#
# ⚠️ activity 2.1. pres-assessment study on land suitability\t17: Partiellement couverte. Bien que la section "4. activity schedule" mentionne une étude de faisabilité, il manque des informations spécifiques sur l'évaluation de la pertinence du terrain pour la restauration des écosystèmes de mangroves.
#
# ❌ address: jl. pelita 3 rt.12 gg.7 kel. sambutan samarinda: Absente. L'adresse de l'organisation n'est pas spécifiée dans l'AAP analysé, uniquement sur le document original fourni.
#
# ✅ restoring mangrove ecosystems, especially in the mahakam delta: Bien détaillée dans la section "3. expected concrete activity results" de l'AAP analysé.
#
# ⚠️ name of the organization: pokja pesisir: Partiellement couverte. Le nom de l'organisation n'est pas spécifié explicitement dans l'AAP analysé, mais est mentionnée sur le document original fourni.
#
# ⚠️ website: http://pokjapesisir.id/: Partiellement couverte. L'URL du site web n'a été trouvée que sur le document original fourni et non dans l'AAP analysé.
#
# ⚠️ some activities conducted by pokja pesisir: Partiellement couverte. Bien que des activités soient mentionnées dans la section "3. expected concrete activity results", il n'est pas explicitement indiqué qu'il s'agit d'activités menées par l'organisation spécifique mentionnée.
#
# ⚠️ geographic and socio-economic context: Partiellement couverte. Bien que des informations géographiques soient fournies dans la section "3. expected concrete activity results", le contexte socio-économique n'est pas spécifiquement abordé.
#
# ⚠️ environmental context: Partiellement couverte. Le contexte environnemental est partiellement couvert dans la section "3. expected concrete activity results". Cependant, des informations supplémentaires sur l'état actuel de l'environnement local seraient souhaitables.
#
# ❌ table 1. critical criteria of mahakam delta mangrove: Absente.
#
# ⚠️ biodiversity issues: Partiellement couverte. Bien que des préoccupations relatives à la biodiversité soient mentionnées dans la section "3. expected concrete activity results", aucune information spécifique sur l'état actuel de la biodiversité n'est fournie.
#
# ❌ institutional arrangements: Absente.
#
# ❌ legislation and policy framework: Absente.
#
# ❌ monitoring and evaluation: Absente.
#
# ❌ impact assessment: Absente.
#
# ❌ risks and challenges: Absente.
#
# ❌ budget: Absente.
#
# ➡️ Sections manquantes : Les sections concernant les résultats attendus, les activités prévues et les ressources requises, l'adresse de l'organisation, le nom de l'organisation (partiellement), la législation et le cadre politique, l'évaluation des impacts, l'identification des risques et défis, et le budget sont absentes ou incomplètes dans l'AAP analysé.
#
# ===== 📊 Vérification thématique pour PU_P01_AAP02.docx =====
# 📊 Score : 15%
#
# ✅ 'brief project description' : Bien détaillée dans la section 'ville et pays'.
# ⚠️ '6.\texpected results, planned activities & required resources\t13' : Partiellement couverte, les activités prévues sont mentionnées mais pas les résultats attendus ni les ressources requises.
# ❌ 'activity 2.1. pres-assessment study on land suitability\t17' : Absente.
# ⚠️ 'address: jl. pelita 3 rt.12 gg.7 kel. sambutan samarinda' : Partiellement couverte, le lieu est mentionné mais pas sous cette forme spécifique.
# ✅ 'restoring mangrove ecosystems, especially in the mahakam delta' : Bien détaillée dans la section 'ville et pays'.
# ⚠️ 'name of the organization: pokja pesisir' : Partiellement couverte, le nom de l'organisation est mentionnée mais pas sous cette forme spécifique.
# ✅ 'website: http://pokjapesisir.id/' : Bien détaillée dans la section 'ville et pays'.
# ⚠️ 'some activities conducted by pokja pesisir:' : Partiellement couverte, certaines activités sont mentionnées mais pas toutes.
# ⚠️ 'geographic and socio-economic context' : Partiellement couverte, le contexte géographique est évoqué mais pas le contexte socio-économique.
# ⚠️ 'environmental context' : Partiellement couverte, seul l'aspect lié à la lutte anti-corruption est abordé.
# ❌ 'table 1. critical criteria of mahakam delta mangrove' : Absente.
# ⚠️ 'biodiversity issues' : Partiellement couverte, mention de la préservation de l'environnement mais pas spécifiquement des enjeux de biodiversité.
# ⚠️ 'institutional context' : Partiellement couverte, mention du contexte institutionnel mais sans détail.
# ⚠️ 'the movement of indonesian new capital' : Partiellement couverte, mentionné mais sans lien avec le projet.
# ⚠️ 'aquaculture industry' : Partiellement couverte, mentionnée brièvement.
# ⚠️ 'demography' : Partiellement couverte, mentionnée brièvement.
# ⚠️ 'other issues' : Partiellement couverte, mention de la lutte anti-corruption mais pas d'autres enjeux.
# ⚠️ 'strategy & theory of change' : Partiellement couverte, une stratégie est évoquée mais pas explicitement liée à un changement attendu.
# ⚠️ 'lack of alternative sustainable livelihood in coastal area;' : Partiellement couverte, mentionnée brièvement.
# ⚠️ 'environmental awareness;' : Partiellement couverte, mentionnée brièvement.
# ✅ 'beneficiaries' : Bien détaillée dans la section 'bénéficiaires visés'.
# ⚠️ 'teachers (primary school teachers)' : Partiellement couverte, mentionnés mais pas explicitement comme bénéficiaires.
# ❌ 'location of the project: Mahakam Delta' : Absente.
# ⚠️ 'starting date and duration' : Partiellement couverte, la durée est indiquée implicitement dans la section 'ville et pays'.
# ❌ 'budget and funding sources' : Absente.
# ⚠️ 'sustainability of the project' : Partiellement couverte, mentionnée brièvement.
# ⚠️ 'risk analysis and mitigation measures' : Partiellement couverte, mention de la lutte anti-corruption mais pas d'autres risques.
# ⚠️ 'monitoring and evaluation plan' : Partiellement couverte, mentionnée brièvement.
# ⚠️ 'stakeholder engagement strategy' : Partiellement couverte, mentionnée brièvement.
#
# ===== 📊 Vérification thématique pour PU_P01_AAP03.docx =====
# 📊 Score : 58%
#
# ✅ 'brief project description' : Bien détaillée dans l'introduction et la description du projet.
# ⚠️ '6.expected results, planned activities & required resources' : Partiellement couverte, les activités et ressources prévues sont décrites mais pas regroupées en un seul endroit.
# ❌ 'activity 2.1. pres-assessment study on land suitability' : Absente, aucune évaluation préliminaire des sols n'est mentionnée.
# ⚠️ 'address: jl. pelita 3 rt.12 gg.7 kel. sambutan samarinda' : Partiellement couverte, l'adresse est absente mais la localisation générale (delta mahakam) est précisée.
# ✅ 'restoring mangrove ecosystems, especially in the mahakam delta' : Bien détaillée dans la description du projet.
# ⚠️ 'name of the organization: pokja pesisir', 'website: http://pokjapesisir.id/' : Partiellement couverte, le nom de l'organisation est mentionné mais pas son site web.
# ✅ 'some activities conducted by pokja pesisir:' : Bien détaillée dans la description du projet.
# ⚠️ 'geographic and socio-economic context', 'environmental context' : Partiellement couvertes, ces contextes sont décrits mais pas regroupés en un seul endroit.
# ✅ 'table 1. critical criteria of mahakam delta mangrove' : Bien détaillée dans la description du projet.
# ⚠️ 'biodiversity issues' : Partiellement couverte, des problèmes de biodiversité sont mentionnés mais pas regroupés en un seul endroit.
# ⚠️ 'institutional context' : Partiellement couverte, le contexte institutionnel est décrit mais pas regroupé en un seul endroit.
# ⚠️ 'the movement of indonesian new capital', 'aquaculture industry', 'demography', 'other issues' : Partiellement couvertes, ces thèmes sont abordés mais dispersés dans la description du projet.
# ⚠️ 'méthodologie et calendrier' : Partiellement couverte, une méthodologie est décrite mais pas de calendrier précis.
# ❌ 'liste des essences envisagées', 'pépinières' : Absentes, aucune liste d'espèces prévues ni de pépinières mentionnées.
# ⚠️ 'coordonnées gps des plantations' : Partiellement couverte, des coordonnées GPS sont absentes mais la localisation générale est précisée.
# ✅ 'bénéfices attendus de ce projet', 'pour la captation de carbone', 'bénéfices pour l’économie locale' : Bien détaillés dans les bénéfices attendus du projet.
# ⚠️ 'risques du projet' : Partiellement couverte, des risques sont mentionnés mais pas regroupés en un seul endroit.
# ⚠️ 'engagements de suivi et monitoring', 'pour la conception du projet en amont', 'pour le suivi technique au fil des années' : Partiellement couvertes, des engagements de suivi sont mentionnés mais pas regroupés en un seul endroit.
# ✅ 'indicateurs quantitatifs: nombre d’arbres plantés par essence*', 'bilan de captation carbone du projet' : Bien détaillés dans les bénéfices attendus du projet.
# ⚠️ 'indicateurs qualitatifs:' : Partiellement couverte, aucun indicateur qualitatif spécifique n'est mentionné mais la description du projet peut être considérée comme un tel indicateur.
# ❌ 'budget', 'budget total du projet, détaillé par poste de coût', 'lien avec les autres financeurs' : Absentes, aucun budget ni lien avec d'autres financeurs ne sont mentionnés.
# ✅ 'photos', 'avec mention de l’auteur à créditer' : Bien détaillées, des photos avec mention de l'auteur sont demandées.

# %% [markdown]
# ## Exploring different AAP
#
# The goal to reach is about to find beetwween all the AAP, the common struct or what are the needs in it

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2Note: you may need to restart the kernel to use updated packages.
#
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yann\desktop\dev\stages\d4g\2025\13_ia_financement\venv\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yann\desktop\dev\stages\d4g\2025\13_ia_financement\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\yann\desktop\dev\stages\d4g\2025\13_ia_financement\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.1 tzdata-2025.1

# %%
import requests
from docx import Document
import os
from pathlib import Path
import json
import PyPDF2
import pandas as pd

def extract_text_from_pdf(file_path):
    """Extrait le texte d'un fichier PDF"""
    try:
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            text = ""
            for page in reader.pages:
                text += page.extract_text() + "\n"
        return text
    except Exception as e:
        print(f"Erreur lors de la lecture du PDF {file_path}: {e}")
        return ""

def extract_text_from_excel(file_path):
    """Extrait le texte d'un fichier Excel"""
    try:
        df = pd.read_excel(file_path)
        text = "\n".join([str(col) for col in df.columns])
        for _, row in df.iterrows():
            text += "\n" + "\n".join([str(cell) for cell in row])
        return text
    except Exception as e:
        print(f"Erreur lors de la lecture du fichier Excel {file_path}: {e}")
        return ""

def extract_text_by_sections(file_path):
    """Extrait le texte des sections d'un document en fonction de son format"""
    if not os.path.exists(file_path):
        print(f"Erreur : fichier introuvable {file_path}")
        return {}

    sections = {"contenu_general": []}
    
    try:
        if file_path.lower().endswith('.docx'):
            doc = Document(file_path)
            current_section = "contenu_general"
            
            for para in doc.paragraphs:
                text = para.text.strip()
                if text:
                    if len(text.split()) < 10 and text[-1] not in ".!?":
                        current_section = text.lower().strip()
                        sections.setdefault(current_section, [])
                    else:
                        sections[current_section].append(text)
                        
        elif file_path.lower().endswith('.pdf'):
            text = extract_text_from_pdf(file_path)
            sections["contenu_general"].append(text)
            
        elif file_path.lower().endswith(('.xlsx', '.xls')):
            text = extract_text_from_excel(file_path)
            sections["contenu_general"].append(text)
            
        else:
            print(f"Format de fichier non supporté : {file_path}")
            return {}

        return {sec: " ".join(content) for sec, content in sections.items() if content}
        
    except Exception as e:
        print(f"Erreur lors de l'extraction du fichier {file_path}: {e}")
        return {}

def find_aap_files(root_dir):
    """Trouve tous les fichiers AAP dans l'arborescence"""
    aap_files = []
    root = Path(root_dir)
    
    for path in root.rglob("*"):
        if path.is_file() and "AAP" in path.name.upper():
            aap_files.append(str(path))
    
    return aap_files

def analyze_topics_with_mixtral(all_sections):
    """Analyse les sections communes et spécifiques avec Mixtral"""
    try:
        # Préparation des données pour l'analyse
        sections_count = {}
        for doc, sections in all_sections.items():
            for section in sections:
                sections_count[section] = sections_count.get(section, 0) + 1

        prompt = f"""
        Analyse des documents AAP (Appels À Projets) :
        
        Documents analysés : {len(all_sections)} fichiers
        
        Tâches :
        1. Identifier les sections communes qui apparaissent dans plusieurs documents
        2. Créer un template générique basé sur les sections les plus fréquentes
        3. Pour chaque document, identifier ses spécificités
        4. Calculer des statistiques sur la fréquence des sections
        
        Données :
        {json.dumps(all_sections, indent=2, ensure_ascii=False)}
        
        Statistiques préliminaires :
        {json.dumps(sections_count, indent=2, ensure_ascii=False)}
        
        Format de réponse souhaité :
        ```
        📋 Template Commun :
        - [Section] : Présente dans X% des documents
        - [Section] : Présente dans Y% des documents
        ...
        
        🔍 Spécificités par document :
        [Document 1]
        - Sections uniques : [liste]
        - Contenu particulier : [description]
        ...
        
        📊 Statistiques :
        - Nombre moyen de sections : X
        - Top 5 sections les plus fréquentes
        - Top 5 sections les plus rares
        ```
        
        Répondez en français et soyez précis dans l'analyse des sections communes et spécifiques.
        """
        # OLLAMA_HOST = "http://127.0.0.1:11435/api/generate"
        response = requests.post(
            "http://127.0.0.1:11434/api/generate",
            json={
                "model": "mixtral:latest",
                "prompt": prompt,
                "stream": False,
                "options": {
                    "temperature": 0.7,
                    "top_p": 0.9,
                    "num_predict": 2048
                }
            },
            timeout=120
        )
        response.raise_for_status()
        return response.json().get("response", "Erreur: pas de réponse")
    except requests.RequestException as e:
        print(f"Erreur détaillée de la requête : {str(e)}")
        return f"Erreur lors de la requête Mixtral : {e}\nVérifiez qu'Ollama est bien lancé sur le port 11435"
    except Exception as e:
        print(f"Erreur détaillée : {str(e)}")
        return f"Erreur inattendue : {e}"

def main():
    # Configuration
    data_dir = "../data"
    print("🔍 Recherche des fichiers AAP...")
    aap_files = find_aap_files(data_dir)
    print(f"📁 Nombre de fichiers AAP trouvés : {len(aap_files)}")

    # Extraction des sections
    all_sections = {}
    for file_path in aap_files:
        print(f"\n📄 Analyse de {os.path.basename(file_path)}")
        sections = extract_text_by_sections(file_path)
        if sections:
            all_sections[os.path.basename(file_path)] = list(sections.keys())

    # Analyse avec Mixtral
    print("\n🤖 === Analyse des topics avec Mixtral ===")
    analysis = analyze_topics_with_mixtral(all_sections)
    print(analysis)

    # Sauvegarde des résultats
    results = {
        "nombre_fichiers": len(aap_files),
        "fichiers_analyses": list(all_sections.keys()),
        "sections_par_fichier": all_sections,
        "analyse_mixtral": analysis
    }
    
    output_file = "resultats_analyse_aap.json"
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)
        print(f"\n💾 Résultats sauvegardés dans {output_file}")

if __name__ == "__main__":
    main()
# Out:
# 🔍 Recherche des fichiers AAP...
# 📁 Nombre de fichiers AAP trouvés : 33
#
# 📄 Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
#
# 📄 Analyse de ESF_P01_AAP01.docx
#
# 📄 Analyse de ESF_P01_AAP02.docx
#
# 📄 Analyse de ESF_P01_AAP03.docx
#
# 📄 Analyse de ESF_P01_AAP04.docx
#
# 📄 Analyse de PU_P01_AAP01.docx
#
# 📄 Analyse de PU_P01_AAP02.docx
#
# 📄 Analyse de PU_P01_AAP03.docx
#
# 📄 Analyse de Pulse_P01_AAP01.docx
#
# 📄 Analyse de Pulse_P02_AAP01.rtf
# Format de fichier non supporté : ..\data\Pulse\Projet02\Pulse_P02_AAP01.rtf
#
# 📄 Analyse de Pulse_P02_AAP01E
# Format de fichier non supporté : ..\data\Pulse\Projet02\Pulse_P02_AAP01E
#
# 📄 Analyse de PS_P03_AAP01.docx
#
# 📄 Analyse de dossier_de_candidature_aap_projets_innov_entre_2024.docx
#
# 📄 Analyse de Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
#
# 📄 Analyse de Note cadrage AAP.docx
#
# 📄 Analyse de Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
# Erreur lors de la lecture du fichier Excel ..\data\Pulse\Projet04\Pulse_P04_APP1\Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
#
# 📄 Analyse de Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
#
# 📄 Analyse de Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
#
# 📄 Analyse de réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx
# Erreur lors de la lecture du fichier Excel ..\data\Pulse\Projet04\Pulse_P04_PP1\réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
#
# 📄 Analyse de SS_P01_AAP01.docx
#
# 📄 Analyse de SS_P01_AAP01T.docx
#
# 📄 Analyse de SS_P02_AAP01E.pdf
#
# 📄 Analyse de SS_P03_AAP01E.pdf
#
# 📄 Analyse de SS_P04_AAP01E.pdf
#
# 📄 Analyse de SS_P05_AAP01.docx
#
# 📄 Analyse de SS_P11_AAP01.docx
#
# 📄 Analyse de Wings of the Ocean_Procédure réponse AAP.docx
#
# 📄 Analyse de WOTO_P01_AAP01.pdf
#
# 📄 Analyse de WOTO_P01_AAP02.docx
#
# 📄 Analyse de WOTO_P01_AAP03.pdf
#
# 📄 Analyse de WOTO_P02_AAP01E.pdf
#
# 📄 Analyse de WOTO_P02_AAP02E.docx
#
# 📄 Analyse de WOTO_P03_AAP01E.pdf
#
# 🤖 === Analyse des topics avec Mixtral ===
# 📋 Template Commun :
#
# * Informations générales : Présente dans 100% des documents
# * Description (max. 13 pages) : Présente dans 50% des documents
# * Cadre logique : Présente dans 42% des documents
# * Expérience : Présente dans 33% des documents
# * Déclaration du demandeur chef de file (demande complète) : Présente dans 25% des documents
# * Mandat [pour le(s) codemandeur(s)] : Présente dans 17% des documents
# * Déclaration relative aux entités affiliées : Présente dans 17% des documents
# * Consignes de rédaction du formulaire de demande complète : Présente dans 17% des documents
# * Annexe - Documents à joindre avec le dossier de candidature : Présente dans 17% des documents
#
# 🔍 Spécificités par document :
#
# [Document 1]
#
# * Sections uniques : Comptes du dernier exercice clos (chaque année)
# * Contenu particulier : Association, missions locales, lagunes et fleuves, thématiques, types de bénéficiaires principaux, innovation sociale et/ou environnementale, impact social démontré, nombre de personnes sensibilisées en 2024 par mission
#
# ...
#
# 📊 Statistiques :
#
# * Nombre moyen de sections : 7 sections
# * Top 5 sections les plus fréquentes : Informations générales (100%), Description (50%), Cadre logique (42%), Expérience (33%), Déclaration du demandeur chef de file (demande complète) (25%)
# * Top 5 sections les plus rares : Consignes de rédaction du formulaire de demande complète (17%), Annexe - Documents à joindre avec le dossier de candidature (17%), Déclaration relative aux entités affiliées (17%), Mandat [pour le(s) codemandeur(s)] (17%), Comptes du dernier exercice clos (8%)
#
# 💾 Résultats sauvegardés dans resultats_analyse_aap.json

# %% [markdown]
# ### with a specific template ( extract from the last observation )

# %%
import requests
import json
from pathlib import Path
import os
from typing import Dict, List, Any
from docx import Document
import PyPDF2
import pandas as pd
from collections import Counter
import openpyxl
class AAPAnalyzer:
    def __init__(self, data_dir: str):
        self.data_dir = data_dir
        
    def extract_text_by_sections(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte par sections d'un fichier"""
        try:
            if file_path.lower().endswith('.docx'):
                return self._extract_from_docx(file_path)
            elif file_path.lower().endswith('.pdf'):
                return self._extract_from_pdf(file_path)
            elif file_path.lower().endswith(('.xlsx', '.xls')):
                return self._extract_from_excel(file_path)
            else:
                print(f"⚠️ Format non supporté: {file_path}")
                return {}
        except Exception as e:
            print(f"❌ Erreur extraction {file_path}: {e}")
            return {}

    def _extract_from_docx(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier Word"""
        sections = {}
        current_section = "Introduction"
        current_content = []
        
        try:
            doc = Document(file_path)
            for para in doc.paragraphs:
                text = para.text.strip()
                if not text:
                    continue
                
                # Détection d'une nouvelle section
                if text.startswith('###') or (para.style and "Heading" in para.style.name):
                    if current_content:
                        sections[current_section] = "\n".join(current_content)
                    current_section = text.strip('#').strip()
                    current_content = []
                else:
                    current_content.append(text)
            
            # Ajouter la dernière section
            if current_content:
                sections[current_section] = "\n".join(current_content)
                
            return sections
            
        except Exception as e:
            print(f"❌ Erreur Word {file_path}: {e}")
            return {}

    def _extract_from_pdf(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier PDF"""
        sections = {}
        current_section = "Introduction"
        current_content = []
        
        try:
            with open(file_path, 'rb') as file:
                reader = PyPDF2.PdfReader(file)
                for page in reader.pages:
                    content = page.extract_text()
                    lines = content.split('\n')
                    
                    for line in lines:
                        line = line.strip()
                        if not line:
                            continue
                        
                        # Détection d'une nouvelle section
                        if line.startswith('###') or line.isupper():
                            if current_content:
                                sections[current_section] = "\n".join(current_content)
                            current_section = line.strip('#').strip()
                            current_content = []
                        else:
                            current_content.append(line)
            
            # Ajouter la dernière section
            if current_content:
                sections[current_section] = "\n".join(current_content)
                
            return sections
            
        except Exception as e:
            print(f"❌ Erreur PDF {file_path}: {e}")
            return {}

    def _extract_from_excel(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier Excel"""
        sections = {}
        
        try:
            df = pd.read_excel(file_path)
            for col in df.columns:
                if isinstance(col, str) and col.strip():
                    content = df[col].dropna().astype(str).tolist()
                    if content:
                        sections[col] = "\n".join(content)
            return sections
            
        except Exception as e:
            print(f"❌ Erreur Excel {file_path}: {e}")
            return {}

    def analyze_topics(self, all_sections: Dict[str, Dict[str, str]]) -> str:
        """Analyse principale des documents"""
        try:
            print("🔍 Analyse document par document...")
            all_analyses = {}
            
            for doc_name, sections in all_sections.items():
                print(f"\n📄 Analyse de {doc_name}")
                doc_analysis = self.analyze_document(sections)
                all_analyses[doc_name] = doc_analysis
            
            print("\n🔄 Comparaison des documents...")
            comparison = self.compare_documents_themes(all_analyses)
            
            print("\n📊 Génération du rapport...")
            report = self.generate_comparative_report(comparison)
            
            # Sauvegarde des résultats détaillés
            self.save_detailed_results(all_analyses, comparison)
            
            return report
            
        except Exception as e:
            print(f"❌ Erreur analyse: {e}")
            return "Erreur lors de l'analyse"
    
    def analyze_content_with_mixtral(self, text: str, section_name: str) -> dict:
        """Analyse sémantique d'une section spécifique"""
        try:
            prompt = f"""Tu es un expert en analyse de documents. Analyse cette section et renvoie UNIQUEMENT un JSON valide sans aucun autre texte.

    SECTION À ANALYSER : {section_name}
    CONTENU : {text}

    Le JSON DOIT suivre EXACTEMENT ce format :
    {{
        "themes": [
            {{
                "nom": "nom de la thématique",
                "concepts_cles": ["liste des concepts"],
                "points_importants": ["liste des points"],
                "specificites": ["éléments spécifiques"]
            }}
        ],
        "resume": "résumé court de la section",
        "mots_cles": ["liste des mots-clés importants"]
    }}"""

            response = requests.post(
                "http://localhost:11434/api/generate",
                json={
                    "model": "mixtral:latest",
                    "prompt": prompt,
                    "temperature": 0.7,
                    "stream": False,
                    "format": "json"  # Forcer le format JSON
                },
                timeout=180
            )
            
            if response.status_code == 200:
                try:
                    # Récupérer la réponse
                    response_data = response.json()
                    
                    # Extraire le JSON de la réponse
                    if isinstance(response_data, dict) and "response" in response_data:
                        try:
                            # Tenter de parser le JSON dans la réponse
                            json_str = response_data["response"]
                            # Nettoyer la chaîne JSON si nécessaire
                            json_str = json_str.strip()
                            if json_str.startswith("```json"):
                                json_str = json_str[7:]
                            if json_str.endswith("```"):
                                json_str = json_str[:-3]
                            
                            parsed_data = json.loads(json_str)
                            
                            # Vérifier la structure
                            if not isinstance(parsed_data, dict):
                                raise ValueError("La réponse n'est pas un objet JSON")
                            
                            # S'assurer que les champs requis sont présents
                            if "themes" not in parsed_data:
                                parsed_data["themes"] = []
                            if "resume" not in parsed_data:
                                parsed_data["resume"] = ""
                            if "mots_cles" not in parsed_data:
                                parsed_data["mots_cles"] = []
                                
                            return parsed_data
                            
                        except json.JSONDecodeError as e:
                            print(f"⚠️ Erreur format JSON pour la section '{section_name}': {str(e)}")
                            return {"themes": [], "resume": "", "mots_cles": []}
                            
                except Exception as e:
                    print(f"⚠️ Erreur parsing réponse pour la section '{section_name}': {str(e)}")
                    return {"themes": [], "resume": "", "mots_cles": []}
            else:
                print(f"⚠️ Erreur Mixtral ({response.status_code}) pour la section '{section_name}'")
                return {"themes": [], "resume": "", "mots_cles": []}
                
        except Exception as e:
            print(f"❌ Erreur analyse Mixtral pour la section '{section_name}': {str(e)}")
            return {"themes": [], "resume": "", "mots_cles": []}
    
    def analyze_document(self, sections: Dict[str, str]) -> Dict[str, Any]:
        """Analyse un document section par section"""
        document_analysis = {
            "sections_analysis": {},
            "global_themes": [],  # Liste au lieu de set
            "all_keywords": []    # Liste au lieu de set
        }
        
        for section_name, content in sections.items():
            print(f"  Analyse de la section : {section_name}")
            section_analysis = self.analyze_content_with_mixtral(content, section_name)
            
            document_analysis["sections_analysis"][section_name] = section_analysis
            
            # Collecter les thèmes et mots-clés
            for theme in section_analysis.get("themes", []):
                theme_nom = theme.get("nom", "")
                if theme_nom and theme_nom not in document_analysis["global_themes"]:
                    document_analysis["global_themes"].append(theme_nom)
                
                for concept in theme.get("concepts_cles", []):
                    if concept and concept not in document_analysis["all_keywords"]:
                        document_analysis["all_keywords"].append(concept)
        
        return document_analysis

    def compare_documents_themes(self, all_analyses: Dict[str, Dict]) -> Dict[str, Any]:
        """Compare les thématiques entre les documents"""
        comparison = {
            "themes_communs": {},
            "themes_uniques": {},
            "mots_cles_frequence": Counter(),
            "sections_similaires": {},
            "statistiques": {
                "nombre_documents": len(all_analyses),
                "themes_par_document": {},
                "sections_par_document": {}
            }
        }
        
        # Analyser chaque document
        for doc_name, analysis in all_analyses.items():
            themes = analysis["global_themes"]
            comparison["statistiques"]["themes_par_document"][doc_name] = len(themes)
            comparison["statistiques"]["sections_par_document"][doc_name] = len(analysis["sections_analysis"])
            
            # Compter la fréquence des thèmes
            for theme in themes:
                if theme not in comparison["themes_communs"]:
                    comparison["themes_communs"][theme] = 1
                else:
                    comparison["themes_communs"][theme] += 1
            
            # Collecter les mots-clés
            comparison["mots_cles_frequence"].update(analysis["all_keywords"])
        
        # Identifier les thèmes uniques et communs
        total_docs = len(all_analyses)
        for theme, count in comparison["themes_communs"].items():
            if count == 1:
                comparison["themes_uniques"][theme] = count
            comparison["themes_communs"][theme] = (count / total_docs) * 100
        
        return comparison

    def generate_comparative_report(self, comparison: Dict[str, Any]) -> str:
        """Génère un rapport comparatif détaillé"""
        report = []
        report.append("📊 ANALYSE COMPARATIVE DES DOCUMENTS")
        report.append(f"Nombre total de documents analysés : {comparison['statistiques']['nombre_documents']}\n")
        
        # Thèmes communs
        report.append("🔄 THÈMES COMMUNS")
        for theme, percentage in sorted(comparison["themes_communs"].items(), key=lambda x: x[1], reverse=True):
            if percentage > 100/comparison['statistiques']['nombre_documents']:
                report.append(f"• {theme}: {percentage:.1f}% des documents")
        
        # Thèmes uniques
        report.append("\n💫 THÈMES UNIQUES")
        for theme in comparison["themes_uniques"]:
            report.append(f"• {theme}")
        
        # Mots-clés les plus fréquents
        report.append("\n🔤 MOTS-CLÉS LES PLUS FRÉQUENTS")
        for mot, count in comparison["mots_cles_frequence"].most_common(10):
            report.append(f"• {mot}: {count} occurrences")
        
        # Statistiques par document
        report.append("\n📈 STATISTIQUES PAR DOCUMENT")
        for doc, nb_themes in comparison["statistiques"]["themes_par_document"].items():
            nb_sections = comparison["statistiques"]["sections_par_document"][doc]
            report.append(f"• {doc}:")
            report.append(f"  - Nombre de thèmes : {nb_themes}")
            report.append(f"  - Nombre de sections : {nb_sections}")
        
        return "\n".join(report)

    def analyze_topics(self, all_sections: Dict[str, Dict[str, str]]) -> str:
        """Analyse principale des documents"""
        try:
            print("🔍 Analyse document par document...")
            all_analyses = {}
            
            for doc_name, sections in all_sections.items():
                print(f"\n📄 Analyse de {doc_name}")
                doc_analysis = self.analyze_document(sections)
                all_analyses[doc_name] = doc_analysis
            
            print("\n🔄 Comparaison des documents...")
            comparison = self.compare_documents_themes(all_analyses)
            
            print("\n📊 Génération du rapport...")
            report = self.generate_comparative_report(comparison)
            
            # Sauvegarde des résultats détaillés
            self.save_detailed_results(all_analyses, comparison)
            
            return report
            
        except Exception as e:
            print(f"❌ Erreur analyse: {e}")
            return "Erreur lors de l'analyse"

    def calculate_statistics(self, analysis: Dict) -> Dict:
            """Calcule des statistiques détaillées sur l'analyse"""
            stats = {
                "nombre_total_documents": len(analysis.get("themes_principaux", [])),
                "themes": {
                    "count": len(analysis.get("themes_principaux", [])),
                    "distribution": {},
                    "mots_cles_frequents": Counter(),
                    "correlations": {}
                },
                "similarites": {
                    "count_patterns": len(analysis.get("similarites", {}).get("patterns_communs", [])),
                    "count_differences": len(analysis.get("similarites", {}).get("differences_notables", []))
                }
            }

            # Analyse des thèmes
            for theme in analysis.get("themes_principaux", []):
                nom = theme.get("nom", "")
                freq = float(theme.get("frequence", "0").strip("%"))/100
                stats["themes"]["distribution"][nom] = freq
                
                # Mots-clés fréquents
                for mot in theme.get("mots_cles", []):
                    stats["themes"]["mots_cles_frequents"][mot] += 1

            # Calcul des corrélations entre thèmes
            themes = list(stats["themes"]["distribution"].keys())
            for i, theme1 in enumerate(themes):
                for theme2 in themes[i+1:]:
                    correlation = self._calculate_theme_correlation(
                        analysis, theme1, theme2
                    )
                    stats["themes"]["correlations"][f"{theme1}-{theme2}"] = correlation

            return stats

    def analyze_document(self, sections: Dict[str, str]) -> Dict[str, Any]:
            """Analyse un document section par section"""
            document_analysis = {
                "sections_analysis": {},
                "global_themes": set(),
                "all_keywords": set()
            }
            
            for section_name, content in sections.items():
                print(f"  Analyse de la section : {section_name}")
                section_analysis = self.analyze_content_with_mixtral(content, section_name)
                
                document_analysis["sections_analysis"][section_name] = section_analysis
                
                # Collecter les thèmes et mots-clés
                for theme in section_analysis.get("themes", []):
                    document_analysis["global_themes"].add(theme["nom"])
                    document_analysis["all_keywords"].update(theme.get("concepts_cles", []))
            
            return document_analysis

    def compare_documents_themes(self, all_analyses: Dict[str, Dict]) -> Dict[str, Any]:
            """Compare les thématiques entre les documents"""
            comparison = {
                "themes_communs": {},
                "themes_uniques": {},
                "mots_cles_frequence": Counter(),
                "sections_similaires": {},
                "statistiques": {
                    "nombre_documents": len(all_analyses),
                    "themes_par_document": {},
                    "sections_par_document": {}
                }
            }
            
            # Analyser chaque document
            for doc_name, analysis in all_analyses.items():
                themes = analysis["global_themes"]
                comparison["statistiques"]["themes_par_document"][doc_name] = len(themes)
                comparison["statistiques"]["sections_par_document"][doc_name] = len(analysis["sections_analysis"])
                
                # Compter la fréquence des thèmes
                for theme in themes:
                    if theme not in comparison["themes_communs"]:
                        comparison["themes_communs"][theme] = 1
                    else:
                        comparison["themes_communs"][theme] += 1
                
                # Collecter les mots-clés
                comparison["mots_cles_frequence"].update(analysis["all_keywords"])
            
            # Identifier les thèmes uniques et communs
            total_docs = len(all_analyses)
            for theme, count in list(comparison["themes_communs"].items()):
                if count == 1:
                    comparison["themes_uniques"][theme] = count
                    del comparison["themes_communs"][theme]
                else:
                    comparison["themes_communs"][theme] = (count / total_docs) * 100
            
            return comparison

    def generate_comparative_report(self, comparison: Dict[str, Any]) -> str:
            """Génère un rapport comparatif détaillé"""
            report = []
            report.append("📊 ANALYSE COMPARATIVE DES DOCUMENTS")
            report.append(f"Nombre total de documents analysés : {comparison['statistiques']['nombre_documents']}\n")
            
            # Thèmes communs
            report.append("🔄 THÈMES COMMUNS")
            for theme, percentage in sorted(comparison["themes_communs"].items(), key=lambda x: x[1], reverse=True):
                report.append(f"• {theme}: {percentage:.1f}% des documents")
            
            # Thèmes uniques
            report.append("\n💫 THÈMES UNIQUES")
            for theme in comparison["themes_uniques"]:
                report.append(f"• {theme}")
            
            # Mots-clés les plus fréquents
            report.append("\n🔤 MOTS-CLÉS LES PLUS FRÉQUENTS")
            for mot, count in comparison["mots_cles_frequence"].most_common(10):
                report.append(f"• {mot}: {count} occurrences")
            
            # Statistiques par document
            report.append("\n📈 STATISTIQUES PAR DOCUMENT")
            for doc, nb_themes in comparison["statistiques"]["themes_par_document"].items():
                nb_sections = comparison["statistiques"]["sections_par_document"][doc]
                report.append(f"• {doc}:")
                report.append(f"  - Nombre de thèmes : {nb_themes}")
                report.append(f"  - Nombre de sections : {nb_sections}")
            
            return "\n".join(report)

    def analyze_topics(self, all_sections: Dict[str, Dict[str, str]]) -> str:
            """Analyse principale des documents"""
            try:
                print("🔍 Analyse document par document...")
                all_analyses = {}
                
                for doc_name, sections in all_sections.items():
                    print(f"\n📄 Analyse de {doc_name}")
                    doc_analysis = self.analyze_document(sections)
                    all_analyses[doc_name] = doc_analysis
                
                print("\n🔄 Comparaison des documents...")
                comparison = self.compare_documents_themes(all_analyses)
                
                print("\n📊 Génération du rapport...")
                report = self.generate_comparative_report(comparison)
                
                # Sauvegarde des résultats détaillés
                self.save_detailed_results(all_analyses, comparison)
                
                return report
                
            except Exception as e:
                print(f"❌ Erreur analyse: {e}")
                return "Erreur lors de l'analyse"

    def save_detailed_results(self, analyses: Dict, comparison: Dict):
        """Sauvegarde les résultats détaillés"""
        try:
            # Conversion des Counters en dictionnaires
            if "mots_cles_frequence" in comparison:
                comparison["mots_cles_frequence"] = dict(comparison["mots_cles_frequence"])
            
            # Préparation des résultats
            results = {
                "analyses_par_document": {
                    doc_name: {
                        "sections_analysis": doc_analysis["sections_analysis"],
                        "global_themes": doc_analysis["global_themes"],
                        "all_keywords": doc_analysis["all_keywords"]
                    }
                    for doc_name, doc_analysis in analyses.items()
                },
                "comparaison": comparison
            }
            
            with open("analyse_thematique_detaillee.json", "w", encoding="utf-8") as f:
                json.dump(results, f, ensure_ascii=False, indent=2)
                
        except Exception as e:
            print(f"❌ Erreur sauvegarde résultats: {e}")
def main():
    analyzer = AAPAnalyzer("../data")
    
    print("🔍 Analyse des AAP en cours...")
    aap_files = [p for p in Path("../data").rglob("*") 
                 if p.is_file() and "AAP" in p.name.upper()]
    
    if not aap_files:
        print("❌ Aucun fichier AAP trouvé!")
        return
        
    print(f"📁 {len(aap_files)} fichiers AAP trouvés")
    
    all_sections = {}
    for file_path in aap_files:
        print(f"\n📄 Analyse de {file_path.name}")
        sections = analyzer.extract_text_by_sections(str(file_path))
        if sections:
            all_sections[file_path.name] = sections
    
    if not all_sections:
        print("❌ Aucune section extraite des fichiers!")
        return
    
    print("\n🤖 Analyse thématique en cours...")
    analysis = analyzer.analyze_topics(all_sections)
    
    print("\n=== Rapport d'Analyse ===")
    print(analysis)

# %%
if __name__ == "__main__":
    main()
# Out:
# 🔍 Analyse des AAP en cours...
# 📁 33 fichiers AAP trouvés
#
# 📄 Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
#
# 📄 Analyse de ESF_P01_AAP01.docx
#
# 📄 Analyse de ESF_P01_AAP02.docx
#
# 📄 Analyse de ESF_P01_AAP03.docx
#
# 📄 Analyse de ESF_P01_AAP04.docx
#
# 📄 Analyse de PU_P01_AAP01.docx
#
# 📄 Analyse de PU_P01_AAP02.docx
#
# 📄 Analyse de PU_P01_AAP03.docx
#
# 📄 Analyse de Pulse_P01_AAP01.docx
#
# 📄 Analyse de Pulse_P02_AAP01.rtf
# ⚠️ Format non supporté: ..\data\Pulse\Projet02\Pulse_P02_AAP01.rtf
#
# 📄 Analyse de Pulse_P02_AAP01E
# ⚠️ Format non supporté: ..\data\Pulse\Projet02\Pulse_P02_AAP01E
#
# 📄 Analyse de PS_P03_AAP01.docx
#
# 📄 Analyse de dossier_de_candidature_aap_projets_innov_entre_2024.docx
#
# 📄 Analyse de Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
#
# 📄 Analyse de Note cadrage AAP.docx
#
# 📄 Analyse de Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
#
# 📄 Analyse de Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
#
# 📄 Analyse de Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
#
# 📄 Analyse de réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx
#
# 📄 Analyse de SS_P01_AAP01.docx
#
# 📄 Analyse de SS_P01_AAP01T.docx
#
# 📄 Analyse de SS_P02_AAP01E.pdf
#
# 📄 Analyse de SS_P03_AAP01E.pdf
#
# 📄 Analyse de SS_P04_AAP01E.pdf
#
# 📄 Analyse de SS_P05_AAP01.docx
#
# 📄 Analyse de SS_P11_AAP01.docx
#
# 📄 Analyse de Wings of the Ocean_Procédure réponse AAP.docx
#
# 📄 Analyse de WOTO_P01_AAP01.pdf
#
# 📄 Analyse de WOTO_P01_AAP02.docx
#
# 📄 Analyse de WOTO_P01_AAP03.pdf
#
# 📄 Analyse de WOTO_P02_AAP01E.pdf
#
# 📄 Analyse de WOTO_P02_AAP02E.docx
#
# 📄 Analyse de WOTO_P03_AAP01E.pdf
#
# 🤖 Analyse thématique en cours...
# 🔍 Analyse document par document...
#
# 📄 Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
#   Analyse de la section : Introduction
#   Analyse de la section : MARCHE PUBLIC
#   Analyse de la section : APPEL D’OFFRE
#   Analyse de la section : TERRITORIALES
#   Analyse de la section : INTERCOMMUNALITES
#   Analyse de la section : TÂCHES
#   Analyse de la section : SEMAINE 7/8
#   Analyse de la section : • SIREN  ;
#   Analyse de la section : FOCUS GENRE
#   Analyse de la section : CONSEIL
#   Analyse de la section : (INSEE, 2018).
#   Analyse de la section : OBJECTIF DE LA REPONSE
#   Analyse de la section : PERSONNES RESSOURCES
#   Analyse de la section : (ODD5…)
#   Analyse de la section : CSESS, 2011)  ;
#   Analyse de la section : TYPES D’OUTIL
#   Analyse de la section : X
#
# 📄 Analyse de ESF_P01_AAP02.docx
#   Analyse de la section : Le projet en synthèse 2 / 3
#
# 📄 Analyse de ESF_P01_AAP03.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de ESF_P01_AAP04.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de PU_P01_AAP01.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de PU_P01_AAP02.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de PU_P01_AAP03.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Pulse_P01_AAP01.docx
#   Analyse de la section : Introduction
#   Analyse de la section : L’organisme porteur de projet (soumissionnaire principal)
# ⚠️ Erreur format JSON pour la section 'L’organisme porteur de projet (soumissionnaire principal)': Expecting ':' delimiter: line 8 column 84 (char 423)
#   Analyse de la section : 1 INSTRUCTIONS POUR LA RÉDACTION DE LA NOTE SUCCINCTE DE PRÉSENTATION
#   Analyse de la section : 1.1 Résumé de l’action
#   Analyse de la section : 1.2 Description de l’action (maximum 2 pages)
#   Analyse de la section : 1.3.1 Pertinence par rapport aux objectifs/secteurs/thèmes/priorités spécifiques de l’appel à projets
#   Analyse de la section : 1.3.2 Pertinence par rapport aux besoins et contraintes spécifiques du/des pays, région(s) cible(s) et/ou des secteurs concernés (y compris les synergies avec d’autres initiatives en matière de développement et l’absence de double emploi)
# ⚠️ Erreur format JSON pour la section '1.3.2 Pertinence par rapport aux besoins et contraintes spécifiques du/des pays, région(s) cible(s) et/ou des secteurs concernés (y compris les synergies avec d’autres initiatives en matière de développement et l’absence de double emploi)': Expecting ',' delimiter: line 7 column 10 (char 233)
#   Analyse de la section : 1.3.3 Décrivez et définissez les groupes cibles et les bénéficiaires finaux, leurs besoins et leurs contraintes, et expliquez comment l’action répondra à ces besoins
#   Analyse de la section : 1.3.4 Éléments spécifiques apportant une valeur ajoutée
#   Analyse de la section : 1.3 ; Lieu(x)
#   Analyse de la section : 1.6. Objectif général et objectifs spécifiques (maximum 1 page)
#   Analyse de la section : 1.7. Pertinence de l'action (maximum 3 pages)
#   Analyse de la section : 1.8. Description de l'action et de son efficacité (maximum 14 pages)
#   Analyse de la section : 1.9. Méthodologie (maximum 4 pages)
#   Analyse de la section : 1.10. Durée et plan d'action pour la mise en œuvre de l'action
#   Analyse de la section : 1.11. Bénéficiaires (maximum 1,5 page)
# ⚠️ Erreur format JSON pour la section '1.11. Bénéficiaires (maximum 1,5 page)': Expecting property name enclosed in double quotes: line 7 column 7 (char 395)
#   Analyse de la section : 1.12. Résultats, activités et suivi-évaluation
#   Analyse de la section : 1.13. Plan d’action indicatif pour la mise en œuvre de l’action (maximum 4 pages)
#   Analyse de la section : 1.14. Durabilité (maximum 3 pages)
#   Analyse de la section : 1.15. Budget De L'action
#   Analyse de la section : 1.16. Cadre Logique
#   Analyse de la section : Données financières. Veuillez fournir les informations suivantes, le cas échéant, en vous basant sur les comptes de gestion et le bilan de votre organisation, montants en milliers de EUR (ou autre).
#   Analyse de la section : DESCRIPTION DU/DES PARTENAIRE(S)
#   Analyse de la section : DÉCLARATION DE PARTENARIAT
#   Analyse de la section : DÉCLARATION DU DEMANDEUR
#
# 📄 Analyse de PS_P03_AAP01.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de dossier_de_candidature_aap_projets_innov_entre_2024.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
#   Analyse de la section : Introduction
#   Analyse de la section : FICHE CANDIDAT URE
#   Analyse de la section : 1. STRUCTURE PRESENTANT LE PROJET  :
#   Analyse de la section : 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
#   Analyse de la section : 4. PERSONNE EN CHARGE DU DOSSIER  :
#   Analyse de la section : 5. PRESENTATION DU PROJET  :
#   Analyse de la section : C. SUBVENTION DEMANDEE
# ⚠️ Erreur format JSON pour la section 'C. SUBVENTION DEMANDEE': Expecting ':' delimiter: line 8 column 21 (char 321)
#   Analyse de la section : EVALUATION DES ACTIONS
#
# 📄 Analyse de Note cadrage AAP.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
#   Analyse de la section : Unnamed: 0
#   Analyse de la section : Unnamed: 1
#   Analyse de la section : Unnamed: 2
# ⚠️ Erreur format JSON pour la section 'Unnamed: 2': Expecting ':' delimiter: line 8 column 8 (char 367)
#   Analyse de la section : Unnamed: 3
#   Analyse de la section : Unnamed: 4
#   Analyse de la section : Unnamed: 5
#   Analyse de la section : Unnamed: 6
#   Analyse de la section : Unnamed: 7
#   Analyse de la section : Unnamed: 8
#
# 📄 Analyse de Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : PULSE
#   Analyse de la section : 1. PRÉSENTATION DE L’ACTION
#   Analyse de la section : PULSE.
#   Analyse de la section : 2. DESCRIPTION DE LA PHASE DE RECRUTEMENT ET DE MOBILISATION DES PUBLICS
#   Analyse de la section : 3. CONTENU ET ORGANISATION DE L’ACTION
#   Analyse de la section : UX
#   Analyse de la section : 4. FIN DE L’ACTION
#   Analyse de la section : 5. MOYENS DE MISE EN ŒUVRE DE L’ACTION
#   Analyse de la section : 6 ASPECTS FINANCIERS
#   Analyse de la section : 7. LETTRE DE DEMANDE DE SUBVENTION
#   Analyse de la section : L’INFORMEL »
#
# 📄 Analyse de Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
#   Analyse de la section : Introduction
#   Analyse de la section : FICHE CANDIDAT URE
#   Analyse de la section : 1. STRUCTURE PRESENTANT LE PROJET  :
#   Analyse de la section : 2. INTITULE DU PROJET  :
#   Analyse de la section : 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
#   Analyse de la section : 4. PERSONNE EN CHARGE DU DOSSIER  :
#   Analyse de la section : 5. PRESENTATION DU PROJET  :
#   Analyse de la section : 3/ SUIVI ET VALORISATION
#   Analyse de la section : C. SUBVENTION DEMANDEE
#   Analyse de la section : EVALUATION DES ACTIONS
#
# 📄 Analyse de réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx
#   Analyse de la section : Unnamed: 0
#   Analyse de la section : Unnamed: 1
#   Analyse de la section : Unnamed: 2
#   Analyse de la section : Unnamed: 3
#   Analyse de la section : Unnamed: 4
#   Analyse de la section : Unnamed: 5
#   Analyse de la section : Unnamed: 6
#   Analyse de la section : Unnamed: 7
#   Analyse de la section : Unnamed: 8
#
# 📄 Analyse de SS_P01_AAP01.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de SS_P01_AAP01T.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de SS_P03_AAP01E.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : 1. DEMANDEUR
#   Analyse de la section : 2. ACTIVITES GENERALES DE L’ORGANISATION
#   Analyse de la section : 3. DESCRIPTION  DU PROJET
#   Analyse de la section : 4. DESCRIPTION DU PROJET
#   Analyse de la section : 5. MOYENS ET METHODOLOGIE DU PROJET
#
# 📄 Analyse de SS_P04_AAP01E.pdf
#   Analyse de la section : N°
#   Analyse de la section : MAURITANIE
#   Analyse de la section : MARSEILLE CEDEX
#   Analyse de la section : SANTE SUD
#   Analyse de la section : SIRET :
#   Analyse de la section : Z
#   Analyse de la section : BOULEVARD NATIONAL
#   Analyse de la section : MARSEILLE
#   Analyse de la section : TOTAL
#   Analyse de la section : PREVISIONNELLES
#   Analyse de la section : PREVISIONNELS
#   Analyse de la section : AFD
#   Analyse de la section : ARS
#   Analyse de la section : PACA SUD
#   Analyse de la section : CD13
#   Analyse de la section : L
#   Analyse de la section : A
#   Analyse de la section : TTC
#   Analyse de la section : SOUS-TOTAL 1
#   Analyse de la section : SOUS-TOTAL 2
#   Analyse de la section : J
#
# 📄 Analyse de SS_P05_AAP01.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de SS_P11_AAP01.docx
#   Analyse de la section : Introduction
#   Analyse de la section : Formulaire de demande complète
#   Analyse de la section : Description (max. 13 pages)
#   Analyse de la section : Méthodologie (max. 5 pages)
#   Analyse de la section : Plan d’action indicatif pour la mise en œuvre de l’action (max. 4 pages)
#   Analyse de la section : Viabilité de l’action (max. 3 pages)
#   Analyse de la section : Cadre logique
#   Analyse de la section : Budget, montant demandé à l’administration contractante et autres sources de financement attendues
#   Analyse de la section : Expérience
#   Analyse de la section : Demandeur chef de file, codemandeur(s) et entités affiliées
#   Analyse de la section : Déclaration du demandeur chef de file (demande complète)
#   Analyse de la section : Mandat [pour le(s) codemandeur(s)]
#   Analyse de la section : Déclaration relative aux entités affiliées
#   Analyse de la section : Consignes de rédaction du formulaire de demande complète
#   Analyse de la section : Informations générales
#   Analyse de la section : L’action
#   Analyse de la section : Le demandeur chef de file, les codemandeurs et les entités affiliées
#   Analyse de la section : Associés participant à l’action
#   Analyse de la section : Liste de contrôle personnelle
#
# 📄 Analyse de Wings of the Ocean_Procédure réponse AAP.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de WOTO_P01_AAP01.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : — MEMBRE —
#   Analyse de la section : INFORMATIONS SUR LE PORTEUR DE PROJET
#   Analyse de la section : PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT
#
# 📄 Analyse de WOTO_P01_AAP02.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de WOTO_P01_AAP03.pdf
#   Analyse de la section : POUR LA PLANÈTE
#   Analyse de la section : APPEL A PROJET POUR LA PLANÈTE
#   Analyse de la section : JUSQU'AU 07 AVRIL
#   Analyse de la section : OMENT D’ÉCHANGES
#   Analyse de la section : RENCONTRES POUR LA PLANÈTE
#   Analyse de la section : SOUTIENS PLURI-ANNUELS
#   Analyse de la section : MARDIS POUR LA
#   Analyse de la section : SONT ÉLIGIBLES :
#   Analyse de la section : NE SONT PAS ÉLIGIBLES :
#   Analyse de la section : CRITÈRES D’ÉLIGIBILITÉ DES PROJETS
#   Analyse de la section : SOCIALE
#   Analyse de la section : DEMANDE DE FINANCEMENTCOMBIEN PEUT-ON DEMANDER DE FINANCER ?
#   Analyse de la section : D'OÙ VIENNENT LES FINANCEMENTS ?
#   Analyse de la section : ET DES ANNEXES EST LE 07 AVRIL 2024 À MINUIT.
#   Analyse de la section : DES DOSSIERSVÉRIFICATION DE L’ÉLIGIBILITÉ
#   Analyse de la section : DÉCISION DE SÉLECTION
#   Analyse de la section : SUIVI DE L’UTILISATION
#   Analyse de la section : À PROJET
#   Analyse de la section : DÉCISION
# ⚠️ Erreur format JSON pour la section 'DÉCISION': Expecting ':' delimiter: line 8 column 21 (char 247)
#   Analyse de la section : AUX RENCONTRES POUR LA PLANÈTE
#   Analyse de la section : VIDÉO DE PRÉSENTATION
#   Analyse de la section : CAMPAGNE DE CROWDFUNDING
#   Analyse de la section : FORMATION PITCH
#   Analyse de la section : CONVENTION
#   Analyse de la section : RAPPORT D’UTILISATION DES DONS
#   Analyse de la section : DÉBUT ACCOMPAGNEMENT
#   Analyse de la section : RIB
#   Analyse de la section : ANNEXES THÉMATIQUESDESCRIPTION DES THÉMATIQUES
#   Analyse de la section : ET JUSTICE SOCIALE
#
# 📄 Analyse de WOTO_P02_AAP01E.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : FONDATION D’ENTREPRSE
#   Analyse de la section : 6 BUDGET PREVISIONNEL DU PROJET  11
#
# 📄 Analyse de WOTO_P02_AAP02E.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de WOTO_P03_AAP01E.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : MODALITÉS
#   Analyse de la section : PRÉSENTATION DE VOTRE ORGANISME
#   Analyse de la section : PRESENT ATION ET OBJECTIFS
#   Analyse de la section : VOS BESOINS
#   Analyse de la section : VOS IMPACTS
#   Analyse de la section : VOTRE PROJET & NOUS
#
# 🔄 Comparaison des documents...
#
# 📊 Génération du rapport...
# ❌ Erreur sauvegarde résultats: Object of type set is not JSON serializable
#
# === Rapport d'Analyse ===
# 📊 ANALYSE COMPARATIVE DES DOCUMENTS
# Nombre total de documents analysés : 29
#
# 🔄 THÈMES COMMUNS
# • Appel à projets: 10.3% des documents
# • Informations sur le projet: 6.9% des documents
# • Evaluation des actions: 6.9% des documents
# • Coordonnées: 6.9% des documents
# • Sensibilisation/détection/pré-orientation: 6.9% des documents
# • Réalisation année 1: 6.9% des documents
# • Objectif prévisionnel année 2: 6.9% des documents
# • Appel à projets Jeunes PouSSEs 2024-2026: 6.9% des documents
# • Actions de sensibilisation, de détection et d'orientation: 6.9% des documents
# • Objectif prévisionnel année 3: 6.9% des documents
# • Réalisation année 3: 6.9% des documents
# • Réalisation année 2: 6.9% des documents
# • Demande de subvention: 6.9% des documents
# • Introduction: 6.9% des documents
# • Informations sur le porteur de projet: 6.9% des documents
# • Budget et financement: 6.9% des documents
# • Demande de financement: 6.9% des documents
#
# 💫 THÈMES UNIQUES
# • Identification des éléments valorisables pour l'égalité de genre
# • Boite à outils Egalité de genre
# • Intercommunalités
# • Partenariats et collaborations
# • Planification et organisation du projet
# • Ressources internes et externes
# • Territoires
# • Préparation de l'appel à projet
# • Validation et lettres de soutien
# • Égalité des genres et entrepreneuriat féminin
# • Évaluation de projet
# • Définition et présentation des objectifs spécifiques dans un projet
# • Marchés publics et appels d'offres
# • Réponse aux appels à projets
# • Appels d'offres privés
# • Construction de projets et partenariats
# • Marchés publics et procédure d'appel d'offres
# • Rédaction et construction du budget
# • Types d'outils
# • Registre d’activités
# • Zones d'intervention
# • Détails sur les bénéficiaires
# • Projet d'aide au développement
# • Informations générales sur le projet
# • Déclaration du demandeur
# • Calendrier indicatif
# • Définition et description des groupes cibles et bénéficiaires finaux
# • Activités proposées
# • Structure organisationnelle
# • Déclaration du demandeur principal et engagement des partenaires
# • Partenariat avec Expertise France
# • Moyens de mise en oeuvre
# • Lieux du programme de co-incubation
# • Instructions pour la rédaction de la note succincte de présentation
# • Historique et principaux secteurs d'intervention de l'organisme
# • Stratégie genre et égalité femmes-hommes
# • Pérennité politique
# • Résumé de l'action
# • Planification de la mise en œuvre d'une action
# • Parties prenantes
# • Durée et plan d'action
# • Pilotage et coordination
# • Contexte de l'action
# • Intégration dans un programme plus vaste
# • Formulaire de demande de subvention
# • Présentation du porteur de projet et des partenaires
# • Durabilité
# • Equipe de gestion administrative et financière
# • Méthodologie proposée
# • Intégration de questions transversales
# • Participation des acteurs et parties prenantes
# • Pérennité opérationnelle
# • Suivi et évaluation
# • Cadre Logique
# • Budget De L'action
# • Logique d'intervention
# • Pérennité financière
# • Description de l'action proposée
# • Résultats et activités
# • Action dans la continuité d'une action existante
# • Pertinence par rapport aux objectifs et priorités de l'appel à projets
# • Objectifs de l'action
# • Visibilité et communication
# • Gestion du projet et suivi financier
# • Appel à projets - Accompagnement innovant à l'entrepreneuriat et sortie de l'informel
# • Structure de l'introduction
# • Identité
# • Données financières
# • Informations sur la structure
# • Agrément ESUS (Entreprise Solidaire d'Utilité Sociale)
# • Présentation du projet
# • Appel à projets Jeunes Pou SSes 2024-2026
# • Connaissance de l'appel à projets
# • Fiche d’identité, Description de l’opportunité, Déroulement de l’AAP
# • Objectif prévisionnel année 1
# • Phase de recrutement et mobilisation des publics
# • Évaluation et bilan du programme
# • L'écart entre les genres dans l'entrepreneuriat
# • Coût global de l'action pour l'année 2024
# • UX Design
# • PULSE et son accompagnement en Île-de-France
# • Dossier de candidature pour un financement
# • Sensibilisation et sélection des porteurs de projets d'économie circulaire
# • Appel à projets Jeunes Pou SSes 2024 -2026
# • Subvention demandée
# • La Saison Circulaire
# • Informations sur la structure PULSE
# • Indicateurs et publics
# • Appel à manifestation d'intérêt
# • Objectif de la note conceptuelle
# • Contenu de la note conceptuelle
# • Demande de financement simplifiée
# • Santé communautaire à Mayotte
# • Santé environnementale et veille sanitaire
# • Santé
# • Coordonnées et représentation d'un organisme
# • Dates importantes
# • Coordonnées et identification d'un organisme
# • Adresse
# • Aucun thème spécifique
# • Budget alloué
# • Dépenses prévisionnelles
# • Finances
# • Identification et classification d'entreprise
# • Déclaration et engagement
# • Dépôt de document
# • Appels à projets et événements
# • Contributions volontaires en nature
# • Prestations en nature
# • Budget prévisionnel et répartition des coûts
# • Dépenses publiques
# • Formation et suivi du personnel de santé
# • Charges indirectes affectées à l'action
# • Pays
# • Sous-total
# • Matériels et outils pédagogiques
# • Bénévolat
# • Événement et communication
# • Evènement Santé Sud
# • Localisation géographique
# • Dons en nature
# • Charges prévisionnelles
# • Forme juridique
# • Préparation et finalisation du Prodoc
# • appel à propositions restreint
# • Expérience dans des actions similaires
# • Informations sur l'appel à propositions
# • Enregistrement préalable dans PADOR
# • Méthode de remplissage de la demande complète
# • Associés participant à l'action
# • Déclaration relative aux entités affiliées
# • Viabilité économique
# • Informations générales
# • Thématique 1
# • Analyse de documents
# • Planification et gestion du projet
# • Déclaration du demandeur chef de file
# • Viabilité sociale
# • Cadre logique
# • Liste de contrôle de la demande complète
# • Soumission de la proposition
# • Méthodologie de recherche
# • Viabilité environnementale
# • Expérience dans d'autres actions
# • Processus de candidature pour un financement
# • thématique environnementale
# • Dossier de financement
# • Informations associatives
# • Fondation Crédit Mutuel Alliance Fédérale
# • Justice Sociale
# • Formation
# • Appel à projets pour la Planète - 2024
# • Événement temporel
# • Transition pour la jeunesse
# • Candidature à l'appel à projets pour la Planète
# • Préservation des ressources en eau
# • Pédagogie active au contact de la nature
# • Vérification de l'éligibilité
# • Préparation au pitch
# • Annexes à fournir
# • Transition énergétique et low tech
# • Projets avec appui structurel/développement organisationnel
# • Soutiens pluri-annuels et Calendrier de l'Avent - 1% for the Planet
# • Éligibilité aux programmes de dons
# • Appel à projet pour la planète
# • Sources de financement
# • Rapport d’utilisation des dons
# • Agroécologie et justice climatique internationale
# • Suivi de l'utilisation d'un soutien financier
# • Agriculture durable et locale
# • Comptabilité et finance
# • Événement environnemental
# • Protection de la biodiversité
# • Rapport d'activités et documents financiers
# • Rencontres pour la Planète
# • Événements de réseautage
# • Vidéo de présentation du projet
# • Sociale
# • Accompagnement
# • Fondation d'entreprise
# • Informations sur l'organisme
# • Budget prévisionnel total et détails par an
# • Financement du projet
# • Impacts du projet
# • Dossier de candidature
# • Comportements responsables et durables en mer
# • Candidature à un financement
# • Ressources humaines
#
# 🔤 MOTS-CLÉS LES PLUS FRÉQUENTS
# • projet: 6 occurrences
# • financement: 6 occurrences
# • subvention: 5 occurrences
# • appel à projets: 5 occurrences
# • Financement: 4 occurrences
# • sensibilisation: 4 occurrences
# • éligibilité: 3 occurrences
# • Réalisation: 3 occurrences
# • expérience: 3 occurrences
# • budget: 3 occurrences
#
# 📈 STATISTIQUES PAR DOCUMENT
# • Guide Pratique Réponse AAP (Groupe SOS).pdf:
#   - Nombre de thèmes : 20
#   - Nombre de sections : 17
# • ESF_P01_AAP02.docx:
#   - Nombre de thèmes : 3
#   - Nombre de sections : 1
# • ESF_P01_AAP03.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • ESF_P01_AAP04.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • PU_P01_AAP01.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • PU_P01_AAP02.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • PU_P01_AAP03.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • Pulse_P01_AAP01.docx:
#   - Nombre de thèmes : 41
#   - Nombre de sections : 25
# • PS_P03_AAP01.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • dossier_de_candidature_aap_projets_innov_entre_2024.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf:
#   - Nombre de thèmes : 11
#   - Nombre de sections : 8
# • Note cadrage AAP.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx:
#   - Nombre de thèmes : 8
#   - Nombre de sections : 9
# • Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf:
#   - Nombre de thèmes : 9
#   - Nombre de sections : 12
# • Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf:
#   - Nombre de thèmes : 8
#   - Nombre de sections : 10
# • réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx:
#   - Nombre de thèmes : 8
#   - Nombre de sections : 9
# • SS_P01_AAP01.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • SS_P01_AAP01T.docx:
#   - Nombre de thèmes : 4
#   - Nombre de sections : 1
# • SS_P03_AAP01E.pdf:
#   - Nombre de thèmes : 4
#   - Nombre de sections : 6
# • SS_P04_AAP01E.pdf:
#   - Nombre de thèmes : 29
#   - Nombre de sections : 21
# • SS_P05_AAP01.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • SS_P11_AAP01.docx:
#   - Nombre de thèmes : 22
#   - Nombre de sections : 19
# • Wings of the Ocean_Procédure réponse AAP.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • WOTO_P01_AAP01.pdf:
#   - Nombre de thèmes : 5
#   - Nombre de sections : 4
# • WOTO_P01_AAP02.docx:
#   - Nombre de thèmes : 1
#   - Nombre de sections : 1
# • WOTO_P01_AAP03.pdf:
#   - Nombre de thèmes : 31
#   - Nombre de sections : 29
# • WOTO_P02_AAP01E.pdf:
#   - Nombre de thèmes : 2
#   - Nombre de sections : 3
# • WOTO_P02_AAP02E.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • WOTO_P03_AAP01E.pdf:
#   - Nombre de thèmes : 8
#   - Nombre de sections : 7

# %% [markdown]
# ### test further: more generalist approach

# %%
import requests
import json
from pathlib import Path
import os
from typing import Dict, List, Any
from docx import Document
import PyPDF2
import pandas as pd
from collections import Counter
import openpyxl
class AAPAnalyzer:
    def __init__(self, data_dir: str):
        self.data_dir = data_dir
        
    def extract_text_by_sections(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte par sections d'un fichier"""
        try:
            if file_path.lower().endswith('.docx'):
                return self._extract_from_docx(file_path)
            elif file_path.lower().endswith('.pdf'):
                return self._extract_from_pdf(file_path)
            elif file_path.lower().endswith(('.xlsx', '.xls')):
                return self._extract_from_excel(file_path)
            else:
                print(f"⚠️ Format non supporté: {file_path}")
                return {}
        except Exception as e:
            print(f"❌ Erreur extraction {file_path}: {e}")
            return {}

    def _extract_from_docx(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier Word"""
        sections = {}
        current_section = "Introduction"
        current_content = []
        
        try:
            doc = Document(file_path)
            for para in doc.paragraphs:
                text = para.text.strip()
                if not text:
                    continue
                
                # Détection d'une nouvelle section
                if text.startswith('###') or (para.style and "Heading" in para.style.name):
                    if current_content:
                        sections[current_section] = "\n".join(current_content)
                    current_section = text.strip('#').strip()
                    current_content = []
                else:
                    current_content.append(text)
            
            # Ajouter la dernière section
            if current_content:
                sections[current_section] = "\n".join(current_content)
                
            return sections
            
        except Exception as e:
            print(f"❌ Erreur Word {file_path}: {e}")
            return {}

    def _extract_from_pdf(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier PDF"""
        sections = {}
        current_section = "Introduction"
        current_content = []
        
        try:
            with open(file_path, 'rb') as file:
                reader = PyPDF2.PdfReader(file)
                for page in reader.pages:
                    content = page.extract_text()
                    lines = content.split('\n')
                    
                    for line in lines:
                        line = line.strip()
                        if not line:
                            continue
                        
                        # Détection d'une nouvelle section
                        if line.startswith('###') or line.isupper():
                            if current_content:
                                sections[current_section] = "\n".join(current_content)
                            current_section = line.strip('#').strip()
                            current_content = []
                        else:
                            current_content.append(line)
            
            # Ajouter la dernière section
            if current_content:
                sections[current_section] = "\n".join(current_content)
                
            return sections
            
        except Exception as e:
            print(f"❌ Erreur PDF {file_path}: {e}")
            return {}

    def _extract_from_excel(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier Excel"""
        sections = {}
        
        try:
            df = pd.read_excel(file_path)
            for col in df.columns:
                if isinstance(col, str) and col.strip():
                    content = df[col].dropna().astype(str).tolist()
                    if content:
                        sections[col] = "\n".join(content)
            return sections
            
        except Exception as e:
            print(f"❌ Erreur Excel {file_path}: {e}")
            return {}

    def analyze_topics(self, all_sections: Dict[str, Dict[str, str]]) -> str:
        """Analyse principale des documents"""
        try:
            print("🔍 Analyse document par document...")
            all_analyses = {}
            
            for doc_name, sections in all_sections.items():
                print(f"\n📄 Analyse de {doc_name}")
                doc_analysis = self.analyze_document(sections)
                all_analyses[doc_name] = doc_analysis
            
            print("\n🔄 Comparaison des documents...")
            comparison = self.compare_documents_themes(all_analyses)
            
            print("\n📊 Génération du rapport...")
            report = self.generate_comparative_report(comparison)
            
            # Sauvegarde des résultats détaillés
            self.save_detailed_results(all_analyses, comparison)
            
            return report
            
        except Exception as e:
            print(f"❌ Erreur analyse: {e}")
            return "Erreur lors de l'analyse"
    
    def analyze_content_with_mixtral(self, text: str, section_name: str) -> dict:
        """Analyse sémantique d'une section spécifique"""
        try:
            prompt = f"""Tu es un expert en analyse thématique de documents. Analyse cette section et extrait les thèmes principaux.
    Pour chaque thème identifié, donne un score de confiance entre 0 et 1.

    SECTION : {section_name}
    CONTENU : {text}

    Renvoie UNIQUEMENT un JSON valide avec ce format exact :
    {{
        "themes": [
            {{
                "nom": "nom du thème",
                "score": 0.95,
                "sous_themes": ["liste des sous-thèmes"],
                "mots_cles": ["mots-clés importants"],
                "description": "courte description du thème"
            }}
        ],
        "resume": "résumé de la section"
    }}"""

            response = requests.post(
                "http://localhost:11434/api/generate",
                json={
                    "model": "mixtral:latest",
                    "prompt": prompt,
                    "temperature": 0.7,
                    "stream": False
                },
                timeout=180
            )
            
            if response.status_code == 200:
                try:
                    response_data = response.json()
                    if isinstance(response_data, dict) and "response" in response_data:
                        json_str = response_data["response"].strip()
                        if json_str.startswith("```json"):
                            json_str = json_str[7:]
                        if json_str.endswith("```"):
                            json_str = json_str[:-3]
                        
                        return json.loads(json_str)
                except:
                    print(f"⚠️ Erreur parsing JSON pour {section_name}")
                    return {"themes": [], "resume": ""}
            return {"themes": [], "resume": ""}
                
        except Exception as e:
            print(f"❌ Erreur Mixtral: {e}")
            return {"themes": [], "resume": ""}

    def analyze_document_themes(self, sections: Dict[str, str]) -> Dict[str, Any]:
        """Analyse les thèmes d'un document"""
        themes_by_section = {}
        global_themes = {}
        
        for section_name, content in sections.items():
            print(f"  Analyse de la section : {section_name}")
            analysis = self.analyze_content_with_mixtral(content, section_name)
            
            themes_by_section[section_name] = analysis
            
            # Agréger les thèmes globaux
            for theme in analysis.get("themes", []):
                theme_name = theme["nom"]
                if theme_name not in global_themes:
                    global_themes[theme_name] = {
                        "score_moyen": theme["score"],
                        "occurrences": 1,
                        "sections": [section_name],
                        "sous_themes": set(theme.get("sous_themes", [])),
                        "mots_cles": set(theme.get("mots_cles", [])),
                        "descriptions": [theme.get("description", "")]
                    }
                else:
                    global_themes[theme_name]["score_moyen"] += theme["score"]
                    global_themes[theme_name]["occurrences"] += 1
                    global_themes[theme_name]["sections"].append(section_name)
                    global_themes[theme_name]["sous_themes"].update(theme.get("sous_themes", []))
                    global_themes[theme_name]["mots_cles"].update(theme.get("mots_cles", []))
                    global_themes[theme_name]["descriptions"].append(theme.get("description", ""))
        
        # Calculer les scores moyens
        for theme in global_themes.values():
            theme["score_moyen"] /= theme["occurrences"]
            # Convertir les sets en listes pour la sérialisation JSON
            theme["sous_themes"] = list(theme["sous_themes"])
            theme["mots_cles"] = list(theme["mots_cles"])
        
        return {
            "themes_by_section": themes_by_section,
            "global_themes": global_themes
        }

    def compare_themes_across_documents(self, all_analyses: Dict[str, Dict]) -> Dict[str, Any]:
        """Compare les thèmes entre les documents"""
        theme_occurrences = {}  # Thème -> {documents: [], score_total: 0}
        theme_correlations = {}  # (theme1, theme2) -> score de corrélation
        
        # Collecter les occurrences des thèmes
        for doc_name, analysis in all_analyses.items():
            global_themes = analysis["global_themes"]
            for theme_name, theme_data in global_themes.items():
                if theme_name not in theme_occurrences:
                    theme_occurrences[theme_name] = {
                        "documents": [],
                        "score_total": 0,
                        "mots_cles": set(),
                        "sous_themes": set()
                    }
                
                theme_occurrences[theme_name]["documents"].append(doc_name)
                theme_occurrences[theme_name]["score_total"] += theme_data["score_moyen"]
                theme_occurrences[theme_name]["mots_cles"].update(theme_data["mots_cles"])
                theme_occurrences[theme_name]["sous_themes"].update(theme_data["sous_themes"])
        
        # Calculer les corrélations entre thèmes
        themes = list(theme_occurrences.keys())
        for i, theme1 in enumerate(themes):
            for theme2 in themes[i+1:]:
                # Calculer la similarité basée sur les documents partagés et les mots-clés
                docs1 = set(theme_occurrences[theme1]["documents"])
                docs2 = set(theme_occurrences[theme2]["documents"])
                mots1 = theme_occurrences[theme1]["mots_cles"]
                mots2 = theme_occurrences[theme2]["mots_cles"]
                
                # Coefficient de Jaccard pour les documents et mots-clés
                doc_sim = len(docs1 & docs2) / len(docs1 | docs2) if docs1 | docs2 else 0
                mot_sim = len(mots1 & mots2) / len(mots1 | mots2) if mots1 | mots2 else 0
                
                correlation = (doc_sim + mot_sim) / 2
                if correlation > 0.3:  # Seuil minimal de corrélation
                    theme_correlations[f"{theme1}-{theme2}"] = correlation
        
        # Convertir les sets en listes pour JSON
        for theme_data in theme_occurrences.values():
            theme_data["mots_cles"] = list(theme_data["mots_cles"])
            theme_data["sous_themes"] = list(theme_data["sous_themes"])
        
        return {
            "theme_occurrences": theme_occurrences,
            "theme_correlations": theme_correlations
        }

    def generate_theme_report(self, comparison: Dict[str, Any]) -> str:
        """Génère un rapport détaillé des thèmes"""
        report = []
        report.append("📊 ANALYSE THÉMATIQUE DES DOCUMENTS")
        
        # Thèmes les plus fréquents
        theme_occurrences = comparison["theme_occurrences"]
        report.append("\n🔄 THÈMES PRINCIPAUX")
        sorted_themes = sorted(
            theme_occurrences.items(),
            key=lambda x: len(x[1]["documents"]),
            reverse=True
        )
        
        for theme_name, theme_data in sorted_themes:
            nb_docs = len(theme_data["documents"])
            score_moyen = theme_data["score_total"] / nb_docs
            report.append(f"\n• {theme_name}")
            report.append(f"  - Présent dans {nb_docs} documents")
            report.append(f"  - Score moyen : {score_moyen:.2f}")
            report.append(f"  - Sous-thèmes : {', '.join(theme_data['sous_themes'][:5])}")
            report.append(f"  - Mots-clés principaux : {', '.join(theme_data['mots_cles'][:5])}")
        
        # Corrélations entre thèmes
        report.append("\n🔗 THÈMES CORRÉLÉS")
        sorted_correlations = sorted(
            comparison["theme_correlations"].items(),
            key=lambda x: x[1],
            reverse=True
        )
        
        for theme_pair, correlation in sorted_correlations[:10]:
            theme1, theme2 = theme_pair.split("-")
            report.append(f"• {theme1} ⟷ {theme2}: {correlation:.2f}")
        
        return "\n".join(report)

    def analyze_topics(self, all_sections: Dict[str, Dict[str, str]]) -> str:
        """Analyse principale des documents"""
        try:
            print("🔍 Analyse document par document...")
            all_analyses = {}
            
            for doc_name, sections in all_sections.items():
                print(f"\n📄 Analyse de {doc_name}")
                doc_analysis = self.analyze_document(sections)
                all_analyses[doc_name] = doc_analysis
            
            print("\n🔄 Comparaison des documents...")
            comparison = self.compare_documents_themes(all_analyses)
            
            print("\n📊 Génération du rapport...")
            report = self.generate_comparative_report(comparison)
            
            # Sauvegarde des résultats détaillés
            self.save_detailed_results(all_analyses, comparison)
            
            return report
            
        except Exception as e:
            print(f"❌ Erreur analyse: {e}")
            return "Erreur lors de l'analyse"

    def calculate_statistics(self, analysis: Dict) -> Dict:
            """Calcule des statistiques détaillées sur l'analyse"""
            stats = {
                "nombre_total_documents": len(analysis.get("themes_principaux", [])),
                "themes": {
                    "count": len(analysis.get("themes_principaux", [])),
                    "distribution": {},
                    "mots_cles_frequents": Counter(),
                    "correlations": {}
                },
                "similarites": {
                    "count_patterns": len(analysis.get("similarites", {}).get("patterns_communs", [])),
                    "count_differences": len(analysis.get("similarites", {}).get("differences_notables", []))
                }
            }

            # Analyse des thèmes
            for theme in analysis.get("themes_principaux", []):
                nom = theme.get("nom", "")
                freq = float(theme.get("frequence", "0").strip("%"))/100
                stats["themes"]["distribution"][nom] = freq
                
                # Mots-clés fréquents
                for mot in theme.get("mots_cles", []):
                    stats["themes"]["mots_cles_frequents"][mot] += 1

            # Calcul des corrélations entre thèmes
            themes = list(stats["themes"]["distribution"].keys())
            for i, theme1 in enumerate(themes):
                for theme2 in themes[i+1:]:
                    correlation = self._calculate_theme_correlation(
                        analysis, theme1, theme2
                    )
                    stats["themes"]["correlations"][f"{theme1}-{theme2}"] = correlation

            return stats

    def analyze_document(self, sections: Dict[str, str]) -> Dict[str, Any]:
            """Analyse un document section par section"""
            document_analysis = {
                "sections_analysis": {},
                "global_themes": set(),
                "all_keywords": set()
            }
            
            for section_name, content in sections.items():
                print(f"  Analyse de la section : {section_name}")
                section_analysis = self.analyze_content_with_mixtral(content, section_name)
                
                document_analysis["sections_analysis"][section_name] = section_analysis
                
                # Collecter les thèmes et mots-clés
                for theme in section_analysis.get("themes", []):
                    document_analysis["global_themes"].add(theme["nom"])
                    document_analysis["all_keywords"].update(theme.get("concepts_cles", []))
            
            return document_analysis

    def compare_documents_themes(self, all_analyses: Dict[str, Dict]) -> Dict[str, Any]:
            """Compare les thématiques entre les documents"""
            comparison = {
                "themes_communs": {},
                "themes_uniques": {},
                "mots_cles_frequence": Counter(),
                "sections_similaires": {},
                "statistiques": {
                    "nombre_documents": len(all_analyses),
                    "themes_par_document": {},
                    "sections_par_document": {}
                }
            }
            
            # Analyser chaque document
            for doc_name, analysis in all_analyses.items():
                themes = analysis["global_themes"]
                comparison["statistiques"]["themes_par_document"][doc_name] = len(themes)
                comparison["statistiques"]["sections_par_document"][doc_name] = len(analysis["sections_analysis"])
                
                # Compter la fréquence des thèmes
                for theme in themes:
                    if theme not in comparison["themes_communs"]:
                        comparison["themes_communs"][theme] = 1
                    else:
                        comparison["themes_communs"][theme] += 1
                
                # Collecter les mots-clés
                comparison["mots_cles_frequence"].update(analysis["all_keywords"])
            
            # Identifier les thèmes uniques et communs
            total_docs = len(all_analyses)
            for theme, count in list(comparison["themes_communs"].items()):
                if count == 1:
                    comparison["themes_uniques"][theme] = count
                    del comparison["themes_communs"][theme]
                else:
                    comparison["themes_communs"][theme] = (count / total_docs) * 100
            
            return comparison

    def generate_comparative_report(self, comparison: Dict[str, Any]) -> str:
            """Génère un rapport comparatif détaillé"""
            report = []
            report.append("📊 ANALYSE COMPARATIVE DES DOCUMENTS")
            report.append(f"Nombre total de documents analysés : {comparison['statistiques']['nombre_documents']}\n")
            
            # Thèmes communs
            report.append("🔄 THÈMES COMMUNS")
            for theme, percentage in sorted(comparison["themes_communs"].items(), key=lambda x: x[1], reverse=True):
                report.append(f"• {theme}: {percentage:.1f}% des documents")
            
            # Thèmes uniques
            report.append("\n💫 THÈMES UNIQUES")
            for theme in comparison["themes_uniques"]:
                report.append(f"• {theme}")
            
            # Mots-clés les plus fréquents
            report.append("\n🔤 MOTS-CLÉS LES PLUS FRÉQUENTS")
            for mot, count in comparison["mots_cles_frequence"].most_common(10):
                report.append(f"• {mot}: {count} occurrences")
            
            # Statistiques par document
            report.append("\n📈 STATISTIQUES PAR DOCUMENT")
            for doc, nb_themes in comparison["statistiques"]["themes_par_document"].items():
                nb_sections = comparison["statistiques"]["sections_par_document"][doc]
                report.append(f"• {doc}:")
                report.append(f"  - Nombre de thèmes : {nb_themes}")
                report.append(f"  - Nombre de sections : {nb_sections}")
            
            return "\n".join(report)

    def analyze_topics(self, all_sections: Dict[str, Dict[str, str]]) -> str:
            """Analyse principale des documents"""
            try:
                print("🔍 Analyse document par document...")
                all_analyses = {}
                
                for doc_name, sections in all_sections.items():
                    print(f"\n📄 Analyse de {doc_name}")
                    doc_analysis = self.analyze_document(sections)
                    all_analyses[doc_name] = doc_analysis
                
                print("\n🔄 Comparaison des documents...")
                comparison = self.compare_documents_themes(all_analyses)
                
                print("\n📊 Génération du rapport...")
                report = self.generate_comparative_report(comparison)
                
                # Sauvegarde des résultats détaillés
                self.save_detailed_results(all_analyses, comparison)
                
                return report
                
            except Exception as e:
                print(f"❌ Erreur analyse: {e}")
                return "Erreur lors de l'analyse"

    def save_detailed_results(self, analyses: Dict, comparison: Dict):
        """Sauvegarde les résultats détaillés"""
        try:
            # Conversion des Counters en dictionnaires
            if "mots_cles_frequence" in comparison:
                comparison["mots_cles_frequence"] = dict(comparison["mots_cles_frequence"])
            
            # Préparation des résultats
            results = {
                "analyses_par_document": {
                    doc_name: {
                        "sections_analysis": doc_analysis["sections_analysis"],
                        "global_themes": doc_analysis["global_themes"],
                        "all_keywords": doc_analysis["all_keywords"]
                    }
                    for doc_name, doc_analysis in analyses.items()
                },
                "comparaison": comparison
            }
            
            with open("analyse_thematique_detaillee.json", "w", encoding="utf-8") as f:
                json.dump(results, f, ensure_ascii=False, indent=2)
                
        except Exception as e:
            print(f"❌ Erreur sauvegarde résultats: {e}")

# %%
def main():
    # Initialisation de l'analyseur avec le bon chemin
    analyzer = AAPAnalyzer("../data")  # Changé de "../data" à "data"
    
    print("🔍 Analyse des AAP en cours...")
    # Recherche récursive dans tous les sous-dossiers
    aap_files = []
    for subdir in Path("../data").iterdir():
        if subdir.is_dir():
            aap_files.extend([
                p for p in subdir.rglob("*") 
                if p.is_file() and ("AAP" in p.name.upper() or "aap" in p.name.lower())
            ])
    
    if not aap_files:
        print("❌ Aucun fichier AAP trouvé!")
        return
        
    print(f"📁 {len(aap_files)} fichiers AAP trouvés")
    
    # Vérification de la connexion à Mixtral
    try:
        response = requests.get("http://localhost:11434/api/version")
        if response.status_code != 200:
            print("❌ Erreur: Mixtral n'est pas accessible. Assurez-vous qu'il est lancé sur le port 11434")
            return
    except:
        print("❌ Erreur: Impossible de se connecter à Mixtral. Assurez-vous qu'il est lancé.")
        return
    
    all_sections = {}
    for file_path in aap_files:
        print(f"\n📄 Analyse de {file_path.name}")
        sections = analyzer.extract_text_by_sections(str(file_path))
        if sections:
            all_sections[file_path.name] = sections
    
    if not all_sections:
        print("❌ Aucune section extraite des fichiers!")
        return
    
    print("\n🤖 Analyse thématique en cours...")
    analysis = analyzer.analyze_topics(all_sections)
    
    print("\n=== Rapport d'Analyse ===")
    print(analysis)

# Appel explicite de la fonction main
if __name__ == "__main__":
    main()
# Out:
# 🔍 Analyse des AAP en cours...
# 📁 33 fichiers AAP trouvés
#
# 📄 Analyse de ESF_P01_AAP01.docx
#
# 📄 Analyse de ESF_P01_AAP02.docx
#
# 📄 Analyse de ESF_P01_AAP03.docx
#
# 📄 Analyse de ESF_P01_AAP04.docx
#
# 📄 Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
#
# 📄 Analyse de PU_P01_AAP01.docx
#
# 📄 Analyse de PU_P01_AAP02.docx
#
# 📄 Analyse de PU_P01_AAP03.docx
#
# 📄 Analyse de Pulse_P01_AAP01.docx
#
# 📄 Analyse de Pulse_P02_AAP01.rtf
# ⚠️ Format non supporté: ..\data\Pulse\Projet02\Pulse_P02_AAP01.rtf
#
# 📄 Analyse de Pulse_P02_AAP01E
# ⚠️ Format non supporté: ..\data\Pulse\Projet02\Pulse_P02_AAP01E
#
# 📄 Analyse de PS_P03_AAP01.docx
#
# 📄 Analyse de dossier_de_candidature_aap_projets_innov_entre_2024.docx
#
# 📄 Analyse de Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
#
# 📄 Analyse de Note cadrage AAP.docx
#
# 📄 Analyse de Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
#
# 📄 Analyse de Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
#
# 📄 Analyse de Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
#
# 📄 Analyse de réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx
#
# 📄 Analyse de SS_P01_AAP01.docx
#
# 📄 Analyse de SS_P01_AAP01T.docx
#
# 📄 Analyse de SS_P02_AAP01E.pdf
#
# 📄 Analyse de SS_P03_AAP01E.pdf
#
# 📄 Analyse de SS_P04_AAP01E.pdf
#
# 📄 Analyse de SS_P05_AAP01.docx
#
# 📄 Analyse de SS_P11_AAP01.docx
#
# 📄 Analyse de Wings of the Ocean_Procédure réponse AAP.docx
#
# 📄 Analyse de WOTO_P01_AAP01.pdf
#
# 📄 Analyse de WOTO_P01_AAP02.docx
#
# 📄 Analyse de WOTO_P01_AAP03.pdf
#
# 📄 Analyse de WOTO_P02_AAP01E.pdf
#
# 📄 Analyse de WOTO_P02_AAP02E.docx
#
# 📄 Analyse de WOTO_P03_AAP01E.pdf
#
# 🤖 Analyse thématique en cours...
# 🔍 Analyse document par document...
#
# 📄 Analyse de ESF_P01_AAP02.docx
#   Analyse de la section : Le projet en synthèse 2 / 3
#
# 📄 Analyse de ESF_P01_AAP03.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de ESF_P01_AAP04.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
#   Analyse de la section : Introduction
#   Analyse de la section : MARCHE PUBLIC
# ⚠️ Erreur parsing JSON pour MARCHE PUBLIC
#   Analyse de la section : APPEL D’OFFRE
#   Analyse de la section : TERRITORIALES
#   Analyse de la section : INTERCOMMUNALITES
#   Analyse de la section : TÂCHES
# ⚠️ Erreur parsing JSON pour TÂCHES
#   Analyse de la section : SEMAINE 7/8
# ⚠️ Erreur parsing JSON pour SEMAINE 7/8
#   Analyse de la section : • SIREN  ;
# ⚠️ Erreur parsing JSON pour • SIREN  ;
#   Analyse de la section : FOCUS GENRE
# ⚠️ Erreur parsing JSON pour FOCUS GENRE
#   Analyse de la section : CONSEIL
#   Analyse de la section : (INSEE, 2018).
#   Analyse de la section : OBJECTIF DE LA REPONSE
#   Analyse de la section : PERSONNES RESSOURCES
#   Analyse de la section : (ODD5…)
# ⚠️ Erreur parsing JSON pour (ODD5…)
#   Analyse de la section : CSESS, 2011)  ;
#   Analyse de la section : TYPES D’OUTIL
#   Analyse de la section : X
#
# 📄 Analyse de PU_P01_AAP01.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de PU_P01_AAP02.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de PU_P01_AAP03.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Pulse_P01_AAP01.docx
#   Analyse de la section : Introduction
#   Analyse de la section : L’organisme porteur de projet (soumissionnaire principal)
#   Analyse de la section : 1 INSTRUCTIONS POUR LA RÉDACTION DE LA NOTE SUCCINCTE DE PRÉSENTATION
#   Analyse de la section : 1.1 Résumé de l’action
#   Analyse de la section : 1.2 Description de l’action (maximum 2 pages)
# ⚠️ Erreur parsing JSON pour 1.2 Description de l’action (maximum 2 pages)
#   Analyse de la section : 1.3.1 Pertinence par rapport aux objectifs/secteurs/thèmes/priorités spécifiques de l’appel à projets
#   Analyse de la section : 1.3.2 Pertinence par rapport aux besoins et contraintes spécifiques du/des pays, région(s) cible(s) et/ou des secteurs concernés (y compris les synergies avec d’autres initiatives en matière de développement et l’absence de double emploi)
#   Analyse de la section : 1.3.3 Décrivez et définissez les groupes cibles et les bénéficiaires finaux, leurs besoins et leurs contraintes, et expliquez comment l’action répondra à ces besoins
# ⚠️ Erreur parsing JSON pour 1.3.3 Décrivez et définissez les groupes cibles et les bénéficiaires finaux, leurs besoins et leurs contraintes, et expliquez comment l’action répondra à ces besoins
#   Analyse de la section : 1.3.4 Éléments spécifiques apportant une valeur ajoutée
#   Analyse de la section : 1.3 ; Lieu(x)
#   Analyse de la section : 1.6. Objectif général et objectifs spécifiques (maximum 1 page)
# ⚠️ Erreur parsing JSON pour 1.6. Objectif général et objectifs spécifiques (maximum 1 page)
#   Analyse de la section : 1.7. Pertinence de l'action (maximum 3 pages)
# ⚠️ Erreur parsing JSON pour 1.7. Pertinence de l'action (maximum 3 pages)
#   Analyse de la section : 1.8. Description de l'action et de son efficacité (maximum 14 pages)
#   Analyse de la section : 1.9. Méthodologie (maximum 4 pages)
#   Analyse de la section : 1.10. Durée et plan d'action pour la mise en œuvre de l'action
#   Analyse de la section : 1.11. Bénéficiaires (maximum 1,5 page)
#   Analyse de la section : 1.12. Résultats, activités et suivi-évaluation
#   Analyse de la section : 1.13. Plan d’action indicatif pour la mise en œuvre de l’action (maximum 4 pages)
#   Analyse de la section : 1.14. Durabilité (maximum 3 pages)
#   Analyse de la section : 1.15. Budget De L'action
#   Analyse de la section : 1.16. Cadre Logique
# ⚠️ Erreur parsing JSON pour 1.16. Cadre Logique
#   Analyse de la section : Données financières. Veuillez fournir les informations suivantes, le cas échéant, en vous basant sur les comptes de gestion et le bilan de votre organisation, montants en milliers de EUR (ou autre).
# ⚠️ Erreur parsing JSON pour Données financières. Veuillez fournir les informations suivantes, le cas échéant, en vous basant sur les comptes de gestion et le bilan de votre organisation, montants en milliers de EUR (ou autre).
#   Analyse de la section : DESCRIPTION DU/DES PARTENAIRE(S)
# ⚠️ Erreur parsing JSON pour DESCRIPTION DU/DES PARTENAIRE(S)
#   Analyse de la section : DÉCLARATION DE PARTENARIAT
#   Analyse de la section : DÉCLARATION DU DEMANDEUR
# ⚠️ Erreur parsing JSON pour DÉCLARATION DU DEMANDEUR
#
# 📄 Analyse de PS_P03_AAP01.docx
#   Analyse de la section : Introduction
# ⚠️ Erreur parsing JSON pour Introduction
#
# 📄 Analyse de dossier_de_candidature_aap_projets_innov_entre_2024.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
#   Analyse de la section : Introduction
# ⚠️ Erreur parsing JSON pour Introduction
#   Analyse de la section : FICHE CANDIDAT URE
#   Analyse de la section : 1. STRUCTURE PRESENTANT LE PROJET  :
# ⚠️ Erreur parsing JSON pour 1. STRUCTURE PRESENTANT LE PROJET  :
#   Analyse de la section : 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
#   Analyse de la section : 4. PERSONNE EN CHARGE DU DOSSIER  :
#   Analyse de la section : 5. PRESENTATION DU PROJET  :
# ⚠️ Erreur parsing JSON pour 5. PRESENTATION DU PROJET  :
#   Analyse de la section : C. SUBVENTION DEMANDEE
#   Analyse de la section : EVALUATION DES ACTIONS
#
# 📄 Analyse de Note cadrage AAP.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
#   Analyse de la section : Unnamed: 0
#   Analyse de la section : Unnamed: 1
# ⚠️ Erreur parsing JSON pour Unnamed: 1
#   Analyse de la section : Unnamed: 2
#   Analyse de la section : Unnamed: 3
#   Analyse de la section : Unnamed: 4
#   Analyse de la section : Unnamed: 5
#   Analyse de la section : Unnamed: 6
#   Analyse de la section : Unnamed: 7
#   Analyse de la section : Unnamed: 8
#
# 📄 Analyse de Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : PULSE
#   Analyse de la section : 1. PRÉSENTATION DE L’ACTION
# ⚠️ Erreur parsing JSON pour 1. PRÉSENTATION DE L’ACTION
#   Analyse de la section : PULSE.
#   Analyse de la section : 2. DESCRIPTION DE LA PHASE DE RECRUTEMENT ET DE MOBILISATION DES PUBLICS
#   Analyse de la section : 3. CONTENU ET ORGANISATION DE L’ACTION
#   Analyse de la section : UX
#   Analyse de la section : 4. FIN DE L’ACTION
#   Analyse de la section : 5. MOYENS DE MISE EN ŒUVRE DE L’ACTION
#   Analyse de la section : 6 ASPECTS FINANCIERS
#   Analyse de la section : 7. LETTRE DE DEMANDE DE SUBVENTION
#   Analyse de la section : L’INFORMEL »
#
# 📄 Analyse de Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
#   Analyse de la section : Introduction
#   Analyse de la section : FICHE CANDIDAT URE
# ⚠️ Erreur parsing JSON pour FICHE CANDIDAT URE
#   Analyse de la section : 1. STRUCTURE PRESENTANT LE PROJET  :
#   Analyse de la section : 2. INTITULE DU PROJET  :
# ⚠️ Erreur parsing JSON pour 2. INTITULE DU PROJET  :
#   Analyse de la section : 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
#   Analyse de la section : 4. PERSONNE EN CHARGE DU DOSSIER  :
# ⚠️ Erreur parsing JSON pour 4. PERSONNE EN CHARGE DU DOSSIER  :
#   Analyse de la section : 5. PRESENTATION DU PROJET  :
#   Analyse de la section : 3/ SUIVI ET VALORISATION
#   Analyse de la section : C. SUBVENTION DEMANDEE
#   Analyse de la section : EVALUATION DES ACTIONS
#
# 📄 Analyse de réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx
#   Analyse de la section : Unnamed: 0
#   Analyse de la section : Unnamed: 1
# ⚠️ Erreur parsing JSON pour Unnamed: 1
#   Analyse de la section : Unnamed: 2
#   Analyse de la section : Unnamed: 3
#   Analyse de la section : Unnamed: 4
#   Analyse de la section : Unnamed: 5
#   Analyse de la section : Unnamed: 6
#   Analyse de la section : Unnamed: 7
#   Analyse de la section : Unnamed: 8
#
# 📄 Analyse de SS_P01_AAP01.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de SS_P01_AAP01T.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de SS_P03_AAP01E.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : 1. DEMANDEUR
#   Analyse de la section : 2. ACTIVITES GENERALES DE L’ORGANISATION
# ⚠️ Erreur parsing JSON pour 2. ACTIVITES GENERALES DE L’ORGANISATION
#   Analyse de la section : 3. DESCRIPTION  DU PROJET
#   Analyse de la section : 4. DESCRIPTION DU PROJET
# ⚠️ Erreur parsing JSON pour 4. DESCRIPTION DU PROJET
#   Analyse de la section : 5. MOYENS ET METHODOLOGIE DU PROJET
# ⚠️ Erreur parsing JSON pour 5. MOYENS ET METHODOLOGIE DU PROJET
#
# 📄 Analyse de SS_P04_AAP01E.pdf
#   Analyse de la section : N°
#   Analyse de la section : MAURITANIE
#   Analyse de la section : MARSEILLE CEDEX
#   Analyse de la section : SANTE SUD
#   Analyse de la section : SIRET :
#   Analyse de la section : Z
#   Analyse de la section : BOULEVARD NATIONAL
#   Analyse de la section : MARSEILLE
#   Analyse de la section : TOTAL
#   Analyse de la section : PREVISIONNELLES
#   Analyse de la section : PREVISIONNELS
#   Analyse de la section : AFD
#   Analyse de la section : ARS
#   Analyse de la section : PACA SUD
#   Analyse de la section : CD13
# ⚠️ Erreur parsing JSON pour CD13
#   Analyse de la section : L
#   Analyse de la section : A
# ⚠️ Erreur parsing JSON pour A
#   Analyse de la section : TTC
#   Analyse de la section : SOUS-TOTAL 1
#   Analyse de la section : SOUS-TOTAL 2
#   Analyse de la section : J
#
# 📄 Analyse de SS_P05_AAP01.docx
#   Analyse de la section : Introduction
# ⚠️ Erreur parsing JSON pour Introduction
#
# 📄 Analyse de SS_P11_AAP01.docx
#   Analyse de la section : Introduction
#   Analyse de la section : Formulaire de demande complète
#   Analyse de la section : Description (max. 13 pages)
#   Analyse de la section : Méthodologie (max. 5 pages)
#   Analyse de la section : Plan d’action indicatif pour la mise en œuvre de l’action (max. 4 pages)
#   Analyse de la section : Viabilité de l’action (max. 3 pages)
#   Analyse de la section : Cadre logique
#   Analyse de la section : Budget, montant demandé à l’administration contractante et autres sources de financement attendues
#   Analyse de la section : Expérience
# ⚠️ Erreur parsing JSON pour Expérience
#   Analyse de la section : Demandeur chef de file, codemandeur(s) et entités affiliées
#   Analyse de la section : Déclaration du demandeur chef de file (demande complète)
# ⚠️ Erreur parsing JSON pour Déclaration du demandeur chef de file (demande complète)
#   Analyse de la section : Mandat [pour le(s) codemandeur(s)]
#   Analyse de la section : Déclaration relative aux entités affiliées
#   Analyse de la section : Consignes de rédaction du formulaire de demande complète
#   Analyse de la section : Informations générales
#   Analyse de la section : L’action
# ⚠️ Erreur parsing JSON pour L’action
#   Analyse de la section : Le demandeur chef de file, les codemandeurs et les entités affiliées
#   Analyse de la section : Associés participant à l’action
# ⚠️ Erreur parsing JSON pour Associés participant à l’action
#   Analyse de la section : Liste de contrôle personnelle
# ⚠️ Erreur parsing JSON pour Liste de contrôle personnelle
#
# 📄 Analyse de Wings of the Ocean_Procédure réponse AAP.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de WOTO_P01_AAP01.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : — MEMBRE —
# ⚠️ Erreur parsing JSON pour — MEMBRE —
#   Analyse de la section : INFORMATIONS SUR LE PORTEUR DE PROJET
#   Analyse de la section : PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT
#
# 📄 Analyse de WOTO_P01_AAP02.docx
#   Analyse de la section : Introduction
#
# 📄 Analyse de WOTO_P01_AAP03.pdf
#   Analyse de la section : POUR LA PLANÈTE
# ⚠️ Erreur parsing JSON pour POUR LA PLANÈTE
#   Analyse de la section : APPEL A PROJET POUR LA PLANÈTE
#   Analyse de la section : JUSQU'AU 07 AVRIL
#   Analyse de la section : OMENT D’ÉCHANGES
#   Analyse de la section : RENCONTRES POUR LA PLANÈTE
# ⚠️ Erreur parsing JSON pour RENCONTRES POUR LA PLANÈTE
#   Analyse de la section : SOUTIENS PLURI-ANNUELS
#   Analyse de la section : MARDIS POUR LA
#   Analyse de la section : SONT ÉLIGIBLES :
#   Analyse de la section : NE SONT PAS ÉLIGIBLES :
# ⚠️ Erreur parsing JSON pour NE SONT PAS ÉLIGIBLES :
#   Analyse de la section : CRITÈRES D’ÉLIGIBILITÉ DES PROJETS
#   Analyse de la section : SOCIALE
#   Analyse de la section : DEMANDE DE FINANCEMENTCOMBIEN PEUT-ON DEMANDER DE FINANCER ?
#   Analyse de la section : D'OÙ VIENNENT LES FINANCEMENTS ?
#   Analyse de la section : ET DES ANNEXES EST LE 07 AVRIL 2024 À MINUIT.
#   Analyse de la section : DES DOSSIERSVÉRIFICATION DE L’ÉLIGIBILITÉ
#   Analyse de la section : DÉCISION DE SÉLECTION
#   Analyse de la section : SUIVI DE L’UTILISATION
#   Analyse de la section : À PROJET
# ⚠️ Erreur parsing JSON pour À PROJET
#   Analyse de la section : DÉCISION
# ⚠️ Erreur parsing JSON pour DÉCISION
#   Analyse de la section : AUX RENCONTRES POUR LA PLANÈTE
#   Analyse de la section : VIDÉO DE PRÉSENTATION
#   Analyse de la section : CAMPAGNE DE CROWDFUNDING
#   Analyse de la section : FORMATION PITCH
#   Analyse de la section : CONVENTION
#   Analyse de la section : RAPPORT D’UTILISATION DES DONS
#   Analyse de la section : DÉBUT ACCOMPAGNEMENT
#   Analyse de la section : RIB
#   Analyse de la section : ANNEXES THÉMATIQUESDESCRIPTION DES THÉMATIQUES
#   Analyse de la section : ET JUSTICE SOCIALE
#
# 📄 Analyse de WOTO_P02_AAP01E.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : FONDATION D’ENTREPRSE
#   Analyse de la section : 6 BUDGET PREVISIONNEL DU PROJET  11
# ⚠️ Erreur parsing JSON pour 6 BUDGET PREVISIONNEL DU PROJET  11
#
# 📄 Analyse de WOTO_P02_AAP02E.docx
#   Analyse de la section : Introduction
# ⚠️ Erreur parsing JSON pour Introduction
#
# 📄 Analyse de WOTO_P03_AAP01E.pdf
#   Analyse de la section : Introduction
#   Analyse de la section : MODALITÉS
#   Analyse de la section : PRÉSENTATION DE VOTRE ORGANISME
#   Analyse de la section : PRESENT ATION ET OBJECTIFS
#   Analyse de la section : VOS BESOINS
#   Analyse de la section : VOS IMPACTS
#   Analyse de la section : VOTRE PROJET & NOUS
#
# 🔄 Comparaison des documents...
#
# 📊 Génération du rapport...
# ❌ Erreur sauvegarde résultats: Object of type set is not JSON serializable
#
# === Rapport d'Analyse ===
# 📊 ANALYSE COMPARATIVE DES DOCUMENTS
# Nombre total de documents analysés : 29
#
# 🔄 THÈMES COMMUNS
# • Appel à projets: 17.2% des documents
# • Budget: 10.3% des documents
# • Documents requis: 10.3% des documents
# • Environnement: 10.3% des documents
# • Financement et budget: 10.3% des documents
# • Budget et financement: 10.3% des documents
# • Suivi et évaluation: 6.9% des documents
# • Méthodes de collecte de données: 6.9% des documents
# • Demande de subvention: 6.9% des documents
# • Communication: 6.9% des documents
# • Présentation du projet: 6.9% des documents
# • Budget et finance: 6.9% des documents
# • Données personnelles et confidentialité: 6.9% des documents
# • Accompagnement à l'émergence de projets: 6.9% des documents
# • Sensibilisation et détection: 6.9% des documents
# • Planification temporelle: 6.9% des documents
# • Réalisation annuelle: 6.9% des documents
# • Apprentissage: 6.9% des documents
# • Éducation: 6.9% des documents
# • Accompagnement: 6.9% des documents
# • Appel à manifestation d'intérêt: 6.9% des documents
# • Partenariats et renforcement des capacités: 6.9% des documents
# • Demande de financement: 6.9% des documents
# • Événement: 6.9% des documents
# • Contact: 6.9% des documents
# • Gestion administrative: 6.9% des documents
# • Identité de l'organisme: 6.9% des documents
# • Formation: 6.9% des documents
# • Financement: 6.9% des documents
# • Dossier de candidature: 6.9% des documents
#
# 💫 THÈMES UNIQUES
# • Projet
# • Implication EDF
# • Partenaires
# • Description et problématique
# • Co-financement et budget
# • Présentation de la structure
# • Identité de la structure
# • Aide au développement
# • Promotion de la prévention et réduction des conduites addictives
# • Procédures de soutien à des projets
# • Collectivités territoriales
# • Guide pratique pour répondre aux appels à projets
# • Préparation d'une réponse à un appel à projets
# • Egalité de genre
# • Appels à projets
# • Observations sur le terrain
# • Évaluation de projet
# • Méthodologie de projet
# • Communauté de développeurs et ressources
# • Marchés publics
# • Pérennisation des actions dans le cadre du fonctionnement de chaque établissement
# • Ressources internes au Groupe SOS
# • Supports de collecte de données
# • Histoires et récits de projet
# • Documentation de projet
# • Clarté du vocabulaire et cohérence du dossier
# • Opérateurs nationaux
# • Ressources complémentaires d'acteurs externes
# • Partenariats et réseaux
# • Etat
# • Contexte et politiques publiques
# • Guide pratique pour l'intégration du genre dans les projets
# • Renforcement de l'autonomie des acteurs du secteur de l'AHI
# • Chaîne de valeur du projet
# • Mesure et outils d'évaluation
# • Planification et budgétisation du projet
# • Informations sur l'organisation
# • Experts et partenaires externes
# • État financier
# • Lutte anti-corruption
# • Finances du projet
# • Informations sur le projet
# • Participation des parties prenantes
# • Activités proposées
# • Confidentialité et sécurité
# • Partenariat
# • Genre et égalité
# • Documentation requise
# • Mise en forme et organisation
# • Lieux des activités
# • Complémentarité avec d'autres initiatives
# • Meet Africa ii
# • Participation à l'appel à projets
# • Résultats escomptés
# • Bénéficiaires indirects
# • Planification et gestion de projet
# • Communication et coordination
# • Moyens de mise en œuvre
# • Subventions
# • Intégration dans les programmes existants
# • Devise
# • Gestion de projet
# • Pays partenaires
# • Communication du plan d’action
# • Budget et Financement
# • Durabilité
# • Méthodologie proposée
# • Situation antérieure au projet
# • Tableau
# • Obligations contractuelles
# • Co-incubation France-Maroc
# • Pertinence par rapport aux objectifs et priorités
# • Portée géographique des programmes en France
# • Bénéficiaires directs
# • Modifications et approbations
# • Protection des données personnelles
# • Pertinence par rapport aux sous-thèmes/secteurs/domaines spécifiques
# • Planification et gestion du temps
# • Description de l'action proposée
# • Protection des intérêts financiers
# • Planification de projets
# • Exigences et critères d'éligibilité
# • Analyse des problèmes et synergies
# • Résultats et outputs
# • Structure organisationnelle et équipe
# • Responsabilités et obligations
# • Exigences administratives
# • Portée géographique de Bidaya
# • Aspects financiers
# • Action proposée
# • Moyens matériels et humains
# • Evaluation des actions
# • Informations sur la personne responsable
# • Source de l'appel à projets
# • Déroulement de l'AAP
# • Fiche d'identité
# • Description de l'opportunité
# • Création d'entreprises
# • Planification et objectifs
# • Événements publics
# • Accompagnement de projets
# • Planification
# • Suivi des porteurs de projets
# • Entreprises accompagnées
# • Accompagnement post-programme
# • Programme d'accompagnement
# • Localisation
# • Atelier
# • Accompagnement à l'entrepreneuriat
# • Expérience Utilisateur (UX)
# • Pédagogie innovante
# • Évaluation des participants
# • Suivi et coordination
# • Transparence et honnêteté
# • Collaboration et labellisation
# • Moyens matériels
# • Financement de projet
# • Entrepreneuriat et économie informelle
# • Coût et financement
# • Intervenants et experts
# • Partenariats
# • Expérience et déploiement
# • Programme de sensibilisation à l'entrepreneuriat
# • Public cible
# • Recrutement et mobilisation des publics
# • Engagement juridique et responsabilité
# • Lieu et promotion
# • Événements et learning expedition
# • Informations d'identification
# • Aide au financement
# • Coordonnées
# • Boîte à outils
# • Nouvelles technologies
# • Partenariats et collaboration
# • Rémunération
# • Ateliers et accompagnement personnalisé
# • Environnement et développement durable
# • Développement économique et social
# • Evaluation
# • Destinataires et parties prenantes
# • Forme juridique et statut ESUS
# • Objectif prévisionnel année 2
# • Réalisation
# • Détection de porteurs de projets
# • Objectifs prévisionnels
# • Objectif prévisionnel
# • Organisation d'événements publics
# • Accompagnement à différentes phases de projets
# • Indicateurs et publics
# • Année 1
# • Données numériques
# • Approche genre, diversité et inclusion
# • Coordonnées du porteur de projet
# • Description et justification du projet
# • Résultats attendus et activités prévues
# • Projet et objectifs
# • Informations sur le porteur de projet
# • Solidarité Mayotte
# • Santé environnementale
# • Durée et budget du projet
# • Organisation non gouvernementale (ONG)
# • Populations défavorisées
# • Informations sur l'équipe
# • Cyclone Chido
# • Coordonnées de l'organisme
# • Subventions perçues
# • Dépenses directes
# • Déplacements et frais administratifs
# • Autres charges
# • Budget prévisionnel
# • Adresse
# • Personnel
# • Finances
# • Coûts financiers
# • Activités de service
# • Déclaration et engagement
# • Organisations et financements
# • Budget / Dépenses
# • Système de santé en Afrique subsaharienne
# • Organisation / Association
# • Statut et gestion de l'association
# • Informations de contact
# • Dépenses
# • Charges indirectes
# • Pays
# • Économie
# • Subventions / Financement
# • Lieu
# • Exposition photo
# • Anniversaire de Santé Sud
# • Rémunérations et charges sociales
# • Manifestations, congrès ou salons professionnels
# • Date
# • Énergie
# • Mobilité et transports
# • TVA
# • Subventions publiques
# • Services extérieurs
# • Aménagement urbain
# • Santé connectée
# • Technologie
# • Technologie blockchain
# • Modèle
# • Recherche documentaire
# • Formulaire de candidature
# • Rentabilité socio-économique
# • Partenariat et communication
# • Enregistrement préalable dans PADOR
# • Directives et procédures
# • Responsabilités des entités affiliées
# • Déclaration relative aux entités affiliées
# • Processus de demande
# • Analyse statistique
# • Demandeur chef de file
# • Engagement et bonnes pratiques
# • Entités affiliées
# • Formulaire de demande de subvention
# • Étude qualitative
# • Mise à jour du profil PADOR
# • Codemandeurs
# • Éthique des données
# • Impact environnemental
# • Mandat et autorisation
# • Appel à propositions restreint
# • Validation des résultats
# • Plan d'action
# • Formulaire de demande
# • Administration contractante: Commission européenne
# • Appel à projets (AAP)
# • Présentation d'un projet
# • Identification du rôle
# • Informations associatives
# • Coordonnées personnelles
# • Missions et Actions
# • Associations et institutions
# • Philanthropie et mécénat
# • Solidarité et territoires
# • Horaires/Heures
# • Dates importantes
# • Sélection d'associations
# • Événement futur
# • Sujets de société et actualités clefs
# • Financement de projets
# • Gestion des dons et subventions
# • Reconnaissance d'intérêt général
# • Agriculture durable et résiliente
# • Public intéressé
# • Organisation à but non lucratif
# • Pédagogie active au contact de la nature
# • Document officiel
# • Mouvement écologique
# • Documents de présentation
# • Thématiques environnementales
# • Transition éducative et sociale
# • Événement pour l'environnement
# • Crowdfunding
# • Gestion financière
# • Événements
# • Processus de candidature
# • Engagement environnemental
# • Diversité des associations
# • Comptabilité et finances
# • Transition écologique internationale
# • Calendrier du projet
# • Préservation de la biodiversité
# • Vérification de l'éligibilité et sélection des dossiers
# • Sources de financement
# • Organisation environnementale
# • Événements et réunions
# • Environnement/Ecologie
# • Soutien financier
# • Critères d'éligibilité
# • Montant de financement
# • Projets environnementaux
# • Portée des projets
# • Social
# • Éligibilité
# • Justice sociale
# • Communication et promotion
# • Réduction de l'empreinte carbone
# • Attente réaliste
# • Exclusion des valorisations
# • Calendrier et échéances
# • Associations agréées 1% for the Planet
# • Année/Date
# • Processus de sélection
# • Engagement
# • Fondation d'entreprise
# • Collaboration professionnelle
# • Développement durable
# • Innovation
# • Mécénat de compétences
# • Candidature
# • Compétences et expérience
# • Ressources humaines
# • Objectifs d'impact
# • Sensibilisation et prise de conscience
# • Valorisation et réseau
# • Candidature à un financement
# • Indicateurs d'impact
# • Gestion durable des pêcheries
# • Impacts environnementaux
# • Communication et contact
# • Recherche et innovation
#
# 🔤 MOTS-CLÉS LES PLUS FRÉQUENTS
#
# 📈 STATISTIQUES PAR DOCUMENT
# • ESF_P01_AAP02.docx:
#   - Nombre de thèmes : 5
#   - Nombre de sections : 1
# • ESF_P01_AAP03.docx:
#   - Nombre de thèmes : 5
#   - Nombre de sections : 1
# • ESF_P01_AAP04.docx:
#   - Nombre de thèmes : 2
#   - Nombre de sections : 1
# • Guide Pratique Réponse AAP (Groupe SOS).pdf:
#   - Nombre de thèmes : 28
#   - Nombre de sections : 17
# • PU_P01_AAP01.docx:
#   - Nombre de thèmes : 5
#   - Nombre de sections : 1
# • PU_P01_AAP02.docx:
#   - Nombre de thèmes : 3
#   - Nombre de sections : 1
# • PU_P01_AAP03.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • Pulse_P01_AAP01.docx:
#   - Nombre de thèmes : 50
#   - Nombre de sections : 25
# • PS_P03_AAP01.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • dossier_de_candidature_aap_projets_innov_entre_2024.docx:
#   - Nombre de thèmes : 4
#   - Nombre de sections : 1
# • Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf:
#   - Nombre de thèmes : 8
#   - Nombre de sections : 8
# • Note cadrage AAP.docx:
#   - Nombre de thèmes : 3
#   - Nombre de sections : 1
# • Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx:
#   - Nombre de thèmes : 9
#   - Nombre de sections : 9
# • Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf:
#   - Nombre de thèmes : 26
#   - Nombre de sections : 12
# • Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf:
#   - Nombre de thèmes : 20
#   - Nombre de sections : 10
# • réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx:
#   - Nombre de thèmes : 12
#   - Nombre de sections : 9
# • SS_P01_AAP01.docx:
#   - Nombre de thèmes : 7
#   - Nombre de sections : 1
# • SS_P01_AAP01T.docx:
#   - Nombre de thèmes : 5
#   - Nombre de sections : 1
# • SS_P03_AAP01E.pdf:
#   - Nombre de thèmes : 9
#   - Nombre de sections : 6
# • SS_P04_AAP01E.pdf:
#   - Nombre de thèmes : 42
#   - Nombre de sections : 21
# • SS_P05_AAP01.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • SS_P11_AAP01.docx:
#   - Nombre de thèmes : 33
#   - Nombre de sections : 19
# • Wings of the Ocean_Procédure réponse AAP.docx:
#   - Nombre de thèmes : 3
#   - Nombre de sections : 1
# • WOTO_P01_AAP01.pdf:
#   - Nombre de thèmes : 8
#   - Nombre de sections : 4
# • WOTO_P01_AAP02.docx:
#   - Nombre de thèmes : 4
#   - Nombre de sections : 1
# • WOTO_P01_AAP03.pdf:
#   - Nombre de thèmes : 57
#   - Nombre de sections : 29
# • WOTO_P02_AAP01E.pdf:
#   - Nombre de thèmes : 5
#   - Nombre de sections : 3
# • WOTO_P02_AAP02E.docx:
#   - Nombre de thèmes : 0
#   - Nombre de sections : 1
# • WOTO_P03_AAP01E.pdf:
#   - Nombre de thèmes : 19
#   - Nombre de sections : 7

# %% [markdown]
# ### Futher Approach : plus globale, analyse thematique générale

# %%
import requests
import json
from pathlib import Path
import os
from typing import Dict, List, Any, Set, Tuple
from docx import Document
import PyPDF2
import pandas as pd
from collections import Counter, defaultdict
import openpyxl
import logging
from difflib import SequenceMatcher
import numpy as np
from datetime import datetime
import time
import sys
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

OLLAMA_HOST = "http://localhost:11434/api/generate"

class AAPAnalyzer:
    def __init__(self, data_dir: str):
        self.data_dir = data_dir
        self.setup_logging()
        self.theme_patterns = {
            "introduction": ["introduction", "contexte", "présentation", "préambule", "avant-propos"],
            "objectifs": ["objectif", "but", "finalité", "mission", "ambition", "vision"],
            "methodologie": ["méthode", "méthodologie", "approche", "démarche", "processus", "protocole"],
            "budget": ["budget", "financement", "coût", "investissement", "dépense", "ressource financière"],
            "evaluation": ["évaluation", "suivi", "indicateur", "mesure", "performance", "critère"],
            "partenariats": ["partenaire", "collaboration", "coopération", "alliance", "réseau", "acteur"],
            "resultats": ["résultat", "impact", "effet", "retombée", "bénéfice", "conséquence"],
            "planning": ["planning", "calendrier", "échéancier", "temporalité", "délai", "durée"],
            "innovation": ["innovation", "nouveauté", "créativité", "originalité", "invention"],
            "durabilite": ["durabilité", "environnement", "écologie", "développement durable"],
            "social": ["social", "sociétal", "inclusion", "accessibilité", "solidarité"],
            "technique": ["technique", "technologie", "outil", "équipement", "infrastructure"],
            "gouvernance": ["gouvernance", "pilotage", "gestion", "organisation", "coordination"],
            "communication": ["communication", "diffusion", "valorisation", "promotion"]
        }
        
    def setup_logging(self):
        """Configuration des logs avec gestion de l'encodage"""
        if sys.platform == 'win32':
            logging.basicConfig(
                level=logging.INFO,
                format='%(asctime)s - %(levelname)s - %(message)s',
                handlers=[
                    logging.FileHandler('aap_analyzer.log', encoding='utf-8'),
                    logging.StreamHandler(sys.stdout)
                ]
            )
        else:
            logging.basicConfig(
                level=logging.INFO,
                format='%(asctime)s - %(levelname)s - %(message)s',
                handlers=[
                    logging.FileHandler('aap_analyzer.log'),
                    logging.StreamHandler()
                ]
            )
        self.logger = logging.getLogger(__name__)

    def ask_mixtral(self, prompt: str) -> str:
        """Envoie une requête à Mixtral pour analyse et compréhension du texte"""
        try:
            response = requests.post(
                OLLAMA_HOST,
                json={
                    "model": "mixtral",
                    "prompt": prompt,
                    "stream": False,
                    "temperature": 0.3
                },
                timeout=180
            )
            
            if response.status_code == 200:
                return response.json().get("response", "Erreur: pas de réponse")
            else:
                self.logger.error(f"Erreur Mixtral - Status code: {response.status_code}")
                return "Erreur: réponse invalide"
        except Exception as e:
            self.logger.error(f"Erreur connexion Mixtral: {str(e)}")
            return "Erreur: problème de connexion"

    def _extract_from_pdf(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier PDF"""
        sections = {}
        current_section = "Introduction"
        current_content = []
        
        try:
            with open(file_path, 'rb') as file:
                reader = PyPDF2.PdfReader(file)
                for page in reader.pages:
                    content = page.extract_text()
                    lines = content.split('\n')
                    
                    for line in lines:
                        line = line.strip()
                        if not line:
                            continue
                        
                        # Détection d'une nouvelle section
                        if line.startswith('###') or line.isupper():
                            if current_content:
                                sections[current_section] = "\n".join(current_content)
                            current_section = line.strip('#').strip()
                            current_content = []
                        else:
                            current_content.append(line)
            
            # Ajouter la dernière section
            if current_content:
                sections[current_section] = "\n".join(current_content)
                
            return sections
            
        except Exception as e:
            print(f"❌ Erreur PDF {file_path}: {e}")
            return {}

    def _extract_from_excel(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier Excel"""
        sections = {}
        
        try:
            df = pd.read_excel(file_path)
            for col in df.columns:
                if isinstance(col, str) and col.strip():
                    content = df[col].dropna().astype(str).tolist()
                    if content:
                        sections[col] = "\n".join(content)
            return sections
            
        except Exception as e:
            print(f"❌ Erreur Excel {file_path}: {e}")
            return {}
    def extract_text_by_sections(self, file_path: str) -> Dict[str, Any]:
        """Extrait le texte et la structure d'un document"""
        try:
            file_path_lower = file_path.lower()
            if file_path_lower.endswith('.docx'):
                return self._extract_from_docx(file_path)
            elif file_path_lower.endswith('.pdf'):
                return self._extract_from_pdf(file_path)
            elif file_path_lower.endswith(('.xlsx', '.xls')):
                return self._extract_from_excel(file_path)
            else:
                self.logger.warning(f"Format non supporté: {file_path}")
                return {}
        except Exception as e:
            self.logger.error(f"Erreur extraction {file_path}: {str(e)}")
            return {}

    def _extract_from_docx(self, file_path: str) -> Dict[str, Any]:
        """Extraction améliorée des documents Word avec structure"""
        sections = {}
        try:
            doc = Document(file_path)
            current_section = "Introduction"
            sections[current_section] = []
            
            for para in doc.paragraphs:
                text = para.text.strip()
                if not text:
                    continue
                
                if para.style and "Heading" in para.style.name:
                    current_section = text
                    sections[current_section] = []
                else:
                    sections[current_section].append(text)
            
            return {sec: " ".join(content) for sec, content in sections.items() if content}
            
        except Exception as e:
            self.logger.error(f"Erreur Word {file_path}: {str(e)}")
            return {}

    def analyze_themes(self, text: str) -> Dict[str, float]:
        """Analyse les thèmes présents dans un texte"""
        themes_scores = {}
        text_lower = text.lower()
        
        for theme, patterns in self.theme_patterns.items():
            score = 0
            for pattern in patterns:
                if pattern in text_lower:
                    score += text_lower.count(pattern)
            if score > 0:
                themes_scores[theme] = score
                
        # Normalisation des scores
        if themes_scores:
            max_score = max(themes_scores.values())
            themes_scores = {k: v/max_score for k, v in themes_scores.items()}
            
        return themes_scores

    def calculate_similarity(self, text1: str, text2: str) -> float:
        """Calcule la similarité entre deux textes"""
        vectorizer = TfidfVectorizer()
        try:
            tfidf_matrix = vectorizer.fit_transform([text1, text2])
            return cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
        except:
            return 0.0

    def analyze_aap_files(self) -> Dict[str, Any]:
        """Analyse complète des fichiers AAP"""
        # Vérifier la connexion à Mixtral
        try:
            response = requests.get("http://localhost:11434/api/version")
            if response.status_code != 200:
                self.logger.error("Mixtral n'est pas accessible")
                return {}
        except:
            self.logger.error("Impossible de se connecter à Mixtral")
            return {}

        # Recherche de tous les AAPs dans le dossier data
        aap_files = []
        for path in Path(self.data_dir).rglob("*"):
            if path.is_file() and "AAP" in path.name.upper() and path.suffix.lower() in ['.docx', '.pdf', '.xlsx', '.xls']:
                aap_files.append(path)

        if not aap_files:
            self.logger.error(f"Aucun fichier AAP trouvé dans {self.data_dir}")
            return {}

        self.logger.info(f"Analyse de {len(aap_files)} fichiers AAP")

        # Analyse des documents
        analyses = {}
        processing_times = {}
        similarities = defaultdict(dict)
        total_start_time = time.time()

        # Analyse de chaque AAP
        for aap_path in aap_files:
            self.logger.info(f"Analyse de {aap_path.name}")
            start_time = time.time()

            try:
                # Extraction et analyse des sections
                aap_sections = self.extract_text_by_sections(str(aap_path))
                if not aap_sections:
                    continue

                # Analyse des thèmes par section
                section_themes = {}
                section_similarities = {}
                
                for section, content in aap_sections.items():
                    # Analyse thématique
                    section_themes[section] = self.analyze_themes(content)

                # Construction du prompt pour l'analyse détaillée
                prompt = f"""
                Analyse détaillée du document {aap_path.name}.
                
                Sections trouvées : {list(aap_sections.keys())}
                
                Pour chaque thématique, évalue :
                1. La couverture du contenu (✅ complète, ⚠️ partielle, ❌ absente)
                2. La pertinence du contenu
                3. Les éléments manquants ou à améliorer
                
                Thématiques à analyser :
                {list(self.theme_patterns.keys())}
                
                Format de réponse souhaité :
                - ✅ [Thème] : Bien couvert, avec [détails]
                - ⚠️ [Thème] : Partiellement couvert, manque [éléments]
                - ❌ [Thème] : Absent, devrait inclure [suggestions]
                """

                # Analyse avec Mixtral
                analysis_result = self.ask_mixtral(prompt)

                # Calcul du temps et enregistrement des résultats
                processing_time = time.time() - start_time
                
                analyses[aap_path.name] = {
                    "file_path": str(aap_path),
                    "sections": aap_sections,
                    "themes": section_themes,
                    "analysis": analysis_result,
                    "processing_time": processing_time
                }
                
                processing_times[aap_path.name] = processing_time

            except Exception as e:
                self.logger.error(f"Erreur analyse {aap_path.name}: {str(e)}")
                continue

        total_time = time.time() - total_start_time

        # Génération du rapport
        report = self.generate_report(analyses, processing_times, total_time)

        return {
            "analyses": analyses,
            "processing_times": processing_times,
            "total_time": total_time,
            "report": report
        }

    def analyze_common_themes(self, analyses: Dict[str, Dict]) -> Dict[str, Any]:
        """Analyse les thèmes communs et uniques entre les AAP"""
        # Initialisation des dictionnaires pour stocker les thèmes par document
        themes_by_doc = {}
        all_themes = set()
        
        # Collecte des thèmes pour chaque document
        for doc_name, doc_data in analyses.items():
            doc_themes = set()
            for section_themes in doc_data["themes"].values():
                doc_themes.update(section_themes.keys())
            themes_by_doc[doc_name] = doc_themes
            all_themes.update(doc_themes)
        
        # Identification des thèmes communs à tous les documents
        common_themes = set.intersection(*themes_by_doc.values()) if themes_by_doc else set()
        
        # Identification des thèmes uniques par document
        unique_themes = {}
        for doc_name, themes in themes_by_doc.items():
            other_docs_themes = set.union(*[t for n, t in themes_by_doc.items() if n != doc_name]) if len(themes_by_doc) > 1 else set()
            unique_themes[doc_name] = themes - other_docs_themes
        
        return {
            "common_themes": list(common_themes),
            "unique_themes": {k: list(v) for k, v in unique_themes.items()},
            "all_themes": list(all_themes)
        }

    def generate_report(self, analyses: Dict[str, Dict], processing_times: Dict[str, float], total_time: float) -> str:
        """Génération d'un rapport détaillé"""
        report = []
        report.append("📊 ANALYSE DES AAP")
        report.append(f"Date de l'analyse : {datetime.now().isoformat()}")
        report.append(f"Nombre de documents analysés : {len(analyses)}")
        
        # Analyse comparative des thèmes
        theme_comparison = self.analyze_common_themes(analyses)
        
        report.append("\n🔄 ANALYSE COMPARATIVE DES THÈMES")
        report.append("\n📌 Thèmes communs à tous les AAP :")
        if theme_comparison["common_themes"]:
            for theme in theme_comparison["common_themes"]:
                report.append(f"• {theme}")
        else:
            report.append("Aucun thème commun trouvé")
            
        report.append("\n🎯 Thèmes uniques par AAP :")
        for doc_name, unique in theme_comparison["unique_themes"].items():
            report.append(f"\n{doc_name}:")
            if unique:
                for theme in unique:
                    report.append(f"• {theme}")
            else:
                report.append("Aucun thème unique")
        
        # Temps de traitement
        report.append("\n⏱️ TEMPS DE TRAITEMENT")
        report.append(f"Temps total : {total_time:.2f} secondes")
        report.append("\nTemps par document :")
        for doc, time_spent in processing_times.items():
            report.append(f"• {doc}: {time_spent:.2f} secondes")
        
        # Analyse par document
        report.append("\n📑 ANALYSE PAR DOCUMENT")
        
        for doc_name, doc_data in analyses.items():
            report.append(f"\n=== {doc_name} ===")
            report.append(f"Chemin : {doc_data['file_path']}")
            
            # Sections trouvées
            report.append("\nSections trouvées :")
            for section in doc_data["sections"].keys():
                report.append(f"• {section}")
            
            # Analyse thématique
            report.append("\nAnalyse thématique :")
            for section, themes in doc_data["themes"].items():
                report.append(f"\n• Section : {section}")
                for theme, score in themes.items():
                    report.append(f"  - {theme}: {score:.2f}")
            
            # Analyse détaillée de Mixtral
            report.append("\nAnalyse détaillée :")
            report.append(doc_data["analysis"])
        
        return "\n".join(report)

def check_mixtral():
    """Vérifie si Mixtral est accessible"""
    try:
        response = requests.get("http://localhost:11434/api/version")
        return response.status_code == 200
    except:
        return False

def main():
    print("🔄 Vérification de Mixtral...")
    if not check_mixtral():
        print("❌ Erreur: Mixtral n'est pas accessible. Assurez-vous qu'il est lancé sur le port 11434")
        return

    print("🔍 Initialisation de l'analyse...")
    analyzer = AAPAnalyzer("../data")
    
    try:
        results = analyzer.analyze_aap_files()
        
        if results:
            print("\n=== Rapport d'Analyse ===")
            print(results["report"])
            
            # Sauvegarde des résultats
            with open("analyse_aap_complete.json", "w", encoding="utf-8") as f:
                json.dump(results, f, ensure_ascii=False, indent=2)
            
            print("\n💾 Résultats détaillés sauvegardés dans analyse_aap_complete.json")
        else:
            print("\n❌ Aucun résultat d'analyse disponible")
        
    except Exception as e:
        print(f"❌ Erreur lors de l'analyse: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# 🔄 Vérification de Mixtral...
# 🔍 Initialisation de l'analyse...
# 2025-03-11 06:04:05,315 - INFO - Analyse de 31 fichiers AAP
# 2025-03-11 06:04:05,315 - INFO - Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
# 2025-03-11 06:05:33,033 - INFO - Analyse de ESF_P01_AAP01.docx
# 2025-03-11 06:05:33,042 - INFO - Analyse de ESF_P01_AAP02.docx
# 2025-03-11 06:06:44,345 - INFO - Analyse de ESF_P01_AAP03.docx
# 2025-03-11 06:07:58,154 - INFO - Analyse de ESF_P01_AAP04.docx
# 2025-03-11 06:09:00,984 - INFO - Analyse de PU_P01_AAP01.docx
# 2025-03-11 06:12:03,082 - ERROR - Erreur connexion Mixtral: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2025-03-11 06:12:03,083 - INFO - Analyse de PU_P01_AAP02.docx
# 2025-03-11 06:13:16,520 - INFO - Analyse de PU_P01_AAP03.docx
# 2025-03-11 06:16:18,633 - ERROR - Erreur connexion Mixtral: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2025-03-11 06:16:18,634 - INFO - Analyse de Pulse_P01_AAP01.docx
# 2025-03-11 06:17:19,941 - INFO - Analyse de PS_P03_AAP01.docx
# 2025-03-11 06:17:55,279 - INFO - Analyse de dossier_de_candidature_aap_projets_innov_entre_2024.docx
# 2025-03-11 06:18:40,502 - INFO - Analyse de Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
# 2025-03-11 06:18:54,257 - INFO - Analyse de Note cadrage AAP.docx
# 2025-03-11 06:19:22,862 - INFO - Analyse de Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
# 2025-03-11 06:20:13,690 - INFO - Analyse de Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
# 2025-03-11 06:22:41,690 - INFO - Analyse de Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
# 2025-03-11 06:25:37,989 - INFO - Analyse de réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx
# 2025-03-11 06:25:43,578 - INFO - Analyse de SS_P01_AAP01.docx
# 2025-03-11 06:26:28,417 - INFO - Analyse de SS_P01_AAP01T.docx
# 2025-03-11 06:29:15,145 - INFO - Analyse de SS_P02_AAP01E.pdf
# 2025-03-11 06:29:25,980 - INFO - Analyse de SS_P03_AAP01E.pdf
# 2025-03-11 06:31:36,955 - INFO - Analyse de SS_P04_AAP01E.pdf
# 2025-03-11 06:34:39,099 - ERROR - Erreur connexion Mixtral: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2025-03-11 06:34:39,099 - INFO - Analyse de SS_P05_AAP01.docx
# 2025-03-11 06:35:06,101 - INFO - Analyse de SS_P11_AAP01.docx
# 2025-03-11 06:37:36,335 - INFO - Analyse de Wings of the Ocean_Procédure réponse AAP.docx
# 2025-03-11 06:39:22,537 - INFO - Analyse de WOTO_P01_AAP01.pdf
# 2025-03-11 06:41:23,163 - INFO - Analyse de WOTO_P01_AAP02.docx
# 2025-03-11 06:44:25,245 - ERROR - Erreur connexion Mixtral: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2025-03-11 06:44:25,247 - INFO - Analyse de WOTO_P01_AAP03.pdf
# 2025-03-11 06:45:46,602 - INFO - Analyse de WOTO_P02_AAP01E.pdf
# 2025-03-11 06:46:51,383 - INFO - Analyse de WOTO_P02_AAP02E.docx
# 2025-03-11 06:47:21,929 - INFO - Analyse de WOTO_P03_AAP01E.pdf
#
# === Rapport d'Analyse ===
# 📊 ANALYSE DES AAP
# Date de l'analyse : 2025-03-11T06:48:35.675997
# Nombre de documents analysés : 29
#
# 🔄 ANALYSE COMPARATIVE DES THÈMES
#
# 📌 Thèmes communs à tous les AAP :
# Aucun thème commun trouvé
#
# 🎯 Thèmes uniques par AAP :
#
# Guide Pratique Réponse AAP (Groupe SOS).pdf:
# Aucun thème unique
#
# ESF_P01_AAP02.docx:
# Aucun thème unique
#
# ESF_P01_AAP03.docx:
# Aucun thème unique
#
# ESF_P01_AAP04.docx:
# Aucun thème unique
#
# PU_P01_AAP01.docx:
# Aucun thème unique
#
# PU_P01_AAP02.docx:
# Aucun thème unique
#
# PU_P01_AAP03.docx:
# Aucun thème unique
#
# Pulse_P01_AAP01.docx:
# Aucun thème unique
#
# PS_P03_AAP01.docx:
# Aucun thème unique
#
# dossier_de_candidature_aap_projets_innov_entre_2024.docx:
# Aucun thème unique
#
# Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf:
# Aucun thème unique
#
# Note cadrage AAP.docx:
# Aucun thème unique
#
# Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx:
# Aucun thème unique
#
# Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf:
# Aucun thème unique
#
# Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf:
# Aucun thème unique
#
# réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx:
# Aucun thème unique
#
# SS_P01_AAP01.docx:
# Aucun thème unique
#
# SS_P01_AAP01T.docx:
# Aucun thème unique
#
# SS_P03_AAP01E.pdf:
# Aucun thème unique
#
# SS_P04_AAP01E.pdf:
# Aucun thème unique
#
# SS_P05_AAP01.docx:
# Aucun thème unique
#
# SS_P11_AAP01.docx:
# Aucun thème unique
#
# Wings of the Ocean_Procédure réponse AAP.docx:
# Aucun thème unique
#
# WOTO_P01_AAP01.pdf:
# Aucun thème unique
#
# WOTO_P01_AAP02.docx:
# Aucun thème unique
#
# WOTO_P01_AAP03.pdf:
# Aucun thème unique
#
# WOTO_P02_AAP01E.pdf:
# Aucun thème unique
#
# WOTO_P02_AAP02E.docx:
# Aucun thème unique
#
# WOTO_P03_AAP01E.pdf:
# Aucun thème unique
#
# ⏱️ TEMPS DE TRAITEMENT
# Temps total : 2670.36 secondes
#
# Temps par document :
# • Guide Pratique Réponse AAP (Groupe SOS).pdf: 87.72 secondes
# • ESF_P01_AAP02.docx: 71.30 secondes
# • ESF_P01_AAP03.docx: 73.81 secondes
# • ESF_P01_AAP04.docx: 62.83 secondes
# • PU_P01_AAP01.docx: 182.10 secondes
# • PU_P01_AAP02.docx: 73.44 secondes
# • PU_P01_AAP03.docx: 182.11 secondes
# • Pulse_P01_AAP01.docx: 61.31 secondes
# • PS_P03_AAP01.docx: 35.34 secondes
# • dossier_de_candidature_aap_projets_innov_entre_2024.docx: 45.22 secondes
# • Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf: 13.75 secondes
# • Note cadrage AAP.docx: 28.60 secondes
# • Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx: 50.83 secondes
# • Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf: 148.00 secondes
# • Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf: 176.30 secondes
# • réponse_Objectifs et réalisations AAP jeunes pousses 2024-2026 PULSE.xlsx: 5.59 secondes
# • SS_P01_AAP01.docx: 44.84 secondes
# • SS_P01_AAP01T.docx: 166.73 secondes
# • SS_P03_AAP01E.pdf: 130.97 secondes
# • SS_P04_AAP01E.pdf: 182.14 secondes
# • SS_P05_AAP01.docx: 27.00 secondes
# • SS_P11_AAP01.docx: 150.23 secondes
# • Wings of the Ocean_Procédure réponse AAP.docx: 106.20 secondes
# • WOTO_P01_AAP01.pdf: 120.63 secondes
# • WOTO_P01_AAP02.docx: 182.08 secondes
# • WOTO_P01_AAP03.pdf: 81.35 secondes
# • WOTO_P02_AAP01E.pdf: 64.78 secondes
# • WOTO_P02_AAP02E.docx: 30.54 secondes
# • WOTO_P03_AAP01E.pdf: 73.75 secondes
#
# 📑 ANALYSE PAR DOCUMENT
#
# === Guide Pratique Réponse AAP (Groupe SOS).pdf ===
# Chemin : ..\data\Planete_Urgence\Guide Pratique Réponse AAP (Groupe SOS).pdf
#
# Sections trouvées :
# • Introduction
# • MARCHE PUBLIC
# • APPEL D’OFFRE
# • TERRITORIALES
# • INTERCOMMUNALITES
# • TÂCHES
# • SEMAINE 7/8
# • • SIREN  ;
# • FOCUS GENRE
# • CONSEIL
# • (INSEE, 2018).
# • OBJECTIF DE LA REPONSE
# • PERSONNES RESSOURCES
# • (ODD5…)
# • CSESS, 2011)  ;
# • TYPES D’OUTIL
# • X
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 1.00
#   - objectifs: 0.50
#   - methodologie: 0.19
#   - budget: 0.25
#   - evaluation: 0.12
#   - partenariats: 0.31
#   - resultats: 0.12
#   - planning: 0.06
#   - innovation: 0.06
#   - durabilite: 0.12
#   - technique: 0.12
#   - gouvernance: 0.06
#   - communication: 0.06
#
# • Section : MARCHE PUBLIC
#   - introduction: 1.00
#   - objectifs: 1.00
#   - evaluation: 1.00
#   - planning: 1.00
#
# • Section : APPEL D’OFFRE
#   - objectifs: 0.25
#   - methodologie: 0.25
#   - budget: 0.25
#   - evaluation: 0.25
#   - partenariats: 1.00
#   - resultats: 0.25
#   - gouvernance: 0.50
#   - communication: 0.25
#
# • Section : TERRITORIALES
#
# • Section : INTERCOMMUNALITES
#   - objectifs: 0.27
#   - methodologie: 0.09
#   - budget: 1.00
#   - evaluation: 0.09
#   - partenariats: 0.45
#   - resultats: 0.09
#   - planning: 0.18
#   - innovation: 0.18
#   - technique: 0.27
#
# • Section : TÂCHES
#   - introduction: 0.20
#   - objectifs: 1.00
#   - budget: 1.00
#   - evaluation: 0.20
#   - partenariats: 0.60
#
# • Section : SEMAINE 7/8
#   - introduction: 1.00
#   - objectifs: 0.33
#   - social: 0.33
#   - gouvernance: 0.33
#
# • Section : • SIREN  ;
#   - introduction: 1.00
#   - objectifs: 0.29
#   - methodologie: 0.14
#   - partenariats: 0.29
#   - social: 0.71
#   - technique: 0.14
#   - communication: 0.29
#
# • Section : FOCUS GENRE
#   - introduction: 0.14
#   - objectifs: 0.23
#   - methodologie: 0.49
#   - budget: 0.63
#   - evaluation: 1.00
#   - partenariats: 0.43
#   - resultats: 0.63
#   - innovation: 0.06
#   - durabilite: 0.06
#   - social: 0.29
#   - technique: 0.20
#   - gouvernance: 0.14
#   - communication: 0.31
#
# • Section : CONSEIL
#   - objectifs: 0.25
#   - methodologie: 1.00
#   - budget: 0.25
#   - partenariats: 0.75
#   - resultats: 0.25
#   - planning: 0.25
#   - innovation: 0.25
#   - technique: 1.00
#   - gouvernance: 0.25
#
# • Section : (INSEE, 2018).
#   - introduction: 0.07
#   - objectifs: 1.00
#   - methodologie: 0.07
#   - budget: 0.03
#   - evaluation: 0.17
#   - partenariats: 0.10
#   - resultats: 0.40
#   - planning: 0.07
#   - durabilite: 0.03
#   - social: 0.20
#   - technique: 0.03
#
# • Section : OBJECTIF DE LA REPONSE
#   - introduction: 0.60
#   - methodologie: 0.20
#   - evaluation: 0.20
#   - partenariats: 0.60
#   - resultats: 0.20
#   - innovation: 0.20
#   - social: 0.20
#   - technique: 1.00
#
# • Section : PERSONNES RESSOURCES
#   - introduction: 1.00
#   - methodologie: 1.00
#   - resultats: 1.00
#   - social: 1.00
#   - gouvernance: 1.00
#
# • Section : (ODD5…)
#   - introduction: 0.43
#   - objectifs: 0.79
#   - methodologie: 0.50
#   - evaluation: 1.00
#   - partenariats: 0.36
#   - resultats: 0.93
#   - social: 0.86
#   - technique: 0.43
#   - gouvernance: 0.36
#   - communication: 0.57
#
# • Section : CSESS, 2011)  ;
#   - introduction: 0.11
#   - objectifs: 0.16
#   - methodologie: 0.21
#   - evaluation: 0.32
#   - resultats: 1.00
#   - durabilite: 0.05
#   - social: 0.05
#   - technique: 0.11
#
# • Section : TYPES D’OUTIL
#   - evaluation: 1.00
#
# • Section : X
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, présente les objectifs et l'utilité du guide pratique.
#
# ⚠️ Objectifs : Partiellement couverts, car bien que certains objectifs soient abordés (comme l'égalité femmes-hommes), d'autres thèmes importants tels que la méthodologie, le budget et l'évaluation ne sont pas traités dans cette section.
#
# ❌ Méthodologie : Absente, aucune information sur la manière dont le guide pratique doit être utilisé ou appliqué.
#
# ⚠️ Budget : Partiellement couvert, car bien que les coûts soient mentionnés à quelques endroits, il n'y a pas de section spécifique traitant du budget et des considérations financières.
#
# ❌ Évaluation : Absente, aucune information sur la manière d'évaluer l'impact ou les résultats du plan d'action.
#
# ⚠️ Partenariats : Partiellement couverts, car si certaines sections abordent le rôle des partenaires (tels que les intercommunalités), il n'y a pas de section spécifique traitant des partenariats et de leur importance.
#
# ❌ Résultats : Absents, aucune information sur les résultats attendus ou les indicateurs clés de performance.
#
# ⚠️ Planning : Partiellement couvert, car même s'il y a une référence à la semaine 7/8, il n'y a pas d'horizon de temps plus large pour les actions proposées.
#
# ⚠️ Innovation : Partiellement couverte, car bien que certaines sections abordent l'innovation (comme les outils numériques), il n'y a pas de section spécifique traitant de ce sujet et de son importance.
#
# ⚠️ Durabilité : Partiellement couverte, car même s'il y a une référence à la durabilité dans certaines sections (telles que les ODD), il n'y a pas de section spécifique traitant de ce sujet et de son rôle dans le plan d'action.
#
# ⚠️ Social : Partiellement couvert, car certains aspects sociaux sont abordés (comme l'égalité femmes-hommes), mais il n'y a pas de section spécifique traitant des questions sociales et de leur importance dans le plan d'action.
#
# ⚠️ Technique : Partiellement couverte, car certaines sections abordent les aspects techniques (tels que les types d'outils), mais il n'y a pas de section spécifique traitant des compétences et des ressources nécessaires pour mettre en œuvre le plan d'action.
#
# ⚠️ Gouvernance : Partiellement couverte, car même s'il y a une référence à la gouvernance dans certaines sections (telles que les personnes ressources), il n'y a pas de section spécifique traitant de ce sujet et de son importance dans le plan d'action.
#
# ⚠️ Communication : Partiellement couverte, car même s'il y a une référence à la communication dans certaines sections (tels que les focus genre), il n'y a pas de section spécifique traitant de ce sujet et de son rôle dans le plan d'action.
#
# === ESF_P01_AAP02.docx ===
# Chemin : ..\data\Electriciens_sans_Frontieres\Projet01\ESF_P01_AAP02.docx
#
# Sections trouvées :
# • Le projet en synthèse 2 / 3
#
# Analyse thématique :
#
# • Section : Le projet en synthèse 2 / 3
#   - objectifs: 1.00
#   - budget: 0.25
#   - partenariats: 0.50
#   - resultats: 0.25
#   - planning: 0.25
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, avec une présentation claire du contexte et des enjeux du projet.
#
# ⚠️ Objectifs : Partiellement couverts, manque des indicateurs quantitatifs ou spécifiques permettant de mesurer les progrès et l'impact du projet.
#
# ⚠️ Méthodologie : Partiellement couverte, la description est générale mais devrait inclure des détails supplémentaires sur les activités prévues, les responsabilités, les ressources et le calendrier opérationnel.
#
# ❌ Budget : Absent, devrait inclure un aperçu détaillé des coûts prévus, des sources de financement et des mécanismes de gestion financière.
#
# ⚠️ Évaluation : Partiellement couverte, il serait bénéfique d'inclure des critères et des indicateurs spécifiques pour mesurer le succès du projet.
#
# ✅ Partenariats : Bien couverts, avec une liste des partenaires clés et de leurs rôles dans le projet.
#
# ⚠️ Résultats : Partiellement couverts, devrait inclure des objectifs spécifiques et mesurables pour chaque résultat attendu.
#
# ❌ Planning : Absent, devrait inclure un calendrier opérationnel détaillé avec des échéances et des livrables clairs.
#
# ⚠️ Innovation : Partiellement couverte, la description de l'innovation est générale ; il serait utile d'inclure des détails spécifiques sur la manière dont le projet sera novateur.
#
# ✅ Durabilité : Bien couverte, avec une discussion sur les avantages à long terme du projet et sa capacité à se poursuivre après son achèvement.
#
# ✅ Social : Bien couverte, avec une description des bénéfices sociaux prévus pour les communautés ciblées.
#
# ⚠️ Technique : Partiellement couverte, la description de l'approche technique est générale ; il serait utile d'inclure des détails spécifiques sur les méthodes et outils qui seront utilisés.
#
# ⚠️ Gouvernance : Partiellement couverte, la structure de gouvernance est décrite mais devrait inclure plus de détails sur les rôles et responsabilités des parties prenantes.
#
# ✅ Communication : Bien couverte, avec une description des canaux et stratégies prévus pour informer les publics cibles et promouvoir le projet.
#
# === ESF_P01_AAP03.docx ===
# Chemin : ..\data\Electriciens_sans_Frontieres\Projet01\ESF_P01_AAP03.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.50
#   - objectifs: 1.00
#   - budget: 1.00
#   - evaluation: 1.00
#   - partenariats: 0.50
#   - resultats: 1.00
#   - planning: 1.00
#   - durabilite: 0.50
#   - technique: 0.50
#
# Analyse détaillée :
# 📁 Analyse détaillée du document ESF\_P01\_AAP03.docx
#
# Les sections suivantes ont été identifiées dans le document : ['Introduction']
#
# Voici une évaluation des différentes thématiques pour cette section :
#
# - ✅ Introduction ('introduction'): Bien couverte, avec une présentation claire de l'objet du document et son contexte.
# - ❌ Objectifs ('objectifs'): Absente, devrait inclure la description des objectifs visés par le projet.
# - ⚠️ Méthodologie ('methodologie'): Partiellement couverte, il y a une brève description des étapes à suivre, mais des détails supplémentaires sur les méthodes spécifiques et les procédures seraient utiles.
# - ❌ Budget ('budget'): Absent, devrait inclure une estimation des coûts associés au projet.
# - ⚠️ Évaluation ('evaluation'): Partiellement couverte, il y a mention d'une évaluation, mais les critères et la méthodologie ne sont pas spécifiés.
# - ❌ Partenariats ('partenariats'): Absent, devrait inclure une liste des partenaires impliqués dans le projet, s'il y en a.
# - ❌ Résultats ('resultats'): Absent, il devrait y avoir une section distincte présentant les résultats attendus et/ou antérieurs (si applicable).
# - ⚠️ Planification ('planning'): Partiellement couverte, bien qu'il y ait une échéance mentionnée pour la fin du projet, des détails supplémentaires sur les jalons et les délais seraient utiles.
# - ❌ Innovation ('innovation'): Absent, devrait inclure toute information sur les approches ou techniques novatrices utilisées dans le cadre du projet.
# - ⚠️ Durabilité ('durabilite'): Partiellement couverte, il y a une mention de la durabilité, mais des détails supplémentaires sur les impacts environnementaux et sociaux seraient préférables.
# - ❌ Social ('social'): Absent, devrait inclure toute information sur l'impact social du projet.
# - ❌ Technique ('technique'): Absent, devrait inclure des informations sur les aspects techniques du projet.
# - ⚠️ Gouvernance ('gouvernance'): Partiellement couverte, il y a une mention de la gouvernance, mais des détails supplémentaires sur la structure et la gestion du projet seraient utiles.
# - ❌ Communication ('communication'): Absente, devrait inclure un plan de communication pour le projet.
#
# === ESF_P01_AAP04.docx ===
# Chemin : ..\data\Electriciens_sans_Frontieres\Projet01\ESF_P01_AAP04.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - budget: 1.00
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, avec une présentation générale du sujet et de l'objectif global du document.
#
# - ⚠️ Objectifs : Partiellement couverts, manque des détails spécifiques sur les objectifs quantitatifs et qualitatifs du projet.
# - ✅ Méthodologie : Bien couverte, avec une description de la méthode générale pour atteindre les objectifs.
# - ❌ Budget : Absent, devrait inclure un aperçu des coûts prévus et des sources de financement.
# - ⚠️ Évaluation : Partiellement couverte, manque des détails spécifiques sur la façon dont les résultats seront mesurés et évalués.
# - ❌ Partenariats : Absent, devrait inclure une liste des partenaires clés et de leur rôle dans le projet.
# - ⚠️ Résultats : Partiellement couverts, manque des détails spécifiques sur les résultats attendus et les bénéfices prévus.
# - ⚠️ Planning : Partiellement couvert, manque des détails spécifiques sur les échéances et les étapes clés du projet.
# - ⚠️ Innovation : Partiellement couverte, manque des détails spécifiques sur la façon dont le projet est innovant et comment cela sera mis en œuvre.
# - ⚠️ Durabilité : Partiellement couverte, manque des détails spécifiques sur la façon dont le projet sera durable à long terme.
# - ❌ Social : Absent, devrait inclure une description de l'impact social attendu du projet.
# - ⚠️ Technique : Partiellement couverte, manque des détails spécifiques sur les outils et techniques qui seront utilisés dans le cadre du projet.
# - ❌ Gouvernance : Absent, devrait inclure une description de la structure de gouvernance du projet et des rôles et responsabilités des différentes parties prenantes.
# - ⚠️ Communication : Partiellement couverte, manque des détails spécifiques sur la stratégie de communication et les canaux qui seront utilisés pour diffuser les résultats du projet.
#
# === PU_P01_AAP01.docx ===
# Chemin : ..\data\Planete_Urgence\Projet01\PU_P01_AAP01.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - objectifs: 1.00
#   - budget: 0.20
#
# Analyse détaillée :
# Erreur: problème de connexion
#
# === PU_P01_AAP02.docx ===
# Chemin : ..\data\Planete_Urgence\Projet01\PU_P01_AAP02.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.33
#   - objectifs: 1.00
#   - budget: 1.00
#   - planning: 0.33
#   - durabilite: 0.33
#   - gouvernance: 0.33
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, avec une présentation générale du sujet et de l'objectif général du document.
#
# 🔶 Objectifs : Non trouvés dans la section 'Introduction', mais devraient être abordés dans les sections suivantes.
#
# ⚠️ Méthodologie : Partiellement couverte, une brève mention de la méthode est faite, mais des détails supplémentaires sur la manière dont les objectifs seront atteints et évalués seraient utiles.
#
# ❌ Budget : Absent, devrait inclure des informations sur le financement prévu pour le projet.
#
# ⚠️ Évaluation : Partiellement couverte, une brève mention de l'évaluation est faite, mais des détails supplémentaires sur la manière dont les progrès seront mesurés et les résultats évalués seraient utiles.
#
# 🔶 Partenariats : Non trouvés dans la section 'Introduction', mais devraient être abordés dans les sections suivantes.
#
# ❌ Résultats : Absent, car il s'agit d'un document de planification et non de rapport sur les résultats.
#
# ⚠️ Planning : Partiellement couvert, une brève mention du calendrier prévu est faite, mais des détails supplémentaires sur les étapes clés et les dates butoir seraient utiles.
#
# 🔶 Innovation : Non trouvée dans la section 'Introduction', mais devrait être abordée dans le document s'il y a des aspects innovants dans le projet.
#
# ⚠️ Durabilité : Partiellement couverte, une brève mention de la durabilité est faite, mais des détails supplémentaires sur les mesures prévues pour assurer la pérennité du projet seraient utiles.
#
# 🔶 Social : Non trouvé dans la section 'Introduction', mais devrait être abordé s'il y a des aspects sociaux importants dans le projet.
#
# ⚠️ Technique : Partiellement couverte, une brève mention de la technique est faite, mais des détails supplémentaires sur les méthodes et techniques spécifiques à utiliser seraient utiles.
#
# 🔶 Gouvernance : Non trouvée dans la section 'Introduction', mais devrait être abordée s'il y a des aspects de gouvernance importants dans le projet.
#
# 🔶 Communication : Non trouvée dans la section 'Introduction', mais devrait être abordée s'il y a des plans spécifiques pour la communication et l'engagement avec les parties prenantes.
#
# === PU_P01_AAP03.docx ===
# Chemin : ..\data\Planete_Urgence\Projet01\PU_P01_AAP03.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.40
#   - objectifs: 0.53
#   - methodologie: 0.40
#   - budget: 0.47
#   - evaluation: 1.00
#   - partenariats: 0.47
#   - resultats: 0.53
#   - planning: 0.47
#   - durabilite: 0.13
#   - technique: 0.27
#   - gouvernance: 0.20
#   - communication: 0.07
#
# Analyse détaillée :
# Erreur: problème de connexion
#
# === Pulse_P01_AAP01.docx ===
# Chemin : ..\data\Pulse\Projet01\Pulse_P01_AAP01.docx
#
# Sections trouvées :
# • Introduction
# • L’organisme porteur de projet (soumissionnaire principal)
# • 1 INSTRUCTIONS POUR LA RÉDACTION DE LA NOTE SUCCINCTE DE PRÉSENTATION
# • 1.1 Résumé de l’action
# • 1.2 Description de l’action (maximum 2 pages)
# • 1.3.1 Pertinence par rapport aux objectifs/secteurs/thèmes/priorités spécifiques de l’appel à projets
# • 1.3.2 Pertinence par rapport aux besoins et contraintes spécifiques du/des pays, région(s) cible(s) et/ou des secteurs concernés (y compris les synergies avec d’autres initiatives en matière de développement et l’absence de double emploi)
# • 1.3.3 Décrivez et définissez les groupes cibles et les bénéficiaires finaux, leurs besoins et leurs contraintes, et expliquez comment l’action répondra à ces besoins
# • 1.3.4 Éléments spécifiques apportant une valeur ajoutée
# • 1.3 ; Lieu(x)
# • 1.6. Objectif général et objectifs spécifiques (maximum 1 page)
# • 1.7. Pertinence de l'action (maximum 3 pages)
# • 1.8. Description de l'action et de son efficacité (maximum 14 pages)
# • 1.9. Méthodologie (maximum 4 pages)
# • 1.10. Durée et plan d'action pour la mise en œuvre de l'action
# • 1.11. Bénéficiaires (maximum 1,5 page)
# • 1.12. Résultats, activités et suivi-évaluation
# • 1.13. Plan d’action indicatif pour la mise en œuvre de l’action (maximum 4 pages)
# • 1.14. Durabilité (maximum 3 pages)
# • 1.15. Budget De L'action
# • 1.16. Cadre Logique
# • Données financières. Veuillez fournir les informations suivantes, le cas échéant, en vous basant sur les comptes de gestion et le bilan de votre organisation, montants en milliers de EUR (ou autre).
# • DESCRIPTION DU/DES PARTENAIRE(S)
# • DÉCLARATION DE PARTENARIAT
# • DÉCLARATION DU DEMANDEUR
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.50
#   - objectifs: 0.50
#   - partenariats: 1.00
#
# • Section : L’organisme porteur de projet (soumissionnaire principal)
#   - introduction: 0.50
#   - objectifs: 1.00
#
# • Section : 1 INSTRUCTIONS POUR LA RÉDACTION DE LA NOTE SUCCINCTE DE PRÉSENTATION
#   - introduction: 1.00
#   - evaluation: 1.00
#
# • Section : 1.1 Résumé de l’action
#
# • Section : 1.2 Description de l’action (maximum 2 pages)
#   - introduction: 1.00
#   - objectifs: 0.33
#   - partenariats: 0.33
#   - resultats: 0.67
#   - planning: 0.33
#   - durabilite: 0.67
#   - gouvernance: 0.33
#   - communication: 0.33
#
# • Section : 1.3.1 Pertinence par rapport aux objectifs/secteurs/thèmes/priorités spécifiques de l’appel à projets
#   - objectifs: 1.00
#   - resultats: 1.00
#
# • Section : 1.3.2 Pertinence par rapport aux besoins et contraintes spécifiques du/des pays, région(s) cible(s) et/ou des secteurs concernés (y compris les synergies avec d’autres initiatives en matière de développement et l’absence de double emploi)
#   - introduction: 0.33
#   - objectifs: 0.33
#   - evaluation: 1.00
#   - partenariats: 0.67
#   - resultats: 0.33
#   - gouvernance: 0.33
#
# • Section : 1.3.3 Décrivez et définissez les groupes cibles et les bénéficiaires finaux, leurs besoins et leurs contraintes, et expliquez comment l’action répondra à ces besoins
#   - methodologie: 1.00
#   - evaluation: 1.00
#
# • Section : 1.3.4 Éléments spécifiques apportant une valeur ajoutée
#   - introduction: 0.09
#   - objectifs: 0.09
#   - budget: 0.09
#   - evaluation: 0.18
#   - partenariats: 1.00
#   - innovation: 0.09
#   - gouvernance: 0.27
#   - communication: 0.09
#
# • Section : 1.3 ; Lieu(x)
#   - partenariats: 1.00
#
# • Section : 1.6. Objectif général et objectifs spécifiques (maximum 1 page)
#   - objectifs: 1.00
#
# • Section : 1.7. Pertinence de l'action (maximum 3 pages)
#   - introduction: 1.00
#   - objectifs: 0.33
#   - partenariats: 0.33
#
# • Section : 1.8. Description de l'action et de son efficacité (maximum 14 pages)
#   - partenariats: 0.25
#   - resultats: 1.00
#
# • Section : 1.9. Méthodologie (maximum 4 pages)
#   - methodologie: 0.67
#   - evaluation: 1.00
#   - partenariats: 0.67
#   - resultats: 0.33
#   - gouvernance: 0.67
#
# • Section : 1.10. Durée et plan d'action pour la mise en œuvre de l'action
#   - objectifs: 1.00
#   - planning: 1.00
#
# • Section : 1.11. Bénéficiaires (maximum 1,5 page)
#   - methodologie: 1.00
#   - gouvernance: 0.50
#
# • Section : 1.12. Résultats, activités et suivi-évaluation
#   - introduction: 0.12
#   - objectifs: 0.25
#   - budget: 0.25
#   - evaluation: 0.38
#   - partenariats: 0.62
#   - resultats: 0.50
#   - planning: 0.25
#   - technique: 0.12
#   - gouvernance: 1.00
#   - communication: 0.12
#
# • Section : 1.13. Plan d’action indicatif pour la mise en œuvre de l’action (maximum 4 pages)
#   - budget: 0.20
#   - partenariats: 0.40
#   - planning: 1.00
#
# • Section : 1.14. Durabilité (maximum 3 pages)
#   - objectifs: 0.83
#   - methodologie: 0.33
#   - budget: 0.17
#   - evaluation: 1.00
#   - partenariats: 0.33
#   - resultats: 0.33
#   - durabilite: 0.50
#   - social: 0.33
#
# • Section : 1.15. Budget De L'action
#   - objectifs: 0.40
#   - budget: 1.00
#   - planning: 0.60
#
# • Section : 1.16. Cadre Logique
#   - partenariats: 0.17
#   - gouvernance: 1.00
#
# • Section : Données financières. Veuillez fournir les informations suivantes, le cas échéant, en vous basant sur les comptes de gestion et le bilan de votre organisation, montants en milliers de EUR (ou autre).
#   - partenariats: 0.25
#   - planning: 0.25
#   - gouvernance: 1.00
#
# • Section : DESCRIPTION DU/DES PARTENAIRE(S)
#   - partenariats: 0.40
#   - planning: 0.20
#   - gouvernance: 1.00
#
# • Section : DÉCLARATION DE PARTENARIAT
#   - partenariats: 1.00
#   - gouvernance: 0.14
#
# • Section : DÉCLARATION DU DEMANDEUR
#   - budget: 0.20
#   - evaluation: 0.20
#   - partenariats: 1.00
#   - gouvernance: 0.20
#
# Analyse détaillée :
# 🔒 (Intro): Bien couvert, with a clear introduction of the document.
#
# 🔵 (Objectifs): Bien couvert, avec une description détaillée de l'objectif général et des objectifs spécifiques du projet.
#
# 🟠 (Méthodologie): Partiellement couvert, manque des détails spécifiques sur les méthodes d'évaluation et de suivi.
#
# 💰 (Budget): Bien couvert, avec une estimation détaillée des coûts du projet.
#
# 📊 (Évaluation): Partiellement couvert, manque des détails sur les indicateurs spécifiques utilisés pour mesurer le succès du projet.
#
# 🤝 (Partenariats): Bien couvert, avec une description des partenaires et de leur rôle dans le projet.
#
# 📅 (Planning): Bien couvert, avec un plan détaillé pour la mise en œuvre du projet.
#
# 💡 (Innovation): Absent, aucune information sur les aspects innovants du projet n'a été fournie.
#
# ♻️ (Durabilité): Partiellement couvert, manque des détails sur la façon dont le projet sera durable à long terme.
#
# 👥 (Social): Bien couvert, avec une description des groupes cibles et des bénéficiaires finaux.
#
# 🔧 (Technique): Partiellement couvert, manque des détails sur les aspects techniques du projet.
#
# 🏛️ (Gouvernance): Absent, aucune information sur la gouvernance du projet n'a été fournie.
#
# 📣 (Communication): Bien couvert, avec une description de la stratégie de communication du projet.
#
# Conclusion: Dans l'ensemble, le document couvre bien la plupart des thématiques importantes pour un plan de projet. Cependant, il manque des détails sur certaines thématiques clés telles que l'innovation et la gouvernance, qui devraient être inclus dans une version future du document.
#
# === PS_P03_AAP01.docx ===
# Chemin : ..\data\Pulse\Projet03\PS_P03_AAP01.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.05
#   - objectifs: 0.32
#   - methodologie: 0.08
#   - budget: 1.00
#   - evaluation: 0.33
#   - partenariats: 0.36
#   - resultats: 0.22
#   - planning: 0.13
#   - innovation: 0.01
#   - durabilite: 0.11
#   - social: 0.26
#   - technique: 0.08
#   - gouvernance: 0.28
#   - communication: 0.07
#
# Analyse détaillée :
#  Introduction:
#
# 1. Couverture du contenu: ✅
# Le document comprend une introduction claire et concise qui présente le sujet de l'appel à projets.
# 2. Pertinence du contenu: ✅
# L'introduction fournit un contexte utile pour le reste du document, en expliquant le but et les objectifs généraux du projet proposé.
# 3. Éléments manquants ou à améliorer:
# * Il pourrait être utile d'inclure une brève description des principaux défis ou problèmes que le projet cherchera à aborder.
# * Une déclaration claire de la portée et de l'étendue géographique du projet pourrait également aider à clarifier les attentes.
#
# Objectifs:
#
# Étant donné que seule l'introduction a été trouvée dans le document, il n'est pas possible d'évaluer les sections sur les objectifs, la méthodologie, le budget, l'évaluation, les partenariats, les résultats, le planning, l'innovation, la durabilité, le social, le technique, la gouvernance et la communication. Une analyse plus détaillée du document est nécessaire pour évaluer ces thématiques.
#
# === dossier_de_candidature_aap_projets_innov_entre_2024.docx ===
# Chemin : ..\data\Pulse\Projet04\Pulse_P04_APP1\dossier_de_candidature_aap_projets_innov_entre_2024.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.20
#   - objectifs: 0.40
#   - budget: 0.80
#   - evaluation: 1.00
#   - planning: 0.20
#   - social: 0.20
#   - technique: 0.40
#   - gouvernance: 0.40
#
# Analyse détaillée :
# ℹ️ ['introduction'] : Partiellement couvert, manque des informations clés.
#
# 1. La couverture du contenu: ⚠️
# - Le dossier de candidature comprend une section intitulée «Introduction», cependant elle ne fournit pas suffisamment d'informations pour que l'on puisse évaluer pleinement la pertinence et l'ambition du projet proposé.
# 2. La pertinence du contenu: ⚠️
# - Le texte présente brièvement le sujet général du projet, mais il manque une justification claire des raisons pour lesquelles ce projet est innovant, important et mérite d'être financé.
# 3. Les éléments manquants ou à améliorer: ⚠️
# - Le titre et l'objectif principal du projet doivent être explicités.
# - Il faut inclure une brève description du problème auquel le projet entend répondre, ainsi qu'une explication de la manière dont il s'inscrit dans un contexte plus large ou dans des objectifs stratégiques plus vastes (p. ex. les Objectifs de développement durable).
# - Il serait bénéfique d'ajouter une section sur l'approche méthodologique prévue pour atteindre ces objectifs.
#
# Remarque générale : Le document semble être incomplet et pourrait grandement bénéficier de la clarification des points mentionnés ci-dessus dans la section «Introduction». Cela permettrait une meilleure compréhension du projet et aiderait à évaluer sa qualité globale.
#
# === Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf ===
# Chemin : ..\data\Pulse\Projet04\Pulse_P04_APP1\Fiche candidature AAP jeunes pousses 2024-2026 (2).pdf
#
# Sections trouvées :
# • Introduction
# • FICHE CANDIDAT URE
# • 1. STRUCTURE PRESENTANT LE PROJET  :
# • 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
# • 4. PERSONNE EN CHARGE DU DOSSIER  :
# • 5. PRESENTATION DU PROJET  :
# • C. SUBVENTION DEMANDEE
# • EVALUATION DES ACTIONS
#
# Analyse thématique :
#
# • Section : Introduction
#
# • Section : FICHE CANDIDAT URE
#   - social: 1.00
#
# • Section : 1. STRUCTURE PRESENTANT LE PROJET  :
#   - objectifs: 0.50
#   - evaluation: 0.25
#   - resultats: 0.50
#   - planning: 0.25
#   - social: 1.00
#   - gouvernance: 0.25
#
# • Section : 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
#
# • Section : 4. PERSONNE EN CHARGE DU DOSSIER  :
#
# • Section : 5. PRESENTATION DU PROJET  :
#   - introduction: 0.33
#   - objectifs: 1.00
#   - partenariats: 0.67
#   - planning: 0.33
#
# • Section : C. SUBVENTION DEMANDEE
#   - objectifs: 1.00
#   - budget: 1.00
#
# • Section : EVALUATION DES ACTIONS
#   - objectifs: 1.00
#   - evaluation: 0.67
#
# Analyse détaillée :
# 1. Introduction
#
#     * ✅ Couverture du contenu : Bien couverte, présente brièvement l'appel à projets "Jeunes Pousses 2024-2026" et ses objectifs généraux.
#
#     * 👍 Pertinence du contenu : Présentation claire et concise de l'objet de la fiche candidature.
#
#     * :
#
# === Note cadrage AAP.docx ===
# Chemin : ..\data\Pulse\Projet04\Pulse_P04_APP1\Note cadrage AAP.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, avec une présentation claire de l'objet et du contexte du document AAP.
#
# 1. Couverture du contenu : La section d'introduction est complète et présente brièvement les objectifs du document, le contexte dans lequel il s'inscrit, et les attentes à son égard. Elle permet au lecteur de bien comprendre l'objet du document et sa place dans la démarche globale.
# 2. Pertinence du contenu : Le contenu est pertinent et directement lié aux objectifs du document AAP. Il situe le document dans son contexte et fournit des informations utiles pour la compréhension des sections suivantes.
# 3. Éléments manquants ou à améliorer : Cette section ne nécessite pas d'amélioration particulière, si ce n'est de s'assurer que les termes et concepts introduits dans l'introduction soient développés et expliqués dans les sections suivantes.
#
# === Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx ===
# Chemin : ..\data\Pulse\Projet04\Pulse_P04_APP1\Objectifs et réalisations AAP jeunes pousses 2024-2026.xlsx
#
# Sections trouvées :
# • Unnamed: 0
# • Unnamed: 1
# • Unnamed: 2
# • Unnamed: 3
# • Unnamed: 4
# • Unnamed: 5
# • Unnamed: 6
# • Unnamed: 7
# • Unnamed: 8
#
# Analyse thématique :
#
# • Section : Unnamed: 0
#   - gouvernance: 1.00
#
# • Section : Unnamed: 1
#   - objectifs: 1.00
#   - budget: 0.40
#   - evaluation: 0.20
#   - partenariats: 0.40
#   - technique: 0.20
#   - communication: 0.40
#
# • Section : Unnamed: 2
#   - evaluation: 0.50
#   - planning: 1.00
#   - social: 0.33
#   - technique: 0.33
#
# • Section : Unnamed: 3
#   - objectifs: 1.00
#
# • Section : Unnamed: 4
#
# • Section : Unnamed: 5
#   - objectifs: 1.00
#
# • Section : Unnamed: 6
#
# • Section : Unnamed: 7
#   - objectifs: 1.00
#
# • Section : Unnamed: 8
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, présente une introduction claire et concise du document.
#
# ⚠️ Objectifs : Partiellement couverts, les objectifs ne sont pas suffisamment spécifiques ou mesurables.
#
# ❌ Méthodologie : Absente, devrait inclure la méthodologie utilisée pour atteindre les objectifs.
#
# ⚠️ Budget : Partiellement couvert, manque de détails sur l'allocation des fonds et les sources de financement.
#
# ⚠️ Évaluation : Partiellement couverte, manque de critères spécifiques pour évaluer les réalisations.
#
# ✅ Partenariats : Bien couverts, mentionne clairement les partenaires impliqués dans le projet.
#
# ⚠️ Résultats : Partiellement couverts, manque de données concrètes et mesurables pour démontrer les réalisations jusqu'à présent.
#
# ✅ Planning : Bien couvert, présente un calendrier clair des activités prévues.
#
# ⚠️ Innovation : Partiellement couverte, manque de détails sur la manière dont le projet est innovant.
#
# ✅ Durabilité : Bien couverte, mentionne clairement les aspects liés à la durabilité du projet.
#
# ⚠️ Social : Partiellement couvert, manque de détails sur l'impact social attendu du projet.
#
# ⚠️ Technique : Partiellement couverte, manque de détails techniques sur la mise en œuvre du projet.
#
# ⚠️ Gouvernance : Partiellement couverte, manque de détails sur la structure de gouvernance et les responsabilités des différents acteurs.
#
# ✅ Communication : Bien couverte, mentionne clairement les stratégies de communication prévues pour le projet.
#
# === Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf ===
# Chemin : ..\data\Pulse\Projet04\Pulse_P04_PP1\Réponse_dossier_de_candidature_aap_projets_innov_entre_2024.pdf
#
# Sections trouvées :
# • Introduction
# • PULSE
# • 1. PRÉSENTATION DE L’ACTION
# • PULSE.
# • 2. DESCRIPTION DE LA PHASE DE RECRUTEMENT ET DE MOBILISATION DES PUBLICS
# • 3. CONTENU ET ORGANISATION DE L’ACTION
# • UX
# • 4. FIN DE L’ACTION
# • 5. MOYENS DE MISE EN ŒUVRE DE L’ACTION
# • 6 ASPECTS FINANCIERS
# • 7. LETTRE DE DEMANDE DE SUBVENTION
# • L’INFORMEL »
#
# Analyse thématique :
#
# • Section : Introduction
#
# • Section : PULSE
#   - objectifs: 0.10
#   - methodologie: 0.10
#   - evaluation: 1.00
#   - partenariats: 0.40
#   - resultats: 0.10
#   - social: 0.20
#   - technique: 0.40
#   - gouvernance: 0.50
#   - communication: 0.10
#
# • Section : 1. PRÉSENTATION DE L’ACTION
#   - objectifs: 0.38
#   - budget: 0.31
#   - evaluation: 0.31
#   - partenariats: 0.15
#   - resultats: 1.00
#   - innovation: 0.08
#   - durabilite: 0.31
#   - social: 0.77
#   - technique: 0.15
#   - gouvernance: 0.08
#   - communication: 0.15
#
# • Section : PULSE.
#   - objectifs: 0.33
#   - budget: 0.17
#   - evaluation: 0.50
#   - partenariats: 1.00
#   - resultats: 0.33
#   - planning: 0.33
#   - gouvernance: 0.17
#   - communication: 0.33
#
# • Section : 2. DESCRIPTION DE LA PHASE DE RECRUTEMENT ET DE MOBILISATION DES PUBLICS
#   - objectifs: 0.29
#   - evaluation: 0.43
#   - partenariats: 1.00
#   - resultats: 0.57
#   - social: 0.14
#   - technique: 0.43
#   - communication: 0.57
#
# • Section : 3. CONTENU ET ORGANISATION DE L’ACTION
#   - introduction: 0.33
#   - objectifs: 0.67
#   - methodologie: 0.67
#   - evaluation: 1.00
#   - partenariats: 1.00
#   - resultats: 1.00
#   - planning: 0.33
#   - social: 1.00
#   - technique: 0.33
#   - communication: 0.33
#
# • Section : UX
#
# • Section : 4. FIN DE L’ACTION
#   - introduction: 0.14
#   - objectifs: 0.57
#   - evaluation: 1.00
#   - partenariats: 0.71
#   - resultats: 0.29
#   - technique: 0.29
#   - communication: 0.14
#
# • Section : 5. MOYENS DE MISE EN ŒUVRE DE L’ACTION
#   - evaluation: 1.00
#   - partenariats: 0.33
#   - technique: 0.67
#   - gouvernance: 0.67
#
# • Section : 6 ASPECTS FINANCIERS
#   - budget: 1.00
#   - social: 0.50
#
# • Section : 7. LETTRE DE DEMANDE DE SUBVENTION
#
# • Section : L’INFORMEL »
#   - budget: 1.00
#   - social: 1.00
#
# Analyse détaillée :
# 1. Introduction
#
#    ✅ Thématique 'introduction' : Bien couverte, présente clairement le sujet et l'objectif général du projet.
#    ✅ Thématique 'communication' : Bien couverte, mentionne les différents canaux de communication prévus pour atteindre les publics cibles.
#    ⚠️ Thématique 'partenariats' : Partiellement couverte, mentionne des partenaires mais sans donner de détails sur la nature et l'étendue de ces collaborations.
#
# 2. PULSE
#
#    ✅ Thématique 'innovation' : Bien couverte, met en avant l'aspect innovant du projet.
#    ⚠️ Thématique 'gouvernance' : Partiellement couverte, mentionne la gouvernance mais sans donner de détails concrets sur son fonctionnement.
#    ❌ Thématique 'budget' : Absente, aucune information concernant le budget n'est fournie dans cette section.
#
# 3. 1. PRÉSENTATION DE L’ACTION
#
#    ✅ Thématique 'objectifs' : Bien couverte, énonce clairement les objectifs du projet.
#    ✅ Thématique 'méthodologie' : Bien couverte, décrit la méthodologie prévue pour atteindre ces objectifs.
#    ⚠️ Thématique 'communication' : Partiellement couverte, mentionne les outils de communication mais sans préciser le planning ou les publics visés.
#    ⚠️ Thématique 'partenariats' : Partiellement couverte, liste des partenaires mais pas d'informations sur leurs rôles et responsabilités.
#
# 4. PULSE.
#
#    (Cette section semble être une répétition de la précédente et ne contient rien de nouveau par rapport à ce qui a déjà été analysé.)
#
# 5. 2. DESCRIPTION DE LA PHASE DE RECRUTEMENT ET DE MOBILISATION DES PUBLICS
#
#    ✅ Thématique 'publics' : Bien couverte, décrit clairement les publics ciblés et leur implication dans le projet.
#    ⚠️ Thématique 'communication' : Partiellement couverte, mentionne la communication mais sans donner de détails sur le planning ou les canaux utilisés.
#    ⚠️ Thématique 'partenariats' : Partiellement couverte, évoque des partenaires pour le recrutement mais pas d'informations sur leurs rôles et responsabilités.
#
# 6. 3. CONTENU ET ORGANISATION DE L’ACTION
#
#    ✅ Thématique 'contenu' : Bien couverte, décrit clairement les activités prévues dans le cadre du projet.
#    ⚠️ Thématique 'méthodologie' : Partiellement couverte, présente la méthodologie mais sans donner de détails concrets sur son application.
#    ⚠️ Thématique 'partenariats' : Partiellement couverte, mentionne des partenaires pour l'organisation mais sans préciser leur rôle et responsabilité.
#
# 7. UX
#
#    (Cette section semble hors sujet et ne contient rien de pertinent par rapport aux thématiques demandées.)
#
# 8. 4. FIN DE L’ACTION
#
#    ⚠️ Thématique 'résultats' : Partiellement couverte, mentionne des résultats attendus mais sans fournir d'indicateurs concrets pour mesurer ces résultats.
#    ❌ Thématique 'évaluation' : Absente, aucune information sur la manière dont le projet sera évalué ou suivi n'est fournie.
#
# 9. 5. MOYENS DE MISE EN ŒUVRE DE L’ACTION
#
#    ✅ Thématique 'budget' : Bien couverte, présente un budget détaillé pour le projet.
#    ⚠️ Thématique 'partenariats' : Partiellement couverte, mentionne des partenaires mais sans préciser leur contribution financière ou matérielle.
#
# 10. 6 ASPECTS FINANCIERS
#
#    ✅ Thématique 'budget' : Bien couverte, présente un budget détaillé pour le projet.
#     ⚠️ Thématique 'durabilité' : Partiellement couverte, aborde la durabilité financière mais sans donner de détails concrets sur sa mise en œuvre.
#
# 11. 7. LETTRE DE DEMANDE DE SUBVENTION
#
#    ❌ Thématique 'budget' : Absente, aucune lettre de demande de subvention n'est incluse dans le document analysé.
#     ⚠️ Thématique 'gouvernance' : Partiellement couverte, mentionne la gouvernance mais sans donner de détails sur les responsabilités financières ou décisionnelles.
#
# 12. L’INFORMEL »
#
#    (Cette dernière section semble être un ajout superflu et ne contient rien de pertinent par rapport aux thématiques demandées.)
#
# === Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf ===
# Chemin : ..\data\Pulse\Projet04\Pulse_P04_PP1\Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf
#
# Sections trouvées :
# • Introduction
# • FICHE CANDIDAT URE
# • 1. STRUCTURE PRESENTANT LE PROJET  :
# • 2. INTITULE DU PROJET  :
# • 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
# • 4. PERSONNE EN CHARGE DU DOSSIER  :
# • 5. PRESENTATION DU PROJET  :
# • 3/ SUIVI ET VALORISATION
# • C. SUBVENTION DEMANDEE
# • EVALUATION DES ACTIONS
#
# Analyse thématique :
#
# • Section : Introduction
#
# • Section : FICHE CANDIDAT URE
#   - social: 1.00
#
# • Section : 1. STRUCTURE PRESENTANT LE PROJET  :
#   - objectifs: 0.50
#   - evaluation: 0.25
#   - resultats: 0.50
#   - planning: 0.25
#   - social: 1.00
#   - gouvernance: 0.25
#
# • Section : 2. INTITULE DU PROJET  :
#
# • Section : 3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :
#
# • Section : 4. PERSONNE EN CHARGE DU DOSSIER  :
#
# • Section : 5. PRESENTATION DU PROJET  :
#   - introduction: 0.15
#   - objectifs: 0.69
#   - methodologie: 0.15
#   - budget: 0.23
#   - evaluation: 0.23
#   - partenariats: 1.00
#   - resultats: 1.00
#   - planning: 0.08
#   - innovation: 0.23
#   - durabilite: 0.31
#   - social: 0.85
#   - technique: 0.62
#   - gouvernance: 0.08
#
# • Section : 3/ SUIVI ET VALORISATION
#   - introduction: 0.04
#   - objectifs: 0.22
#   - methodologie: 0.02
#   - budget: 0.07
#   - evaluation: 0.28
#   - partenariats: 1.00
#   - resultats: 0.20
#   - planning: 0.09
#   - innovation: 0.02
#   - durabilite: 0.02
#   - social: 0.09
#   - technique: 0.17
#   - gouvernance: 0.20
#   - communication: 0.39
#
# • Section : C. SUBVENTION DEMANDEE
#   - objectifs: 1.00
#   - budget: 1.00
#
# • Section : EVALUATION DES ACTIONS
#   - objectifs: 1.00
#   - evaluation: 0.67
#
# Analyse détaillée :
# ierfichecandidature AAP jeunes pousses 2024-2026 (1) analysis
# ==============================================================
#
# Après une analyse approfondie du document Réponse_Fiche candidature AAP jeunes pousses 2024-2026 (1).pdf, voici les résultats pour chaque thème et section concernant la couverture du contenu, sa pertinence et les éléments manquants ou à améliorer :
#
# Sections trouvées : ['Introduction', 'FICHE CANDIDAT URE', '1. STRUCTURE PRESENTANT LE PROJET  :', '2. INTITULE DU PROJET  :', '3. MODULE(S) DE L’APPEL A PROJETS VISE(S)  :', '4. PERSONNE EN CHARGE DU DOSSIER  :', '5. PRESENTATION DU PROJET  :', '3/ SUIVI ET VALORISATION', 'C. SUBVENTION DEMANDEE', 'EVALUATION DES ACTIONS']
#
# Thématiques à analyser : ['introduction', 'objectifs', 'methodologie', 'budget', 'evaluation', 'partenariats', 'resultats', 'planning', 'innovation', 'durabilite', 'social', 'technique', 'gouvernance', 'communication']
#
# Introduction
# ------------
#
# * ✅ Introduction : Bien couverte, présente le sujet et les objectifs de l'AAP.
# * ✅ Pertinence : Correspond bien au contexte et suscite l'intérêt du lecteur.
# * ❌ Éléments manquants ou à améliorer : Aucun, car il s'agit d'une brève introduction.
#
# FICHE CANDIDAT URE
# ------------------
#
# * ⚠️ Objectifs : Partiellement couverts, les objectifs spécifiques du candidat ne sont pas clairement énoncés.
# * ✅ Pertinence : Adéquat pour fournir des informations sur le candidat.
# * ❌ Éléments manquants ou à améliorer : Inclure des objectifs spécifiques et mesurables du candidat.
#
# 1. STRUCTURE PRESENTANT LE PROJET :
# ------------------------------------
#
# * ✅ Couverture du contenu : Bien couverte, présente l'organisation et les membres de l'équipe.
# * ✅ Pertinence : Important pour démontrer l'expérience et la capacité du candidat à mener le projet.
# * ❌ Éléments manquants ou à améliorer : Aucun, car il fournit les informations nécessaires sur l'équipe.
#
# 2. INTITULE DU PROJET :
# ----------------------
#
# * ✅ Couverture du contenu : Absente, car c'est un simple titre et non une section à part entière.
# * ✅ Pertinence : Important pour identifier le projet.
# * ❌ Éléments manquants ou à améliorer : Aucun, car il s'agit d'une information fournie dans l'en-tête du document.
#
# 3. MODULE(S) DE L’APPEL A PROJETS VISE(S) :
# ------------------------------------------
#
# * ✅ Couverture du contenu : Bien couverte, spécifie les modules de l'AAP visés par le candidat.
# * ✅ Pertinence : Essentiel pour comprendre l'adéquation entre le projet et les objectifs de l'AAP.
# * ❌ Éléments manquants ou à améliorer : Aucun, car il fournit l'information nécessaire sur les modules ciblés.
#
# 4. PERSONNE EN CHARGE DU DOSSIER :
# ----------------------------------
#
# * ✅ Couverture du contenu : Bien couverte, présente la personne responsable du dossier de candidature.
# ...
#
# ⚠️ Évaluation : Partiellement couverte, la section « PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT » évoque brièvement l'évaluation des résultats du projet, mais ne fournit pas de détails sur les indicateurs ou les méthodes d'évaluation. Il devrait inclure une description claire et précise des critères d'évaluation et des outils ou techniques prévus pour mesurer les progrès accomplis.
#
# ❌ Partenariats : Absents, la section « INFORMATIONS SUR LE PORTEUR DE PROJET » ne mentionne pas les partenaires potentiels ou existants du projet. Il devrait inclure une liste des organisations ou des individus qui soutiennent le projet et décrire leur rôle et leurs contributions.
#
# ⚠️ Résultats : Partiellement couverts, la section « PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT » mentionne brièvement les résultats attendus du projet, mais ne fournit pas de détails sur les bénéfices concrets pour le public cible ou l'impact escompté. Il devrait inclure des chiffres ou des estimations pour évaluer l'ampleur et la portée du projet.
#
# ⚠️ Planning : Partiellement couvert, la section « PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT » décrit brièvement le calendrier prévu pour le projet, mais ne fournit pas de détails sur les étapes clés ou les dates butoir. Il devrait inclure un diagramme de Gantt ou un autre outil de planification pour visualiser les tâches et les échéances du projet.
#
# ⚠️ Innovation : Partiellement couverte, la section « PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT » mentionne brièvement l'aspect innovant du projet, mais ne fournit pas de détails sur ce qui le rend unique ou différent des projets existants. Il devrait inclure une description plus détaillée et argumentée de la manière dont le projet se distingue des autres initiatives similaires.
#
# ⚠️ Durabilité : Partiellement couverte, la section « PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT » évoque brièvement l'aspect durable du projet, mais ne fournit pas de détails sur les stratégies ou les mesures prévues pour assurer sa pérennité. Il devrait inclure une description plus détaillée des moyens par lesquels le projet s'inscrit dans une perspective de long terme et contribue à un changement durable.
#
# ⚠️ Social : Partiellement couverte, la section « PRÉSENTATION DU PROJET : OBJET DE LA DEMANDE DE FINANCEMENT » mentionne brièvement les bénéfices sociaux du projet, mais ne fournit pas de détails sur les groupes cibles ou les parties prenantes concernées. Il devrait inclure une description plus précise des publics visés et des avantages prévus pour
#
# === WOTO_P01_AAP02.docx ===
# Chemin : ..\data\Wings_of_Ocean\Projet01\WOTO_P01_AAP02.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.20
#   - objectifs: 0.60
#   - budget: 1.00
#   - partenariats: 0.60
#   - resultats: 0.40
#   - durabilite: 0.40
#   - social: 0.20
#   - communication: 0.40
#
# Analyse détaillée :
# Erreur: problème de connexion
#
# === WOTO_P01_AAP03.pdf ===
# Chemin : ..\data\Wings_of_Ocean\Projet01\WOTO_P01_AAP03.pdf
#
# Sections trouvées :
# • POUR LA PLANÈTE
# • APPEL A PROJET POUR LA PLANÈTE
# • JUSQU'AU 07 AVRIL
# • OMENT D’ÉCHANGES
# • RENCONTRES POUR LA PLANÈTE
# • SOUTIENS PLURI-ANNUELS
# • MARDIS POUR LA
# • SONT ÉLIGIBLES :
# • NE SONT PAS ÉLIGIBLES :
# • CRITÈRES D’ÉLIGIBILITÉ DES PROJETS
# • SOCIALE
# • DEMANDE DE FINANCEMENTCOMBIEN PEUT-ON DEMANDER DE FINANCER ?
# • D'OÙ VIENNENT LES FINANCEMENTS ?
# • ET DES ANNEXES EST LE 07 AVRIL 2024 À MINUIT.
# • DES DOSSIERSVÉRIFICATION DE L’ÉLIGIBILITÉ
# • DÉCISION DE SÉLECTION
# • SUIVI DE L’UTILISATION
# • À PROJET
# • DÉCISION
# • AUX RENCONTRES POUR LA PLANÈTE
# • VIDÉO DE PRÉSENTATION
# • CAMPAGNE DE CROWDFUNDING
# • FORMATION PITCH
# • CONVENTION
# • RAPPORT D’UTILISATION DES DONS
# • DÉBUT ACCOMPAGNEMENT
# • RIB
# • ANNEXES THÉMATIQUESDESCRIPTION DES THÉMATIQUES
# • ET JUSTICE SOCIALE
#
# Analyse thématique :
#
# • Section : POUR LA PLANÈTE
#
# • Section : APPEL A PROJET POUR LA PLANÈTE
#
# • Section : JUSQU'AU 07 AVRIL
#
# • Section : OMENT D’ÉCHANGES
#   - objectifs: 0.25
#   - budget: 0.50
#   - evaluation: 1.00
#   - partenariats: 0.50
#   - durabilite: 0.25
#   - social: 0.25
#   - gouvernance: 0.75
#
# • Section : RENCONTRES POUR LA PLANÈTE
#
# • Section : SOUTIENS PLURI-ANNUELS
#   - introduction: 0.50
#   - planning: 1.00
#   - durabilite: 0.50
#   - gouvernance: 0.50
#
# • Section : MARDIS POUR LA
#   - objectifs: 0.50
#   - durabilite: 1.00
#   - gouvernance: 0.50
#
# • Section : SONT ÉLIGIBLES :
#
# • Section : NE SONT PAS ÉLIGIBLES :
#   - objectifs: 1.00
#
# • Section : CRITÈRES D’ÉLIGIBILITÉ DES PROJETS
#   - introduction: 0.17
#   - objectifs: 0.50
#   - budget: 0.33
#   - resultats: 0.33
#   - durabilite: 0.17
#   - gouvernance: 1.00
#
# • Section : SOCIALE
#
# • Section : DEMANDE DE FINANCEMENTCOMBIEN PEUT-ON DEMANDER DE FINANCER ?
#   - introduction: 0.20
#   - budget: 1.00
#   - gouvernance: 0.20
#   - communication: 0.20
#
# • Section : D'OÙ VIENNENT LES FINANCEMENTS ?
#   - budget: 1.00
#   - planning: 1.00
#   - durabilite: 1.00
#
# • Section : ET DES ANNEXES EST LE 07 AVRIL 2024 À MINUIT.
#   - budget: 0.50
#   - gouvernance: 1.00
#
# • Section : DES DOSSIERSVÉRIFICATION DE L’ÉLIGIBILITÉ
#   - evaluation: 1.00
#   - partenariats: 0.50
#   - resultats: 0.50
#   - durabilite: 0.50
#
# • Section : DÉCISION DE SÉLECTION
#   - evaluation: 1.00
#
# • Section : SUIVI DE L’UTILISATION
#   - gouvernance: 1.00
#
# • Section : À PROJET
#   - resultats: 1.00
#   - gouvernance: 1.00
#
# • Section : DÉCISION
#
# • Section : AUX RENCONTRES POUR LA PLANÈTE
#   - objectifs: 1.00
#
# • Section : VIDÉO DE PRÉSENTATION
#   - introduction: 0.50
#   - objectifs: 1.00
#   - planning: 0.50
#
# • Section : CAMPAGNE DE CROWDFUNDING
#
# • Section : FORMATION PITCH
#
# • Section : CONVENTION
#
# • Section : RAPPORT D’UTILISATION DES DONS
#   - gouvernance: 1.00
#
# • Section : DÉBUT ACCOMPAGNEMENT
#
# • Section : RIB
#   - introduction: 0.67
#   - evaluation: 0.33
#   - resultats: 0.33
#   - gouvernance: 1.00
#
# • Section : ANNEXES THÉMATIQUESDESCRIPTION DES THÉMATIQUES
#   - durabilite: 1.00
#   - technique: 1.00
#
# • Section : ET JUSTICE SOCIALE
#
# Analyse détaillée :
# 📄 'WOTO\_P01\_AAP03.pdf' Analysis
#
# I. Introduction
#
# * ✅ 'introduction': The document starts with a clear and concise introduction to the "Appel à Projet pour la Planète" (Call for Projects for the Planet).
#
# II. Objectifs
#
# * ⚠️ 'objectifs' : While the general objective is stated in the first section, specific goals could be more clearly defined throughout the document.
#
# III. Méthodologie
#
# * ❌ 'methodologie': The methodology of the call for projects is not directly addressed in this document. It would be helpful to include guidelines on how applications will be reviewed and evaluated.
#
# IV. Budget
#
# * ⚠️ 'budget' : Although there is mention of financing, a specific section dedicated to outlining budget expectations and considerations is absent.
#
# V. Évaluation
#
# * ⚠️ 'evaluation': While criteria for eligibility and selection are mentioned, an explicit description of the evaluation process would be beneficial.
#
# VI. Partenariats
#
# * ❌ 'partenariats': The document does not mention partnerships or collaborations between projects. Consider adding guidelines on forming strategic alliances.
#
# VII. Résultats
#
# * ⚠️ 'resultats' : Expected outcomes and results are not explicitly stated in the document, but the focus is more on eligibility and application steps.
#
# VIII. Planning
#
# * ⚠️ 'planning': The timeline for the call for projects is provided, but a more detailed planning of each stage would be helpful.
#
# IX. Innovation
#
# * ✅ 'innovation' : Encouragement for innovative projects can be found throughout the document, particularly in the "SOUTIENS PLURI-ANNUELS" and "INNOVATION" sections.
#
# X. Durabilité
#
# * ✅ 'durabilite': The entire document emphasizes sustainability and eco-friendly projects, making this theme well covered.
#
# XI. Social
#
# * ✅ 'social' : The social aspect is a significant part of the call for projects, with several sections detailing the importance of societal benefits.
#
# XII. Technique
#
# * ❌ 'technique': This document does not explicitly address the technical aspects or requirements for submitted projects.
#
# XIII. Gouvernance
#
# * ⚠️ 'gouvernance' : The governance theme is partially covered, with some mention of eligibility and responsibility regarding funds use. More in-depth coverage would be beneficial.
#
# XIV. Communication
#
# * ✅ 'communication': The document includes a section on communication, emphasizing the importance of project presentation, crowdfunding campaigns, and social media presence.
#
# Global Evaluation:
# This document is mostly focused on eligibility criteria, application process, and timeline for the "Appel à Projet pour la Planète". Although there are some gaps in addressing specific themes such as methodology, budget, partnerships, and governance, it does well in conveying the general objectives and expectations for projects that align with sustainability and social responsibility.
#
# === WOTO_P02_AAP01E.pdf ===
# Chemin : ..\data\Wings_of_Ocean\Projet02\WOTO_P02_AAP01E.pdf
#
# Sections trouvées :
# • Introduction
# • FONDATION D’ENTREPRSE
# • 6 BUDGET PREVISIONNEL DU PROJET  11
#
# Analyse thématique :
#
# • Section : Introduction
#
# • Section : FONDATION D’ENTREPRSE
#
# • Section : 6 BUDGET PREVISIONNEL DU PROJET  11
#   - introduction: 0.17
#   - objectifs: 1.00
#   - budget: 0.63
#   - evaluation: 0.07
#   - partenariats: 0.47
#   - resultats: 0.03
#   - planning: 0.10
#   - innovation: 0.03
#   - durabilite: 0.07
#   - social: 0.10
#   - technique: 0.07
#   - communication: 0.23
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, présente les objectifs de l'entreprise et fournit un aperçu du contenu du document.
#
# ⚠️ Objectifs : Partiellement couverts, les objectifs spécifiques du projet ne sont pas clairement définis.
#
# ⚠️ Méthodologie : Partiellement couverte, la méthodologie utilisée pour atteindre les objectifs n'est que brièvement abordée.
#
# ✅ Budget : Bien couvert, un budget détaillé est fourni dans la section "6 BUDGET PREVISIONNEL DU PROJET".
#
# ⚠️ Évaluation : Partiellement couverte, il n'y a pas de preuve claire d'une évaluation des risques ou des bénéfices potentiels du projet.
#
# ❌ Partenariats : Absents, aucun partenariat n'est mentionné dans le document.
#
# ⚠️ Résultats : Partiellement couverts, les résultats attendus ne sont pas clairement définis, mais il y a une section sur les "résultats" dans la méthodologie.
#
# ❌ Planning : Absent, aucune information sur le calendrier ou l'échéancier du projet n'est fournie.
#
# ⚠️ Innovation : Partiellement couverte, il y a une brève mention de l'innovation dans la méthodologie, mais aucun détail spécifique n'est donné.
#
# ⚠️ Durabilité : Partiellement couverte, la durabilité est abordée brièvement dans la méthodologie, mais aucune mesure spécifique n'est proposée.
#
# ⚠️ Social : Partiellement couvert, il y a une brève mention des impacts sociaux dans la méthodologie, mais aucun détail spécifique n'est donné.
#
# ✅ Technique : Bien couverte, la section "FONDATION D’ENTREPRSE" fournit des informations techniques sur l'entreprise.
#
# ⚠️ Gouvernance : Partiellement couverte, il y a une brève mention de la gouvernance dans la méthodologie, mais aucun détail spécifique n'est donné.
#
# ❌ Communication : Absente, aucune information sur la communication ou l'engagement avec les parties prenantes n'est fournie.
#
# === WOTO_P02_AAP02E.docx ===
# Chemin : ..\data\Wings_of_Ocean\Projet02\WOTO_P02_AAP02E.docx
#
# Sections trouvées :
# • Introduction
#
# Analyse thématique :
#
# • Section : Introduction
#   - introduction: 0.03
#   - objectifs: 1.00
#   - budget: 0.04
#   - evaluation: 0.19
#   - partenariats: 0.16
#   - resultats: 0.27
#   - planning: 0.11
#   - innovation: 0.03
#   - durabilite: 0.09
#   - social: 0.06
#   - technique: 0.01
#   - gouvernance: 0.06
#
# Analyse détaillée :
# 🌍 Introduction 🔎:
#
# 1. Couverture du contenu ✅: La section d'introduction est présente et offre un aperçu général du sujet abordé dans le document WOTO\_P02\_AAP02E.
# 2. Pertinence du contenu ✅: L'introduction définit clairement l'objet du document, ce qui permet aux lecteurs de bien comprendre les problèmes traités et d'être intéressés pour continuer la lecture.
# 3. Éléments manquants ou à améliorer ❌: Bien que la couverture et la pertinence soient satisfaisantes, il serait utile de mentionner brièvement les objectifs du document dans l'introduction. Cela donnerait une meilleure idée des résultats attendus et inciterait le lecteur à poursuivre sa lecture pour découvrir comment ces objectifs sont abordés dans les autres sections.
#
# En conséquence, la notation serait:
# - ✅ Introduction : Bien couvert (mais améliorable en ajoutant une brève mention des objectifs du document).
#
# === WOTO_P03_AAP01E.pdf ===
# Chemin : ..\data\Wings_of_Ocean\Projet03\WOTO_P03_AAP01E.pdf
#
# Sections trouvées :
# • Introduction
# • MODALITÉS
# • PRÉSENTATION DE VOTRE ORGANISME
# • PRESENT ATION ET OBJECTIFS
# • VOS BESOINS
# • VOS IMPACTS
# • VOTRE PROJET & NOUS
#
# Analyse thématique :
#
# • Section : Introduction
#
# • Section : MODALITÉS
#   - objectifs: 0.33
#   - budget: 1.00
#   - planning: 0.67
#
# • Section : PRÉSENTATION DE VOTRE ORGANISME
#   - introduction: 1.00
#   - objectifs: 1.00
#   - budget: 1.00
#   - partenariats: 1.00
#   - technique: 1.00
#
# • Section : PRESENT ATION ET OBJECTIFS
#   - budget: 1.00
#   - partenariats: 1.00
#   - innovation: 0.50
#   - durabilite: 0.50
#   - social: 0.50
#
# • Section : VOS BESOINS
#   - objectifs: 0.50
#   - budget: 1.00
#   - communication: 0.12
#
# • Section : VOS IMPACTS
#   - objectifs: 0.25
#   - evaluation: 1.00
#   - resultats: 0.75
#   - durabilite: 0.25
#
# • Section : VOTRE PROJET & NOUS
#   - objectifs: 0.17
#   - budget: 1.00
#   - evaluation: 0.17
#   - partenariats: 0.17
#   - resultats: 0.17
#   - technique: 0.17
#   - gouvernance: 0.17
#   - communication: 0.33
#
# Analyse détaillée :
# ✅ Introduction : Bien couverte, la section d'introduction présente clairement l'objet du document et situe le contexte du projet.
#
# ⚠️ Objectifs : Partiellement couverts, les objectifs généraux sont abordés mais il manque des objectifs spécifiques et mesurables pour chaque activité ou résultat attendu.
#
# ❌ Méthodologie : Absente, aucune information n'est donnée sur la méthodologie qui sera utilisée pour mener à bien le projet.
#
# ⚠️ Budget : Partiellement couvert, une estimation globale du budget est fournie mais il manque des détails sur la répartition des coûts et les sources de financement prévues.
#
# ⚠️ Évaluation : Partiellement couverte, la section mentionne brièvement l'évaluation mais sans fournir de détails sur les critères d'évaluation ou les méthodes qui seront utilisées pour mesurer les résultats.
#
# ⚠️ Partenariats : Partiellement couverts, la section mentionne les partenaires impliqués dans le projet mais sans préciser leur rôle spécifique et leur contribution.
#
# ⚠️ Résultats : Partiellement couverts, les résultats attendus sont évoqués de manière générale mais il manque des indicateurs spécifiques pour mesurer les progrès réalisés.
#
# ❌ Planning : Absent, aucune information n'est donnée sur le calendrier prévu pour la réalisation du projet.
#
# ⚠️ Innovation : Partiellement couverte, la section mentionne brièvement l'innovation mais sans fournir de détails concrets sur les nouveautés apportées par le projet.
#
# ✅ Durabilité : Bien couverte, la section présente clairement les aspects environnementaux et sociaux du projet et leur intégration dans la durée.
#
# ⚠️ Social : Partiellement couvert, les bénéfices sociaux attendus sont mentionnés mais il manque des détails sur les publics ciblés et les impacts prévus sur ces publics.
#
# ✅ Technique : Bien couverte, la section décrit clairement les aspects techniques du projet et les compétences nécessaires pour sa réalisation.
#
# ⚠️ Gouvernance : Partiellement couverte, la section mentionne brièvement la gouvernance mais sans fournir de détails sur les rôles et responsabilités des différents acteurs impliqués dans le projet.
#
# ✅ Communication : Bien couverte, la section présente clairement les modalités de communication prévues pour assurer la visibilité du projet et favoriser son appropriation par les publics cibles.
#
# 💾 Résultats détaillés sauvegardés dans analyse_aap_complete.json

# %% [markdown]
# ### Based on Guide pratique

# %%
import requests
import json
from pathlib import Path
import os
from typing import Dict, List, Any, Set, Tuple
from docx import Document
import PyPDF2
import pandas as pd
from collections import Counter, defaultdict
import openpyxl
import logging
from difflib import SequenceMatcher
import numpy as np
from datetime import datetime
import time
import sys
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

OLLAMA_HOST = "http://localhost:11434/api/generate"

class AAPAnalyzer:
    def __init__(self, data_dir: str):
        self.data_dir = data_dir
        self.setup_logging()
        self.theme_patterns = {
            "introduction": ["introduction", "contexte", "présentation", "préambule", "avant-propos"],
            "objectifs": ["objectif", "but", "finalité", "mission", "ambition", "vision"],
            "methodologie": ["méthode", "méthodologie", "approche", "démarche", "processus", "protocole"],
            "budget": ["budget", "financement", "coût", "investissement", "dépense", "ressource financière"],
            "evaluation": ["évaluation", "suivi", "indicateur", "mesure", "performance", "critère"],
            "partenariats": ["partenaire", "collaboration", "coopération", "alliance", "réseau", "acteur"],
            "resultats": ["résultat", "impact", "effet", "retombée", "bénéfice", "conséquence"],
            "planning": ["planning", "calendrier", "échéancier", "temporalité", "délai", "durée"],
            "innovation": ["innovation", "nouveauté", "créativité", "originalité", "invention"],
            "durabilite": ["durabilité", "environnement", "écologie", "développement durable"],
            "social": ["social", "sociétal", "inclusion", "accessibilité", "solidarité"],
            "technique": ["technique", "technologie", "outil", "équipement", "infrastructure"],
            "gouvernance": ["gouvernance", "pilotage", "gestion", "organisation", "coordination"],
            "communication": ["communication", "diffusion", "valorisation", "promotion"]
        }
        
        self.reference_sections = {
            "resume": ["résumé", "synthèse", "abstract"],
            "introduction": ["introduction", "contexte", "présentation"],
            "objectifs": ["objectifs", "buts", "finalités"],
            "description_projet": ["description", "présentation détaillée", "contenu"],
            "methodologie": ["méthodologie", "méthode", "approche"],
            "moyens": ["moyens", "ressources", "équipements"],
            "budget": ["budget", "financement", "coûts"],
            "planning": ["planning", "calendrier", "échéancier"],
            "equipe": ["équipe", "personnel", "ressources humaines"],
            "partenaires": ["partenaires", "partenariats", "collaborations"],
            "innovation": ["innovation", "originalité", "nouveauté"],
            "impact": ["impact", "retombées", "effets"],
            "evaluation": ["évaluation", "suivi", "indicateurs"],
            "perennisation": ["pérennisation", "durabilité", "suite"],
            "communication": ["communication", "diffusion", "valorisation"],
            "annexes": ["annexes", "pièces jointes", "documents complémentaires"]
        }

        self.section_requirements = {
            "resume": ["synthèse claire", "objectifs principaux", "résultats attendus"],
            "introduction": ["contexte", "problématique", "enjeux"],
            "objectifs": ["objectifs généraux", "objectifs spécifiques", "résultats attendus"],
            "description_projet": ["description détaillée", "public cible", "territoire"],
            "methodologie": ["approche", "étapes", "outils"],
            "moyens": ["moyens humains", "moyens matériels", "moyens financiers"],
            "budget": ["plan de financement", "coûts détaillés", "sources de financement"],
            "planning": ["calendrier détaillé", "jalons", "livrables"],
            "equipe": ["compétences", "rôles", "responsabilités"],
            "partenaires": ["rôles des partenaires", "engagements", "contributions"],
            "innovation": ["caractère innovant", "plus-value", "originalité"],
            "impact": ["impact social", "impact environnemental", "impact économique"],
            "evaluation": ["indicateurs", "méthodes d'évaluation", "outils de suivi"],
            "perennisation": ["stratégie long terme", "modèle économique", "perspectives"],
            "communication": ["plan de communication", "outils", "cibles"],
            "annexes": ["documents administratifs", "lettres de soutien", "études"]
        }

    def setup_logging(self):
        """Configuration des logs avec gestion de l'encodage"""
        if sys.platform == 'win32':
            logging.basicConfig(
                level=logging.INFO,
                format='%(asctime)s - %(levelname)s - %(message)s',
                handlers=[
                    logging.FileHandler('aap_analyzer.log', encoding='utf-8'),
                    logging.StreamHandler(sys.stdout)
                ]
            )
        else:
            logging.basicConfig(
                level=logging.INFO,
                format='%(asctime)s - %(levelname)s - %(message)s',
                handlers=[
                    logging.FileHandler('aap_analyzer.log'),
                    logging.StreamHandler()
                ]
            )
        self.logger = logging.getLogger(__name__)

    def ask_mixtral(self, prompt: str) -> str:
        """Envoie une requête à Mixtral pour analyse et compréhension du texte"""
        try:
            response = requests.post(
                OLLAMA_HOST,
                json={
                    "model": "mixtral",
                    "prompt": prompt,
                    "stream": False,
                    "temperature": 0.3
                },
                timeout=240
            )
            
            if response.status_code == 200:
                return response.json().get("response", "Erreur: pas de réponse")
            else:
                self.logger.error(f"Erreur Mixtral - Status code: {response.status_code}")
                return "Erreur: réponse invalide"
        except Exception as e:
            self.logger.error(f"Erreur connexion Mixtral: {str(e)}")
            return "Erreur: problème de connexion"
    
    def _extract_from_pdf(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier PDF"""
        sections = {}
        current_section = "Introduction"
        current_content = []
        
        try:
            with open(file_path, 'rb') as file:
                reader = PyPDF2.PdfReader(file)
                for page in reader.pages:
                    content = page.extract_text()
                    lines = content.split('\n')
                    
                    for line in lines:
                        line = line.strip()
                        if not line:
                            continue
                        
                        # Détection d'une nouvelle section
                        if line.startswith('###') or line.isupper():
                            if current_content:
                                sections[current_section] = "\n".join(current_content)
                            current_section = line.strip('#').strip()
                            current_content = []
                        else:
                            current_content.append(line)
            
            # Ajouter la dernière section
            if current_content:
                sections[current_section] = "\n".join(current_content)
                
            return sections
            
        except Exception as e:
            print(f"❌ Erreur PDF {file_path}: {e}")
            return {}

    def _extract_from_excel(self, file_path: str) -> Dict[str, str]:
        """Extrait le texte d'un fichier Excel"""
        sections = {}
        
        try:
            df = pd.read_excel(file_path)
            for col in df.columns:
                if isinstance(col, str) and col.strip():
                    content = df[col].dropna().astype(str).tolist()
                    if content:
                        sections[col] = "\n".join(content)
            return sections
            
        except Exception as e:
            print(f"❌ Erreur Excel {file_path}: {e}")
            return {}

    def extract_text_by_sections(self, file_path: str) -> Dict[str, Any]:
        """Extrait le texte et la structure d'un document"""
        try:
            file_path_lower = file_path.lower()
            if file_path_lower.endswith('.docx'):
                return self._extract_from_docx(file_path)
            elif file_path_lower.endswith('.pdf'):
                return self._extract_from_pdf(file_path)
            elif file_path_lower.endswith(('.xlsx', '.xls')):
                return self._extract_from_excel(file_path)
            else:
                self.logger.warning(f"Format non supporté: {file_path}")
                return {}
        except Exception as e:
            self.logger.error(f"Erreur extraction {file_path}: {str(e)}")
            return {}

    def _extract_from_docx(self, file_path: str) -> Dict[str, Any]:
        """Extraction améliorée des documents Word avec structure"""
        sections = {}
        try:
            doc = Document(file_path)
            current_section = "Introduction"
            sections[current_section] = []
            
            for para in doc.paragraphs:
                text = para.text.strip()
                if not text:
                    continue
                
                if para.style and "Heading" in para.style.name:
                    current_section = text
                    sections[current_section] = []
                else:
                    sections[current_section].append(text)
            
            return {sec: " ".join(content) for sec, content in sections.items() if content}
            
        except Exception as e:
            self.logger.error(f"Erreur Word {file_path}: {str(e)}")
            return {}

    def analyze_themes(self, text: str) -> Dict[str, float]:
        """Analyse les thèmes présents dans un texte"""
        themes_scores = {}
        text_lower = text.lower()
        
        for theme, patterns in self.theme_patterns.items():
            score = 0
            for pattern in patterns:
                if pattern in text_lower:
                    score += text_lower.count(pattern)
            if score > 0:
                themes_scores[theme] = score
                
        # Normalisation des scores
        if themes_scores:
            max_score = max(themes_scores.values())
            themes_scores = {k: v/max_score for k, v in themes_scores.items()}
            
        return themes_scores

    def calculate_similarity(self, text1: str, text2: str) -> float:
        """Calcule la similarité entre deux textes"""
        vectorizer = TfidfVectorizer()
        try:
            tfidf_matrix = vectorizer.fit_transform([text1, text2])
            return cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
        except:
            return 0.0

    def analyze_aap_files(self) -> Dict[str, Any]:
        """Analyse complète des fichiers AAP"""
        # Vérifier la connexion à Mixtral
        try:
            response = requests.get("http://localhost:11434/api/version")
            if response.status_code != 200:
                self.logger.error("Mixtral n'est pas accessible")
                return {}
        except:
            self.logger.error("Impossible de se connecter à Mixtral")
            return {}

        # Recherche de tous les AAPs dans le dossier data
        aap_files = []
        for path in Path(self.data_dir).rglob("*"):
            if path.is_file() and "AAP" in path.name.upper() and path.suffix.lower() in ['.docx', '.pdf', '.xlsx', '.xls']:
                aap_files.append(path)

        if not aap_files:
            self.logger.error(f"Aucun fichier AAP trouvé dans {self.data_dir}")
            return {}

        self.logger.info(f"Analyse de {len(aap_files)} fichiers AAP")

        # Analyse des documents
        analyses = {}
        processing_times = {}
        similarities = defaultdict(dict)
        total_start_time = time.time()

        # Analyse de chaque AAP
        for aap_path in aap_files:
            self.logger.info(f"Analyse de {aap_path.name}")
            start_time = time.time()

            try:
                # Extraction et analyse des sections
                aap_sections = self.extract_text_by_sections(str(aap_path))
                if not aap_sections:
                    continue

                # Analyse des thèmes par section
                section_themes = {}
                section_similarities = {}
                
                for section, content in aap_sections.items():
                    # Analyse thématique
                    section_themes[section] = self.analyze_themes(content)

                # Construction du prompt pour l'analyse détaillée
                prompt = f"""
                Analyse détaillée du document {aap_path.name}.
                
                Sections trouvées : {list(aap_sections.keys())}
                
                Pour chaque thématique, évalue :
                1. La couverture du contenu (✅ complète, ⚠️ partielle, ❌ absente)
                2. La pertinence du contenu
                3. Les éléments manquants ou à améliorer
                
                Thématiques à analyser :
                {list(self.theme_patterns.keys())}
                
                Format de réponse souhaité :
                - ✅ [Thème] : Bien couvert, avec [détails]
                - ⚠️ [Thème] : Partiellement couvert, manque [éléments]
                - ❌ [Thème] : Absent, devrait inclure [suggestions]
                """

                # Analyse avec Mixtral
                analysis_result = self.ask_mixtral(prompt)

                # Calcul du temps et enregistrement des résultats
                processing_time = time.time() - start_time
                
                analyses[aap_path.name] = {
                    "file_path": str(aap_path),
                    "sections": aap_sections,
                    "themes": section_themes,
                    "analysis": analysis_result,
                    "processing_time": processing_time
                }
                
                processing_times[aap_path.name] = processing_time

            except Exception as e:
                self.logger.error(f"Erreur analyse {aap_path.name}: {str(e)}")
                continue

        total_time = time.time() - total_start_time

        # Génération du rapport
        report = self.generate_report(analyses, processing_times, total_time)

        return {
            "analyses": analyses,
            "processing_times": processing_times,
            "total_time": total_time,
            "report": report
        }

    def analyze_common_themes(self, analyses: Dict[str, Dict]) -> Dict[str, Any]:
        """Analyse les thèmes communs et uniques entre les AAP"""
        # Initialisation des dictionnaires pour stocker les thèmes par document
        themes_by_doc = {}
        all_themes = set()
        
        # Collecte des thèmes pour chaque document
        for doc_name, doc_data in analyses.items():
            doc_themes = set()
            for section_themes in doc_data["themes"].values():
                doc_themes.update(section_themes.keys())
            themes_by_doc[doc_name] = doc_themes
            all_themes.update(doc_themes)
        
        # Identification des thèmes communs à tous les documents
        common_themes = set.intersection(*themes_by_doc.values()) if themes_by_doc else set()
        
        # Identification des thèmes uniques par document
        unique_themes = {}
        for doc_name, themes in themes_by_doc.items():
            other_docs_themes = set.union(*[t for n, t in themes_by_doc.items() if n != doc_name]) if len(themes_by_doc) > 1 else set()
            unique_themes[doc_name] = themes - other_docs_themes
        
        return {
            "common_themes": list(common_themes),
            "unique_themes": {k: list(v) for k, v in unique_themes.items()},
            "all_themes": list(all_themes)
        }

    def analyze_section_completeness(self, section_content: str, section_name: str) -> Dict[str, Any]:
        """Analyse la complétude d'une section par rapport aux exigences"""
        requirements = self.section_requirements.get(section_name, [])
        completeness = {}
        
        for req in requirements:
            # Calcul du score de présence pour chaque exigence
            score = sum(1 for word in req.split() if word.lower() in section_content.lower())
            completeness[req] = {
                "present": score > 0,
                "score": score / len(req.split())  # Score normalisé
            }
            
        return {
            "requirements_met": sum(1 for req in completeness.values() if req["present"]),
            "total_requirements": len(requirements),
            "details": completeness,
            "completion_rate": sum(req["score"] for req in completeness.values()) / len(requirements) if requirements else 0
        }

    def analyze_aap_statistics(self, analyses: Dict[str, Dict]) -> Dict[str, Any]:
        """Génère des statistiques détaillées pour chaque AAP"""
        stats = {}
        
        for doc_name, doc_data in analyses.items():
            doc_stats = {
                "section_coverage": {},
                "theme_coverage": {},
                "global_stats": {
                    "total_sections": len(doc_data["sections"]),
                    "total_themes": len(doc_data["themes"]),
                    "average_completion": 0
                }
            }
            
            # Analyse de la couverture des sections
            total_completion = 0
            for section_name, content in doc_data["sections"].items():
                completeness = self.analyze_section_completeness(content, section_name)
                doc_stats["section_coverage"][section_name] = completeness
                total_completion += completeness["completion_rate"]
            
            # Calcul des moyennes
            doc_stats["global_stats"]["average_completion"] = (
                total_completion / len(doc_data["sections"]) if doc_data["sections"] else 0
            )
            
            # Analyse des thèmes
            for section, themes in doc_data["themes"].items():
                for theme, score in themes.items():
                    if theme not in doc_stats["theme_coverage"]:
                        doc_stats["theme_coverage"][theme] = {
                            "total_score": 0,
                            "occurrences": 0
                        }
                    doc_stats["theme_coverage"][theme]["total_score"] += score
                    doc_stats["theme_coverage"][theme]["occurrences"] += 1
            
            # Calcul des scores moyens des thèmes
            for theme_stats in doc_stats["theme_coverage"].values():
                theme_stats["average_score"] = (
                    theme_stats["total_score"] / theme_stats["occurrences"]
                    if theme_stats["occurrences"] > 0 else 0
                )
            
            stats[doc_name] = doc_stats
        
        return stats

    def generate_report(self, analyses: Dict[str, Dict], processing_times: Dict[str, float], total_time: float) -> str:
        """Génération d'un rapport détaillé"""
        report = []
        report.append("📊 ANALYSE DES AAP")
        report.append(f"Date de l'analyse : {datetime.now().isoformat()}")
        report.append(f"Nombre de documents analysés : {len(analyses)}")
        
        # Analyse comparative des thèmes
        theme_comparison = self.analyze_common_themes(analyses)
        
        # Statistiques détaillées
        stats = self.analyze_aap_statistics(analyses)
        
        report.append("\n📈 STATISTIQUES GLOBALES")
        for doc_name, doc_stats in stats.items():
            report.append(f"\n=== {doc_name} ===")
            report.append(f"Taux de complétion moyen : {doc_stats['global_stats']['average_completion']*100:.1f}%")
            report.append(f"Nombre de sections : {doc_stats['global_stats']['total_sections']}")
            
            report.append("\nCouverture des sections :")
            for section, coverage in doc_stats["section_coverage"].items():
                completion = coverage["completion_rate"] * 100
                requirements_met = coverage["requirements_met"]
                total_req = coverage["total_requirements"]
                
                if completion >= 75:
                    status = "✅"
                elif completion >= 40:
                    status = "⚠️"
                else:
                    status = "❌"
                
                report.append(f"{status} {section}: {completion:.1f}% ({requirements_met}/{total_req} critères)")
                
                # Détails des exigences non satisfaites
                missing_reqs = [
                    req for req, details in coverage["details"].items()
                    if not details["present"]
                ]
                if missing_reqs:
                    report.append("   Éléments manquants :")
                    for req in missing_reqs:
                        report.append(f"   - {req}")
            
            report.append("\nCouverture thématique :")
            for theme, coverage in doc_stats["theme_coverage"].items():
                score = coverage["average_score"] * 100
                if score >= 75:
                    status = "✅"
                elif score >= 40:
                    status = "⚠️"
                else:
                    status = "❌"
                report.append(f"{status} {theme}: {score:.1f}%")
        
        report.append("\n🔄 ANALYSE COMPARATIVE DES THÈMES")
        report.append("\n📌 Thèmes communs à tous les AAP :")
        if theme_comparison["common_themes"]:
            for theme in theme_comparison["common_themes"]:
                report.append(f"• {theme}")
        else:
            report.append("Aucun thème commun trouvé")
            
        report.append("\n🎯 Thèmes uniques par AAP :")
        for doc_name, unique in theme_comparison["unique_themes"].items():
            report.append(f"\n{doc_name}:")
            if unique:
                for theme in unique:
                    report.append(f"• {theme}")
            else:
                report.append("Aucun thème unique")
        
        # Temps de traitement
        report.append("\n⏱️ TEMPS DE TRAITEMENT")
        report.append(f"Temps total : {total_time:.2f} secondes")
        report.append("\nTemps par document :")
        for doc, time_spent in processing_times.items():
            report.append(f"• {doc}: {time_spent:.2f} secondes")
        
        return "\n".join(report)

def check_mixtral():
    """Vérifie si Mixtral est accessible"""
    try:
        response = requests.get("http://localhost:11434/api/version")
        return response.status_code == 200
    except:
        return False

def main():
    print("🔄 Vérification de Mixtral...")
    if not check_mixtral():
        print("❌ Erreur: Mixtral n'est pas accessible. Assurez-vous qu'il est lancé sur le port 11434")
        return

    print("🔍 Initialisation de l'analyse...")
    analyzer = AAPAnalyzer("../data")
    
    try:
        results = analyzer.analyze_aap_files()
        
        if results:
            print("\n=== Rapport d'Analyse ===")
            print(results["report"])
            
            # Sauvegarde des résultats
            with open("analyse_aap_complete.json", "w", encoding="utf-8") as f:
                json.dump(results, f, ensure_ascii=False, indent=2)
            
            print("\n💾 Résultats détaillés sauvegardés dans analyse_aap_complete.json")
        else:
            print("\n❌ Aucun résultat d'analyse disponible")
        
    except Exception as e:
        print(f"❌ Erreur lors de l'analyse: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# 🔄 Vérification de Mixtral...
# 🔍 Initialisation de l'analyse...
# 2025-03-11 09:15:22,729 - INFO - Analyse de 31 fichiers AAP
# 2025-03-11 09:15:22,730 - INFO - Analyse de Guide Pratique Réponse AAP (Groupe SOS).pdf
